# %% [markdown]
# # UCI mHealth Classification - CNN-Transformer
# - https://archive.ics.uci.edu/dataset/319/mhealth+dataset
#
# #### 데이터 구조
# - 10명의 참가자별로 mHealth_subject<SUBJECT_ID>.log 파일 존재
# - 가속도, 자이로, 자기장, 심전도 -> 총 23개의 feature
#
# #### 라벨
# 0. Other
# 1. Standing still
# 2. Sitting and relaxing
# 3. Lying down
# 4. Walking
# 5. Climbing stairs
# 6. Waist bends forward
# 7. Frontal elevation of arms
# 8. Knees bending (crouching)
# 9. Cycling
# 10. Jogging
# 11. Running
# 12. Jump front & back

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Conv1D, BatchNormalization, ReLU, MaxPool1D, GlobalAveragePooling1D, MultiHeadAttention, LayerNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils import resample
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
LABELS = [
    'Other', 'Standing', 'Sitting', 'Lying', 'Walking',
    'Climbing stairs', 'Waist bends', 'Frontal elevation',
    'Knees bending', 'Cycling', 'Jogging', 'Running', 'Jumping'
]

# %%
base_dir = "/content/drive/MyDrive/AI_data/MHEALTHDATASET"
dfs = []
col_names = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg1', 'ecg2',
    'acc_left_ankle_x', 'acc_left_ankle_y', 'acc_left_ankle_z',
    'gyro_left_ankle_x', 'gyro_left_ankle_y', 'gyro_left_ankle_z',
    'magnet_left_ankle_x', 'magnet_left_ankl6e_y', 'magnet_left_ankle_z',
    'acc_right_arm_x', 'acc_right_arm_y', 'acc_right_arm_z',
    'gyro_right_arm_x', 'gyro_right_arm_y', 'gyro_right_arm_z',
    'magnet_right_arm_x', 'magnet_right_arm_y', 'magnet_right_arm_z',
    'label', 'subject'
]

for i in range(1, 11):
    path = os.path.join(base_dir, f"mHealth_subject{i}.log")
    df_i = pd.read_csv(path, sep='\t', header=None)
    df_i['subject'] = i
    dfs.append(df_i)

df = pd.concat(dfs, ignore_index=True)
df = df.dropna(how='any', axis=0)
df.columns = col_names
df
# Out:
#          acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0            -9.8184     0.009971      0.29563  0.004186  0.004186
# 1            -9.8489     0.524040      0.37348  0.004186  0.016745
# 2            -9.6602     0.181850      0.43742  0.016745  0.037677
# 3            -9.6507     0.214220      0.24033  0.079540  0.117220
# 4            -9.7030     0.303890      0.31156  0.221870  0.205130
# ...              ...          ...          ...       ...       ...
# 1215740      -9.2476    -0.248070     -2.62230  0.230250  0.234430
# 1215741      -9.4632    -0.073513     -2.11190  0.276300  0.284670
# 1215742      -9.4011    -0.144580     -3.02350  0.288850  0.301410
# 1215743      -9.3732    -0.026252     -2.70760  0.351650  0.347460
# 1215744      -9.3518    -0.592450     -2.63230  0.280480  0.272110
#
#          acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0                  2.1849           -9.6967           0.63077
# 1                  2.3876           -9.5080           0.68389
# 2                  2.4086           -9.5674           0.68113
# 3                  2.1814           -9.4301           0.55031
# 4                  2.4173           -9.3889           0.71098
# ...                   ...               ...               ...
# 1215740            1.7849           -9.8287           0.29725
# 1215741            1.8687           -9.8766           0.46236
# 1215742            1.6928           -9.9290           0.16631
# 1215743            1.5279           -9.6306           0.30458
# 1215744            1.6614           -9.8398           0.18088
#
#          gyro_left_ankle_x  gyro_left_ankle_y  ...  acc_right_arm_y  \
# 0                 0.103900           -0.84053  ...          -4.5781
# 1                 0.085343           -0.83865  ...          -4.3198
# 2                 0.085343           -0.83865  ...          -4.2772
# 3                 0.085343           -0.83865  ...          -4.3163
# 4                 0.085343           -0.83865  ...          -4.1459
# ...                    ...                ...  ...              ...
# 1215740          -0.341370           -0.90056  ...          -8.9071
# 1215741          -0.341370           -0.90056  ...          -8.7455
# 1215742          -0.341370           -0.90056  ...          -9.1155
# 1215743          -0.341370           -0.90056  ...          -9.1441
# 1215744          -0.332100           -0.90432  ...          -8.9324
#
#          acc_right_arm_z  gyro_right_arm_x  gyro_right_arm_y  \
# 0               0.187760         -0.449020          -1.01030
# 1               0.023595         -0.449020          -1.01030
# 2               0.275720         -0.449020          -1.01030
# 3               0.367520         -0.456860          -1.00820
# 4               0.407290         -0.456860          -1.00820
# ...                  ...               ...               ...
# 1215740         0.294230          0.041176          -0.99384
# 1215741         0.448140          0.041176          -0.99384
# 1215742         0.450480          0.041176          -0.99384
# 1215743         0.594880          0.041176          -0.99384
# 1215744         0.761710          0.035294          -1.02050
#
#          gyro_right_arm_z  magnet_right_arm_x  magnet_right_arm_y  \
# 0                0.034483            -2.35000           -1.610200
# 1                0.034483            -2.16320           -0.882540
# 2                0.034483            -1.61750           -0.165620
# 3                0.025862            -1.07710            0.006945
# 4                0.025862            -0.53684            0.175900
# ...                   ...                 ...                 ...
# 1215740         -0.480600             2.40890            7.496100
# 1215741         -0.480600             1.69450            7.866000
# 1215742         -0.480600             1.15770            8.052800
# 1215743         -0.480600             0.27441            9.487900
# 1215744         -0.471980            -0.98056            9.663600
#
#          magnet_right_arm_z  label  subject
# 0                 -0.030899      0        1
# 1                  0.326570      0        1
# 2                 -0.030693      0        1
# 3                 -0.382620      0        1
# 4                 -1.095500      0        1
# ...                     ...    ...      ...
# 1215740            7.915500      0       10
# 1215741            7.897500      0       10
# 1215742            7.884900      0       10
# 1215743            5.325800      0       10
# 1215744            3.493900      0       10
#
# [1215745 rows x 25 columns]

# %%
df.label.value_counts()
# Out:
# label
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 5      30720
# 11     30720
# 10     30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: count, dtype: int64

# %%
# downsampling
from sklearn.utils import resample

df_majority = df[df.label==0]
df_minorities = df[df.label!=0]

df_majority_downsampled = resample(df_majority, n_samples=30000, random_state=42)
df = pd.concat([df_majority_downsampled, df_minorities])
df.label.value_counts()
# Out:
# label
# 1     30720
# 3     30720
# 2     30720
# 4     30720
# 9     30720
# 11    30720
# 5     30720
# 10    30720
# 0     30000
# 7     29441
# 8     29337
# 6     28315
# 12    10342
# Name: count, dtype: int64

# %%
# df.to_csv('/content/drive/MyDrive/AI_data/MHEALTHDATASET/mhealth_resampled_data.csv',index = False)

# %%
df.isnull().sum()
# Out:
# acc_chest_x             0
# acc_chest_y             0
# acc_chest_z             0
# ecg1                    0
# ecg2                    0
# acc_left_ankle_x        0
# acc_left_ankle_y        0
# acc_left_ankle_z        0
# gyro_left_ankle_x       0
# gyro_left_ankle_y       0
# gyro_left_ankle_z       0
# magnet_left_ankle_x     0
# magnet_left_ankl6e_y    0
# magnet_left_ankle_z     0
# acc_right_arm_x         0
# acc_right_arm_y         0
# acc_right_arm_z         0
# gyro_right_arm_x        0
# gyro_right_arm_y        0
# gyro_right_arm_z        0
# magnet_right_arm_x      0
# magnet_right_arm_y      0
# magnet_right_arm_z      0
# label                   0
# subject                 0
# dtype: int64

# %%
# 피험자 1-6: 훈련, 피험자 7-8: 검증, 피험자 8-9: 테스트
train = df[~df['subject'].isin([7, 8, 9, 10])]
val = df[df['subject'].isin([7, 8])]
test = df[df['subject'].isin([9, 10])]

train.shape, val.shape, test.shape
# Out:
# ((226128, 25), (73326, 25), (73741, 25))

# %%
X_train = train.drop(['label','subject'], axis=1)
y_train = train['label']

X_val = val.drop(['label','subject'], axis=1)
y_val = val['label']

X_test = test.drop(['label','subject'], axis=1)
y_test = test['label']

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((226128, 23), (226128,), (73326, 23), (73326,), (73741, 23), (73741,))

# %%
sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)
X_val = pd.DataFrame(sc.transform(X_val), columns=X_val.columns)
X_test = pd.DataFrame(sc.transform(X_test), columns=X_train.columns)

X_train
# Out:
#         acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0         -0.087384    -0.180627    -0.786215  0.007915 -0.011472
# 1         -0.328788    -0.300078     0.605666 -0.081073 -0.087624
# 2          0.241808     0.040644    -0.641235  0.070732 -0.107931
# 3         -0.354832    -0.009466     0.177121 -0.447507 -1.224823
# 4          0.244441     0.152781    -0.843392 -0.332342 -0.184085
# ...             ...          ...          ...       ...       ...
# 226123    -0.998367     0.135213    -0.547845 -0.248588 -0.544528
# 226124    -1.148293     0.104779    -0.661009 -0.180527 -0.544528
# 226125    -1.076286     0.134339    -1.033485 -0.107247 -0.534377
# 226126    -0.955557     0.620911    -1.302284  0.002681 -0.427768
# 226127    -1.031326     1.212066    -1.397428  0.028855 -0.493764
#
#         acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0              -0.577582          0.733111          0.855263
# 1              -0.048897         -0.100417          0.083515
# 2               0.010368          0.093603         -0.501927
# 3              -0.497284         -0.085610          0.353416
# 4              -1.151754         -0.146134         -0.361905
# ...                  ...               ...               ...
# 226123         -0.299251         -0.707677          0.882140
# 226124          0.232369         -0.590383          0.757580
# 226125          1.156834         -0.723743          0.356439
# 226126          0.927660         -0.718710         -0.643712
# 226127          0.327690         -1.632098         -1.826351
#
#         gyro_left_ankle_x  gyro_left_ankle_y  ...  magnet_left_ankle_z  \
# 0                0.283638          -0.578020  ...            -0.402525
# 1               -0.577486          -0.415903  ...             0.011245
# 2               -0.867129           0.049140  ...             0.540380
# 3               -1.442512          -0.458564  ...            -0.030661
# 4                1.782740           0.484325  ...             2.124397
# ...                   ...                ...  ...                  ...
# 226123          -0.432654          -0.603626  ...             0.449349
# 226124          -0.432654          -0.603626  ...             0.287044
# 226125          -0.432654          -0.603626  ...             0.031366
# 226126          -0.354383          -0.629232  ...             0.009413
# 226127          -0.354383          -0.629232  ...            -0.011482
#
#         acc_right_arm_x  acc_right_arm_y  acc_right_arm_z  gyro_right_arm_x  \
# 0             -0.878509        -0.115785         0.092842         -1.287582
# 1              0.142070        -0.403044         0.292032         -1.181228
# 2              0.419364        -0.149160        -0.108985         -0.159630
# 3              0.347123        -0.554803        -0.268771          0.292298
# 4             -0.463871        -0.334905        -0.028403         -0.584985
# ...                 ...              ...              ...               ...
# 226123        -0.424959        -0.777297         0.256151         -0.190019
# 226124        -0.667105        -1.022036         0.412414         -0.190019
# 226125        -0.789524        -1.428916         0.539305         -0.190019
# 226126        -0.565365        -1.578079         0.372380         -0.190019
# 226127        -0.266865        -1.285248         0.331576         -0.045704
#
#         gyro_right_arm_y  gyro_right_arm_z  magnet_right_arm_x  \
# 0               0.881529         -0.227001            0.355856
# 1              -0.788334         -0.017597           -0.007098
# 2              -0.799296         -1.414959           -0.118250
# 3              -1.000270         -1.567971            0.008544
# 4              -0.481392          0.522008            0.201140
# ...                  ...               ...                 ...
# 226123         -1.164606         -0.086059           -0.832750
# 226124         -1.164606         -0.086059           -0.891081
# 226125         -1.164606         -0.086059           -0.798699
# 226126         -1.164606         -0.086059           -0.468607
# 226127         -1.259630         -0.118272           -0.137930
#
#         magnet_right_arm_y  magnet_right_arm_z
# 0                -0.757309            0.065910
# 1                -0.073927           -0.046895
# 2                -0.093139           -0.227639
# 3                -0.094608           -0.020982
# 4                 0.141492           -0.024674
# ...                    ...                 ...
# 226123           -0.733695           -0.744858
# 226124           -1.279427           -0.798790
# 226125           -2.073697           -0.786247
# 226126           -2.871990           -0.626123
# 226127           -3.089391           -0.301282
#
# [226128 rows x 23 columns]

# %% [markdown]
# ### create_dataset
# - X에 dataframe을 입력 -> 여러 개의 columns
# - x.shape이 (time_steps, n_features)이기 때문에 Xs.shape은 (n_samples, time_steps, n_features). 따라서 reshape이 필요 없음
# - ys: 윈도우 내 최빈값을 라벨로 설정, 1D 리스트
# - sklearn, keras에서 y를 (n_samples, 1) 형태로 사용하기 때문에 reshape

# %%
def create_dataset(X, y, time_steps, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        x = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(x)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

# %%
TIME_STEPS = 200
STEPS = 40

X_train, y_train = create_dataset(X_train, y_train, TIME_STEPS, STEPS)
X_val, y_val = create_dataset(X_val, y_val, TIME_STEPS, STEPS)
X_test, y_test = create_dataset(X_test, y_test, TIME_STEPS, STEPS)

print(f"Training sequences: {X_train.shape}")
print(f"Validation sequences: {X_val.shape}")
print(f"Test sequences: {X_test.shape}")
# Out:
# Training sequences: (5649, 200, 23)
# Validation sequences: (1829, 200, 23)
# Test sequences: (1839, 200, 23)

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, Transformer 1
# - Conv1D 출력과 TransformerBlock의 embed_dim 수가 일치해야함
# - residual addition 할 때 shape이 맞아야 하기 때문

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_1             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 479,629 (1.83 MB)
#  Trainable params: 478,861 (1.83 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.7145 - sparse_categorical_accuracy: 0.7894
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.73975, saving model to UCI_mHealth_CNN_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step - loss: 0.7098 - sparse_categorical_accuracy: 0.7908 - val_loss: 0.8439 - val_sparse_categorical_accuracy: 0.7397
# Epoch 2/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9901
# Epoch 2: val_sparse_categorical_accuracy improved from 0.73975 to 0.74248, saving model to UCI_mHealth_CNN_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.7104 - val_sparse_categorical_accuracy: 0.7425
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0507 - sparse_categorical_accuracy: 0.9852
# Epoch 3: val_sparse_categorical_accuracy improved from 0.74248 to 0.87808, saving model to UCI_mHealth_CNN_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0507 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.5257 - val_sparse_categorical_accuracy: 0.8781
# Epoch 4/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9880
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0449 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.6150 - val_sparse_categorical_accuracy: 0.7693
# Epoch 5/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9955
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.8958 - val_sparse_categorical_accuracy: 0.7753
# Epoch 6/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9899
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9898 - val_loss: 1.5187 - val_sparse_categorical_accuracy: 0.7698
# Epoch 7/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9927
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.7357 - val_sparse_categorical_accuracy: 0.8283
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9955
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.9193 - val_sparse_categorical_accuracy: 0.8190
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 0.8469
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9950
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0172 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.6273 - val_sparse_categorical_accuracy: 0.8491
# Epoch 11/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9911
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.87808
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9911 - val_loss: 1.0345 - val_sparse_categorical_accuracy: 0.8092
# Epoch 12/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9903
# Epoch 12: val_sparse_categorical_accuracy improved from 0.87808 to 0.92346, saving model to UCI_mHealth_CNN_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0240 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.3372 - val_sparse_categorical_accuracy: 0.9235
# Epoch 13/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9964
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.3922 - val_sparse_categorical_accuracy: 0.8830
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9984
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.8077 - val_sparse_categorical_accuracy: 0.8885
# Epoch 15/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9962
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.2361 - val_sparse_categorical_accuracy: 0.8108
# Epoch 16/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9966
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.1272 - val_sparse_categorical_accuracy: 0.8371
# Epoch 17/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9922
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0273 - sparse_categorical_accuracy: 0.9922 - val_loss: 1.0655 - val_sparse_categorical_accuracy: 0.8436
# Epoch 18/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9950
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9950 - val_loss: 2.0656 - val_sparse_categorical_accuracy: 0.7004
# Epoch 19/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9967
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.4499 - val_sparse_categorical_accuracy: 0.8168
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9978
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.5388 - val_sparse_categorical_accuracy: 0.8054
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9983
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.4304 - val_sparse_categorical_accuracy: 0.8453
# Epoch 22/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9941
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9942 - val_loss: 1.2357 - val_sparse_categorical_accuracy: 0.8316
# Epoch 23/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9979
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9979 - val_loss: 1.1533 - val_sparse_categorical_accuracy: 0.8409
# Epoch 24/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9904
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9903 - val_loss: 2.3957 - val_sparse_categorical_accuracy: 0.7589
# Epoch 25/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0526 - sparse_categorical_accuracy: 0.9841
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.4039 - val_sparse_categorical_accuracy: 0.7868
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9928
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9928 - val_loss: 1.4467 - val_sparse_categorical_accuracy: 0.7709
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9978
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.1667 - val_sparse_categorical_accuracy: 0.8075
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9964
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.7709 - val_sparse_categorical_accuracy: 0.8480
# Epoch 29/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9982
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0042 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.9813 - val_sparse_categorical_accuracy: 0.8491
# Epoch 30/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9994
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.7887 - val_sparse_categorical_accuracy: 0.8677
# Epoch 31/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991 - val_loss: 1.0004 - val_sparse_categorical_accuracy: 0.8573
# Epoch 32/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9994
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.92346
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.0896 - val_sparse_categorical_accuracy: 0.8644
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.68%
# Training loss: 0.0078
# Test accuracy: 95.11%
# Test loss: 0.1985

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9929    1.0000    0.9964       140
#            1     1.0000    0.9935    0.9967       154
#            2     1.0000    0.5000    0.6667       154
#            3     0.9935    1.0000    0.9967       153
#            4     0.9808    0.9935    0.9871       154
#            5     1.0000    0.9935    0.9967       154
#            6     1.0000    0.9774    0.9886       133
#            7     0.6422    0.9929    0.7799       141
#            8     1.0000    0.9863    0.9931       146
#            9     0.9871    1.0000    0.9935       153
#           10     0.9872    1.0000    0.9935       154
#           11     1.0000    0.9740    0.9868       154
#           12     0.9423    1.0000    0.9703        49
#
#     accuracy                         0.9511      1839
#    macro avg     0.9635    0.9547    0.9497      1839
# weighted avg     0.9662    0.9511    0.9487      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 3, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_7 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_3             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_3      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 529,421 (2.02 MB)
#  Trainable params: 528,397 (2.02 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.6200 - sparse_categorical_accuracy: 0.8097
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.67195, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - loss: 0.6159 - sparse_categorical_accuracy: 0.8109 - val_loss: 1.1765 - val_sparse_categorical_accuracy: 0.6720
# Epoch 2/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9853
# Epoch 2: val_sparse_categorical_accuracy improved from 0.67195 to 0.70804, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 22s 19ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9854 - val_loss: 1.0505 - val_sparse_categorical_accuracy: 0.7080
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9884
# Epoch 3: val_sparse_categorical_accuracy improved from 0.70804 to 0.76490, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.9203 - val_sparse_categorical_accuracy: 0.7649
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9931
# Epoch 4: val_sparse_categorical_accuracy improved from 0.76490 to 0.78185, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0207 - sparse_categorical_accuracy: 0.9931 - val_loss: 1.0501 - val_sparse_categorical_accuracy: 0.7818
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9884
# Epoch 5: val_sparse_categorical_accuracy improved from 0.78185 to 0.79497, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0291 - sparse_categorical_accuracy: 0.9885 - val_loss: 1.2760 - val_sparse_categorical_accuracy: 0.7950
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9965
# Epoch 6: val_sparse_categorical_accuracy improved from 0.79497 to 0.82723, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9965 - val_loss: 1.0946 - val_sparse_categorical_accuracy: 0.8272
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9892
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.82723
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9892 - val_loss: 1.6805 - val_sparse_categorical_accuracy: 0.8174
# Epoch 8/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9811
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.82723
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9812 - val_loss: 1.1250 - val_sparse_categorical_accuracy: 0.7922
# Epoch 9/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0159 - sparse_categorical_accuracy: 0.9946
# Epoch 9: val_sparse_categorical_accuracy improved from 0.82723 to 0.84090, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.8238 - val_sparse_categorical_accuracy: 0.8409
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9943
# Epoch 10: val_sparse_categorical_accuracy improved from 0.84090 to 0.86878, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.5817 - val_sparse_categorical_accuracy: 0.8688
# Epoch 11/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9969
# Epoch 11: val_sparse_categorical_accuracy improved from 0.86878 to 0.88354, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.4224 - val_sparse_categorical_accuracy: 0.8835
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9971
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.9987 - val_sparse_categorical_accuracy: 0.8365
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9988
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.2199 - val_sparse_categorical_accuracy: 0.8518
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9959
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9959 - val_loss: 1.0498 - val_sparse_categorical_accuracy: 0.8611
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9985
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9985 - val_loss: 1.0723 - val_sparse_categorical_accuracy: 0.8475
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9990
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.9724 - val_sparse_categorical_accuracy: 0.8502
# Epoch 17/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9995
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9995 - val_loss: 1.2324 - val_sparse_categorical_accuracy: 0.8540
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0150 - sparse_categorical_accuracy: 0.9955
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9955 - val_loss: 2.6890 - val_sparse_categorical_accuracy: 0.6441
# Epoch 19/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9891
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9891 - val_loss: 1.4771 - val_sparse_categorical_accuracy: 0.8496
# Epoch 20/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9914
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9915 - val_loss: 1.7577 - val_sparse_categorical_accuracy: 0.8496
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9918
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9919 - val_loss: 2.1905 - val_sparse_categorical_accuracy: 0.8529
# Epoch 22/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9963
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.9711 - val_sparse_categorical_accuracy: 0.8453
# Epoch 23/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9944
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9944 - val_loss: 3.4295 - val_sparse_categorical_accuracy: 0.6359
# Epoch 24/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9936
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.7988 - val_sparse_categorical_accuracy: 0.8218
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9940
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9940 - val_loss: 1.6239 - val_sparse_categorical_accuracy: 0.8633
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9967
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.6039 - val_sparse_categorical_accuracy: 0.8721
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9992
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9992 - val_loss: 1.7517 - val_sparse_categorical_accuracy: 0.8431
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9995
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.88354
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9995 - val_loss: 1.7590 - val_sparse_categorical_accuracy: 0.8578
# Epoch 29/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9967
# Epoch 29: val_sparse_categorical_accuracy improved from 0.88354 to 0.88628, saving model to UCI_mHealth_CNN_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0152 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.8855 - val_sparse_categorical_accuracy: 0.8863
# Epoch 30/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9962
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9962 - val_loss: 2.1565 - val_sparse_categorical_accuracy: 0.8414
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9921
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9921 - val_loss: 3.1853 - val_sparse_categorical_accuracy: 0.7479
# Epoch 32/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9885
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9886 - val_loss: 1.8864 - val_sparse_categorical_accuracy: 0.8639
# Epoch 33/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9963
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.8700 - val_sparse_categorical_accuracy: 0.8393
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1321 - sparse_categorical_accuracy: 0.9784
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1314 - sparse_categorical_accuracy: 0.9785 - val_loss: 2.4139 - val_sparse_categorical_accuracy: 0.7365
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9956
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9956 - val_loss: 2.2519 - val_sparse_categorical_accuracy: 0.7999
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9942
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9942 - val_loss: 2.2284 - val_sparse_categorical_accuracy: 0.8021
# Epoch 37/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984 - val_loss: 2.1039 - val_sparse_categorical_accuracy: 0.8496
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9974
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9973 - val_loss: 2.2222 - val_sparse_categorical_accuracy: 0.8551
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9965
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9965 - val_loss: 2.0400 - val_sparse_categorical_accuracy: 0.8190
# Epoch 40/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9993
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9993 - val_loss: 2.2329 - val_sparse_categorical_accuracy: 0.8486
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9993
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9993 - val_loss: 2.1625 - val_sparse_categorical_accuracy: 0.8546
# Epoch 42/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9987
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9987 - val_loss: 2.1375 - val_sparse_categorical_accuracy: 0.8332
# Epoch 43/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9993
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9993 - val_loss: 2.3363 - val_sparse_categorical_accuracy: 0.8300
# Epoch 44/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9997
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9997 - val_loss: 2.3181 - val_sparse_categorical_accuracy: 0.8420
# Epoch 45/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9997
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998 - val_loss: 2.3814 - val_sparse_categorical_accuracy: 0.8420
# Epoch 46/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9994
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9994 - val_loss: 2.4737 - val_sparse_categorical_accuracy: 0.8529
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.1798e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 4.2108e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.5126 - val_sparse_categorical_accuracy: 0.8502
# Epoch 48/100
# 86/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8425e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 4.9026e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.6195 - val_sparse_categorical_accuracy: 0.8507
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.9847e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.88628
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 7.9498e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 2.7022 - val_sparse_categorical_accuracy: 0.8502
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 29.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 66 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.61%
# Training loss: 0.0104
# Test accuracy: 98.53%
# Test loss: 0.0375

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9872    1.0000    0.9935       154
#            2     1.0000    0.9935    0.9967       154
#            3     0.9935    1.0000    0.9967       153
#            4     1.0000    0.9935    0.9967       154
#            5     1.0000    0.9870    0.9935       154
#            6     0.8636    1.0000    0.9268       133
#            7     1.0000    1.0000    1.0000       141
#            8     1.0000    0.8493    0.9185       146
#            9     0.9935    1.0000    0.9967       153
#           10     1.0000    0.9935    0.9967       154
#           11     0.9935    1.0000    0.9968       154
#           12     0.9800    1.0000    0.9899        49
#
#     accuracy                         0.9853      1839
#    macro avg     0.9855    0.9859    0.9848      1839
# weighted avg     0.9869    0.9853    0.9853      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 3, Transformer 2

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_15 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_17 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_17 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_6             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_7             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_6      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 859,533 (3.28 MB)
#  Trainable params: 858,509 (3.27 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.6492 - sparse_categorical_accuracy: 0.7975
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.80098, saving model to UCI_mHealth_CNN_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 30s 156ms/step - loss: 0.6450 - sparse_categorical_accuracy: 0.7988 - val_loss: 0.5886 - val_sparse_categorical_accuracy: 0.8010
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9864
# Epoch 2: val_sparse_categorical_accuracy improved from 0.80098 to 0.90323, saving model to UCI_mHealth_CNN_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.9032
# Epoch 3/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9862
# Epoch 3: val_sparse_categorical_accuracy improved from 0.90323 to 0.93330, saving model to UCI_mHealth_CNN_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9863 - val_loss: 0.2215 - val_sparse_categorical_accuracy: 0.9333
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0261 - sparse_categorical_accuracy: 0.9928
# Epoch 4: val_sparse_categorical_accuracy improved from 0.93330 to 0.94259, saving model to UCI_mHealth_CNN_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.1914 - val_sparse_categorical_accuracy: 0.9426
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9947
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9947 - val_loss: 0.2490 - val_sparse_categorical_accuracy: 0.9404
# Epoch 6/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9812
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0658 - sparse_categorical_accuracy: 0.9811 - val_loss: 1.9602 - val_sparse_categorical_accuracy: 0.6063
# Epoch 7/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0405 - sparse_categorical_accuracy: 0.9858
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.1519 - val_sparse_categorical_accuracy: 0.7633
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9892
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9891 - val_loss: 1.0639 - val_sparse_categorical_accuracy: 0.8655
# Epoch 9/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9842
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.4902 - val_sparse_categorical_accuracy: 0.8578
# Epoch 10/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9941
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.4328 - val_sparse_categorical_accuracy: 0.8896
# Epoch 11/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9957
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.3214 - val_sparse_categorical_accuracy: 0.9328
# Epoch 12/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9975
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.6049 - val_sparse_categorical_accuracy: 0.8562
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9974
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9974 - val_loss: 1.7129 - val_sparse_categorical_accuracy: 0.7572
# Epoch 14/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9832
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0572 - sparse_categorical_accuracy: 0.9833 - val_loss: 1.8509 - val_sparse_categorical_accuracy: 0.8054
# Epoch 15/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9843
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0537 - sparse_categorical_accuracy: 0.9844 - val_loss: 1.0019 - val_sparse_categorical_accuracy: 0.8803
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9863
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.0425 - sparse_categorical_accuracy: 0.9863 - val_loss: 1.4211 - val_sparse_categorical_accuracy: 0.8119
# Epoch 17/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9935
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.9481 - val_sparse_categorical_accuracy: 0.8513
# Epoch 18/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9965
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.8920 - val_sparse_categorical_accuracy: 0.8814
# Epoch 19/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9863
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.5674 - val_sparse_categorical_accuracy: 0.7212
# Epoch 20/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9864
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9865 - val_loss: 1.1962 - val_sparse_categorical_accuracy: 0.7977
# Epoch 21/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9950
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9951 - val_loss: 1.0085 - val_sparse_categorical_accuracy: 0.7977
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9979
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.7513 - val_sparse_categorical_accuracy: 0.8065
# Epoch 23/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9981
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9980 - val_loss: 1.7638 - val_sparse_categorical_accuracy: 0.8168
# Epoch 24/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0204 - sparse_categorical_accuracy: 0.9941
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.94259
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9941 - val_loss: 1.9190 - val_sparse_categorical_accuracy: 0.8010
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 98 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 97.95%
# Training loss: 0.0687
# Test accuracy: 90.86%
# Test loss: 0.4631

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9872    1.0000    0.9935       154
#            2     1.0000    0.5000    0.6667       154
#            3     1.0000    1.0000    1.0000       153
#            4     1.0000    0.7143    0.8333       154
#            5     0.7778    1.0000    0.8750       154
#            6     1.0000    0.9925    0.9962       133
#            7     0.6435    0.9858    0.7787       141
#            8     0.9722    0.9589    0.9655       146
#            9     0.9503    1.0000    0.9745       153
#           10     1.0000    0.7532    0.8593       154
#           11     0.9872    1.0000    0.9935       154
#           12     0.6125    1.0000    0.7597        49
#
#     accuracy                         0.9086      1839
#    macro avg     0.9177    0.9157    0.8997      1839
# weighted avg     0.9352    0.9086    0.9063      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
