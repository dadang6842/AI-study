# %% [markdown]
# # UCI HAR - classification
# - https://archive.ics.uci.edu/dataset/240/human+activity+recognition+using+smartphones
#
# #### 데이터 종류
# - 561개 특성으로 전처리된 메인 데이터셋(X_train, X_test)
# - Inertial Signals 데이터셋: 원시 센서 값(raw signal)
#
# #### Inertial Signals 데이터 구조
# - 각 파일은 행 = 샘플(segment), 열 = 시계열 프레임을 의미
# - 각 샘플은 2.56초 길이 (샘플링 주파수 50Hz, 128 타임스텝 → 128 / 50 = 2.56초)
# - 이미 샘플링이 되어 있으므로(7352개의 샘플) split_sequence() 사용하지 않아도 됨
# - 한 행이 (128,) 길이의 시계열 벡터
# - 세 축(X, Y, Z)와 센서 종류(acc, gyro)로 분리되어 있음
#
# #### 센서 및 값의 의미
# - Total acceleration (total_acc): 스마트폰 가속도계로 측정한 총 가속도 (중력 + 신체 움직임 포함)
# - Body acceleration (body_acc): 총 가속도에서 중력 성분을 제거한 값 (실제 동작 가속도)
# - Gyroscope (body_gyro): 각속도(회전 속도), 단위는 rad/sec, 스마트폰의 자이로스코프 센서 값

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Conv1D, BatchNormalization, ReLU, MaxPool1D, LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/drive/MyDrive/AI_data/UCI_HAR_Dataset/UCI HAR Dataset/"

# Load "X"
def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []  # 한 센서축 데이터 전체 저장

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ') # 공백 2개를 1개로
                row_clean = row_clean.strip() # 양쪽 공백 제거
                serie = row_clean.split(' ') # 공백 기준 split
                serie_array = np.array(serie, dtype=np.float32) # float32 numpy 배열로 변환
                series_list.append(serie_array) # 시퀀스 추가

        # 하나의 센서축 데이터 추가 (feature)
        X_signals.append(series_list)

    # shape: (특성 수, 샘플 수, 타임스텝 수)
    X_signals = np.array(X_signals)
    # shape 변환 → (샘플 수, 타임스텝 수, 특성 수)
    return np.transpose(X_signals, (1, 2, 0))


X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt"
    for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt"
    for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)

# %%
# Load "y"

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    # 라벨을 0부터 시작하도록 -1 (원래 라벨이 1부터 시)
    return np.array(labels, dtype=np.int32) - 1


y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# y_train shape: (7352,)
# y_test shape: (2947,)

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, GRU 1, Transformer 1
# - Conv1D 출력과 TransformerBlock의 embed_dim 수가 일치해야함
# - residual addition 할 때 shape이 맞아야 하기 때문

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 64, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_2             │ (None, 64, 256)        │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 469,766 (1.79 MB)
#  Trainable params: 468,998 (1.79 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_CNN_GRU_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.4916 - sparse_categorical_accuracy: 0.7949
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.27532, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 113ms/step - loss: 0.4895 - sparse_categorical_accuracy: 0.7959 - val_loss: 5.0060 - val_sparse_categorical_accuracy: 0.2753
# Epoch 2/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1294 - sparse_categorical_accuracy: 0.9438
# Epoch 2: val_sparse_categorical_accuracy improved from 0.27532 to 0.31611, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1289 - sparse_categorical_accuracy: 0.9440 - val_loss: 4.4007 - val_sparse_categorical_accuracy: 0.3161
# Epoch 3/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9328
# Epoch 3: val_sparse_categorical_accuracy improved from 0.31611 to 0.82121, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1482 - sparse_categorical_accuracy: 0.9329 - val_loss: 0.5871 - val_sparse_categorical_accuracy: 0.8212
# Epoch 4/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9563
# Epoch 4: val_sparse_categorical_accuracy improved from 0.82121 to 0.90959, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1060 - sparse_categorical_accuracy: 0.9562 - val_loss: 0.2280 - val_sparse_categorical_accuracy: 0.9096
# Epoch 5/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1092 - sparse_categorical_accuracy: 0.9528
# Epoch 5: val_sparse_categorical_accuracy improved from 0.90959 to 0.91774, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1095 - sparse_categorical_accuracy: 0.9527 - val_loss: 0.2182 - val_sparse_categorical_accuracy: 0.9177
# Epoch 6/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9546
# Epoch 6: val_sparse_categorical_accuracy improved from 0.91774 to 0.92250, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1053 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.2375 - val_sparse_categorical_accuracy: 0.9225
# Epoch 7/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9557
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.92250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.4072 - val_sparse_categorical_accuracy: 0.9171
# Epoch 8/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0869 - sparse_categorical_accuracy: 0.9594
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.92250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0869 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.2615 - val_sparse_categorical_accuracy: 0.8973
# Epoch 9/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9590
# Epoch 9: val_sparse_categorical_accuracy improved from 0.92250 to 0.92930, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0968 - sparse_categorical_accuracy: 0.9591 - val_loss: 0.3206 - val_sparse_categorical_accuracy: 0.9293
# Epoch 10/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0854 - sparse_categorical_accuracy: 0.9629
# Epoch 10: val_sparse_categorical_accuracy improved from 0.92930 to 0.93610, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.9361
# Epoch 11/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0856 - sparse_categorical_accuracy: 0.9568
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.93610
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9568 - val_loss: 0.3675 - val_sparse_categorical_accuracy: 0.9089
# Epoch 12/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9535
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.93610
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.3324 - val_sparse_categorical_accuracy: 0.9205
# Epoch 13/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0852 - sparse_categorical_accuracy: 0.9552
# Epoch 13: val_sparse_categorical_accuracy improved from 0.93610 to 0.93746, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.4046 - val_sparse_categorical_accuracy: 0.9375
# Epoch 14/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1184 - sparse_categorical_accuracy: 0.9485
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.6080 - val_sparse_categorical_accuracy: 0.8674
# Epoch 15/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1215 - sparse_categorical_accuracy: 0.9509
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1214 - sparse_categorical_accuracy: 0.9509 - val_loss: 0.3153 - val_sparse_categorical_accuracy: 0.9218
# Epoch 16/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9569
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.3449 - val_sparse_categorical_accuracy: 0.9089
# Epoch 17/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9575
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3226 - val_sparse_categorical_accuracy: 0.9116
# Epoch 18/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0827 - sparse_categorical_accuracy: 0.9631
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.4364 - val_sparse_categorical_accuracy: 0.9116
# Epoch 19/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9616
# Epoch 19: val_sparse_categorical_accuracy improved from 0.93746 to 0.93814, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.3581 - val_sparse_categorical_accuracy: 0.9381
# Epoch 20/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0870 - sparse_categorical_accuracy: 0.9555
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.93814
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0870 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.3861 - val_sparse_categorical_accuracy: 0.9211
# Epoch 21/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9608
# Epoch 21: val_sparse_categorical_accuracy improved from 0.93814 to 0.94222, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.3227 - val_sparse_categorical_accuracy: 0.9422
# Epoch 22/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9588
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.94222
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.3706 - val_sparse_categorical_accuracy: 0.9320
# Epoch 23/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0740 - sparse_categorical_accuracy: 0.9665
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.94222
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0744 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.3106 - val_sparse_categorical_accuracy: 0.9354
# Epoch 24/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0920 - sparse_categorical_accuracy: 0.9609
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.94222
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.2919 - val_sparse_categorical_accuracy: 0.9381
# Epoch 25/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9604
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.94222
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0814 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.9279
# Epoch 26/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0846 - sparse_categorical_accuracy: 0.9633
# Epoch 26: val_sparse_categorical_accuracy improved from 0.94222 to 0.94969, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.2960 - val_sparse_categorical_accuracy: 0.9497
# Epoch 27/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0605 - sparse_categorical_accuracy: 0.9739
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1645 - val_sparse_categorical_accuracy: 0.9341
# Epoch 28/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0904 - sparse_categorical_accuracy: 0.9625
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.4791 - val_sparse_categorical_accuracy: 0.9375
# Epoch 29/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9669
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0723 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.9341
# Epoch 30/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9666
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0706 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.3524 - val_sparse_categorical_accuracy: 0.9218
# Epoch 31/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0679 - sparse_categorical_accuracy: 0.9697
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0679 - sparse_categorical_accuracy: 0.9697 - val_loss: 0.2636 - val_sparse_categorical_accuracy: 0.9320
# Epoch 32/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0751 - sparse_categorical_accuracy: 0.9667
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.5626 - val_sparse_categorical_accuracy: 0.8776
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0923 - sparse_categorical_accuracy: 0.9613
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.94969
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0922 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.4465 - val_sparse_categorical_accuracy: 0.9171
# Epoch 34/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1135 - sparse_categorical_accuracy: 0.9582
# Epoch 34: val_sparse_categorical_accuracy improved from 0.94969 to 0.95037, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1133 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.2990 - val_sparse_categorical_accuracy: 0.9504
# Epoch 35/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9699
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.3430 - val_sparse_categorical_accuracy: 0.9402
# Epoch 36/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0811 - sparse_categorical_accuracy: 0.9620
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0815 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.3011 - val_sparse_categorical_accuracy: 0.9089
# Epoch 37/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9662
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2312 - val_sparse_categorical_accuracy: 0.9375
# Epoch 38/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9721
# Epoch 38: val_sparse_categorical_accuracy improved from 0.95037 to 0.96125, saving model to UCI_HAR_CNN_Transformer_best.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2796 - val_sparse_categorical_accuracy: 0.9613
# Epoch 39/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9739
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.2206 - val_sparse_categorical_accuracy: 0.9273
# Epoch 40/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9701
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0672 - sparse_categorical_accuracy: 0.9700 - val_loss: 0.3124 - val_sparse_categorical_accuracy: 0.9497
# Epoch 41/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9702
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.9293
# Epoch 42/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9712
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0628 - sparse_categorical_accuracy: 0.9713 - val_loss: 0.2944 - val_sparse_categorical_accuracy: 0.9477
# Epoch 43/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9797
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.3071 - val_sparse_categorical_accuracy: 0.9429
# Epoch 44/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0546 - sparse_categorical_accuracy: 0.9761
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.3774 - val_sparse_categorical_accuracy: 0.9551
# Epoch 45/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9753
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.2813 - val_sparse_categorical_accuracy: 0.9490
# Epoch 46/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9795
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.3373 - val_sparse_categorical_accuracy: 0.9368
# Epoch 47/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9777
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.3297 - val_sparse_categorical_accuracy: 0.9470
# Epoch 48/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9788
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.9477
# Epoch 49/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9828
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0476 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.2673 - val_sparse_categorical_accuracy: 0.9511
# Epoch 50/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0609 - sparse_categorical_accuracy: 0.9799
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0610 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.3446 - val_sparse_categorical_accuracy: 0.9470
# Epoch 51/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9793
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.3719 - val_sparse_categorical_accuracy: 0.9490
# Epoch 52/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9797
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.3176 - val_sparse_categorical_accuracy: 0.9483
# Epoch 53/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9842
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.2957 - val_sparse_categorical_accuracy: 0.9585
# Epoch 54/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9832
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.2750 - val_sparse_categorical_accuracy: 0.9585
# Epoch 55/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9839
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.3098 - val_sparse_categorical_accuracy: 0.9504
# Epoch 56/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9819
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.2937 - val_sparse_categorical_accuracy: 0.9517
# Epoch 57/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9806
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.3127 - val_sparse_categorical_accuracy: 0.9470
# Epoch 58/100
# 86/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9817
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.96125
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0419 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.3124 - val_sparse_categorical_accuracy: 0.9531
# Epoch 58: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_HAR_CNN_GRU_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 97.55%
# Training loss: 0.0938
# Test accuracy: 93.52%
# Test loss: 0.3976

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9811    0.9395    0.9598       496
#            1     0.9932    0.9363    0.9639       471
#            2     0.8811    0.9881    0.9315       420
#            3     0.9176    0.8167    0.8642       491
#            4     0.8581    0.9323    0.8937       532
#            5     0.9908    1.0000    0.9954       537
#
#     accuracy                         0.9352      2947
#    macro avg     0.9370    0.9355    0.9348      2947
# weighted avg     0.9378    0.9352    0.9351      2947

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 2, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 128, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_9 (ReLU)                  │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 64, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_4             │ (None, 64, 256)        │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_3      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 519,558 (1.98 MB)
#  Trainable params: 518,534 (1.98 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_CNN_GRU_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.5135 - sparse_categorical_accuracy: 0.8013
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.28484, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 156ms/step - loss: 0.5110 - sparse_categorical_accuracy: 0.8023 - val_loss: 4.8042 - val_sparse_categorical_accuracy: 0.2848
# Epoch 2/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1238 - sparse_categorical_accuracy: 0.9480
# Epoch 2: val_sparse_categorical_accuracy improved from 0.28484 to 0.30727, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1236 - sparse_categorical_accuracy: 0.9480 - val_loss: 3.5147 - val_sparse_categorical_accuracy: 0.3073
# Epoch 3/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9458
# Epoch 3: val_sparse_categorical_accuracy improved from 0.30727 to 0.67029, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9459 - val_loss: 1.4727 - val_sparse_categorical_accuracy: 0.6703
# Epoch 4/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1078 - sparse_categorical_accuracy: 0.9487
# Epoch 4: val_sparse_categorical_accuracy improved from 0.67029 to 0.89463, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1077 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.2894 - val_sparse_categorical_accuracy: 0.8946
# Epoch 5/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0942 - sparse_categorical_accuracy: 0.9545
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.89463
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.7673 - val_sparse_categorical_accuracy: 0.7294
# Epoch 6/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1267 - sparse_categorical_accuracy: 0.9456
# Epoch 6: val_sparse_categorical_accuracy improved from 0.89463 to 0.91502, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.3044 - val_sparse_categorical_accuracy: 0.9150
# Epoch 7/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9476
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.91502
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9477 - val_loss: 0.4238 - val_sparse_categorical_accuracy: 0.9035
# Epoch 8/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0956 - sparse_categorical_accuracy: 0.9595
# Epoch 8: val_sparse_categorical_accuracy improved from 0.91502 to 0.91774, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.4505 - val_sparse_categorical_accuracy: 0.9177
# Epoch 9/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9566
# Epoch 9: val_sparse_categorical_accuracy improved from 0.91774 to 0.92114, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.3803 - val_sparse_categorical_accuracy: 0.9211
# Epoch 10/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0826 - sparse_categorical_accuracy: 0.9597
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.92114
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0827 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.3558 - val_sparse_categorical_accuracy: 0.9211
# Epoch 11/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0896 - sparse_categorical_accuracy: 0.9630
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.92114
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0901 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.2693 - val_sparse_categorical_accuracy: 0.9075
# Epoch 12/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1107 - sparse_categorical_accuracy: 0.9537
# Epoch 12: val_sparse_categorical_accuracy improved from 0.92114 to 0.92658, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9538 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.9266
# Epoch 13/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9600
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.2580 - val_sparse_categorical_accuracy: 0.9184
# Epoch 14/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9544
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0933 - sparse_categorical_accuracy: 0.9544 - val_loss: 0.2967 - val_sparse_categorical_accuracy: 0.9116
# Epoch 15/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0920 - sparse_categorical_accuracy: 0.9614
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9614 - val_loss: 0.2861 - val_sparse_categorical_accuracy: 0.9266
# Epoch 16/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9606
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.2818 - val_sparse_categorical_accuracy: 0.9075
# Epoch 17/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0807 - sparse_categorical_accuracy: 0.9639
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0809 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.3417 - val_sparse_categorical_accuracy: 0.9116
# Epoch 18/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9611
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.92658
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.9096
# Epoch 19/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0916 - sparse_categorical_accuracy: 0.9613
# Epoch 19: val_sparse_categorical_accuracy improved from 0.92658 to 0.93746, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0915 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.3241 - val_sparse_categorical_accuracy: 0.9375
# Epoch 20/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0935 - sparse_categorical_accuracy: 0.9569
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0933 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.9334
# Epoch 21/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9593
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.4337 - val_sparse_categorical_accuracy: 0.9354
# Epoch 22/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9629
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.93746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0950 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.4257 - val_sparse_categorical_accuracy: 0.9177
# Epoch 23/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9658
# Epoch 23: val_sparse_categorical_accuracy improved from 0.93746 to 0.94154, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0704 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.3121 - val_sparse_categorical_accuracy: 0.9415
# Epoch 24/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1041 - sparse_categorical_accuracy: 0.9552
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1043 - sparse_categorical_accuracy: 0.9552 - val_loss: 0.3881 - val_sparse_categorical_accuracy: 0.9307
# Epoch 25/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9555
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0989 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.2580 - val_sparse_categorical_accuracy: 0.9300
# Epoch 26/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1112 - sparse_categorical_accuracy: 0.9534
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1109 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.3149 - val_sparse_categorical_accuracy: 0.9361
# Epoch 27/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0794 - sparse_categorical_accuracy: 0.9668
# Epoch 27: val_sparse_categorical_accuracy improved from 0.94154 to 0.95037, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0793 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.9504
# Epoch 28/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9636
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9637 - val_loss: 0.3526 - val_sparse_categorical_accuracy: 0.9429
# Epoch 29/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0897 - sparse_categorical_accuracy: 0.9657
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0896 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.3138 - val_sparse_categorical_accuracy: 0.9415
# Epoch 30/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0673 - sparse_categorical_accuracy: 0.9664
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.9449
# Epoch 31/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9691
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0682 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.3199 - val_sparse_categorical_accuracy: 0.9239
# Epoch 32/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9726
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.95037
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9725 - val_loss: 0.3704 - val_sparse_categorical_accuracy: 0.9477
# Epoch 33/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0739 - sparse_categorical_accuracy: 0.9681
# Epoch 33: val_sparse_categorical_accuracy improved from 0.95037 to 0.95649, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0739 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.3289 - val_sparse_categorical_accuracy: 0.9565
# Epoch 34/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9727
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0706 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.2666 - val_sparse_categorical_accuracy: 0.9395
# Epoch 35/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9752
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.3045 - val_sparse_categorical_accuracy: 0.9313
# Epoch 36/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9732
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0628 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.3509 - val_sparse_categorical_accuracy: 0.9388
# Epoch 37/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9722
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.3944 - val_sparse_categorical_accuracy: 0.9436
# Epoch 38/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9712
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0727 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.4243 - val_sparse_categorical_accuracy: 0.9381
# Epoch 39/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0786 - sparse_categorical_accuracy: 0.9642
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.3601 - val_sparse_categorical_accuracy: 0.9504
# Epoch 40/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9781
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.3059 - val_sparse_categorical_accuracy: 0.9266
# Epoch 41/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0560 - sparse_categorical_accuracy: 0.9763
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.9483
# Epoch 42/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0511 - sparse_categorical_accuracy: 0.9812
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9811 - val_loss: 0.2521 - val_sparse_categorical_accuracy: 0.9286
# Epoch 43/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0453 - sparse_categorical_accuracy: 0.9829
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.2839 - val_sparse_categorical_accuracy: 0.9477
# Epoch 44/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9844
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.2133 - val_sparse_categorical_accuracy: 0.9368
# Epoch 45/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9764
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1589 - val_sparse_categorical_accuracy: 0.9443
# Epoch 46/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0543 - sparse_categorical_accuracy: 0.9767
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.3157 - val_sparse_categorical_accuracy: 0.9545
# Epoch 47/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9781
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.3243 - val_sparse_categorical_accuracy: 0.9354
# Epoch 48/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0524 - sparse_categorical_accuracy: 0.9769
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0523 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.9497
# Epoch 49/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9811
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.95649
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.3396 - val_sparse_categorical_accuracy: 0.9558
# Epoch 50/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9849
# Epoch 50: val_sparse_categorical_accuracy improved from 0.95649 to 0.96057, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.3102 - val_sparse_categorical_accuracy: 0.9606
# Epoch 51/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9858
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0353 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.3266 - val_sparse_categorical_accuracy: 0.9558
# Epoch 52/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9847
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.2461 - val_sparse_categorical_accuracy: 0.9572
# Epoch 53/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9859
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.3245 - val_sparse_categorical_accuracy: 0.9592
# Epoch 54/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9895
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.2792 - val_sparse_categorical_accuracy: 0.9579
# Epoch 55/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9825
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.3007 - val_sparse_categorical_accuracy: 0.9585
# Epoch 56/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9864
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9863 - val_loss: 0.2375 - val_sparse_categorical_accuracy: 0.9225
# Epoch 57/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9869
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.9470
# Epoch 58/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9817
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.2969 - val_sparse_categorical_accuracy: 0.9592
# Epoch 59/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9829
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9828 - val_loss: 0.2876 - val_sparse_categorical_accuracy: 0.9375
# Epoch 60/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9857
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.2953 - val_sparse_categorical_accuracy: 0.9483
# Epoch 61/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9869
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.2646 - val_sparse_categorical_accuracy: 0.9449
# Epoch 62/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9860
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.96057
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0333 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.3605 - val_sparse_categorical_accuracy: 0.9592
# Epoch 63/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9856
# Epoch 63: val_sparse_categorical_accuracy improved from 0.96057 to 0.96397, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0368 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3290 - val_sparse_categorical_accuracy: 0.9640
# Epoch 64/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9874
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.9524
# Epoch 65/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9882
# Epoch 65: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.1977 - val_sparse_categorical_accuracy: 0.9538
# Epoch 66/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9836
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.2157 - val_sparse_categorical_accuracy: 0.9524
# Epoch 67/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9894
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.1517 - val_sparse_categorical_accuracy: 0.9511
# Epoch 68/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9890
# Epoch 68: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0306 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.3654 - val_sparse_categorical_accuracy: 0.9443
# Epoch 69/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9865
# Epoch 69: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.3049 - val_sparse_categorical_accuracy: 0.9579
# Epoch 70/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9916
# Epoch 70: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.3454 - val_sparse_categorical_accuracy: 0.9585
# Epoch 71/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9936
# Epoch 71: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.3180 - val_sparse_categorical_accuracy: 0.9579
# Epoch 72/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9853
# Epoch 72: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0363 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.2608 - val_sparse_categorical_accuracy: 0.9613
# Epoch 73/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9893
# Epoch 73: val_sparse_categorical_accuracy did not improve from 0.96397
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.3252 - val_sparse_categorical_accuracy: 0.9640
# Epoch 74/100
# 87/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9907
# Epoch 74: val_sparse_categorical_accuracy improved from 0.96397 to 0.96533, saving model to UCI_HAR_CNN_Transformer_best2.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.3241 - val_sparse_categorical_accuracy: 0.9653
# Epoch 75/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9890
# Epoch 75: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.9531
# Epoch 76/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9937
# Epoch 76: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.9592
# Epoch 77/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9791
# Epoch 77: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0751 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.2710 - val_sparse_categorical_accuracy: 0.9572
# Epoch 78/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9875
# Epoch 78: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0310 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.2862 - val_sparse_categorical_accuracy: 0.9585
# Epoch 79/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9931
# Epoch 79: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.1940 - val_sparse_categorical_accuracy: 0.9606
# Epoch 80/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9905
# Epoch 80: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.9572
# Epoch 81/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0228 - sparse_categorical_accuracy: 0.9907
# Epoch 81: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.3388 - val_sparse_categorical_accuracy: 0.9592
# Epoch 82/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9899
# Epoch 82: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.2287 - val_sparse_categorical_accuracy: 0.9653
# Epoch 83/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9901
# Epoch 83: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.2925 - val_sparse_categorical_accuracy: 0.9307
# Epoch 84/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9846
# Epoch 84: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.3762 - val_sparse_categorical_accuracy: 0.9606
# Epoch 85/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9904
# Epoch 85: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0275 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.3904 - val_sparse_categorical_accuracy: 0.9511
# Epoch 86/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9889
# Epoch 86: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3184 - val_sparse_categorical_accuracy: 0.9579
# Epoch 87/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0305 - sparse_categorical_accuracy: 0.9888
# Epoch 87: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.3510 - val_sparse_categorical_accuracy: 0.9579
# Epoch 88/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - sparse_categorical_accuracy: 0.9920
# Epoch 88: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.1951 - val_sparse_categorical_accuracy: 0.9606
# Epoch 89/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9910
# Epoch 89: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.1525 - val_sparse_categorical_accuracy: 0.9646
# Epoch 90/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9898
# Epoch 90: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.2655 - val_sparse_categorical_accuracy: 0.9524
# Epoch 91/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9894
# Epoch 91: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.3364 - val_sparse_categorical_accuracy: 0.9619
# Epoch 92/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9945
# Epoch 92: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.9633
# Epoch 93/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9919
# Epoch 93: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.9640
# Epoch 94/100
# 88/92 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9914
# Epoch 94: val_sparse_categorical_accuracy did not improve from 0.96533
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.3543 - val_sparse_categorical_accuracy: 0.9585
# Epoch 94: early stopping
# Restoring model weights from the end of the best epoch: 74.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_HAR_CNN_GRU_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 66 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 98.88%
# Training loss: 0.0780
# Test accuracy: 92.81%
# Test loss: 0.6683

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.8468    0.9170       496
#            1     0.9844    0.9363    0.9597       471
#            2     0.8092    1.0000    0.8946       420
#            3     0.9548    0.8167    0.8804       491
#            4     0.8571    0.9699    0.9101       532
#            5     0.9981    1.0000    0.9991       537
#
#     accuracy                         0.9281      2947
#    macro avg     0.9339    0.9283    0.9268      2947
# weighted avg     0.9367    0.9281    0.9282      2947

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 3, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 128, 9)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 128, 128)       │         5,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_14 (ReLU)                 │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 128, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_15 (ReLU)                 │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 64, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 64, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_6             │ (None, 64, 256)        │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_7             │ (None, 64, 256)        │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_5      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849,670 (3.24 MB)
#  Trainable params: 848,646 (3.24 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_CNN_GRU_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.5405 - sparse_categorical_accuracy: 0.7854
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.24133, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - loss: 0.5379 - sparse_categorical_accuracy: 0.7865 - val_loss: 6.2246 - val_sparse_categorical_accuracy: 0.2413
# Epoch 2/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1220 - sparse_categorical_accuracy: 0.9492
# Epoch 2: val_sparse_categorical_accuracy improved from 0.24133 to 0.26581, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 20ms/step - loss: 0.1218 - sparse_categorical_accuracy: 0.9492 - val_loss: 5.4013 - val_sparse_categorical_accuracy: 0.2658
# Epoch 3/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1184 - sparse_categorical_accuracy: 0.9479
# Epoch 3: val_sparse_categorical_accuracy improved from 0.26581 to 0.70836, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1186 - sparse_categorical_accuracy: 0.9480 - val_loss: 1.1124 - val_sparse_categorical_accuracy: 0.7084
# Epoch 4/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1279 - sparse_categorical_accuracy: 0.9460
# Epoch 4: val_sparse_categorical_accuracy improved from 0.70836 to 0.91978, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1283 - sparse_categorical_accuracy: 0.9459 - val_loss: 0.1939 - val_sparse_categorical_accuracy: 0.9198
# Epoch 5/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9464
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.91978
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1201 - sparse_categorical_accuracy: 0.9465 - val_loss: 0.2526 - val_sparse_categorical_accuracy: 0.8511
# Epoch 6/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1230 - sparse_categorical_accuracy: 0.9433
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.91978
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.3786 - val_sparse_categorical_accuracy: 0.9103
# Epoch 7/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9511
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.91978
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9511 - val_loss: 0.4899 - val_sparse_categorical_accuracy: 0.8579
# Epoch 8/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9549
# Epoch 8: val_sparse_categorical_accuracy improved from 0.91978 to 0.92114, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.1063 - sparse_categorical_accuracy: 0.9548 - val_loss: 0.2528 - val_sparse_categorical_accuracy: 0.9211
# Epoch 9/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9576
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.92114
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0907 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3188 - val_sparse_categorical_accuracy: 0.9157
# Epoch 10/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0961 - sparse_categorical_accuracy: 0.9565
# Epoch 10: val_sparse_categorical_accuracy improved from 0.92114 to 0.92726, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0964 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.2752 - val_sparse_categorical_accuracy: 0.9273
# Epoch 11/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9557
# Epoch 11: val_sparse_categorical_accuracy improved from 0.92726 to 0.93814, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0985 - sparse_categorical_accuracy: 0.9558 - val_loss: 0.3789 - val_sparse_categorical_accuracy: 0.9381
# Epoch 12/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0911 - sparse_categorical_accuracy: 0.9600
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.93814
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0910 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.3262 - val_sparse_categorical_accuracy: 0.9368
# Epoch 13/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9566
# Epoch 13: val_sparse_categorical_accuracy improved from 0.93814 to 0.94154, saving model to UCI_HAR_CNN_Transformer_best3.weights.h5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1081 - sparse_categorical_accuracy: 0.9568 - val_loss: 0.2854 - val_sparse_categorical_accuracy: 0.9415
# Epoch 14/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9605
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1024 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.4205 - val_sparse_categorical_accuracy: 0.9069
# Epoch 15/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9461
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1160 - sparse_categorical_accuracy: 0.9463 - val_loss: 0.2889 - val_sparse_categorical_accuracy: 0.9347
# Epoch 16/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1300 - sparse_categorical_accuracy: 0.9482
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.2822 - val_sparse_categorical_accuracy: 0.9103
# Epoch 17/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1393 - sparse_categorical_accuracy: 0.9465
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1385 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.2787 - val_sparse_categorical_accuracy: 0.9157
# Epoch 18/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1042 - sparse_categorical_accuracy: 0.9537
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1043 - sparse_categorical_accuracy: 0.9537 - val_loss: 0.3377 - val_sparse_categorical_accuracy: 0.9082
# Epoch 19/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0982 - sparse_categorical_accuracy: 0.9587
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0981 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.3528 - val_sparse_categorical_accuracy: 0.9286
# Epoch 20/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9608
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0904 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.3071 - val_sparse_categorical_accuracy: 0.9232
# Epoch 21/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1089 - sparse_categorical_accuracy: 0.9530
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1087 - sparse_categorical_accuracy: 0.9531 - val_loss: 0.2810 - val_sparse_categorical_accuracy: 0.9109
# Epoch 22/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9554
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0961 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.3110 - val_sparse_categorical_accuracy: 0.9341
# Epoch 23/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9584
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9584 - val_loss: 0.3356 - val_sparse_categorical_accuracy: 0.9341
# Epoch 24/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0940 - sparse_categorical_accuracy: 0.9598
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0941 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.3635 - val_sparse_categorical_accuracy: 0.9279
# Epoch 25/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0948 - sparse_categorical_accuracy: 0.9535
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0949 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.3005 - val_sparse_categorical_accuracy: 0.9245
# Epoch 26/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9566
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.3647 - val_sparse_categorical_accuracy: 0.8892
# Epoch 27/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1130 - sparse_categorical_accuracy: 0.9552
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.3217 - val_sparse_categorical_accuracy: 0.9232
# Epoch 28/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0957 - sparse_categorical_accuracy: 0.9576
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0956 - sparse_categorical_accuracy: 0.9577 - val_loss: 0.3672 - val_sparse_categorical_accuracy: 0.9164
# Epoch 29/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9553
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.1057 - sparse_categorical_accuracy: 0.9554 - val_loss: 0.3591 - val_sparse_categorical_accuracy: 0.9164
# Epoch 30/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9619
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0838 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.3328 - val_sparse_categorical_accuracy: 0.9334
# Epoch 31/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9633
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0876 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.2549 - val_sparse_categorical_accuracy: 0.9116
# Epoch 32/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9622
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.2779 - val_sparse_categorical_accuracy: 0.9334
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9632
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.94154
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0818 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.3333 - val_sparse_categorical_accuracy: 0.9286
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_HAR_CNN_GRU_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 98 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 96.12%
# Training loss: 0.1134
# Test accuracy: 93.35%
# Test loss: 0.2276

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9713    0.9536    0.9624       496
#            1     0.9354    0.9533    0.9443       471
#            2     0.9142    0.9643    0.9386       420
#            3     0.8894    0.8350    0.8613       491
#            4     0.8933    0.8966    0.8949       532
#            5     0.9908    1.0000    0.9954       537
#
#     accuracy                         0.9335      2947
#    macro avg     0.9324    0.9338    0.9328      2947
# weighted avg     0.9332    0.9335    0.9331      2947

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
