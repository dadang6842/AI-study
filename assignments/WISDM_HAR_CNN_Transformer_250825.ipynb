# %% [markdown]
# # WISDM HAR
#
# Class
# - Walking, Jogging, Upstairs, Downstairs, Sitting, Standing
#
# Sampling rate
# - 20Hz
#
# Fields
# - user, activity, timestamp, x-acceleration, y-acceleration, z-acceleration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Conv1D, MaxPool1D, BatchNormalization, Dense,
                                     Input, ReLU, Dropout, LayerNormalization,
                                     MultiHeadAttention, GlobalAveragePooling1D, GRU)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
LABELS = ["Walking", "Jogging", "Upstairs", "Downstairs", "Sitting", "Standing"]

# %%
names = ["user_id", "activity", "timestamp", "x_axis", "y_axis", "z_axis", "NaN"]
data = pd.read_csv("/content/drive/MyDrive/AI_data/WISDM_ar_v1.1_raw.txt", header=None, names=names, comment=";") # comment: ';'로 시작하는 줄 무시(주석)

# %%
data.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis  NaN
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953  NaN
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424  NaN
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722  NaN
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717  NaN
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164  NaN

# %%
def convert_to_float(x):
    try:
        return np.float32(x)
    except:
        return np.nan

# %%
df = data.drop('NaN', axis=1)
df.isna().sum()
# Out:
# user_id      0
# activity     0
# timestamp    0
# x_axis       0
# y_axis       0
# z_axis       1
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# user_id      0
# activity     0
# timestamp    0
# x_axis       0
# y_axis       0
# z_axis       0
# dtype: int64

# %%
df["z_axis"] = df["z_axis"].replace(regex=True, to_replace=r';', value=r'')

df["x_axis"] = df["x_axis"].apply(convert_to_float)
df["y_axis"] = df["y_axis"].apply(convert_to_float)
df["z_axis"] = df["z_axis"].apply(convert_to_float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1098203 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1098203 non-null  int64
#  1   activity   1098203 non-null  object
#  2   timestamp  1098203 non-null  int64
#  3   x_axis     1098203 non-null  float32
#  4   y_axis     1098203 non-null  float32
#  5   z_axis     1098203 non-null  float32
# dtypes: float32(3), int64(2), object(1)
# memory usage: 46.1+ MB

# %%
df['activity'].value_counts()
# Out:
# activity
# Walking       424397
# Jogging       342176
# Upstairs      122869
# Downstairs    100427
# Sitting        59939
# Standing       48395
# Name: count, dtype: int64

# %%
df['user_id'].value_counts()
# Out:
# user_id
# 20    56632
# 19    45383
# 31    44282
# 8     41188
# 29    38245
# 14    38192
# 13    37093
# 34    35947
# 32    35506
# 21    35436
# 3     35161
# 27    34958
# 10    34883
# 18    32811
# 12    32641
# 26    32578
# 36    32261
# 11    31658
# 7     30967
# 1     29978
# 6     29704
# 33    29453
# 5     28509
# 15    28154
# 24    25736
# 23    25673
# 30    25335
# 2     23525
# 35    22394
# 22    22310
# 17    22020
# 28    21358
# 16    20470
# 25    13468
# 9     12923
# 4     11371
# Name: count, dtype: int64

# %%
# Label Encoding
label_encoder = LabelEncoder()
df['activity_encoded'] = label_encoder.fit_transform(df['activity'])
num_classes = len(label_encoder.classes_)

df.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis  \
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164
#
#    activity_encoded
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
# label_encoder 매핑 결과 보기
dict(enumerate(label_encoder.classes_))
# Out:
# {0: 'Downstairs',
#  1: 'Jogging',
#  2: 'Sitting',
#  3: 'Standing',
#  4: 'Upstairs',
#  5: 'Walking'}

# %%
# Data Split
df_train = df[df['user_id'] <= 28]
df_val   = df[(df['user_id'] > 28) & (df['user_id'] <= 32)]
df_test = df[df['user_id'] > 32]

# %%
# 정규화
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_train.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.fit_transform(df_train.loc[:, ['x_axis', 'y_axis', 'z_axis']])
# test 셋에서 train에서 학습한 scaler 사용
df_val.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.transform(df_val.loc[:, ['x_axis', 'y_axis', 'z_axis']])
df_test.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.transform(df_test.loc[:, ['x_axis', 'y_axis', 'z_axis']])

# %% [markdown]
# Segmentation
# - 슬라이딩 윈도우 방식
# - 데이터를 time_steps만큼 자르고 step 간격으로 이동
# - 해당 구간에서 가장 많이 나타난 label을 출력값으로 저장
# - 결과적으로 딥러닝 모델에 넣을 수 있는 3차원 입력 데이터와 라벨 벡터를 생성
# - 3차원 입력 데이터: (샘플 수, 한 샘플이 가지는 시간 길이, feature 개수)

# %%
def create_dataset(x, y, time_steps=200, step=40):
    xs, ys = [], []
    for i in range(0, len(x) - time_steps, step):
        v = x.iloc[i:i + time_steps].values
        labels = y.iloc[i:i + time_steps]
        values, counts = np.unique(labels, return_counts=True)
        mode_label = values[np.argmax(counts)]
        xs.append(v)
        ys.append(mode_label)
    return np.array(xs), np.array(ys)

TIME_STEPS = 200
STEP = 40
x_train, y_train = create_dataset(df_train[['x_axis', 'y_axis', 'z_axis']], df_train['activity_encoded'], TIME_STEPS, STEP)
x_val, y_val = create_dataset(df_val[['x_axis', 'y_axis', 'z_axis']], df_val['activity_encoded'], TIME_STEPS, STEP)
x_test, y_test = create_dataset(df_test[['x_axis', 'y_axis', 'z_axis']], df_test['activity_encoded'], TIME_STEPS, STEP)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((20865, 200, 3), (20865,), (3580, 200, 3), (3580,), (2997, 200, 3), (2997,))

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, Transformer 1

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 200, 128)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 465,926 (1.78 MB)
#  Trainable params: 465,158 (1.77 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WIDSM_HAR_CNN_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4758 - sparse_categorical_accuracy: 0.8258
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.79749, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 27s 40ms/step - loss: 0.4752 - sparse_categorical_accuracy: 0.8260 - val_loss: 0.6019 - val_sparse_categorical_accuracy: 0.7975
# Epoch 2/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1650 - sparse_categorical_accuracy: 0.9453
# Epoch 2: val_sparse_categorical_accuracy improved from 0.79749 to 0.80698, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - loss: 0.1644 - sparse_categorical_accuracy: 0.9454 - val_loss: 1.3219 - val_sparse_categorical_accuracy: 0.8070
# Epoch 3/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9663
# Epoch 3: val_sparse_categorical_accuracy improved from 0.80698 to 0.82318, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9664 - val_loss: 1.4038 - val_sparse_categorical_accuracy: 0.8232
# Epoch 4/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9819
# Epoch 4: val_sparse_categorical_accuracy improved from 0.82318 to 0.83743, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.8678 - val_sparse_categorical_accuracy: 0.8374
# Epoch 5/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9834
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9834 - val_loss: 2.0252 - val_sparse_categorical_accuracy: 0.8098
# Epoch 6/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9827
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9827 - val_loss: 1.5421 - val_sparse_categorical_accuracy: 0.8341
# Epoch 7/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1259 - sparse_categorical_accuracy: 0.9601
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1258 - sparse_categorical_accuracy: 0.9601 - val_loss: 1.9248 - val_sparse_categorical_accuracy: 0.8092
# Epoch 8/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1197 - sparse_categorical_accuracy: 0.9605
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1192 - sparse_categorical_accuracy: 0.9607 - val_loss: 2.0248 - val_sparse_categorical_accuracy: 0.7922
# Epoch 9/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9868
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9868 - val_loss: 2.1790 - val_sparse_categorical_accuracy: 0.8184
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9788
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9788 - val_loss: 2.0430 - val_sparse_categorical_accuracy: 0.8140
# Epoch 11/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0852 - sparse_categorical_accuracy: 0.9736
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9737 - val_loss: 1.2882 - val_sparse_categorical_accuracy: 0.8204
# Epoch 12/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1560 - sparse_categorical_accuracy: 0.9508
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1554 - sparse_categorical_accuracy: 0.9510 - val_loss: 1.8101 - val_sparse_categorical_accuracy: 0.7916
# Epoch 13/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0866 - sparse_categorical_accuracy: 0.9716
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0862 - sparse_categorical_accuracy: 0.9717 - val_loss: 1.9912 - val_sparse_categorical_accuracy: 0.8120
# Epoch 14/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9890
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9889 - val_loss: 2.4669 - val_sparse_categorical_accuracy: 0.8123
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9925
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9925 - val_loss: 2.4917 - val_sparse_categorical_accuracy: 0.7567
# Epoch 16/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9735
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9736 - val_loss: 2.2318 - val_sparse_categorical_accuracy: 0.8059
# Epoch 17/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9885
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9886 - val_loss: 2.5480 - val_sparse_categorical_accuracy: 0.7838
# Epoch 18/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9848
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9848 - val_loss: 2.4999 - val_sparse_categorical_accuracy: 0.8039
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9852
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9853 - val_loss: 2.1155 - val_sparse_categorical_accuracy: 0.7905
# Epoch 20/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9921
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9921 - val_loss: 2.1929 - val_sparse_categorical_accuracy: 0.8020
# Epoch 21/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1118 - sparse_categorical_accuracy: 0.9694
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1111 - sparse_categorical_accuracy: 0.9696 - val_loss: 2.5090 - val_sparse_categorical_accuracy: 0.7980
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9917
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9917 - val_loss: 3.2688 - val_sparse_categorical_accuracy: 0.7933
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9946
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9946 - val_loss: 3.0684 - val_sparse_categorical_accuracy: 0.7743
# Epoch 24/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0207 - sparse_categorical_accuracy: 0.9922
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.83743
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0207 - sparse_categorical_accuracy: 0.9922 - val_loss: 2.3644 - val_sparse_categorical_accuracy: 0.7905
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WIDSM_HAR_CNN_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 98.44%
# Training loss: 0.0379
# Test accuracy: 93.19%
# Test loss: 0.3115

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7414    0.8293    0.7829       287
#            1     0.9897    0.9495    0.9691      1009
#            2     0.9955    0.9865    0.9910       223
#            3     0.9931    0.9730    0.9829       148
#            4     0.8041    0.8097    0.8069       289
#            5     0.9505    0.9597    0.9551      1041
#
#     accuracy                         0.9319      2997
#    macro avg     0.9124    0.9179    0.9147      2997
# weighted avg     0.9350    0.9319    0.9331      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 3, Transformer 1

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(64, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 200, 64)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 200, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 200, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_2             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 489,862 (1.87 MB)
#  Trainable params: 488,966 (1.87 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4235 - sparse_categorical_accuracy: 0.8444
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.80475, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - loss: 0.4229 - sparse_categorical_accuracy: 0.8446 - val_loss: 1.2337 - val_sparse_categorical_accuracy: 0.8047
# Epoch 2/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1090 - sparse_categorical_accuracy: 0.9643
# Epoch 2: val_sparse_categorical_accuracy improved from 0.80475 to 0.80782, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1088 - sparse_categorical_accuracy: 0.9643 - val_loss: 1.9999 - val_sparse_categorical_accuracy: 0.8078
# Epoch 3/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1504 - sparse_categorical_accuracy: 0.9493
# Epoch 3: val_sparse_categorical_accuracy improved from 0.80782 to 0.81061, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.1498 - sparse_categorical_accuracy: 0.9496 - val_loss: 1.3486 - val_sparse_categorical_accuracy: 0.8106
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9833
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.81061
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9833 - val_loss: 1.3330 - val_sparse_categorical_accuracy: 0.8059
# Epoch 5/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9862
# Epoch 5: val_sparse_categorical_accuracy improved from 0.81061 to 0.84777, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.1943 - val_sparse_categorical_accuracy: 0.8478
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9819
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9820 - val_loss: 1.8290 - val_sparse_categorical_accuracy: 0.8067
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9860
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9860 - val_loss: 1.9894 - val_sparse_categorical_accuracy: 0.7372
# Epoch 8/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0500 - sparse_categorical_accuracy: 0.9845
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9845 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.7807
# Epoch 9/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1390 - sparse_categorical_accuracy: 0.9603
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1382 - sparse_categorical_accuracy: 0.9605 - val_loss: 1.7659 - val_sparse_categorical_accuracy: 0.8204
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9889
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9889 - val_loss: 1.7827 - val_sparse_categorical_accuracy: 0.8011
# Epoch 11/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9921
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9920 - val_loss: 1.6071 - val_sparse_categorical_accuracy: 0.8117
# Epoch 12/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9910
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9910 - val_loss: 2.3500 - val_sparse_categorical_accuracy: 0.7707
# Epoch 13/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9905
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9905 - val_loss: 1.8201 - val_sparse_categorical_accuracy: 0.7835
# Epoch 14/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9906
# Epoch 14: val_sparse_categorical_accuracy improved from 0.84777 to 0.86117, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.7331 - val_sparse_categorical_accuracy: 0.8612
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9917
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.86117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9917 - val_loss: 2.0877 - val_sparse_categorical_accuracy: 0.8008
# Epoch 16/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9911
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.86117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9911 - val_loss: 1.8659 - val_sparse_categorical_accuracy: 0.8022
# Epoch 17/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9916
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.86117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9916 - val_loss: 1.9460 - val_sparse_categorical_accuracy: 0.8095
# Epoch 18/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9863
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.86117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9863 - val_loss: 1.9048 - val_sparse_categorical_accuracy: 0.8204
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9628
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.86117
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1120 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.7728 - val_sparse_categorical_accuracy: 0.8369
# Epoch 20/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9761
# Epoch 20: val_sparse_categorical_accuracy improved from 0.86117 to 0.86145, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.5972 - val_sparse_categorical_accuracy: 0.8615
# Epoch 21/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9852
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9852 - val_loss: 1.7054 - val_sparse_categorical_accuracy: 0.8394
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9839
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9839 - val_loss: 1.7701 - val_sparse_categorical_accuracy: 0.8075
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9946
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9946 - val_loss: 1.3652 - val_sparse_categorical_accuracy: 0.8198
# Epoch 24/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9939
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9939 - val_loss: 1.5958 - val_sparse_categorical_accuracy: 0.8402
# Epoch 25/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9967
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.9557 - val_sparse_categorical_accuracy: 0.8285
# Epoch 26/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9880
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9880 - val_loss: 1.5501 - val_sparse_categorical_accuracy: 0.8003
# Epoch 27/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9938
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9938 - val_loss: 1.6195 - val_sparse_categorical_accuracy: 0.8307
# Epoch 28/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9620
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9621 - val_loss: 1.9784 - val_sparse_categorical_accuracy: 0.8162
# Epoch 29/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9897
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9898 - val_loss: 1.6563 - val_sparse_categorical_accuracy: 0.8212
# Epoch 30/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9953
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9953 - val_loss: 1.2890 - val_sparse_categorical_accuracy: 0.8318
# Epoch 31/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9931
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9931 - val_loss: 2.1650 - val_sparse_categorical_accuracy: 0.8221
# Epoch 32/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9947
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9947 - val_loss: 2.1687 - val_sparse_categorical_accuracy: 0.8358
# Epoch 33/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9970
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9970 - val_loss: 2.3302 - val_sparse_categorical_accuracy: 0.8232
# Epoch 34/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9963
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.5339 - val_sparse_categorical_accuracy: 0.8237
# Epoch 35/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9893
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9893 - val_loss: 2.4537 - val_sparse_categorical_accuracy: 0.8232
# Epoch 36/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9946
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0146 - sparse_categorical_accuracy: 0.9946 - val_loss: 2.5921 - val_sparse_categorical_accuracy: 0.8134
# Epoch 37/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9967
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.3454 - val_sparse_categorical_accuracy: 0.8246
# Epoch 38/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9942
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9942 - val_loss: 1.4557 - val_sparse_categorical_accuracy: 0.8182
# Epoch 39/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9964
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9964 - val_loss: 1.4172 - val_sparse_categorical_accuracy: 0.8380
# Epoch 40/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9949
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.86145
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0176 - sparse_categorical_accuracy: 0.9949 - val_loss: 1.4266 - val_sparse_categorical_accuracy: 0.8182
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 66 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.02%
# Training loss: 0.0322
# Test accuracy: 92.39%
# Test loss: 0.4423

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7853    0.9303    0.8517       287
#            1     0.9956    0.8910    0.9404      1009
#            2     0.8926    0.9686    0.9290       223
#            3     0.9835    0.8041    0.8848       148
#            4     0.8269    0.8097    0.8182       289
#            5     0.9332    0.9933    0.9623      1041
#
#     accuracy                         0.9239      2997
#    macro avg     0.9028    0.8995    0.8977      2997
# weighted avg     0.9292    0.9239    0.9241      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 2, Transformer 2

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 200, 128)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_11 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_4             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_5             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 796,038 (3.04 MB)
#  Trainable params: 795,270 (3.03 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.4493 - sparse_categorical_accuracy: 0.8414
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.59860, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 30s 48ms/step - loss: 0.4488 - sparse_categorical_accuracy: 0.8416 - val_loss: 1.2968 - val_sparse_categorical_accuracy: 0.5986
# Epoch 2/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1166 - sparse_categorical_accuracy: 0.9610
# Epoch 2: val_sparse_categorical_accuracy improved from 0.59860 to 0.78380, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1165 - sparse_categorical_accuracy: 0.9610 - val_loss: 0.8617 - val_sparse_categorical_accuracy: 0.7838
# Epoch 3/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2144 - sparse_categorical_accuracy: 0.9305
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.78380
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.2139 - sparse_categorical_accuracy: 0.9307 - val_loss: 1.3370 - val_sparse_categorical_accuracy: 0.7500
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9787
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.78380
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0653 - sparse_categorical_accuracy: 0.9787 - val_loss: 1.3322 - val_sparse_categorical_accuracy: 0.7782
# Epoch 5/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1051 - sparse_categorical_accuracy: 0.9630
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.78380
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1050 - sparse_categorical_accuracy: 0.9630 - val_loss: 1.6105 - val_sparse_categorical_accuracy: 0.7765
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1013 - sparse_categorical_accuracy: 0.9706
# Epoch 6: val_sparse_categorical_accuracy improved from 0.78380 to 0.79274, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9706 - val_loss: 1.7527 - val_sparse_categorical_accuracy: 0.7927
# Epoch 7/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0743 - sparse_categorical_accuracy: 0.9767
# Epoch 7: val_sparse_categorical_accuracy improved from 0.79274 to 0.79385, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0742 - sparse_categorical_accuracy: 0.9768 - val_loss: 2.1311 - val_sparse_categorical_accuracy: 0.7939
# Epoch 8/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1713 - sparse_categorical_accuracy: 0.9321
# Epoch 8: val_sparse_categorical_accuracy improved from 0.79385 to 0.80642, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9323 - val_loss: 1.7099 - val_sparse_categorical_accuracy: 0.8064
# Epoch 9/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9817
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.80642
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9817 - val_loss: 1.9146 - val_sparse_categorical_accuracy: 0.7969
# Epoch 10/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2305 - sparse_categorical_accuracy: 0.9289
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.80642
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9292 - val_loss: 1.9526 - val_sparse_categorical_accuracy: 0.8020
# Epoch 11/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9386
# Epoch 11: val_sparse_categorical_accuracy improved from 0.80642 to 0.84050, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.2031 - sparse_categorical_accuracy: 0.9388 - val_loss: 1.4621 - val_sparse_categorical_accuracy: 0.8405
# Epoch 12/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1606 - sparse_categorical_accuracy: 0.9517
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.84050
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1600 - sparse_categorical_accuracy: 0.9519 - val_loss: 1.8878 - val_sparse_categorical_accuracy: 0.8182
# Epoch 13/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9839
# Epoch 13: val_sparse_categorical_accuracy improved from 0.84050 to 0.84274, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9839 - val_loss: 2.0080 - val_sparse_categorical_accuracy: 0.8427
# Epoch 14/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9868
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9868 - val_loss: 1.8082 - val_sparse_categorical_accuracy: 0.8061
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9682
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - loss: 0.1002 - sparse_categorical_accuracy: 0.9683 - val_loss: 1.6503 - val_sparse_categorical_accuracy: 0.8061
# Epoch 16/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0762 - sparse_categorical_accuracy: 0.9753
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0761 - sparse_categorical_accuracy: 0.9753 - val_loss: 1.6285 - val_sparse_categorical_accuracy: 0.8204
# Epoch 17/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9862
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.9512 - val_sparse_categorical_accuracy: 0.8249
# Epoch 18/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9861
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9861 - val_loss: 1.6089 - val_sparse_categorical_accuracy: 0.7849
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9728
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - loss: 0.0870 - sparse_categorical_accuracy: 0.9729 - val_loss: 2.0083 - val_sparse_categorical_accuracy: 0.7880
# Epoch 20/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1557 - sparse_categorical_accuracy: 0.9522
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.1554 - sparse_categorical_accuracy: 0.9523 - val_loss: 1.2424 - val_sparse_categorical_accuracy: 0.8117
# Epoch 21/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9860
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9860 - val_loss: 1.3541 - val_sparse_categorical_accuracy: 0.8039
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9861
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9861 - val_loss: 1.3774 - val_sparse_categorical_accuracy: 0.8061
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9885
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0337 - sparse_categorical_accuracy: 0.9885 - val_loss: 1.3902 - val_sparse_categorical_accuracy: 0.8142
# Epoch 24/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9884
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9884 - val_loss: 1.0755 - val_sparse_categorical_accuracy: 0.8254
# Epoch 25/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0321 - sparse_categorical_accuracy: 0.9888
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9888 - val_loss: 1.5281 - val_sparse_categorical_accuracy: 0.8193
# Epoch 26/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0359 - sparse_categorical_accuracy: 0.9871
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0360 - sparse_categorical_accuracy: 0.9871 - val_loss: 1.8028 - val_sparse_categorical_accuracy: 0.8089
# Epoch 27/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9839
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9839 - val_loss: 1.9395 - val_sparse_categorical_accuracy: 0.8249
# Epoch 28/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9881
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0383 - sparse_categorical_accuracy: 0.9881 - val_loss: 1.7546 - val_sparse_categorical_accuracy: 0.8338
# Epoch 29/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9856
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9856 - val_loss: 2.5512 - val_sparse_categorical_accuracy: 0.7944
# Epoch 30/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9868
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9867 - val_loss: 1.8011 - val_sparse_categorical_accuracy: 0.7690
# Epoch 31/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9809
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9810 - val_loss: 1.9840 - val_sparse_categorical_accuracy: 0.8075
# Epoch 32/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9888
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9888 - val_loss: 2.1744 - val_sparse_categorical_accuracy: 0.7782
# Epoch 33/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1531 - sparse_categorical_accuracy: 0.9571
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.84274
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - loss: 0.1526 - sparse_categorical_accuracy: 0.9573 - val_loss: 1.8684 - val_sparse_categorical_accuracy: 0.8087
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.08%
# Training loss: 0.0260
# Test accuracy: 93.46%
# Test loss: 0.3046

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8224    0.8711    0.8460       287
#            1     0.9855    0.9425    0.9635      1009
#            2     0.8980    0.9865    0.9402       223
#            3     0.9840    0.8311    0.9011       148
#            4     0.8040    0.8374    0.8203       289
#            5     0.9603    0.9750    0.9676      1041
#
#     accuracy                         0.9346      2997
#    macro avg     0.9090    0.9073    0.9065      2997
# weighted avg     0.9370    0.9346    0.9351      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 4
# - CNN 3, Transformer 2

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(64, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 200, 64)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 200, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_14 (ReLU)                 │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 200, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_15 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_8             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_9             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_6      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 819,974 (3.13 MB)
#  Trainable params: 819,078 (3.12 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best4.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.4255 - sparse_categorical_accuracy: 0.8485
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.79637, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - loss: 0.4249 - sparse_categorical_accuracy: 0.8487 - val_loss: 1.2239 - val_sparse_categorical_accuracy: 0.7964
# Epoch 2/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1420 - sparse_categorical_accuracy: 0.9534
# Epoch 2: val_sparse_categorical_accuracy improved from 0.79637 to 0.81872, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 24s 26ms/step - loss: 0.1419 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.9313 - val_sparse_categorical_accuracy: 0.8187
# Epoch 3/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1711 - sparse_categorical_accuracy: 0.9474
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.81872
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.1707 - sparse_categorical_accuracy: 0.9475 - val_loss: 1.4918 - val_sparse_categorical_accuracy: 0.8020
# Epoch 4/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9810
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.81872
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9810 - val_loss: 1.7705 - val_sparse_categorical_accuracy: 0.7360
# Epoch 5/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1925 - sparse_categorical_accuracy: 0.9423
# Epoch 5: val_sparse_categorical_accuracy improved from 0.81872 to 0.82291, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.1922 - sparse_categorical_accuracy: 0.9424 - val_loss: 0.6191 - val_sparse_categorical_accuracy: 0.8229
# Epoch 6/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9814
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9814 - val_loss: 1.6596 - val_sparse_categorical_accuracy: 0.8196
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1179 - sparse_categorical_accuracy: 0.9626
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.1175 - sparse_categorical_accuracy: 0.9627 - val_loss: 1.9189 - val_sparse_categorical_accuracy: 0.8168
# Epoch 8/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9843
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.7914 - val_sparse_categorical_accuracy: 0.8209
# Epoch 9/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1425 - sparse_categorical_accuracy: 0.9564
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.1422 - sparse_categorical_accuracy: 0.9565 - val_loss: 1.3667 - val_sparse_categorical_accuracy: 0.8198
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9436
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.1782 - sparse_categorical_accuracy: 0.9438 - val_loss: 1.9532 - val_sparse_categorical_accuracy: 0.7528
# Epoch 11/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9818
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9818 - val_loss: 2.1358 - val_sparse_categorical_accuracy: 0.7925
# Epoch 12/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1562 - sparse_categorical_accuracy: 0.9536
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.1560 - sparse_categorical_accuracy: 0.9536 - val_loss: 2.0910 - val_sparse_categorical_accuracy: 0.7899
# Epoch 13/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9813
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9813 - val_loss: 2.0902 - val_sparse_categorical_accuracy: 0.7911
# Epoch 14/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2038 - sparse_categorical_accuracy: 0.9350
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.2029 - sparse_categorical_accuracy: 0.9353 - val_loss: 1.7181 - val_sparse_categorical_accuracy: 0.8003
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9773
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0803 - sparse_categorical_accuracy: 0.9773 - val_loss: 1.4671 - val_sparse_categorical_accuracy: 0.8017
# Epoch 16/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9837
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9837 - val_loss: 1.5466 - val_sparse_categorical_accuracy: 0.8229
# Epoch 17/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0536 - sparse_categorical_accuracy: 0.9834
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0535 - sparse_categorical_accuracy: 0.9834 - val_loss: 1.7104 - val_sparse_categorical_accuracy: 0.7905
# Epoch 18/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1035 - sparse_categorical_accuracy: 0.9704
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9704 - val_loss: 2.1926 - val_sparse_categorical_accuracy: 0.8179
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9888
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9888 - val_loss: 1.2805 - val_sparse_categorical_accuracy: 0.8101
# Epoch 20/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1894 - sparse_categorical_accuracy: 0.9430
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9431 - val_loss: 1.2104 - val_sparse_categorical_accuracy: 0.8179
# Epoch 21/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9783
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.82291
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9783 - val_loss: 1.8433 - val_sparse_categorical_accuracy: 0.7930
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9823
# Epoch 22: val_sparse_categorical_accuracy improved from 0.82291 to 0.82374, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9823 - val_loss: 1.4598 - val_sparse_categorical_accuracy: 0.8237
# Epoch 23/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9828
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.82374
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.4149 - val_sparse_categorical_accuracy: 0.8154
# Epoch 24/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9872
# Epoch 24: val_sparse_categorical_accuracy improved from 0.82374 to 0.82709, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9872 - val_loss: 1.7159 - val_sparse_categorical_accuracy: 0.8271
# Epoch 25/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9887
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9887 - val_loss: 2.0738 - val_sparse_categorical_accuracy: 0.8201
# Epoch 26/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9829
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9829 - val_loss: 2.3222 - val_sparse_categorical_accuracy: 0.8036
# Epoch 27/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0598 - sparse_categorical_accuracy: 0.9818
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0598 - sparse_categorical_accuracy: 0.9818 - val_loss: 1.4592 - val_sparse_categorical_accuracy: 0.8170
# Epoch 28/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1475 - sparse_categorical_accuracy: 0.9551
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9552 - val_loss: 2.0302 - val_sparse_categorical_accuracy: 0.8003
# Epoch 29/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0656 - sparse_categorical_accuracy: 0.9774
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0655 - sparse_categorical_accuracy: 0.9775 - val_loss: 2.0721 - val_sparse_categorical_accuracy: 0.8142
# Epoch 30/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9887
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9887 - val_loss: 1.9861 - val_sparse_categorical_accuracy: 0.8000
# Epoch 31/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9792
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0690 - sparse_categorical_accuracy: 0.9792 - val_loss: 1.5994 - val_sparse_categorical_accuracy: 0.8014
# Epoch 32/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9830
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.82709
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0538 - sparse_categorical_accuracy: 0.9830 - val_loss: 2.3421 - val_sparse_categorical_accuracy: 0.7997
# Epoch 33/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0371 - sparse_categorical_accuracy: 0.9879
# Epoch 33: val_sparse_categorical_accuracy improved from 0.82709 to 0.83492, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9879 - val_loss: 1.5960 - val_sparse_categorical_accuracy: 0.8349
# Epoch 34/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9869
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9869 - val_loss: 2.0783 - val_sparse_categorical_accuracy: 0.8061
# Epoch 35/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1238 - sparse_categorical_accuracy: 0.9643
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.1237 - sparse_categorical_accuracy: 0.9643 - val_loss: 2.2142 - val_sparse_categorical_accuracy: 0.8159
# Epoch 36/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9827
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9827 - val_loss: 2.2615 - val_sparse_categorical_accuracy: 0.8148
# Epoch 37/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9899
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9899 - val_loss: 1.6937 - val_sparse_categorical_accuracy: 0.8137
# Epoch 38/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9636
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1150 - sparse_categorical_accuracy: 0.9637 - val_loss: 1.6863 - val_sparse_categorical_accuracy: 0.8291
# Epoch 39/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9843
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 0.0424 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.6230 - val_sparse_categorical_accuracy: 0.8226
# Epoch 40/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9840
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.83492
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9841 - val_loss: 1.4007 - val_sparse_categorical_accuracy: 0.8092
# Epoch 41/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1049 - sparse_categorical_accuracy: 0.9707
# Epoch 41: val_sparse_categorical_accuracy improved from 0.83492 to 0.84860, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.1048 - sparse_categorical_accuracy: 0.9707 - val_loss: 1.3811 - val_sparse_categorical_accuracy: 0.8486
# Epoch 42/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9853
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9854 - val_loss: 1.5485 - val_sparse_categorical_accuracy: 0.8073
# Epoch 43/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9726
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9726 - val_loss: 1.4230 - val_sparse_categorical_accuracy: 0.8008
# Epoch 44/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9855
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9855 - val_loss: 1.2687 - val_sparse_categorical_accuracy: 0.8232
# Epoch 45/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9884
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9884 - val_loss: 2.0124 - val_sparse_categorical_accuracy: 0.8218
# Epoch 46/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0334 - sparse_categorical_accuracy: 0.9883
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0334 - sparse_categorical_accuracy: 0.9883 - val_loss: 2.0186 - val_sparse_categorical_accuracy: 0.8330
# Epoch 47/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9927
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9927 - val_loss: 1.4983 - val_sparse_categorical_accuracy: 0.8120
# Epoch 48/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9850
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9850 - val_loss: 1.5235 - val_sparse_categorical_accuracy: 0.8087
# Epoch 49/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0385 - sparse_categorical_accuracy: 0.9873
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9873 - val_loss: 2.5612 - val_sparse_categorical_accuracy: 0.8123
# Epoch 50/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9856
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9856 - val_loss: 2.5623 - val_sparse_categorical_accuracy: 0.8201
# Epoch 51/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9883
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9884 - val_loss: 2.5856 - val_sparse_categorical_accuracy: 0.8304
# Epoch 52/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9902
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9902 - val_loss: 2.7455 - val_sparse_categorical_accuracy: 0.8399
# Epoch 53/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9474
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.1973 - sparse_categorical_accuracy: 0.9475 - val_loss: 2.3438 - val_sparse_categorical_accuracy: 0.8240
# Epoch 54/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9796
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9796 - val_loss: 2.5907 - val_sparse_categorical_accuracy: 0.8299
# Epoch 55/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9858
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9858 - val_loss: 2.3280 - val_sparse_categorical_accuracy: 0.8148
# Epoch 56/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9908
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9908 - val_loss: 2.5639 - val_sparse_categorical_accuracy: 0.8193
# Epoch 57/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9832
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9832 - val_loss: 2.1323 - val_sparse_categorical_accuracy: 0.8128
# Epoch 58/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9904
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0293 - sparse_categorical_accuracy: 0.9904 - val_loss: 2.2974 - val_sparse_categorical_accuracy: 0.8274
# Epoch 59/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9811
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9811 - val_loss: 2.7955 - val_sparse_categorical_accuracy: 0.7947
# Epoch 60/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9878
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9878 - val_loss: 1.7879 - val_sparse_categorical_accuracy: 0.8360
# Epoch 61/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0383 - sparse_categorical_accuracy: 0.9884
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.84860
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.9698 - val_sparse_categorical_accuracy: 0.8332
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 41.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best4.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 98 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 98.77%
# Training loss: 0.0368
# Test accuracy: 87.35%
# Test loss: 0.5743

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6685    0.8362    0.7430       287
#            1     0.9957    0.9138    0.9530      1009
#            2     0.8606    0.9686    0.9114       223
#            3     0.9528    0.8176    0.8800       148
#            4     0.5613    0.7924    0.6571       289
#            5     0.9611    0.8549    0.9049      1041
#
#     accuracy                         0.8735      2997
#    macro avg     0.8333    0.8639    0.8416      2997
# weighted avg     0.8983    0.8735    0.8810      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
