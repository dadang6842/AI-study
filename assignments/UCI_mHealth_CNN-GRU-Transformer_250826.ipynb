# %% [markdown]
# # UCI mHealth Classification - CNN-GRU-Transformer
# - https://archive.ics.uci.edu/dataset/319/mhealth+dataset
#
# #### 데이터 구조
# - 10명의 참가자별로 mHealth_subject<SUBJECT_ID>.log 파일 존재
# - 가속도, 자이로, 자기장, 심전도 -> 총 23개의 feature
#
# #### 라벨
# 0. Other
# 1. Standing still
# 2. Sitting and relaxing
# 3. Lying down
# 4. Walking
# 5. Climbing stairs
# 6. Waist bends forward
# 7. Frontal elevation of arms
# 8. Knees bending (crouching)
# 9. Cycling
# 10. Jogging
# 11. Running
# 12. Jump front & back

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Conv1D, BatchNormalization, ReLU, MaxPool1D, GlobalAveragePooling1D, MultiHeadAttention, LayerNormalization, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils import resample
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
LABELS = [
    'Other', 'Standing', 'Sitting', 'Lying', 'Walking',
    'Climbing stairs', 'Waist bends', 'Frontal elevation',
    'Knees bending', 'Cycling', 'Jogging', 'Running', 'Jumping'
]

# %%
base_dir = "/content/drive/MyDrive/AI_data/MHEALTHDATASET"
dfs = []
col_names = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg1', 'ecg2',
    'acc_left_ankle_x', 'acc_left_ankle_y', 'acc_left_ankle_z',
    'gyro_left_ankle_x', 'gyro_left_ankle_y', 'gyro_left_ankle_z',
    'magnet_left_ankle_x', 'magnet_left_ankl6e_y', 'magnet_left_ankle_z',
    'acc_right_arm_x', 'acc_right_arm_y', 'acc_right_arm_z',
    'gyro_right_arm_x', 'gyro_right_arm_y', 'gyro_right_arm_z',
    'magnet_right_arm_x', 'magnet_right_arm_y', 'magnet_right_arm_z',
    'label', 'subject'
]

for i in range(1, 11):
    path = os.path.join(base_dir, f"mHealth_subject{i}.log")
    df_i = pd.read_csv(path, sep='\t', header=None)
    df_i['subject'] = i
    dfs.append(df_i)

df = pd.concat(dfs, ignore_index=True)
df = df.dropna(how='any', axis=0)
df.columns = col_names
df
# Out:
#          acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0            -9.8184     0.009971      0.29563  0.004186  0.004186
# 1            -9.8489     0.524040      0.37348  0.004186  0.016745
# 2            -9.6602     0.181850      0.43742  0.016745  0.037677
# 3            -9.6507     0.214220      0.24033  0.079540  0.117220
# 4            -9.7030     0.303890      0.31156  0.221870  0.205130
# ...              ...          ...          ...       ...       ...
# 1215740      -9.2476    -0.248070     -2.62230  0.230250  0.234430
# 1215741      -9.4632    -0.073513     -2.11190  0.276300  0.284670
# 1215742      -9.4011    -0.144580     -3.02350  0.288850  0.301410
# 1215743      -9.3732    -0.026252     -2.70760  0.351650  0.347460
# 1215744      -9.3518    -0.592450     -2.63230  0.280480  0.272110
#
#          acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0                  2.1849           -9.6967           0.63077
# 1                  2.3876           -9.5080           0.68389
# 2                  2.4086           -9.5674           0.68113
# 3                  2.1814           -9.4301           0.55031
# 4                  2.4173           -9.3889           0.71098
# ...                   ...               ...               ...
# 1215740            1.7849           -9.8287           0.29725
# 1215741            1.8687           -9.8766           0.46236
# 1215742            1.6928           -9.9290           0.16631
# 1215743            1.5279           -9.6306           0.30458
# 1215744            1.6614           -9.8398           0.18088
#
#          gyro_left_ankle_x  gyro_left_ankle_y  ...  acc_right_arm_y  \
# 0                 0.103900           -0.84053  ...          -4.5781
# 1                 0.085343           -0.83865  ...          -4.3198
# 2                 0.085343           -0.83865  ...          -4.2772
# 3                 0.085343           -0.83865  ...          -4.3163
# 4                 0.085343           -0.83865  ...          -4.1459
# ...                    ...                ...  ...              ...
# 1215740          -0.341370           -0.90056  ...          -8.9071
# 1215741          -0.341370           -0.90056  ...          -8.7455
# 1215742          -0.341370           -0.90056  ...          -9.1155
# 1215743          -0.341370           -0.90056  ...          -9.1441
# 1215744          -0.332100           -0.90432  ...          -8.9324
#
#          acc_right_arm_z  gyro_right_arm_x  gyro_right_arm_y  \
# 0               0.187760         -0.449020          -1.01030
# 1               0.023595         -0.449020          -1.01030
# 2               0.275720         -0.449020          -1.01030
# 3               0.367520         -0.456860          -1.00820
# 4               0.407290         -0.456860          -1.00820
# ...                  ...               ...               ...
# 1215740         0.294230          0.041176          -0.99384
# 1215741         0.448140          0.041176          -0.99384
# 1215742         0.450480          0.041176          -0.99384
# 1215743         0.594880          0.041176          -0.99384
# 1215744         0.761710          0.035294          -1.02050
#
#          gyro_right_arm_z  magnet_right_arm_x  magnet_right_arm_y  \
# 0                0.034483            -2.35000           -1.610200
# 1                0.034483            -2.16320           -0.882540
# 2                0.034483            -1.61750           -0.165620
# 3                0.025862            -1.07710            0.006945
# 4                0.025862            -0.53684            0.175900
# ...                   ...                 ...                 ...
# 1215740         -0.480600             2.40890            7.496100
# 1215741         -0.480600             1.69450            7.866000
# 1215742         -0.480600             1.15770            8.052800
# 1215743         -0.480600             0.27441            9.487900
# 1215744         -0.471980            -0.98056            9.663600
#
#          magnet_right_arm_z  label  subject
# 0                 -0.030899      0        1
# 1                  0.326570      0        1
# 2                 -0.030693      0        1
# 3                 -0.382620      0        1
# 4                 -1.095500      0        1
# ...                     ...    ...      ...
# 1215740            7.915500      0       10
# 1215741            7.897500      0       10
# 1215742            7.884900      0       10
# 1215743            5.325800      0       10
# 1215744            3.493900      0       10
#
# [1215745 rows x 25 columns]

# %%
df.label.value_counts()
# Out:
# label
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 5      30720
# 11     30720
# 10     30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: count, dtype: int64

# %%
# downsampling
from sklearn.utils import resample

df_majority = df[df.label==0]
df_minorities = df[df.label!=0]

df_majority_downsampled = resample(df_majority, n_samples=30000, random_state=42)
df = pd.concat([df_majority_downsampled, df_minorities])
df.label.value_counts()
# Out:
# label
# 1     30720
# 3     30720
# 2     30720
# 4     30720
# 9     30720
# 11    30720
# 5     30720
# 10    30720
# 0     30000
# 7     29441
# 8     29337
# 6     28315
# 12    10342
# Name: count, dtype: int64

# %%
# df.to_csv('/content/drive/MyDrive/AI_data/MHEALTHDATASET/mhealth_resampled_data.csv',index = False)

# %%
df.isnull().sum()
# Out:
# acc_chest_x             0
# acc_chest_y             0
# acc_chest_z             0
# ecg1                    0
# ecg2                    0
# acc_left_ankle_x        0
# acc_left_ankle_y        0
# acc_left_ankle_z        0
# gyro_left_ankle_x       0
# gyro_left_ankle_y       0
# gyro_left_ankle_z       0
# magnet_left_ankle_x     0
# magnet_left_ankl6e_y    0
# magnet_left_ankle_z     0
# acc_right_arm_x         0
# acc_right_arm_y         0
# acc_right_arm_z         0
# gyro_right_arm_x        0
# gyro_right_arm_y        0
# gyro_right_arm_z        0
# magnet_right_arm_x      0
# magnet_right_arm_y      0
# magnet_right_arm_z      0
# label                   0
# subject                 0
# dtype: int64

# %%
# 피험자 1-6: 훈련, 피험자 7-8: 검증, 피험자 8-9: 테스트
train = df[~df['subject'].isin([7, 8, 9, 10])]
val = df[df['subject'].isin([7, 8])]
test = df[df['subject'].isin([9, 10])]

train.shape, val.shape, test.shape
# Out:
# ((226128, 25), (73326, 25), (73741, 25))

# %%
X_train = train.drop(['label','subject'], axis=1)
y_train = train['label']

X_val = val.drop(['label','subject'], axis=1)
y_val = val['label']

X_test = test.drop(['label','subject'], axis=1)
y_test = test['label']

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((226128, 23), (226128,), (73326, 23), (73326,), (73741, 23), (73741,))

# %%
sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)
X_val = pd.DataFrame(sc.transform(X_val), columns=X_val.columns)
X_test = pd.DataFrame(sc.transform(X_test), columns=X_train.columns)

X_train
# Out:
#         acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0         -0.087384    -0.180627    -0.786215  0.007915 -0.011472
# 1         -0.328788    -0.300078     0.605666 -0.081073 -0.087624
# 2          0.241808     0.040644    -0.641235  0.070732 -0.107931
# 3         -0.354832    -0.009466     0.177121 -0.447507 -1.224823
# 4          0.244441     0.152781    -0.843392 -0.332342 -0.184085
# ...             ...          ...          ...       ...       ...
# 226123    -0.998367     0.135213    -0.547845 -0.248588 -0.544528
# 226124    -1.148293     0.104779    -0.661009 -0.180527 -0.544528
# 226125    -1.076286     0.134339    -1.033485 -0.107247 -0.534377
# 226126    -0.955557     0.620911    -1.302284  0.002681 -0.427768
# 226127    -1.031326     1.212066    -1.397428  0.028855 -0.493764
#
#         acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0              -0.577582          0.733111          0.855263
# 1              -0.048897         -0.100417          0.083515
# 2               0.010368          0.093603         -0.501927
# 3              -0.497284         -0.085610          0.353416
# 4              -1.151754         -0.146134         -0.361905
# ...                  ...               ...               ...
# 226123         -0.299251         -0.707677          0.882140
# 226124          0.232369         -0.590383          0.757580
# 226125          1.156834         -0.723743          0.356439
# 226126          0.927660         -0.718710         -0.643712
# 226127          0.327690         -1.632098         -1.826351
#
#         gyro_left_ankle_x  gyro_left_ankle_y  ...  magnet_left_ankle_z  \
# 0                0.283638          -0.578020  ...            -0.402525
# 1               -0.577486          -0.415903  ...             0.011245
# 2               -0.867129           0.049140  ...             0.540380
# 3               -1.442512          -0.458564  ...            -0.030661
# 4                1.782740           0.484325  ...             2.124397
# ...                   ...                ...  ...                  ...
# 226123          -0.432654          -0.603626  ...             0.449349
# 226124          -0.432654          -0.603626  ...             0.287044
# 226125          -0.432654          -0.603626  ...             0.031366
# 226126          -0.354383          -0.629232  ...             0.009413
# 226127          -0.354383          -0.629232  ...            -0.011482
#
#         acc_right_arm_x  acc_right_arm_y  acc_right_arm_z  gyro_right_arm_x  \
# 0             -0.878509        -0.115785         0.092842         -1.287582
# 1              0.142070        -0.403044         0.292032         -1.181228
# 2              0.419364        -0.149160        -0.108985         -0.159630
# 3              0.347123        -0.554803        -0.268771          0.292298
# 4             -0.463871        -0.334905        -0.028403         -0.584985
# ...                 ...              ...              ...               ...
# 226123        -0.424959        -0.777297         0.256151         -0.190019
# 226124        -0.667105        -1.022036         0.412414         -0.190019
# 226125        -0.789524        -1.428916         0.539305         -0.190019
# 226126        -0.565365        -1.578079         0.372380         -0.190019
# 226127        -0.266865        -1.285248         0.331576         -0.045704
#
#         gyro_right_arm_y  gyro_right_arm_z  magnet_right_arm_x  \
# 0               0.881529         -0.227001            0.355856
# 1              -0.788334         -0.017597           -0.007098
# 2              -0.799296         -1.414959           -0.118250
# 3              -1.000270         -1.567971            0.008544
# 4              -0.481392          0.522008            0.201140
# ...                  ...               ...                 ...
# 226123         -1.164606         -0.086059           -0.832750
# 226124         -1.164606         -0.086059           -0.891081
# 226125         -1.164606         -0.086059           -0.798699
# 226126         -1.164606         -0.086059           -0.468607
# 226127         -1.259630         -0.118272           -0.137930
#
#         magnet_right_arm_y  magnet_right_arm_z
# 0                -0.757309            0.065910
# 1                -0.073927           -0.046895
# 2                -0.093139           -0.227639
# 3                -0.094608           -0.020982
# 4                 0.141492           -0.024674
# ...                    ...                 ...
# 226123           -0.733695           -0.744858
# 226124           -1.279427           -0.798790
# 226125           -2.073697           -0.786247
# 226126           -2.871990           -0.626123
# 226127           -3.089391           -0.301282
#
# [226128 rows x 23 columns]

# %% [markdown]
# ### create_dataset
# - X에 dataframe을 입력 -> 여러 개의 columns
# - x.shape이 (time_steps, n_features)이기 때문에 Xs.shape은 (n_samples, time_steps, n_features). 따라서 reshape이 필요 없음
# - ys: 윈도우 내 최빈값을 라벨로 설정, 1D 리스트
# - sklearn, keras에서 y를 (n_samples, 1) 형태로 사용하기 때문에 reshape

# %%
def create_dataset(X, y, time_steps, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        x = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(x)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

# %%
TIME_STEPS = 200
STEPS = 40

X_train, y_train = create_dataset(X_train, y_train, TIME_STEPS, STEPS)
X_val, y_val = create_dataset(X_val, y_val, TIME_STEPS, STEPS)
X_test, y_test = create_dataset(X_test, y_test, TIME_STEPS, STEPS)

print(f"Training sequences: {X_train.shape}")
print(f"Validation sequences: {X_val.shape}")
print(f"Test sequences: {X_test.shape}")
# Out:
# Training sequences: (5649, 200, 23)
# Validation sequences: (1829, 200, 23)
# Test sequences: (1839, 200, 23)

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, GRU 1, Transformer 1
# - Conv1D 출력과 TransformerBlock의 embed_dim 수가 일치해야함
# - residual addition 할 때 shape이 맞아야 하기 때문

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 874,381 (3.34 MB)
#  Trainable params: 873,613 (3.33 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6764 - sparse_categorical_accuracy: 0.7915
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.89612, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - loss: 0.6720 - sparse_categorical_accuracy: 0.7929 - val_loss: 0.2621 - val_sparse_categorical_accuracy: 0.8961
# Epoch 2/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9834
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.89612
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.4422 - val_sparse_categorical_accuracy: 0.8606
# Epoch 3/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0488 - sparse_categorical_accuracy: 0.9839
# Epoch 3: val_sparse_categorical_accuracy improved from 0.89612 to 0.93166, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.1890 - val_sparse_categorical_accuracy: 0.9317
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9939
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.93166
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.6173 - val_sparse_categorical_accuracy: 0.8562
# Epoch 5/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0377 - sparse_categorical_accuracy: 0.9921
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.93166
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0377 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.7165 - val_sparse_categorical_accuracy: 0.7305
# Epoch 6/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9950
# Epoch 6: val_sparse_categorical_accuracy improved from 0.93166 to 0.93384, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 0.9338
# Epoch 7/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9910
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.3708 - val_sparse_categorical_accuracy: 0.8781
# Epoch 8/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9980
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.5996 - val_sparse_categorical_accuracy: 0.8967
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9968
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.5040 - val_sparse_categorical_accuracy: 0.8250
# Epoch 10/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9905
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.4238 - val_sparse_categorical_accuracy: 0.8682
# Epoch 11/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9973
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.3741 - val_sparse_categorical_accuracy: 0.8732
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9969
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.9054 - val_sparse_categorical_accuracy: 0.8174
# Epoch 13/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9979
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9979 - val_loss: 1.3045 - val_sparse_categorical_accuracy: 0.8026
# Epoch 14/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9991
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.9583 - val_sparse_categorical_accuracy: 0.7999
# Epoch 15/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9974
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9973 - val_loss: 1.0325 - val_sparse_categorical_accuracy: 0.8398
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9730
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9731 - val_loss: 1.7886 - val_sparse_categorical_accuracy: 0.7698
# Epoch 17/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9917
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9916 - val_loss: 1.4515 - val_sparse_categorical_accuracy: 0.8185
# Epoch 18/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9964
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0113 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.8579 - val_sparse_categorical_accuracy: 0.9202
# Epoch 19/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9967
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.93384
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.9848 - val_sparse_categorical_accuracy: 0.8879
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9962
# Epoch 20: val_sparse_categorical_accuracy improved from 0.93384 to 0.93603, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.7827 - val_sparse_categorical_accuracy: 0.9360
# Epoch 21/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9968
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9968 - val_loss: 1.1461 - val_sparse_categorical_accuracy: 0.9010
# Epoch 22/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9978
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9977 - val_loss: 1.1677 - val_sparse_categorical_accuracy: 0.8633
# Epoch 23/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1213 - sparse_categorical_accuracy: 0.9710
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9711 - val_loss: 1.6212 - val_sparse_categorical_accuracy: 0.7671
# Epoch 24/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9899
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 0.0291 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.9280 - val_sparse_categorical_accuracy: 0.8300
# Epoch 25/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9971
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.7325 - val_sparse_categorical_accuracy: 0.9295
# Epoch 26/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9974
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.9493 - val_sparse_categorical_accuracy: 0.9213
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9974
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.9194 - val_sparse_categorical_accuracy: 0.9235
# Epoch 28/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9985
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9985 - val_loss: 1.2284 - val_sparse_categorical_accuracy: 0.8611
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9992
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9992 - val_loss: 1.1209 - val_sparse_categorical_accuracy: 0.8753
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9994
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.7207 - val_sparse_categorical_accuracy: 0.8568
# Epoch 31/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9995
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0019 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.4983 - val_sparse_categorical_accuracy: 0.8628
# Epoch 32/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9990
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.4463 - val_sparse_categorical_accuracy: 0.8600
# Epoch 33/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9956
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.6491 - val_sparse_categorical_accuracy: 0.8666
# Epoch 34/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9960
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9959 - val_loss: 1.0918 - val_sparse_categorical_accuracy: 0.8365
# Epoch 35/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0305 - sparse_categorical_accuracy: 0.9919
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0301 - sparse_categorical_accuracy: 0.9920 - val_loss: 1.6238 - val_sparse_categorical_accuracy: 0.8376
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9975
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9975 - val_loss: 1.8539 - val_sparse_categorical_accuracy: 0.8414
# Epoch 37/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9936
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.7548 - val_sparse_categorical_accuracy: 0.8387
# Epoch 38/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9984
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.3190 - val_sparse_categorical_accuracy: 0.8551
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9971
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.9025 - val_sparse_categorical_accuracy: 0.8874
# Epoch 40/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9983
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.93603
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9982 - val_loss: 1.0792 - val_sparse_categorical_accuracy: 0.8792
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 64 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.89%
# Training loss: 0.0031
# Test accuracy: 93.75%
# Test loss: 0.4389

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9857    0.9928       140
#            1     1.0000    1.0000    1.0000       154
#            2     1.0000    0.9935    0.9967       154
#            3     0.9871    1.0000    0.9935       153
#            4     1.0000    0.7727    0.8718       154
#            5     0.8095    0.9935    0.8921       154
#            6     0.6456    1.0000    0.7847       133
#            7     1.0000    0.9929    0.9964       141
#            8     1.0000    0.4863    0.6544       146
#            9     0.9808    1.0000    0.9903       153
#           10     1.0000    1.0000    1.0000       154
#           11     1.0000    1.0000    1.0000       154
#           12     0.9800    1.0000    0.9899        49
#
#     accuracy                         0.9375      1839
#    macro avg     0.9541    0.9404    0.9356      1839
# weighted avg     0.9552    0.9375    0.9345      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 2, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_2             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,269,133 (4.84 MB)
#  Trainable params: 1,268,365 (4.84 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.7392 - sparse_categorical_accuracy: 0.7644
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.84254, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 0.7342 - sparse_categorical_accuracy: 0.7660 - val_loss: 0.3884 - val_sparse_categorical_accuracy: 0.8425
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9923
# Epoch 2: val_sparse_categorical_accuracy improved from 0.84254 to 0.85949, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.6291 - val_sparse_categorical_accuracy: 0.8595
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0586 - sparse_categorical_accuracy: 0.9825
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.85949
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.6985 - val_sparse_categorical_accuracy: 0.8332
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9865
# Epoch 4: val_sparse_categorical_accuracy improved from 0.85949 to 0.98907, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0427 - val_sparse_categorical_accuracy: 0.9891
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0262 - sparse_categorical_accuracy: 0.9922
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0261 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.2149 - val_sparse_categorical_accuracy: 0.8994
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0284 - sparse_categorical_accuracy: 0.9933
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9933 - val_loss: 0.4553 - val_sparse_categorical_accuracy: 0.9081
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9965
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9732
# Epoch 8/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9904
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.8331 - val_sparse_categorical_accuracy: 0.9142
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9956
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.7348 - val_sparse_categorical_accuracy: 0.9393
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9964
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.6443 - val_sparse_categorical_accuracy: 0.9464
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9990
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.7835 - val_sparse_categorical_accuracy: 0.9404
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9973
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.7422 - val_sparse_categorical_accuracy: 0.9459
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9978
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.5833 - val_sparse_categorical_accuracy: 0.9377
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9990
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.5835 - val_sparse_categorical_accuracy: 0.9481
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9992
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.7421 - val_sparse_categorical_accuracy: 0.9486
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9986
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.7985 - val_sparse_categorical_accuracy: 0.9481
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.8578 - val_sparse_categorical_accuracy: 0.9481
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8427 - val_sparse_categorical_accuracy: 0.9502
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.8752 - val_sparse_categorical_accuracy: 0.9481
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9986
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.9505 - val_sparse_categorical_accuracy: 0.8699
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1270 - sparse_categorical_accuracy: 0.9709
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.1275 - sparse_categorical_accuracy: 0.9707 - val_loss: 1.0801 - val_sparse_categorical_accuracy: 0.8486
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9905
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0292 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.6358 - val_sparse_categorical_accuracy: 0.9404
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1613 - sparse_categorical_accuracy: 0.9631
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.1605 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.8682
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9890
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.4901 - val_sparse_categorical_accuracy: 0.8978
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 70 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.79%
# Training loss: 0.0085
# Test accuracy: 98.75%
# Test loss: 0.0507

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9872    1.0000    0.9935       154
#            2     0.9934    0.9740    0.9836       154
#            3     1.0000    0.9935    0.9967       153
#            4     1.0000    0.9935    0.9967       154
#            5     1.0000    0.9870    0.9935       154
#            6     0.9925    1.0000    0.9963       133
#            7     0.9771    0.9078    0.9412       141
#            8     0.9864    0.9932    0.9898       146
#            9     0.9217    1.0000    0.9592       153
#           10     0.9935    1.0000    0.9968       154
#           11     1.0000    0.9935    0.9967       154
#           12     1.0000    1.0000    1.0000        49
#
#     accuracy                         0.9875      1839
#    macro avg     0.9886    0.9879    0.9880      1839
# weighted avg     0.9879    0.9875    0.9875      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 3, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_9 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_4             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,318,925 (5.03 MB)
#  Trainable params: 1,317,901 (5.03 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7318 - sparse_categorical_accuracy: 0.7698
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.76599, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 0.7269 - sparse_categorical_accuracy: 0.7714 - val_loss: 1.2479 - val_sparse_categorical_accuracy: 0.7660
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0776 - sparse_categorical_accuracy: 0.9786
# Epoch 2: val_sparse_categorical_accuracy improved from 0.76599 to 0.90159, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 0.0774 - sparse_categorical_accuracy: 0.9786 - val_loss: 0.6512 - val_sparse_categorical_accuracy: 0.9016
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9849
# Epoch 3: val_sparse_categorical_accuracy improved from 0.90159 to 0.90268, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.6545 - val_sparse_categorical_accuracy: 0.9027
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9908
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9908 - val_loss: 1.1396 - val_sparse_categorical_accuracy: 0.7895
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9907
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0291 - sparse_categorical_accuracy: 0.9906 - val_loss: 1.4783 - val_sparse_categorical_accuracy: 0.7944
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9946
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0175 - sparse_categorical_accuracy: 0.9946 - val_loss: 1.2727 - val_sparse_categorical_accuracy: 0.8311
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9950
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9950 - val_loss: 1.6491 - val_sparse_categorical_accuracy: 0.8300
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9589
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.1871 - sparse_categorical_accuracy: 0.9590 - val_loss: 1.0174 - val_sparse_categorical_accuracy: 0.7704
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9859
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.5695 - val_sparse_categorical_accuracy: 0.8999
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9940
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9940 - val_loss: 1.1447 - val_sparse_categorical_accuracy: 0.7758
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9976
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.5875 - val_sparse_categorical_accuracy: 0.8841
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9960
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9960 - val_loss: 0.4367 - val_sparse_categorical_accuracy: 0.8841
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9900
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.90268
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9900 - val_loss: 1.3800 - val_sparse_categorical_accuracy: 0.7731
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9897
# Epoch 14: val_sparse_categorical_accuracy improved from 0.90268 to 0.91580, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.4799 - val_sparse_categorical_accuracy: 0.9158
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9975
# Epoch 15: val_sparse_categorical_accuracy improved from 0.91580 to 0.92400, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.6521 - val_sparse_categorical_accuracy: 0.9240
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9991
# Epoch 16: val_sparse_categorical_accuracy improved from 0.92400 to 0.93986, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.6163 - val_sparse_categorical_accuracy: 0.9399
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9986
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.9321 - val_sparse_categorical_accuracy: 0.8868
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9984
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.8386 - val_sparse_categorical_accuracy: 0.8934
# Epoch 19/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9973
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9973 - val_loss: 1.1141 - val_sparse_categorical_accuracy: 0.8671
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9880
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.8986 - val_sparse_categorical_accuracy: 0.8185
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9742
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9743 - val_loss: 1.1734 - val_sparse_categorical_accuracy: 0.7846
# Epoch 22/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1004 - sparse_categorical_accuracy: 0.9758
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0996 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.9211 - val_sparse_categorical_accuracy: 0.9032
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9881
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.5506 - val_sparse_categorical_accuracy: 0.9163
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9982
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0107 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.6189 - val_sparse_categorical_accuracy: 0.9054
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9968
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.7798 - val_sparse_categorical_accuracy: 0.9005
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9969
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.7132 - val_sparse_categorical_accuracy: 0.9147
# Epoch 27/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9944
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.8300 - val_sparse_categorical_accuracy: 0.9043
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9987
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0046 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.5386 - val_sparse_categorical_accuracy: 0.9245
# Epoch 29/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9979
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.5090 - val_sparse_categorical_accuracy: 0.9399
# Epoch 30/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9984
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.93986
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0047 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.6660 - val_sparse_categorical_accuracy: 0.9366
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9991
# Epoch 31: val_sparse_categorical_accuracy improved from 0.93986 to 0.94204, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.7150 - val_sparse_categorical_accuracy: 0.9420
# Epoch 32/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9992
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.7135 - val_sparse_categorical_accuracy: 0.9388
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9993
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.7378 - val_sparse_categorical_accuracy: 0.9399
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9987
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.7038 - val_sparse_categorical_accuracy: 0.9420
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9983
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.7207 - val_sparse_categorical_accuracy: 0.9420
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9998
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.6126 - val_sparse_categorical_accuracy: 0.9338
# Epoch 37/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9995
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.5463 - val_sparse_categorical_accuracy: 0.9388
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9889
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0440 - sparse_categorical_accuracy: 0.9889 - val_loss: 1.1229 - val_sparse_categorical_accuracy: 0.8239
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9939
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.1928 - val_sparse_categorical_accuracy: 0.9377
# Epoch 40/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.2437 - sparse_categorical_accuracy: 0.9620
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.94204
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.2406 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.3547 - val_sparse_categorical_accuracy: 0.9360
# Epoch 41/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9918
# Epoch 41: val_sparse_categorical_accuracy improved from 0.94204 to 0.97321, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.1110 - val_sparse_categorical_accuracy: 0.9732
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9915
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0950 - val_sparse_categorical_accuracy: 0.9716
# Epoch 43/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9977
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0123 - sparse_categorical_accuracy: 0.9976 - val_loss: 2.0684 - val_sparse_categorical_accuracy: 0.6998
# Epoch 44/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0163 - sparse_categorical_accuracy: 0.9943
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.8888 - val_sparse_categorical_accuracy: 0.8272
# Epoch 45/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0278 - sparse_categorical_accuracy: 0.9927
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.8336 - val_sparse_categorical_accuracy: 0.9098
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9979
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.4470 - val_sparse_categorical_accuracy: 0.9153
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9983
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.3967 - val_sparse_categorical_accuracy: 0.9120
# Epoch 48/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9990
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.1370 - val_sparse_categorical_accuracy: 0.9590
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9996
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.2307 - val_sparse_categorical_accuracy: 0.9169
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0010 - sparse_categorical_accuracy: 0.9998
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0010 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.1167 - val_sparse_categorical_accuracy: 0.9672
# Epoch 51/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9988
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.1212 - val_sparse_categorical_accuracy: 0.9716
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9983
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.2108 - val_sparse_categorical_accuracy: 0.9546
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9976
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.1381 - val_sparse_categorical_accuracy: 0.9645
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9920
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.97321
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0410 - sparse_categorical_accuracy: 0.9919 - val_loss: 1.5270 - val_sparse_categorical_accuracy: 0.8185
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9722
# Epoch 55: val_sparse_categorical_accuracy improved from 0.97321 to 0.97540, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.1011 - val_sparse_categorical_accuracy: 0.9754
# Epoch 56/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9976
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.7672 - val_sparse_categorical_accuracy: 0.9054
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9979
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.6163 - val_sparse_categorical_accuracy: 0.9377
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9984
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.5832 - val_sparse_categorical_accuracy: 0.9426
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9982
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.6757 - val_sparse_categorical_accuracy: 0.9300
# Epoch 60/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9986
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0053 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.6847 - val_sparse_categorical_accuracy: 0.9284
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9991
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.7056 - val_sparse_categorical_accuracy: 0.9311
# Epoch 62/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9999
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.97540
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.7185 - val_sparse_categorical_accuracy: 0.9322
# Epoch 63/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9968
# Epoch 63: val_sparse_categorical_accuracy improved from 0.97540 to 0.98032, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0972 - val_sparse_categorical_accuracy: 0.9803
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9974
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.98032
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9672
# Epoch 65/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9992
# Epoch 65: val_sparse_categorical_accuracy improved from 0.98032 to 0.98742, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0691 - val_sparse_categorical_accuracy: 0.9874
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9990
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0721 - val_sparse_categorical_accuracy: 0.9858
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9998
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9820
# Epoch 68/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 9.0596e-04 - sparse_categorical_accuracy: 0.9999
# Epoch 68: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 9.0509e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0833 - val_sparse_categorical_accuracy: 0.9814
# Epoch 69/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9994
# Epoch 69: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9994 - val_loss: 0.1379 - val_sparse_categorical_accuracy: 0.9754
# Epoch 70/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0392 - sparse_categorical_accuracy: 0.9927
# Epoch 70: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.6804 - val_sparse_categorical_accuracy: 0.8786
# Epoch 71/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9949
# Epoch 71: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.9187 - val_sparse_categorical_accuracy: 0.8529
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988
# Epoch 72: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.1280 - val_sparse_categorical_accuracy: 0.8617
# Epoch 73/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9987
# Epoch 73: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0076 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.4532 - val_sparse_categorical_accuracy: 0.9158
# Epoch 74/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9978
# Epoch 74: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.8921 - val_sparse_categorical_accuracy: 0.8852
# Epoch 75/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9896
# Epoch 75: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9896 - val_loss: 1.4168 - val_sparse_categorical_accuracy: 0.8185
# Epoch 76/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9835
# Epoch 76: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9836 - val_loss: 1.3072 - val_sparse_categorical_accuracy: 0.8475
# Epoch 77/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9938
# Epoch 77: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9939 - val_loss: 1.6941 - val_sparse_categorical_accuracy: 0.8781
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9983
# Epoch 78: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.6356 - val_sparse_categorical_accuracy: 0.8857
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9988
# Epoch 79: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.7558 - val_sparse_categorical_accuracy: 0.8950
# Epoch 80/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9986
# Epoch 80: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0031 - sparse_categorical_accuracy: 0.9986 - val_loss: 1.8337 - val_sparse_categorical_accuracy: 0.8830
# Epoch 81/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9891
# Epoch 81: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.1058 - val_sparse_categorical_accuracy: 0.9759
# Epoch 82/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9963
# Epoch 82: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9963 - val_loss: 0.2576 - val_sparse_categorical_accuracy: 0.9355
# Epoch 83/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9980
# Epoch 83: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.7718 - val_sparse_categorical_accuracy: 0.9235
# Epoch 84/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9967
# Epoch 84: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.7323 - val_sparse_categorical_accuracy: 0.8147
# Epoch 85/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9469
# Epoch 85: val_sparse_categorical_accuracy did not improve from 0.98742
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9471 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9820
# Epoch 85: early stopping
# Restoring model weights from the end of the best epoch: 65.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 78 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.95%
# Training loss: 0.0015
# Test accuracy: 91.41%
# Test loss: 0.9462

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6393    1.0000    0.7799       140
#            1     1.0000    0.9935    0.9967       154
#            2     0.8652    0.5000    0.6337       154
#            3     0.9935    1.0000    0.9967       153
#            4     1.0000    0.9870    0.9935       154
#            5     1.0000    0.9935    0.9967       154
#            6     0.6856    1.0000    0.8135       133
#            7     0.9859    0.9929    0.9894       141
#            8     0.9859    0.4795    0.6452       146
#            9     0.9935    1.0000    0.9967       153
#           10     1.0000    1.0000    1.0000       154
#           11     1.0000    1.0000    1.0000       154
#           12     0.9800    1.0000    0.9899        49
#
#     accuracy                         0.9141      1839
#    macro avg     0.9330    0.9190    0.9102      1839
# weighted avg     0.9347    0.9141    0.9082      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 4
# - CNN 3, GRU 2, Transformer 2

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_18 (InputLayer)     │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_20 (Conv1D)              │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_20 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_21 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_22 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_22 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_14 (GRU)                    │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_15 (GRU)                    │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_10            │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_11            │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_8      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,649,037 (6.29 MB)
#  Trainable params: 1,648,013 (6.29 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.6698 - sparse_categorical_accuracy: 0.7966
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.83215, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - loss: 0.6605 - sparse_categorical_accuracy: 0.7994 - val_loss: 0.4664 - val_sparse_categorical_accuracy: 0.8321
# Epoch 2/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1313 - sparse_categorical_accuracy: 0.9682
# Epoch 2: val_sparse_categorical_accuracy improved from 0.83215 to 0.87042, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9683 - val_loss: 0.4868 - val_sparse_categorical_accuracy: 0.8704
# Epoch 3/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9928
# Epoch 3: val_sparse_categorical_accuracy improved from 0.87042 to 0.90815, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.2151 - val_sparse_categorical_accuracy: 0.9081
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9956
# Epoch 4: val_sparse_categorical_accuracy improved from 0.90815 to 0.93056, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0131 - sparse_categorical_accuracy: 0.9956 - val_loss: 0.1674 - val_sparse_categorical_accuracy: 0.9306
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9971
# Epoch 5: val_sparse_categorical_accuracy improved from 0.93056 to 0.94150, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.0101 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.3363 - val_sparse_categorical_accuracy: 0.9415
# Epoch 6/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0538 - sparse_categorical_accuracy: 0.9826
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.94150
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.0541 - sparse_categorical_accuracy: 0.9826 - val_loss: 1.6855 - val_sparse_categorical_accuracy: 0.7141
# Epoch 7/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9890
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.94150
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.6998 - val_sparse_categorical_accuracy: 0.8469
# Epoch 8/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1362 - sparse_categorical_accuracy: 0.9709
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.94150
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.1355 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.3508 - val_sparse_categorical_accuracy: 0.8835
# Epoch 9/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0633 - sparse_categorical_accuracy: 0.9844
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.94150
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.5722 - val_sparse_categorical_accuracy: 0.9169
# Epoch 10/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9928
# Epoch 10: val_sparse_categorical_accuracy improved from 0.94150 to 0.94587, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.3185 - val_sparse_categorical_accuracy: 0.9459
# Epoch 11/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0161 - sparse_categorical_accuracy: 0.9962
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.5289 - val_sparse_categorical_accuracy: 0.9442
# Epoch 12/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9967
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.3734 - val_sparse_categorical_accuracy: 0.9448
# Epoch 13/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9953
# Epoch 13: val_sparse_categorical_accuracy improved from 0.94587 to 0.94915, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.1628 - val_sparse_categorical_accuracy: 0.9492
# Epoch 14/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9963
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.2413 - val_sparse_categorical_accuracy: 0.8857
# Epoch 15/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0347 - sparse_categorical_accuracy: 0.9912
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0359 - sparse_categorical_accuracy: 0.9910 - val_loss: 5.0599 - val_sparse_categorical_accuracy: 0.5806
# Epoch 16/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1247 - sparse_categorical_accuracy: 0.9672
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.1237 - sparse_categorical_accuracy: 0.9675 - val_loss: 0.8077 - val_sparse_categorical_accuracy: 0.8606
# Epoch 17/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9884
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0494 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.9359 - val_sparse_categorical_accuracy: 0.9114
# Epoch 18/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0166 - sparse_categorical_accuracy: 0.9948
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9946 - val_loss: 0.3675 - val_sparse_categorical_accuracy: 0.8792
# Epoch 19/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1179 - sparse_categorical_accuracy: 0.9693
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.1173 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.4080 - val_sparse_categorical_accuracy: 0.8939
# Epoch 20/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1001 - sparse_categorical_accuracy: 0.9765
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0991 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.4810 - val_sparse_categorical_accuracy: 0.9163
# Epoch 21/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9920
# Epoch 21: val_sparse_categorical_accuracy improved from 0.94915 to 0.95462, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - loss: 0.0321 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.1560 - val_sparse_categorical_accuracy: 0.9546
# Epoch 22/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9950
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.2029 - val_sparse_categorical_accuracy: 0.9546
# Epoch 23/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9981
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0055 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.4783 - val_sparse_categorical_accuracy: 0.9295
# Epoch 24/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0039 - sparse_categorical_accuracy: 0.9986
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.5964 - val_sparse_categorical_accuracy: 0.9224
# Epoch 25/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9983
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.7264 - val_sparse_categorical_accuracy: 0.9092
# Epoch 26/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9992
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.7503 - val_sparse_categorical_accuracy: 0.9076
# Epoch 27/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9993
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.6982 - val_sparse_categorical_accuracy: 0.9114
# Epoch 28/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9989
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0033 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.6351 - val_sparse_categorical_accuracy: 0.9114
# Epoch 29/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9981
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.7073 - val_sparse_categorical_accuracy: 0.9169
# Epoch 30/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9975
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0052 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.8220 - val_sparse_categorical_accuracy: 0.8939
# Epoch 31/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9970
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.6369 - val_sparse_categorical_accuracy: 0.9114
# Epoch 32/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9974
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.5909 - val_sparse_categorical_accuracy: 0.9120
# Epoch 33/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9899
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9898 - val_loss: 1.8114 - val_sparse_categorical_accuracy: 0.8611
# Epoch 34/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1095 - sparse_categorical_accuracy: 0.9721
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.1118 - sparse_categorical_accuracy: 0.9715 - val_loss: 1.2452 - val_sparse_categorical_accuracy: 0.8365
# Epoch 35/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1195 - sparse_categorical_accuracy: 0.9728
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.1193 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.8828 - val_sparse_categorical_accuracy: 0.8978
# Epoch 36/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9871
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9870 - val_loss: 0.5197 - val_sparse_categorical_accuracy: 0.9306
# Epoch 37/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9880
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.4332 - val_sparse_categorical_accuracy: 0.9393
# Epoch 38/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9945
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9945 - val_loss: 1.6197 - val_sparse_categorical_accuracy: 0.8568
# Epoch 39/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1407 - sparse_categorical_accuracy: 0.9657
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.95462
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.1399 - sparse_categorical_accuracy: 0.9658 - val_loss: 0.2284 - val_sparse_categorical_accuracy: 0.9360
# Epoch 40/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9920
# Epoch 40: val_sparse_categorical_accuracy improved from 0.95462 to 0.95735, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.1723 - val_sparse_categorical_accuracy: 0.9574
# Epoch 41/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9905
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.95735
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.1987 - val_sparse_categorical_accuracy: 0.9464
# Epoch 42/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0250 - sparse_categorical_accuracy: 0.9934
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.95735
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0248 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.2301 - val_sparse_categorical_accuracy: 0.9355
# Epoch 43/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9945
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.95735
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.4485 - val_sparse_categorical_accuracy: 0.9109
# Epoch 44/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1158 - sparse_categorical_accuracy: 0.9789
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.95735
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.1147 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.2897 - val_sparse_categorical_accuracy: 0.9322
# Epoch 45/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9924
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.95735
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.3310 - val_sparse_categorical_accuracy: 0.9344
# Epoch 46/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9914
# Epoch 46: val_sparse_categorical_accuracy improved from 0.95735 to 0.97048, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.1155 - val_sparse_categorical_accuracy: 0.9705
# Epoch 47/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9965
# Epoch 47: val_sparse_categorical_accuracy improved from 0.97048 to 0.97485, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.1232 - val_sparse_categorical_accuracy: 0.9748
# Epoch 48/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9883
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9883 - val_loss: 1.0156 - val_sparse_categorical_accuracy: 0.8464
# Epoch 49/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3338 - sparse_categorical_accuracy: 0.9215
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.3321 - sparse_categorical_accuracy: 0.9217 - val_loss: 1.2674 - val_sparse_categorical_accuracy: 0.8152
# Epoch 50/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1507 - sparse_categorical_accuracy: 0.9585
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.1514 - sparse_categorical_accuracy: 0.9584 - val_loss: 0.8218 - val_sparse_categorical_accuracy: 0.8568
# Epoch 51/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9859
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0526 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.6276 - val_sparse_categorical_accuracy: 0.8688
# Epoch 52/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9903
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9903 - val_loss: 1.0157 - val_sparse_categorical_accuracy: 0.8644
# Epoch 53/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9937
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.8860 - val_sparse_categorical_accuracy: 0.8365
# Epoch 54/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9830
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.9275 - val_sparse_categorical_accuracy: 0.8999
# Epoch 55/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9934
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.9908 - val_sparse_categorical_accuracy: 0.8682
# Epoch 56/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9938
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.9816 - val_sparse_categorical_accuracy: 0.8650
# Epoch 57/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9942
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.6464 - val_sparse_categorical_accuracy: 0.8814
# Epoch 58/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9961
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - loss: 0.0125 - sparse_categorical_accuracy: 0.9960 - val_loss: 1.8730 - val_sparse_categorical_accuracy: 0.8546
# Epoch 59/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9926
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - loss: 0.0185 - sparse_categorical_accuracy: 0.9927 - val_loss: 1.5412 - val_sparse_categorical_accuracy: 0.8682
# Epoch 60/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9971
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9971 - val_loss: 1.6493 - val_sparse_categorical_accuracy: 0.8507
# Epoch 61/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9983
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.8688 - val_sparse_categorical_accuracy: 0.8803
# Epoch 62/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9952
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0139 - sparse_categorical_accuracy: 0.9952 - val_loss: 1.5984 - val_sparse_categorical_accuracy: 0.9065
# Epoch 63/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9982
# Epoch 63: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9982 - val_loss: 1.6764 - val_sparse_categorical_accuracy: 0.9010
# Epoch 64/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9969
# Epoch 64: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9969 - val_loss: 2.2216 - val_sparse_categorical_accuracy: 0.8573
# Epoch 65/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9932
# Epoch 65: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 0.0231 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.9568 - val_sparse_categorical_accuracy: 0.8917
# Epoch 66/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1012 - sparse_categorical_accuracy: 0.9755
# Epoch 66: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9756 - val_loss: 0.9113 - val_sparse_categorical_accuracy: 0.9027
# Epoch 67/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0297 - sparse_categorical_accuracy: 0.9897
# Epoch 67: val_sparse_categorical_accuracy did not improve from 0.97485
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.9406 - val_sparse_categorical_accuracy: 0.8759
# Epoch 67: early stopping
# Restoring model weights from the end of the best epoch: 47.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 110 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.45%
# Training loss: 0.0160
# Test accuracy: 99.46%
# Test loss: 0.0245

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9935    1.0000    0.9968       154
#            2     1.0000    1.0000    1.0000       154
#            3     0.9935    0.9935    0.9935       153
#            4     0.9934    0.9740    0.9836       154
#            5     0.9747    1.0000    0.9872       154
#            6     0.9925    1.0000    0.9963       133
#            7     1.0000    0.9929    0.9964       141
#            8     1.0000    0.9863    0.9931       146
#            9     0.9935    1.0000    0.9967       153
#           10     1.0000    1.0000    1.0000       154
#           11     0.9935    1.0000    0.9968       154
#           12     1.0000    0.9592    0.9792        49
#
#     accuracy                         0.9946      1839
#    macro avg     0.9950    0.9928    0.9938      1839
# weighted avg     0.9946    0.9946    0.9946      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
