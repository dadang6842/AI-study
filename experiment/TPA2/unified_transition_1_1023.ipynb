# %%
# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Pure-TPA
Compare three models on pre-augmented transition datasets
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_seg_kernel: int = 9
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_transition_dataset(base_dir: str, transition_name: str, mix_pct: int):
    """
    Load pre-augmented transition dataset
    Args:
        base_dir: base directory containing all transition datasets
        transition_name: e.g., "STANDING_TO_LAYING"
        mix_pct: percentage (10, 20, 30, 40)
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, f"{transition_name}_{mix_pct}pct")

    print(f"\nLoading {transition_name} ({mix_pct}%)...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class ConvBNAct(nn.Module):
    def __init__(self, c_in, c_out, k, s=1, p=None, g=1):
        super().__init__()
        self.c = nn.Conv1d(c_in, c_out, k, s, k//2 if p is None else p, groups=g, bias=False)
        self.bn = nn.BatchNorm1d(c_out)
        self.act = nn.GELU()

    def forward(self, x):
        return self.act(self.bn(self.c(x)))

class MultiPathCNN(nn.Module):
    """Shared backbone for all models"""
    def __init__(self, in_ch=9, d_model=128, branches=(3,5,9,15), stride=2):
        super().__init__()
        h = d_model // 2
        self.pre = ConvBNAct(in_ch, h, 1)
        self.branches = nn.ModuleList([
            nn.Sequential(ConvBNAct(h, h, k, stride, g=h), ConvBNAct(h, h, 1))
            for k in branches
        ])
        self.post = ConvBNAct(len(branches)*h, d_model, 1)

    def forward(self, x):
        return self.post(torch.cat([b(self.pre(x)) for b in self.branches], dim=1))

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=6):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# TPA Model (with Conv Preprocessing)
# ========================
class ProductionTPA(nn.Module):
    """TPA with Conv Preprocessing"""
    def __init__(self, dim, num_prototypes=16, seg_kernel=9, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        pad = (seg_kernel - 1) // 2
        self.dw = nn.Conv1d(dim, dim, kernel_size=seg_kernel, padding=pad, groups=dim, bias=False)
        self.pw = nn.Conv1d(dim, dim, kernel_size=1, bias=False)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)
        self.out_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.conf_head = nn.Sequential(
            nn.Linear(dim, dim // 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(dim // 4, 1)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        # Conv preprocessing
        xloc = self.pw(self.dw(x.transpose(1, 2))).transpose(1, 2)
        xloc = self.pre_norm(xloc) + x

        K = self.k_proj(xloc)
        V = self.v_proj(xloc)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        topk = max(1, int(P * self.topk_ratio))
        vals, _ = torch.topk(proto_tokens, k=topk, dim=1)
        z_tpa = vals.mean(dim=1)

        z_tpa = self.fuse(z_tpa)
        z_tpa = self.out_proj(z_tpa)

        z_gap = x.mean(dim=1)
        confidence = torch.sigmoid(self.conf_head(z_tpa))
        z = confidence * z_tpa + (1 - confidence) * z_gap

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            seg_kernel=tpa_config['seg_kernel'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Pure TPA Model (without Conv Preprocessing)
# ========================
class PureTPA(nn.Module):
    """Pure TPA WITHOUT Conv Preprocessing"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        # Learnable prototypes
        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        # Simple normalization (NO conv layers)
        self.pre_norm = nn.LayerNorm(dim)

        # Q, K, V projections
        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)
        self.out_proj = nn.Linear(dim, dim, bias=False)

        # Fusion layer
        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        # Confidence predictor
        self.conf_head = nn.Sequential(
            nn.Linear(dim, dim // 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(dim // 4, 1)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        # Simple normalization (no conv preprocessing)
        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        topk = max(1, int(P * self.topk_ratio))
        vals, _ = torch.topk(proto_tokens, k=topk, dim=1)
        z_tpa = vals.mean(dim=1)

        z_tpa = self.fuse(z_tpa)
        z_tpa = self.out_proj(z_tpa)

        z_gap = x.mean(dim=1)
        confidence = torch.sigmoid(self.conf_head(z_tpa))
        z = confidence * z_tpa + (1 - confidence) * z_gap

        return z

class PureTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = PureTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Training Functions
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'seg_kernel': cfg.tpa_seg_kernel,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Pure-TPA":
        return PureTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(transition_name: str, mix_pct: int, cfg: Config):
    """Run complete experiment for one transition-mix combination"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {transition_name} - {mix_pct}%")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_transition_dataset(
        cfg.data_dir, transition_name, mix_pct
    )

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Pure-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Transition': transition_name,
            'Mix_Ratio': f"{mix_pct}%",
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Pure-TPA")
    print("="*80)

    # Define all transitions and mix ratios to test
    transitions = [
        "STANDING_TO_SITTING",
        "STANDING_TO_LAYING",
        "SITTING_TO_LAYING",
        "SITTING_TO_STANDING",
        "LAYING_TO_SITTING",
        "LAYING_TO_STANDING"
    ]

    mix_pcts = [10, 20, 30, 40]

    all_results = []

    # Run experiments
    for transition in transitions:
        for mix_pct in mix_pcts:
            results = run_experiment(transition, mix_pct, cfg)
            all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Pure-TPA'],
            'transitions': transitions,
            'mix_ratios': [f"{p}%" for p in mix_pcts],
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_comparison_results.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Transitions tested: {len(transitions)}")
    print(f"Mix ratios tested: {len(mix_pcts)}")
    print(f"Models compared: 3 (GAP, TPA, Pure-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Pure-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:10s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Pure-TPA
# ================================================================================
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 10%
# ================================================================================
#
# Loading STANDING_TO_SITTING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_SITTING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9338, Val Acc=0.9462, F1=0.9528
#   Epoch  20: Train Acc=0.9400, Val Acc=0.9518, F1=0.9583
#   Epoch  30: Train Acc=0.9439, Val Acc=0.9611, F1=0.9677
#   Epoch  40: Train Acc=0.9470, Val Acc=0.9561, F1=0.9623
#   Epoch  50: Train Acc=0.9478, Val Acc=0.9493, F1=0.9557
#   Early stopping at epoch 50
#   Best Val Acc: 0.9611
#
# [GAP Results]
#   Val Acc: 0.9611
#   Test Acc: 0.9077, F1: 0.9132
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9532, Val Acc=0.9629, F1=0.9687
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9747, F1=0.9783
#   Epoch  30: Train Acc=0.9819, Val Acc=0.9852, F1=0.9875
#   Epoch  40: Train Acc=0.9889, Val Acc=0.9858, F1=0.9881
#   Epoch  50: Train Acc=0.9943, Val Acc=0.9870, F1=0.9891
#   Epoch  60: Train Acc=0.9981, Val Acc=0.9901, F1=0.9917
#   Epoch  70: Train Acc=0.9983, Val Acc=0.9907, F1=0.9922
#   Early stopping at epoch 79
#   Best Val Acc: 0.9920
#
# [TPA Results]
#   Val Acc: 0.9920
#   Test Acc: 0.9583, F1: 0.9587
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9575, Val Acc=0.9697, F1=0.9743
#   Epoch  20: Train Acc=0.9658, Val Acc=0.9703, F1=0.9747
#   Epoch  30: Train Acc=0.9733, Val Acc=0.9753, F1=0.9791
#   Epoch  40: Train Acc=0.9791, Val Acc=0.9796, F1=0.9828
#   Epoch  50: Train Acc=0.9824, Val Acc=0.9821, F1=0.9848
#   Epoch  60: Train Acc=0.9855, Val Acc=0.9827, F1=0.9854
#   Epoch  70: Train Acc=0.9892, Val Acc=0.9833, F1=0.9860
#   Epoch  80: Train Acc=0.9913, Val Acc=0.9839, F1=0.9865
#   Epoch  90: Train Acc=0.9917, Val Acc=0.9852, F1=0.9875
#   Early stopping at epoch 99
#   Best Val Acc: 0.9883
#
# [Pure-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9389, F1: 0.9385
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 20%
# ================================================================================
#
# Loading STANDING_TO_SITTING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9640, Val Acc=0.9648, F1=0.9702
#   Epoch  20: Train Acc=0.9688, Val Acc=0.9716, F1=0.9758
#   Epoch  30: Train Acc=0.9745, Val Acc=0.9660, F1=0.9716
#   Epoch  40: Train Acc=0.9790, Val Acc=0.9778, F1=0.9812
#   Epoch  50: Train Acc=0.9802, Val Acc=0.9790, F1=0.9823
#   Epoch  60: Train Acc=0.9842, Val Acc=0.9784, F1=0.9821
#   Epoch  70: Train Acc=0.9884, Val Acc=0.9839, F1=0.9866
#   Epoch  80: Train Acc=0.9932, Val Acc=0.9932, F1=0.9943
#   Epoch  90: Train Acc=0.9934, Val Acc=0.9926, F1=0.9937
#   Epoch 100: Train Acc=0.9937, Val Acc=0.9907, F1=0.9922
#   Best Val Acc: 0.9938
#
# [Pure-TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9457, F1: 0.9441
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 20%
# ================================================================================
#
# Loading STANDING_TO_LAYING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9385, Val Acc=0.9382, F1=0.9447
#   Epoch  20: Train Acc=0.9499, Val Acc=0.9493, F1=0.9554
#   Epoch  30: Train Acc=0.9567, Val Acc=0.9604, F1=0.9663
#   Epoch  40: Train Acc=0.9563, Val Acc=0.9549, F1=0.9602
#   Epoch  50: Train Acc=0.9581, Val Acc=0.9530, F1=0.9582
#   Epoch  60: Train Acc=0.9590, Val Acc=0.9611, F1=0.9668
#   Epoch  70: Train Acc=0.9610, Val Acc=0.9617, F1=0.9672
#   Early stopping at epoch 72
#   Best Val Acc: 0.9623
#
# [GAP Results]
#   Val Acc: 0.9623
#   Test Acc: 0.9287, F1: 0.9295
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9637, Val Acc=0.9567, F1=0.9620
#   Epoch  20: Train Acc=0.9722, Val Acc=0.9703, F1=0.9746
#   Epoch  30: Train Acc=0.9814, Val Acc=0.9852, F1=0.9873
#   Epoch  40: Train Acc=0.9926, Val Acc=0.9889, F1=0.9905
#   Epoch  50: Train Acc=0.9934, Val Acc=0.9883, F1=0.9900
#   Epoch  60: Train Acc=0.9958, Val Acc=0.9883, F1=0.9900
#   Epoch  70: Train Acc=0.9983, Val Acc=0.9889, F1=0.9906
#   Epoch  80: Train Acc=0.9975, Val Acc=0.9889, F1=0.9905
#   Epoch  90: Train Acc=0.9981, Val Acc=0.9901, F1=0.9916
#   Epoch 100: Train Acc=0.9992, Val Acc=0.9895, F1=0.9910
#   Best Val Acc: 0.9907
#
# [TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9562, F1: 0.9552
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9615, Val Acc=0.9604, F1=0.9658
#   Epoch  20: Train Acc=0.9694, Val Acc=0.9635, F1=0.9693
#   Epoch  30: Train Acc=0.9734, Val Acc=0.9691, F1=0.9734
#   Epoch  40: Train Acc=0.9784, Val Acc=0.9728, F1=0.9770
#   Epoch  50: Train Acc=0.9825, Val Acc=0.9765, F1=0.9804
#   Epoch  60: Train Acc=0.9830, Val Acc=0.9734, F1=0.9773
#   Epoch  70: Train Acc=0.9878, Val Acc=0.9778, F1=0.9810
#   Epoch  80: Train Acc=0.9912, Val Acc=0.9796, F1=0.9827
#   Early stopping at epoch 83
#   Best Val Acc: 0.9852
#
# [Pure-TPA Results]
#   Val Acc: 0.9852
#   Test Acc: 0.9380, F1: 0.9365
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 30%
# ================================================================================
#
# Loading STANDING_TO_LAYING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9389, Val Acc=0.9295, F1=0.9382
#   Epoch  20: Train Acc=0.9529, Val Acc=0.9431, F1=0.9496
#   Epoch  30: Train Acc=0.9583, Val Acc=0.9444, F1=0.9520
#   Epoch  40: Train Acc=0.9589, Val Acc=0.9487, F1=0.9558
#   Early stopping at epoch 43
#   Best Val Acc: 0.9555
#
# [GAP Results]
#   Val Acc: 0.9555
#   Test Acc: 0.9136, F1: 0.9155
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9638, Val Acc=0.9574, F1=0.9637
#   Epoch  20: Train Acc=0.9729, Val Acc=0.9666, F1=0.9712
#   Epoch  30: Train Acc=0.9802, Val Acc=0.9771, F1=0.9805
#   Epoch  40: Train Acc=0.9898, Val Acc=0.9870, F1=0.9888
#   Epoch  50: Train Acc=0.9929, Val Acc=0.9864, F1=0.9885
#   Epoch  60: Train Acc=0.9954, Val Acc=0.9920, F1=0.9932
#   Epoch  70: Train Acc=0.9986, Val Acc=0.9895, F1=0.9911
#   Epoch  80: Train Acc=0.9977, Val Acc=0.9907, F1=0.9922
#   Early stopping at epoch 80
#   Best Val Acc: 0.9920
#
# [TPA Results]
#   Val Acc: 0.9920
#   Test Acc: 0.9466, F1: 0.9456
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9604, Val Acc=0.9598, F1=0.9655
#   Epoch  20: Train Acc=0.9699, Val Acc=0.9654, F1=0.9705
#   Epoch  30: Train Acc=0.9736, Val Acc=0.9685, F1=0.9733
#   Epoch  40: Train Acc=0.9787, Val Acc=0.9740, F1=0.9780
#   Epoch  50: Train Acc=0.9832, Val Acc=0.9815, F1=0.9845
#   Epoch  60: Train Acc=0.9852, Val Acc=0.9827, F1=0.9855
#   Epoch  70: Train Acc=0.9904, Val Acc=0.9852, F1=0.9875
#   Epoch  80: Train Acc=0.9920, Val Acc=0.9815, F1=0.9845
#   Epoch  90: Train Acc=0.9918, Val Acc=0.9901, F1=0.9917
#   Epoch 100: Train Acc=0.9951, Val Acc=0.9833, F1=0.9860
#   Best Val Acc: 0.9901
#
# [Pure-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9546, F1: 0.9542
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 40%
# ================================================================================
#
# Loading STANDING_TO_LAYING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9416, Val Acc=0.9487, F1=0.9558
#   Epoch  20: Train Acc=0.9524, Val Acc=0.9543, F1=0.9601
#   Epoch  30: Train Acc=0.9564, Val Acc=0.9666, F1=0.9720
#   Epoch  40: Train Acc=0.9559, Val Acc=0.9629, F1=0.9684
#   Epoch  50: Train Acc=0.9553, Val Acc=0.9635, F1=0.9690
#   Early stopping at epoch 56
#   Best Val Acc: 0.9672
#
# [GAP Results]
#   Val Acc: 0.9672
#   Test Acc: 0.9192, F1: 0.9211
#
# [Training TPA]
#   Epoch  10: Train Acc=0.
#   Epoch  80: Train Acc=0.9949, Val Acc=0.9858, F1=0.9880
#   Epoch  90: Train Acc=0.9946, Val Acc=0.9852, F1=0.9876
#   Early stopping at epoch 99
#   Best Val Acc: 0.9876
#
# [Pure-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9457, F1: 0.9476
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 30%
# ================================================================================
#
# Loading SITTING_TO_LAYING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_LAYING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9474, Val Acc=0.9431, F1=0.9519
#   Epoch  20: Train Acc=0.9590, Val Acc=0.9326, F1=0.9454
#   Epoch  30: Train Acc=0.9604, Val Acc=0.9530, F1=0.9610
#   Epoch  40: Train Acc=0.9573, Val Acc=0.9518, F1=0.9601
#   Epoch  50: Train Acc=0.9598, Val Acc=0.9431, F1=0.9539
#   Early stopping at epoch 53
#   Best Val Acc: 0.9555
#
# [GAP Results]
#   Val Acc: 0.9555
#   Test Acc: 0.9185, F1: 0.9246
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9615, Val Acc=0.9419, F1=0.9528
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9567, F1=0.9645
#   Epoch  30: Train Acc=0.9794, Val Acc=0.9747, F1=0.9792
#   Epoch  40: Train Acc=0.9917, Val Acc=0.9864, F1=0.9888
#   Epoch  50: Train Acc=0.9937, Val Acc=0.9827, F1=0.9858
#   Epoch  60: Train Acc=0.9952, Val Acc=0.9833, F1=0.9862
#   Epoch  70: Train Acc=0.9986, Val Acc=0.9852, F1=0.9878
#   Epoch  80: Train Acc=0.9988, Val Acc=0.9870, F1=0.9893
#   Early stopping at epoch 84
#   Best Val Acc: 0.9895
#
# [TPA Results]
#   Val Acc: 0.9895
#   Test Acc: 0.9556, F1: 0.9581
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9603, Val Acc=0.9450, F1=0.9555
#   Epoch  20: Train Acc=0.9680, Val Acc=0.9629, F1=0.9690
#   Epoch  30: Train Acc=0.9742, Val Acc=0.9629, F1=0.9695
#   Epoch  40: Train Acc=0.9794, Val Acc=0.9753, F1=0.9798
#   Epoch  50: Train Acc=0.9853, Val Acc=0.9753, F1=0.9797
#   Epoch  60: Train Acc=0.9892, Val Acc=0.9778, F1=0.9814
#   Epoch  70: Train Acc=0.9943, Val Acc=0.9883, F1=0.9901
#   Epoch  80: Train Acc=0.9946, Val Acc=0.9839, F1=0.9867
#   Epoch  90: Train Acc=0.9952, Val Acc=0.9864, F1=0.9889
#   Epoch 100: Train Acc=0.9964, Val Acc=0.9895, F1=0.9913
#   Best Val Acc: 0.9907
#
# [Pure-TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9491, F1: 0.9502
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 40%
# ================================================================================
#
# Loading SITTING_TO_LAYING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_LAYING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9495, Val Acc=0.9487, F1=0.9561
#   Epoch  20: Train Acc=0.9578, Val Acc=0.9456, F1=0.9552
#   Epoch  30: Train Acc=0.9581, Val Acc=0.9555, F1=0.9631
#   Epoch  40: Train Acc=0.9592, Val Acc=0.9567, F1=0.9642
#   Epoch  50: Train Acc=0.9593, Val Acc=0.9530, F1=0.9618
#   Early stopping at epoch 52
#   Best Val Acc: 0.9567
#
# [GAP Results]
#   Val Acc: 0.9567
#   Test Acc: 0.9250, F1: 0.9307
#
# [Training TPA]
#   Epoch  10: Train Acc=0.
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9513, Val Acc=0.9592, F1=0.9658
#   Epoch  20: Train Acc=0.9603, Val Acc=0.9703, F1=0.9755
#   Epoch  30: Train Acc=0.9708, Val Acc=0.9784, F1=0.9821
#   Epoch  40: Train Acc=0.9765, Val Acc=0.9759, F1=0.9802
#   Epoch  50: Train Acc=0.9825, Val Acc=0.9771, F1=0.9810
#   Epoch  60: Train Acc=0.9841, Val Acc=0.9833, F1=0.9863
#   Epoch  70: Train Acc=0.9866, Val Acc=0.9870, F1=0.9893
#   Epoch  80: Train Acc=0.9895, Val Acc=0.9883, F1=0.9903
#   Epoch  90: Train Acc=0.9927, Val Acc=0.9876, F1=0.9896
#   Early stopping at epoch 98
#   Best Val Acc: 0.9883
#
# [Pure-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9364, F1: 0.9379
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 30%
# ================================================================================
#
# Loading SITTING_TO_STANDING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9403, Val Acc=0.9468, F1=0.9542
#   Epoch  20: Train Acc=0.9443, Val Acc=0.9475, F1=0.9563
#   Early stopping at epoch 29
#   Best Val Acc: 0.9493
#
# [GAP Results]
#   Val Acc: 0.9493
#   Test Acc: 0.8735, F1: 0.8801
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9508, Val Acc=0.9592, F1=0.9661
#   Epoch  20: Train Acc=0.9657, Val Acc=0.9660, F1=0.9719
#   Epoch  30: Train Acc=0.9771, Val Acc=0.9753, F1=0.9798
#   Epoch  40: Train Acc=0.9873, Val Acc=0.9821, F1=0.9853
#   Epoch  50: Train Acc=0.9924, Val Acc=0.9883, F1=0.9904
#   Epoch  60: Train Acc=0.9949, Val Acc=0.9907, F1=0.9924
#   Epoch  70: Train Acc=0.9972, Val Acc=0.9895, F1=0.9913
#   Epoch  80: Train Acc=0.9969, Val Acc=0.9913, F1=0.9928
#   Early stopping at epoch 89
#   Best Val Acc: 0.9938
#
# [TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9506, F1: 0.9533
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9542, Val Acc=0.9499, F1=0.9587
#   Epoch  20: Train Acc=0.9646, Val Acc=0.9617, F1=0.9685
#   Epoch  30: Train Acc=0.9697, Val Acc=0.9586, F1=0.9656
#   Epoch  40: Train Acc=0.9734, Val Acc=0.9679, F1=0.9735
#   Epoch  50: Train Acc=0.9787, Val Acc=0.9710, F1=0.9757
#   Epoch  60: Train Acc=0.9791, Val Acc=0.9784, F1=0.9823
#   Epoch  70: Train Acc=0.9861, Val Acc=0.9710, F1=0.9764
#   Epoch  80: Train Acc=0.9859, Val Acc=0.9753, F1=0.9798
#   Epoch  90: Train Acc=0.9904, Val Acc=0.9759, F1=0.9799
#   Epoch 100: Train Acc=0.9898, Val Acc=0.9883, F1=0.9903
#   Best Val Acc: 0.9883
#
# [Pure-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9349, F1: 0.9377
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 40%
# ================================================================================
#
# Loading SITTING_TO_STANDING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9341, Val Acc=0.9462, F1=0.9558
#   Epoch  20: Train Acc=0.9374, Val Acc=0.9468, F1=0.9565
#   Epoch  30: Train Acc=0.9413, Val Acc=0.9468, F1=0.9563
#   Epoch  40: Train Acc=0.9399, Val Acc=0.9468, F1=0.9563
#   Early stopping at epoch 41
#   Best Val Acc: 0.9493
#
# [GAP Results]
#   Val Acc: 0.9493
#   Test Acc: 0.8936, F1: 0.9016
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9518, Val Acc=0.9635, F1=0.9694
#   Epoch  20: Train Acc=0.9646, Val Acc=0.9740, F1=0.9784
#   Epoch  30: Train Acc=0.9816, Val Acc=0.9808, F1=0.9842
#   Epoch  40: Train Acc=0.9887, Val Acc=0.9864, F1=0.9887
#   Epoch  50: Train Acc=0.9937, Val Acc=0.9883, F1=0.9902
#   Epoch  60: Train Acc=0.9946, Val Acc=0.9901, F1=0.9917
#   Epoch  70: Train Acc=0.9975, Val Acc=0.9901, F1=0.9918
#   Early stopping at epoch 77
#   Best Val Acc: 0.9932
#
# [TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9466, F1: 0.9493
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9518, Val Acc=0.9648, F1=0.9702
#   Epoch  20: Train Acc=0.9621, Val Acc=0.9747, F1=0.9790
#   Epoch  30: Train Acc=0.9729, Val Acc=0.9734, F1=0.9776
#   Epoch  40: Train Acc=0.9754, Val Acc=0.9716, F1=0.9767
#   Epoch  50: Train Acc=0.9802, Val Acc=0.9796, F1=0.9829
#   Epoch  60: Train Acc=0.9822, Val Acc=0.9802, F1=0.9835
#   Epoch  70: Train Acc=0.9853, Val Acc=0.9815, F1=0.9848
#   Epoch  80: Train Acc=0.9850, Val Acc=0.9827, F1=0.9856
#   Epoch  90: Train Acc=0.9893, Val Acc=0.9852, F1=0.9876
#   Epoch 100: Train Acc=0.9913, Val Acc=0.9852, F1=0.9877
#   Best Val Acc: 0.9883
#
# [Pure-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9337, F1: 0.9370
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 10%
# ================================================================================
#
# Loading LAYING_TO_SITTING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9495, Val Acc=0.9499, F1=0.9487
#   Epoch  20: Train Acc=0.9564, Val Acc=0.9524, F1=0.9522
#   Epoch  30: Train Acc=0.9583, Val Acc=0.9574, F1=0.9568
#   Epoch  40: Train Acc=0.9575, Val Acc=0.9580, F1=0.9574
#   Epoch  50: Train Acc=0.9597, Val Acc=0.9574, F1=0.9568
#   Early stopping at epoch 52
#   Best Val Acc: 0.9586
#
# [GAP Results]
#   Val Acc: 0.9586
#   Test Acc: 0.9266, F1: 0.9188
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9629, Val Acc=0.9580, F1=0.9573
#   Epoch  20: Train Acc=0.9688, Val Acc=0.9561, F1=0.9554
#   Epoch  30: Train Acc=0.9808, Val Acc=0.9629, F1=0.9623
#   Epoch  40: Train Acc=0.9861, Val Acc=0.9722, F1=0.9717
#   Epoch  50: Train Acc=0.9927, Val Acc=0.9734, F1=0.9730
#   Epoch  60: Train Acc=0.9952, Val Acc=0.9815, F1=0.9811
#   Epoch  70: Train Acc=0.9981, Val Acc=0.9852, F1=0.9848
#   Epoch  80: Train Acc=0.9981, Val Acc=0.9845, F1=0.9842
#   Epoch  90: Train Acc=0.9985, Val Acc=0.9852, F1=0.9848
#   Epoch 100: Train Acc=0.9994, Val Acc=0.9852, F1=0.9849
#   Best Val Acc: 0.9895
#
# [TPA Results]
#   Val Acc: 0.9895
#   Test Acc: 0.9553, F1: 0.9509
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.
#   Epoch  80: Train Acc=0.9883, Val Acc=0.9796, F1=0.9792
#   Epoch  90: Train Acc=0.9896, Val Acc=0.9815, F1=0.9812
#   Epoch 100: Train Acc=0.9866, Val Acc=0.9870, F1=0.9868
#   Best Val Acc: 0.9889
#
# [Pure-TPA Results]
#   Val Acc: 0.9889
#   Test Acc: 0.9395, F1: 0.9332
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 30%
# ================================================================================
#
# Loading LAYING_TO_SITTING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9471, Val Acc=0.9468, F1=0.9447
#   Epoch  20: Train Acc=0.9559, Val Acc=0.9475, F1=0.9467
#   Epoch  30: Train Acc=0.9553, Val Acc=0.9592, F1=0.9586
#   Epoch  40: Train Acc=0.9589, Val Acc=0.9580, F1=0.9574
#   Epoch  50: Train Acc=0.9584, Val Acc=0.9574, F1=0.9567
#   Early stopping at epoch 50
#   Best Val Acc: 0.9592
#
# [GAP Results]
#   Val Acc: 0.9592
#   Test Acc: 0.9269, F1: 0.9191
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9621, Val Acc=0.9666, F1=0.9661
#   Epoch  20: Train Acc=0.9680, Val Acc=0.9642, F1=0.9637
#   Epoch  30: Train Acc=0.9785, Val Acc=0.9728, F1=0.9724
#   Epoch  40: Train Acc=0.9892, Val Acc=0.9808, F1=0.9806
#   Epoch  50: Train Acc=0.9941, Val Acc=0.9815, F1=0.9812
#   Epoch  60: Train Acc=0.9958, Val Acc=0.9864, F1=0.9862
#   Epoch  70: Train Acc=0.9980, Val Acc=0.9870, F1=0.9868
#   Epoch  80: Train Acc=0.9981, Val Acc=0.9870, F1=0.9868
#   Epoch  90: Train Acc=0.9983, Val Acc=0.9901, F1=0.9900
#   Epoch 100: Train Acc=0.9997, Val Acc=0.9895, F1=0.9893
#   Best Val Acc: 0.9932
#
# [TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9571, F1: 0.9528
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9620, Val Acc=0.9592, F1=0.9584
#   Epoch  20: Train Acc=0.9669, Val Acc=0.9654, F1=0.9648
#   Epoch  30: Train Acc=0.9723, Val Acc=0.9722, F1=0.9717
#   Epoch  40: Train Acc=0.9760, Val Acc=0.9771, F1=0.9768
#   Epoch  50: Train Acc=0.9799, Val Acc=0.9722, F1=0.9718
#   Epoch  60: Train Acc=0.9824, Val Acc=0.9784, F1=0.9780
#   Early stopping at epoch 68
#   Best Val Acc: 0.9796
#
# [Pure-TPA Results]
#   Val Acc: 0.9796
#   Test Acc: 0.9392, F1: 0.9329
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 40%
# ================================================================================
#
# Loading LAYING_TO_SITTING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9470, Val Acc=0.9363, F1=0.9344
#   Epoch  20: Train Acc=0.9561, Val Acc=0.9518, F1=0.9510
#   Epoch  30: Train Acc=0.9586, Val Acc=0.9468, F1=0.9458
#   Epoch  40: Train Acc=0.9595, Val Acc=0.9536, F1=0.9530
#   Early stopping at epoch 45
#   Best Val Acc: 0.9574
#
# [GAP Results]
#   Val Acc: 0.9574
#   Test Acc: 0.9185, F1: 0.9105
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9646, Val Acc=0.9586, F1=0.9578
#   Epoch  20: Train Acc=0.9685, Val Acc=0.9635, F1=0.9628
#   Epoch  30: Train Acc=0.9797, Val Acc=0.9765, F1=0.9760
#   Epoch  40: Train Acc=0.9895, Val Acc=0.9870, F1=0.9867
#   Epoch  50: Train Acc=0.9938, Val Acc=0.9833, F1=0.9829
#   Epoch  60: Train Acc=0.9972, Val Acc=0.9907, F1=0.9904
#   Epoch  70: Train Acc=0.9980, Val Acc=0.9901, F1=0.9898
#   Epoch  80: Train Acc=0.9981, Val Acc=0.9883, F1=0.9879
#   Epoch  90: Train Acc=0.9986, Val Acc=0.9901, F1=0.9900
#   Epoch 100: Train Acc=0.9986, Val Acc=0.9926, F1=0.9923
#   Best Val Acc: 0.9951
#
# [TPA Results]
#   Val Acc: 0.9951
#   Test Acc: 0.9525, F1: 0.9474
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9621, Val Acc=0.9617, F1=0.9608
#   Epoch  20: Train Acc=0.9712, Val Acc=0.9574, F1=0.9566
#   Epoch  30: Train Acc=0.9760, Val Acc=0.9648, F1=0.9642
#   Epoch  40: Train Acc=0.9784, Val Acc=0.9703, F1=0.9699
#   Epoch  50: Train Acc=0.9804, Val Acc=0.9666, F1=0.9660
#   Epoch  60: Train Acc=0.9827, Val Acc=0.9765, F1=0.9760
#   Epoch  70: Train Acc=0.9867, Val Acc=0.9784, F1=0.9779
#   Epoch  80: Train Acc=0.9875, Val Acc=0.9722, F1=0.9716
#   Early stopping at epoch 84
#   Best Val Acc: 0.9808
#
# [Pure-TPA Results]
#   Val Acc: 0.9808
#   Test Acc: 0.9472, F1: 0.9421
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 10%
# ================================================================================
#
# Loading LAYING_TO_STANDING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9476, Val Acc=0.9536, F1=0.9523
#   Epoch  20: Train Acc=0.9558, Val Acc=0.9574, F1=0.9567
#   Epoch  30: Train Acc=0.9549, Val Acc=0.9574, F1=0.9567
#   Epoch  40: Train Acc=0.9575, Val Acc=0.9604, F1=0.9599
#   Epoch  50: Train Acc=0.9592, Val Acc=0.9598, F1=0.9592
#   Early stopping at epoch 52
#   Best Val Acc: 0.9611
#
# [GAP Results]
#   Val Acc: 0.9611
#   Test Acc: 0.9232, F1: 0.9153
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9597, Val Acc=0.9549, F1=0.9537
#   Epoch  20: Train Acc=0.9680, Val Acc=0.9672, F1=0.9667
#   Epoch  30: Train Acc=0.9801, Val Acc=0.9784, F1=0.9777
#   Epoch  40: Train Acc=0.9833, Val Acc=0.9821, F1=0.9815
#   Epoch  50: Train Acc=0.9930, Val Acc=0.9901, F1=0.9897
#   Epoch  60: Train Acc=0.9960, Val Acc=0.9932, F1=0.9929
#   Epoch  70: Train Acc=0.9964, Val Acc=0.9932, F1=0.9929
#   Epoch  80: Train Acc=0.9981, Val Acc=0.9926, F1=0.9923
#   Early stopping at epoch 81
#   Best Val Acc: 0.9938
#
# [TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9639, F1: 0.9598
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9635, Val Acc=0.9592, F1=0.9584
#   Epoch  20: Train Acc=0.9669, Val Acc=0.9666, F1=0.9661
#   Epoch  30: Train Acc=0.9703, Val Acc=0.9672, F1=0.9667
#   Epoch  40: Train Acc=0.9773, Val Acc=0.9747, F1=0.9742
#   Epoch  50: Train Acc=0.9802, Val Acc=0.9648, F1=0.9636
#   Epoch  60: Train Acc=0.9824, Val Acc=0.9728, F1=0.9722
#   Epoch  70: Train Acc=0.9858, Val Acc=0.9808, F1=0.9805
#   Epoch  80: Train Acc=0.9889, Val Acc=0.9827, F1=0.9823
#   Epoch  90: Train Acc=0.9873, Val Acc=0.9808, F1=0.9805
#   Epoch 100: Train Acc=0.9903, Val Acc=0.9815, F1=0.9811
#   Best Val Acc: 0.9845
#
# [Pure-TPA Results]
#   Val Acc: 0.9845
#   Test Acc: 0.9454, F1: 0.9397
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 20%
# ================================================================================
#
# Loading LAYING_TO_STANDING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9484, Val Acc=0.9506, F1=0.9499
#   Epoch  20: Train Acc=0.9549, Val Acc=0.9512, F1=0.9507
#   Epoch  30: Train Acc=0.9584, Val Acc=0.9586, F1=0.9580
#   Epoch  40: Train Acc=0.9576, Val Acc=0.9623, F1=0.9618
#   Epoch  50: Train Acc=0.9573, Val Acc=0.9592, F1=0.9586
#   Early stopping at epoch 59
#   Best Val Acc: 0.9635
#
# [GAP Results]
#   Val Acc: 0.9635
#   Test Acc: 0.9284, F1: 0.9213
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9589, Val Acc=0.9648, F1=0.9642
#   Epoch  20: Train Acc=0.9688, Val Acc=0.9685, F1=0.9679
#   Epoch  30: Train Acc=0.9788, Val Acc=0.9703, F1=0.9697
#   Epoch  40: Train Acc=0.9879, Val Acc=0.9852, F1=0.9849
#   Epoch  50: Train Acc=0.9930, Val Acc=0.9870, F1=0.9867
#   Epoch  60: Train Acc=0.9963, Val Acc=0.9876, F1=0.9875
#   Epoch  70: Train Acc=0.9985, Val Acc=0.9883, F1=0.9879
#   Epoch  80: Train Acc=0.9985, Val Acc=0.9889, F1=0.9887
#   Epoch  90: Train Acc=0.9995, Val Acc=0.9901, F1=0.9900
#   Early stopping at epoch 93
#   Best Val Acc: 0.9913
#
# [TPA Results]
#   Val Acc: 0.9913
#   Test Acc: 0.9479, F1: 0.9422
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9609, Val Acc=0.9604, F1=0.9597
#   Epoch  20: Train Acc=0.9682, Val Acc=0.9611, F1=0.9603
#   Epoch  30: Train Acc=0.9737, Val Acc=0.9660, F1=0.9652
#   Epoch  40: Train Acc=0.9756, Val Acc=0.9703, F1=0.9698
#   Epoch  50: Train Acc=0.9763, Val Acc=0.9734, F1=0.9729
#   Epoch  60: Train Acc=0.9839, Val Acc=0.9740, F1=0.9735
#   Epoch  70: Train Acc=0.9858, Val Acc=0.9734, F1=0.9729
#   Epoch  80: Train Acc=0.9876, Val Acc=0.9802, F1=0.9798
#   Epoch  90: Train Acc=0.9896, Val Acc=0.9740, F1=0.9735
#   Epoch 100: Train Acc=0.9920, Val Acc=0.9691, F1=0.9684
#   Early stopping at epoch 100
#   Best Val Acc: 0.9802
#
# [Pure-TPA Results]
#   Val Acc: 0.9802
#   Test Acc: 0.9349, F1: 0.9304
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 30%
# ================================================================================
#
# Loading LAYING_TO_STANDING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9464, Val Acc=0.9450, F1=0.9427
#   Epoch  20: Train Acc=0.9558, Val Acc=0.9543, F1=0.9532
#   Epoch  30: Train Acc=0.9576, Val Acc=0.9580, F1=0.9571
#   Epoch  40: Train Acc=0.9589, Val Acc=0.9586, F1=0.9579
#   Early stopping at epoch 48
#   Best Val Acc: 0.9617
#
# [GAP Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9266, F1: 0.9192
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9623, Val Acc=0.9642, F1=0.9634
#   Epoch  20: Train Acc=0.9682, Val Acc=0.9642, F1=0.9633
#   Epoch  30: Train Acc=0.9779, Val Acc=0.9808, F1=0.9806
#   Epoch  40: Train Acc=0.9876, Val Acc=0.9839, F1=0.9837
#   Epoch  50: Train Acc=0.9934, Val Acc=0.9883, F1=0.9881
#   Epoch  60: Train Acc=0.9958, Val Acc=0.9864, F1=0.9862
#   Epoch  70: Train Acc=0.9978, Val Acc=0.9876, F1=0.9874
#   Epoch  80: Train Acc=0.9991, Val Acc=0.9907, F1=0.9906
#   Epoch  90: Train Acc=0.9992, Val Acc=0.9913, F1=0.9912
#   Epoch 100: Train Acc=0.9986, Val Acc=0.9901, F1=0.9900
#   Best Val Acc: 0.9926
#
# [TPA Results]
#   Val Acc: 0.9926
#   Test Acc: 0.9580, F1: 0.9536
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9617, Val Acc=0.9648, F1=0.9640
#   Epoch  20: Train Acc=0.9703, Val Acc=0.9654, F1=0.9647
#   Epoch  30: Train Acc=0.9750, Val Acc=0.9716, F1=0.9711
#   Epoch  40: Train Acc=0.9784, Val Acc=0.9734, F1=0.9731
#   Epoch  50: Train Acc=0.9784, Val Acc=0.9740, F1=0.9735
#   Epoch  60: Train Acc=0.9814, Val Acc=0.9784, F1=0.9780
#   Epoch  70: Train Acc=0.9858, Val Acc=0.9802, F1=0.9799
#   Epoch  80: Train Acc=0.9870, Val Acc=0.9765, F1=0.9762
#   Epoch  90: Train Acc=0.9887, Val Acc=0.9864, F1=0.9862
#   Epoch 100: Train Acc=0.9903, Val Acc=0.9815, F1=0.9812
#   Best Val Acc: 0.9889
#
# [Pure-TPA Results]
#   Val Acc: 0.9889
#   Test Acc: 0.9309, F1: 0.9260
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 40%
# ================================================================================
#
# Loading LAYING_TO_STANDING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9490, Val Acc=0.9438, F1=0.9420
#   Epoch  20: Train Acc=0.9539, Val Acc=0.9543, F1=0.9538
#   Epoch  30: Train Acc=0.9580, Val Acc=0.9518, F1=0.9509
#   Epoch  40: Train Acc=0.9570, Val Acc=0.9617, F1=0.9611
#   Epoch  50: Train Acc=0.9586, Val Acc=0.9561, F1=0.9553
#   Epoch  60: Train Acc=0.9581, Val Acc=0.9629, F1=0.9624
#   Epoch  70: Train Acc=0.9607, Val Acc=0.9549, F1=0.9540
#   Epoch  80: Train Acc=0.9620, Val Acc=0.9635, F1=0.9630
#   Epoch  90: Train Acc=0.9648, Val Acc=0.9629, F1=0.9624
#   Epoch 100: Train Acc=0.9657, Val Acc=0.9629, F1=0.9624
#   Best Val Acc: 0.9660
#
# [GAP Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9451, F1: 0.9400
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9617, Val Acc=0.9617, F1=0.9609
#   Epoch  20: Train Acc=0.9722, Val Acc=0.9629, F1=0.9622
#   Epoch  30: Train Acc=0.9767, Val Acc=0.9722, F1=0.9717
#   Epoch  40: Train Acc=0.9872, Val Acc=0.9796, F1=0.9792
#   Epoch  50: Train Acc=0.9903, Val Acc=0.9833, F1=0.9829
#   Epoch  60: Train Acc=0.9951, Val Acc=0.9883, F1=0.9880
#   Epoch  70: Train Acc=0.9968, Val Acc=0.9839, F1=0.9836
#   Epoch  80: Train Acc=0.9969, Val Acc=0.9876, F1=0.9874
#   Epoch  90: Train Acc=0.9991, Val Acc=0.9870, F1=0.9866
#   Early stopping at epoch 95
#   Best Val Acc: 0.9895
#
# [TPA Results]
#   Val Acc: 0.9895
#   Test Acc: 0.9593, F1: 0.9554
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9620, Val Acc=0.9629, F1=0.9621
#   Epoch  20: Train Acc=0.9692, Val Acc=0.9648, F1=0.9640
#   Epoch  30: Train Acc=0.9739, Val Acc=0.9685, F1=0.9679
#   Epoch  40: Train Acc=0.9771, Val Acc=0.9771, F1=0.9767
#   Epoch  50: Train Acc=0.9824, Val Acc=0.9747, F1=0.9742
#   Epoch  60: Train Acc=0.9842, Val Acc=0.9784, F1=0.9779
#   Epoch  70: Train Acc=0.9859, Val Acc=0.9808, F1=0.9805
#   Epoch  80: Train Acc=0.9896, Val Acc=0.9778, F1=0.9773
#   Epoch  90: Train Acc=0.9906, Val Acc=0.9870, F1=0.9867
#   Epoch 100: Train Acc=0.9937, Val Acc=0.9833, F1=0.9829
#   Best Val Acc: 0.9876
#
# [Pure-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9494, F1: 0.9446
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_comparison_results.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 72
# Transitions tested: 6
# Mix ratios tested: 4
# Models compared: 3 (GAP, TPA, Pure-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE
# ================================================================================
# GAP       : Acc=0.9212, F1=0.9216
# TPA       : Acc=0.9556, F1=0.9550
# Pure-TPA  : Acc=0.9418, F1=0.9405
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
