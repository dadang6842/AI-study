# %%
# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Pure-TPA
Compare three models on pre-augmented transition datasets
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_seg_kernel: int = 9
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_transition_dataset(base_dir: str, transition_name: str, mix_pct: int):
    """
    Load pre-augmented transition dataset
    Args:
        base_dir: base directory containing all transition datasets
        transition_name: e.g., "STANDING_TO_LAYING"
        mix_pct: percentage (10, 20, 30, 40)
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, f"{transition_name}_{mix_pct}pct")

    print(f"\nLoading {transition_name} ({mix_pct}%)...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class ConvBNAct(nn.Module):
    def __init__(self, c_in, c_out, k, s=1, p=None, g=1):
        super().__init__()
        self.c = nn.Conv1d(c_in, c_out, k, s, k//2 if p is None else p, groups=g, bias=False)
        self.bn = nn.BatchNorm1d(c_out)
        self.act = nn.GELU()

    def forward(self, x):
        return self.act(self.bn(self.c(x)))

class MultiPathCNN(nn.Module):
    """Shared backbone for all models"""
    def __init__(self, in_ch=9, d_model=128, branches=(3,5,9,15), stride=2):
        super().__init__()
        h = d_model // 2
        self.pre = ConvBNAct(in_ch, h, 1)
        self.branches = nn.ModuleList([
            nn.Sequential(ConvBNAct(h, h, k, stride, g=h), ConvBNAct(h, h, 1))
            for k in branches
        ])
        self.post = ConvBNAct(len(branches)*h, d_model, 1)

    def forward(self, x):
        return self.post(torch.cat([b(self.pre(x)) for b in self.branches], dim=1))

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=6):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# TPA Model (with Conv Preprocessing)
# ========================
class ProductionTPA(nn.Module):
    """TPA with Conv Preprocessing"""
    def __init__(self, dim, num_prototypes=16, seg_kernel=9, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        pad = (seg_kernel - 1) // 2
        self.dw = nn.Conv1d(dim, dim, kernel_size=seg_kernel, padding=pad, groups=dim, bias=False)
        self.pw = nn.Conv1d(dim, dim, kernel_size=1, bias=False)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)
        self.out_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.conf_head = nn.Sequential(
            nn.Linear(dim, dim // 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(dim // 4, 1)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        # Conv preprocessing
        xloc = self.pw(self.dw(x.transpose(1, 2))).transpose(1, 2)
        xloc = self.pre_norm(xloc) + x

        K = self.k_proj(xloc)
        V = self.v_proj(xloc)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        topk = max(1, int(P * self.topk_ratio))
        vals, _ = torch.topk(proto_tokens, k=topk, dim=1)
        z_tpa = vals.mean(dim=1)

        z_tpa = self.fuse(z_tpa)
        z_tpa = self.out_proj(z_tpa)

        z_gap = x.mean(dim=1)
        confidence = torch.sigmoid(self.conf_head(z_tpa))
        z = confidence * z_tpa + (1 - confidence) * z_gap

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            seg_kernel=tpa_config['seg_kernel'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Pure TPA Model (without Conv Preprocessing)
# ========================
class PureTPA(nn.Module):
    """Pure TPA WITHOUT Conv Preprocessing"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        # Learnable prototypes
        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        # Simple normalization (NO conv layers)
        self.pre_norm = nn.LayerNorm(dim)

        # Q, K, V projections
        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)
        self.out_proj = nn.Linear(dim, dim, bias=False)

        # Fusion layer
        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        # Confidence predictor
        self.conf_head = nn.Sequential(
            nn.Linear(dim, dim // 4),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(dim // 4, 1)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        # Simple normalization (no conv preprocessing)
        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        topk = max(1, int(P * self.topk_ratio))
        vals, _ = torch.topk(proto_tokens, k=topk, dim=1)
        z_tpa = vals.mean(dim=1)

        z_tpa = self.fuse(z_tpa)
        z_tpa = self.out_proj(z_tpa)

        z_gap = x.mean(dim=1)
        confidence = torch.sigmoid(self.conf_head(z_tpa))
        z = confidence * z_tpa + (1 - confidence) * z_gap

        return z

class PureTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = PureTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Training Functions
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'seg_kernel': cfg.tpa_seg_kernel,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Pure-TPA":
        return PureTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(transition_name: str, mix_pct: int, cfg: Config):
    """Run complete experiment for one transition-mix combination"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {transition_name} - {mix_pct}%")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_transition_dataset(
        cfg.data_dir, transition_name, mix_pct
    )

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Pure-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Transition': transition_name,
            'Mix_Ratio': f"{mix_pct}%",
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Pure-TPA")
    print("="*80)

    # Define all transitions and mix ratios to test
    transitions = [
        "STANDING_TO_SITTING",
        "STANDING_TO_LAYING",
        "SITTING_TO_LAYING",
        "SITTING_TO_STANDING",
        "LAYING_TO_SITTING",
        "LAYING_TO_STANDING"
    ]

    mix_pcts = [10, 20, 30, 40]

    all_results = []

    # Run experiments
    for transition in transitions:
        for mix_pct in mix_pcts:
            results = run_experiment(transition, mix_pct, cfg)
            all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Pure-TPA'],
            'transitions': transitions,
            'mix_ratios': [f"{p}%" for p in mix_pcts],
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_comparison_results.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Transitions tested: {len(transitions)}")
    print(f"Mix ratios tested: {len(mix_pcts)}")
    print(f"Models compared: 3 (GAP, TPA, Pure-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Pure-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:10s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Mounted at /content/drive
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Pure-TPA
# ================================================================================
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 10%
# ================================================================================
#
# Loading STANDING_TO_SITTING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_SITTING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9303, Val Acc=0.9263, F1=0.9379
#   Epoch  20: Train Acc=0.9395, Val Acc=0.9326, F1=0.9435
#   Epoch  30: Train Acc=0.9449, Val Acc=0.9484, F1=0.9566
#   Epoch  40: Train Acc=0.9525, Val Acc=0.9530, F1=0.9592
#   Epoch  50: Train Acc=0.9541, Val Acc=0.9541, F1=0.9589
#   Epoch  60: Train Acc=0.9576, Val Acc=0.9575, F1=0.9630
#   Epoch  70: Train Acc=0.9572, Val Acc=0.9586, F1=0.9645
#   Epoch  80: Train Acc=0.9615, Val Acc=0.9564, F1=0.9614
#   Epoch  90: Train Acc=0.9636, Val Acc=0.9632, F1=0.9681
#   Epoch 100: Train Acc=0.9681, Val Acc=0.9632, F1=0.9692
#   Best Val Acc: 0.9683
#
# [GAP Results]
#   Val Acc: 0.9683
#   Test Acc: 0.9262, F1: 0.9265
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9616, Val Acc=0.9575, F1=0.9624
#   Epoch  20: Train Acc=0.9715, Val Acc=0.9666, F1=0.9717
#   Epoch  30: Train Acc=0.9824, Val Acc=0.9734, F1=0.9778
#   Epoch  40: Train Acc=0.9912, Val Acc=0.9830, F1=0.9853
#   Epoch  50: Train Acc=0.9936, Val Acc=0.9830, F1=0.9851
#   Epoch  60: Train Acc=0.9966, Val Acc=0.9898, F1=0.9911
#   Epoch  70: Train Acc=0.9960, Val Acc=0.9904, F1=0.9914
#   Early stopping at epoch 79
#   Best Val Acc: 0.9926
#
# [TPA Results]
#   Val Acc: 0.9926
#   Test Acc: 0.9621, F1: 0.9607
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9615, Val Acc=0.9569, F1=0.9618
#   Epoch  20: Train Acc=0.9731, Val Acc=0.9694, F1=0.9741
#   Epoch  30: Train Acc=0.9800, Val Acc=0.9768, F1=0.9807
#   Epoch  40: Train Acc=0.9831, Val Acc=0.9756, F1=0.9793
#   Epoch  50: Train Acc=0.9868, Val Acc=0.9751, F1=0.9783
#   Epoch  60: Train Acc=0.9919, Val Acc=0.9768, F1=0.9807
#   Epoch  70: Train Acc=0.9904, Val Acc=0.9722, F1=0.9776
#   Epoch  80: Train Acc=0.9935, Val Acc=0.9841, F1=0.9864
#   Epoch  90: Train Acc=0.9953, Val Acc=0.9875, F1=0.9894
#   Early stopping at epoch 91
#   Best Val Acc: 0.9904
#
# [Pure-TPA Results]
#   Val Acc: 0.9904
#   Test Acc: 0.9465, F1: 0.9450
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 20%
# ================================================================================
#
# Loading STANDING_TO_SITTING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_SITTING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9325, Val Acc=0.9235, F1=0.9354
#   Epoch  20: Train Acc=0.9399, Val Acc=0.9320, F1=0.9448
#   Epoch  30: Train Acc=0.9432, Val Acc=0.9365, F1=0.9505
#   Epoch  40: Train Acc=0.9483, Val Acc=0.9501, F1=0.9572
#   Epoch  50: Train Acc=0.9541, Val Acc=0.9547, F1=0.9617
#   Epoch  60: Train Acc=0.9549, Val Acc=0.9558, F1=0.9612
#   Epoch  70: Train Acc=0.9573, Val Acc=0.9575, F1=0.9639
#   Epoch  80: Train Acc=0.9603, Val Acc=0.9581, F1=0.9640
#   Epoch  90: Train Acc=0.9643, Val Acc=0.9649, F1=0.9709
#   Epoch 100: Train Acc=0.9668, Val Acc=0.9637, F1=0.9693
#   Best Val Acc: 0.9654
#
# [GAP Results]
#   Val Acc: 0.9654
#   Test Acc: 0.9287, F1: 0.9291
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9633, Val Acc=0.9626, F1=0.9681
#   Epoch  20: Train Acc=0.9769, Val Acc=0.9762, F1=0.9806
#   Epoch  30: Train Acc=0.9865, Val Acc=0.9813, F1=0.9848
#   Epoch  40: Train Acc=0.9905, Val Acc=0.9881, F1=0.9901
#   Epoch  50: Train Acc=0.9972, Val Acc=0.9915, F1=0.9929
#   Epoch  60: Train Acc=0.9979, Val Acc=0.9921, F1=0.9934
#   Epoch  70: Train Acc=0.9989, Val Acc=0.9909, F1=0.9924
#   Epoch  80: Train Acc=0.9994, Val Acc=0.9870, F1=0.9892
#   Early stopping at epoch 88
#   Best Val Acc: 0.9943
#
# [TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9519, F1: 0.9495
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9593, Val Acc=0.9501, F1=0.9585
#   Epoch  20: Train Acc=0.9683, Val Acc=0.9598, F1=0.9675
#   Epoch  30: Train Acc=0.9768, Val Acc=0.9739, F1=0.9789
#   Epoch  40: Train Acc=0.9809, Val Acc=0.9751, F1=0.9797
#   Epoch  50: Train Acc=0.9851, Val Acc=0.9700, F1=0.9742
#   Early stopping at epoch 58
#   Best Val Acc: 0.9807
#
# [Pure-TPA Results]
#   Val Acc: 0.9807
#   Test Acc: 0.9276, F1: 0.9253
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 30%
# ================================================================================
#
# Loading STANDING_TO_SITTING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_SITTING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9294, Val Acc=0.9252, F1=0.9372
#   Epoch  20: Train Acc=0.9385, Val Acc=0.9320, F1=0.9429
#   Epoch  30: Train Acc=0.9435, Val Acc=0.9484, F1=0.9583
#   Epoch  40: Train Acc=0.9490, Val Acc=0.9496, F1=0.9560
#   Epoch  50: Train Acc=0.9517, Val Acc=0.9598, F1=0.9660
#   Epoch  60: Train Acc=0.9538, Val Acc=0.9541, F1=0.9605
#   Epoch  70: Train Acc=0.9555, Val Acc=0.9586, F1=0.9652
#   Epoch  80: Train Acc=0.9583, Val Acc=0.9637, F1=0.9684
#   Epoch  90: Train Acc=0.9640, Val Acc=0.9734, F1=0.9778
#   Epoch 100: Train Acc=0.9656, Val Acc=0.9683, F1=0.9739
#   Best Val Acc: 0.9790
#
# [GAP Results]
#   Val Acc: 0.9790
#   Test Acc: 0.9330, F1: 0.9342
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9554, Val Acc=0.9422, F1=0.9525
#   Epoch  20: Train Acc=0.9759, Val Acc=0.9739, F1=0.9785
#   Epoch  30: Train Acc=0.9834, Val Acc=0.9802, F1=0.9836
#   Epoch  40: Train Acc=0.9914, Val Acc=0.9875, F1=0.9895
#   Epoch  50: Train Acc=0.9945, Val Acc=0.9853, F1=0.9875
#   Early stopping at epoch 58
#   Best Val Acc: 0.9881
#
# [TPA Results]
#   Val Acc: 0.9881
#   Test Acc: 0.9494, F1: 0.9476
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9615, Val Acc=0.9660, F1=0.9715
#   Epoch  20: Train Acc=0.9724, Val Acc=0.9649, F1=0.9712
#   Epoch  30: Train Acc=0.9778, Val Acc=0.9677, F1=0.9741
#   Epoch  40: Train Acc=0.9797, Val Acc=0.9688, F1=0.9752
#   Epoch  50: Train Acc=0.9855, Val Acc=0.9807, F1=0.9838
#   Epoch  60: Train Acc=0.9870, Val Acc=0.9824, F1=0.9853
#   Epoch  70: Train Acc=0.9887, Val Acc=0.9785, F1=0.9815
#   Epoch  80: Train Acc=0.9909, Val Acc=0.9847, F1=0.9871
#   Epoch  90: Train Acc=0.9943, Val Acc=0.9864, F1=0.9885
#   Epoch 100: Train Acc=0.9962, Val Acc=0.9711, F1=0.9762
#   Best Val Acc: 0.9881
#
# [Pure-TPA Results]
#   Val Acc: 0.9881
#   Test Acc: 0.9468, F1: 0.9461
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING - 40%
# ================================================================================
#
# Loading STANDING_TO_SITTING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_SITTING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9270, Val Acc=0.9184, F1=0.9312
#   Epoch  20: Train Acc=0.9382, Val Acc=0.9314, F1=0.9427
#   Epoch  30: Train Acc=0.9456, Val Acc=0.9445, F1=0.9529
#   Epoch  40: Train Acc=0.9527, Val Acc=0.9496, F1=0.9564
#   Epoch  50: Train Acc=0.9554, Val Acc=0.9496, F1=0.9556
#   Epoch  60: Train Acc=0.9602, Val Acc=0.9535, F1=0.9590
#   Epoch  70: Train Acc=0.9605, Val Acc=0.9552, F1=0.9628
#   Epoch  80: Train Acc=0.9634, Val Acc=0.9581, F1=0.9630
#   Epoch  90: Train Acc=0.9670, Val Acc=0.9598, F1=0.9660
#   Epoch 100: Train Acc=0.9700, Val Acc=0.9643, F1=0.9696
#   Best Val Acc: 0.9688
#
# [GAP Results]
#   Val Acc: 0.9688
#   Test Acc: 0.9437, F1: 0.9453
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9617, Val Acc=0.9620, F1=0.9682
#   Epoch  20: Train Acc=0.9782, Val Acc=0.9711, F1=0.9754
#   Epoch  30: Train Acc=0.9877, Val Acc=0.9807, F1=0.9838
#   Epoch  40: Train Acc=0.9923, Val Acc=0.9796, F1=0.9826
#   Epoch  50: Train Acc=0.9950, Val Acc=0.9881, F1=0.9898
#   Epoch  60: Train Acc=0.9984, Val Acc=0.9898, F1=0.9913
#   Epoch  70: Train Acc=0.9977, Val Acc=0.9881, F1=0.9899
#   Epoch  80: Train Acc=0.9984, Val Acc=0.9892, F1=0.9911
#   Early stopping at epoch 87
#   Best Val Acc: 0.9921
#
# [TPA Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9581, F1: 0.9566
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9629, Val Acc=0.9586, F1=0.9641
#   Epoch  20: Train Acc=0.9705, Val Acc=0.9637, F1=0.9692
#   Epoch  30: Train Acc=0.9770, Val Acc=0.9694, F1=0.9744
#   Epoch  40: Train Acc=0.9807, Val Acc=0.9722, F1=0.9772
#   Epoch  50: Train Acc=0.9847, Val Acc=0.9620, F1=0.9691
#   Epoch  60: Train Acc=0.9857, Val Acc=0.9807, F1=0.9841
#   Epoch  70: Train Acc=0.9892, Val Acc=0.9841, F1=0.9868
#   Epoch  80: Train Acc=0.9914, Val Acc=0.9858, F1=0.9882
#   Early stopping at epoch 87
#   Best Val Acc: 0.9887
#
# [Pure-TPA Results]
#   Val Acc: 0.9887
#   Test Acc: 0.9395, F1: 0.9385
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 10%
# ================================================================================
#
# Loading STANDING_TO_LAYING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_LAYING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9347, Val Acc=0.9354, F1=0.9451
#   Epoch  20: Train Acc=0.9532, Val Acc=0.9552, F1=0.9610
#   Epoch  30: Train Acc=0.9565, Val Acc=0.9586, F1=0.9646
#   Epoch  40: Train Acc=0.9596, Val Acc=0.9649, F1=0.9711
#   Epoch  50: Train Acc=0.9600, Val Acc=0.9649, F1=0.9689
#   Early stopping at epoch 54
#   Best Val Acc: 0.9677
#
# [GAP Results]
#   Val Acc: 0.9677
#   Test Acc: 0.9313, F1: 0.9306
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9647, Val Acc=0.9643, F1=0.9689
#   Epoch  20: Train Acc=0.9739, Val Acc=0.9745, F1=0.9792
#   Epoch  30: Train Acc=0.9872, Val Acc=0.9819, F1=0.9852
#   Epoch  40: Train Acc=0.9931, Val Acc=0.9892, F1=0.9910
#   Epoch  50: Train Acc=0.9957, Val Acc=0.9881, F1=0.9901
#   Epoch  60: Train Acc=0.9967, Val Acc=0.9915, F1=0.9929
#   Epoch  70: Train Acc=0.9986, Val Acc=0.9915, F1=0.9930
#   Early stopping at epoch 73
#   Best Val Acc: 0.9932
#
# [TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9627, F1: 0.9592
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9654, Val Acc=0.9694, F1=0.9732
#   Epoch  20: Train Acc=0.9736, Val Acc=0.9688, F1=0.9746
#   Epoch  30: Train Acc=0.9772, Val Acc=0.9796, F1=0.9827
#   Epoch  40: Train Acc=0.9877, Val Acc=0.9768, F1=0.9810
#   Epoch  50: Train Acc=0.9881, Val Acc=0.9836, F1=0.9864
#   Epoch  60: Train Acc=0.9939, Val Acc=0.9881, F1=0.9900
#   Epoch  70: Train Acc=0.9960, Val Acc=0.9870, F1=0.9890
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9870, F1=0.9891
#   Epoch  90: Train Acc=0.9976, Val Acc=0.9921, F1=0.9935
#   Early stopping at epoch 93
#   Best Val Acc: 0.9921
#
# [Pure-TPA Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9570, F1: 0.9543
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 20%
# ================================================================================
#
# Loading STANDING_TO_LAYING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_LAYING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9412, Val Acc=0.9360, F1=0.9467
#   Epoch  20: Train Acc=0.9569, Val Acc=0.9632, F1=0.9691
#   Epoch  30: Train Acc=0.9592, Val Acc=0.9666, F1=0.9727
#   Epoch  40: Train Acc=0.9603, Val Acc=0.9637, F1=0.9701
#   Epoch  50: Train Acc=0.9636, Val Acc=0.9620, F1=0.9682
#   Early stopping at epoch 50
#   Best Val Acc: 0.9666
#
# [GAP Results]
#   Val Acc: 0.9666
#   Test Acc: 0.9299, F1: 0.9298
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9649, Val Acc=0.9666, F1=0.9725
#   Epoch  20: Train Acc=0.9770, Val Acc=0.9739, F1=0.9786
#   Epoch  30: Train Acc=0.9846, Val Acc=0.9841, F1=0.9868
#   Epoch  40: Train Acc=0.9921, Val Acc=0.9915, F1=0.9929
#   Epoch  50: Train Acc=0.9959, Val Acc=0.9926, F1=0.9939
#   Epoch  60: Train Acc=0.9980, Val Acc=0.9909, F1=0.9925
#   Epoch  70: Train Acc=0.9991, Val Acc=0.9898, F1=0.9916
#   Epoch  80: Train Acc=0.9984, Val Acc=0.9915, F1=0.9930
#   Epoch  90: Train Acc=0.9991, Val Acc=0.9938, F1=0.9948
#   Early stopping at epoch 96
#   Best Val Acc: 0.9955
#
# [TPA Results]
#   Val Acc: 0.9955
#   Test Acc: 0.9581, F1: 0.9551
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9630, Val Acc=0.9671, F1=0.9722
#   Epoch  20: Train Acc=0.9731, Val Acc=0.9649, F1=0.9716
#   Epoch  30: Train Acc=0.9780, Val Acc=0.9773, F1=0.9807
#   Epoch  40: Train Acc=0.9864, Val Acc=0.9756, F1=0.9803
#   Epoch  50: Train Acc=0.9887, Val Acc=0.9870, F1=0.9892
#   Epoch  60: Train Acc=0.9911, Val Acc=0.9802, F1=0.9837
#   Epoch  70: Train Acc=0.9932, Val Acc=0.9836, F1=0.9864
#   Epoch  80: Train Acc=0.9953, Val Acc=0.9921, F1=0.9934
#   Epoch  90: Train Acc=0.9973, Val Acc=0.9921, F1=0.9934
#   Epoch 100: Train Acc=0.9979, Val Acc=0.9847, F1=0.9876
#   Best Val Acc: 0.9943
#
# [Pure-TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9471, F1: 0.9419
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 30%
# ================================================================================
#
# Loading STANDING_TO_LAYING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_LAYING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9446, Val Acc=0.9535, F1=0.9607
#   Epoch  20: Train Acc=0.9582, Val Acc=0.9558, F1=0.9617
#   Epoch  30: Train Acc=0.9573, Val Acc=0.9666, F1=0.9724
#   Epoch  40: Train Acc=0.9617, Val Acc=0.9649, F1=0.9708
#   Early stopping at epoch 44
#   Best Val Acc: 0.9677
#
# [GAP Results]
#   Val Acc: 0.9677
#   Test Acc: 0.9234, F1: 0.9229
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9657, Val Acc=0.9711, F1=0.9760
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9705, F1=0.9755
#   Epoch  30: Train Acc=0.9820, Val Acc=0.9807, F1=0.9838
#   Epoch  40: Train Acc=0.9882, Val Acc=0.9807, F1=0.9839
#   Epoch  50: Train Acc=0.9942, Val Acc=0.9813, F1=0.9844
#   Epoch  60: Train Acc=0.9940, Val Acc=0.9875, F1=0.9897
#   Epoch  70: Train Acc=0.9982, Val Acc=0.9921, F1=0.9931
#   Epoch  80: Train Acc=0.9976, Val Acc=0.9909, F1=0.9923
#   Epoch  90: Train Acc=0.9990, Val Acc=0.9915, F1=0.9929
#   Epoch 100: Train Acc=0.9996, Val Acc=0.9915, F1=0.9930
#   Best Val Acc: 0.9938
#
# [TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9539, F1: 0.9496
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9660, Val Acc=0.9700, F1=0.9746
#   Epoch  20: Train Acc=0.9718, Val Acc=0.9700, F1=0.9753
#   Epoch  30: Train Acc=0.9812, Val Acc=0.9796, F1=0.9828
#   Epoch  40: Train Acc=0.9885, Val Acc=0.9819, F1=0.9850
#   Epoch  50: Train Acc=0.9892, Val Acc=0.9841, F1=0.9865
#   Epoch  60: Train Acc=0.9904, Val Acc=0.9824, F1=0.9855
#   Epoch  70: Train Acc=0.9936, Val Acc=0.9819, F1=0.9843
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9909, F1=0.9922
#   Epoch  90: Train Acc=0.9976, Val Acc=0.9926, F1=0.9936
#   Epoch 100: Train Acc=0.9957, Val Acc=0.9909, F1=0.9922
#   Best Val Acc: 0.9938
#
# [Pure-TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9539, F1: 0.9493
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING - 40%
# ================================================================================
#
# Loading STANDING_TO_LAYING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/STANDING_TO_LAYING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9447, Val Acc=0.9654, F1=0.9688
#   Epoch  20: Train Acc=0.9565, Val Acc=0.9717, F1=0.9764
#   Epoch  30: Train Acc=0.9568, Val Acc=0.9717, F1=0.9767
#   Epoch  40: Train Acc=0.9583, Val Acc=0.9717, F1=0.9767
#   Early stopping at epoch 44
#   Best Val Acc: 0.9734
#
# [GAP Results]
#   Val Acc: 0.9734
#   Test Acc: 0.9301, F1: 0.9298
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9673, Val Acc=0.9722, F1=0.9775
#   Epoch  20: Train Acc=0.9753, Val Acc=0.9700, F1=0.9752
#   Epoch  30: Train Acc=0.9831, Val Acc=0.9870, F1=0.9891
#   Epoch  40: Train Acc=0.9916, Val Acc=0.9921, F1=0.9934
#   Epoch  50: Train Acc=0.9965, Val Acc=0.9909, F1=0.9924
#   Epoch  60: Train Acc=0.9976, Val Acc=0.9926, F1=0.9939
#   Epoch  70: Train Acc=0.9980, Val Acc=0.9926, F1=0.9938
#   Epoch  80: Train Acc=0.9996, Val Acc=0.9943, F1=0.9953
#   Epoch  90: Train Acc=0.9990, Val Acc=0.9932, F1=0.9944
#   Early stopping at epoch 93
#   Best Val Acc: 0.9955
#
# [TPA Results]
#   Val Acc: 0.9955
#   Test Acc: 0.9613, F1: 0.9585
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9626, Val Acc=0.9654, F1=0.9715
#   Epoch  20: Train Acc=0.9719, Val Acc=0.9700, F1=0.9757
#   Epoch  30: Train Acc=0.9790, Val Acc=0.9785, F1=0.9824
#   Epoch  40: Train Acc=0.9820, Val Acc=0.9796, F1=0.9835
#   Epoch  50: Train Acc=0.9867, Val Acc=0.9830, F1=0.9860
#   Epoch  60: Train Acc=0.9902, Val Acc=0.9847, F1=0.9875
#   Epoch  70: Train Acc=0.9909, Val Acc=0.9807, F1=0.9845
#   Epoch  80: Train Acc=0.9925, Val Acc=0.9813, F1=0.9849
#   Early stopping at epoch 85
#   Best Val Acc: 0.9892
#
# [Pure-TPA Results]
#   Val Acc: 0.9892
#   Test Acc: 0.9514, F1: 0.9489
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 10%
# ================================================================================
#
# Loading SITTING_TO_LAYING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_LAYING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9459, Val Acc=0.9382, F1=0.9453
#   Epoch  20: Train Acc=0.9609, Val Acc=0.9603, F1=0.9678
#   Epoch  30: Train Acc=0.9592, Val Acc=0.9620, F1=0.9688
#   Epoch  40: Train Acc=0.9592, Val Acc=0.9637, F1=0.9714
#   Epoch  50: Train Acc=0.9610, Val Acc=0.9626, F1=0.9711
#   Early stopping at epoch 57
#   Best Val Acc: 0.9671
#
# [GAP Results]
#   Val Acc: 0.9671
#   Test Acc: 0.9270, F1: 0.9338
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9657, Val Acc=0.9620, F1=0.9707
#   Epoch  20: Train Acc=0.9742, Val Acc=0.9739, F1=0.9793
#   Epoch  30: Train Acc=0.9820, Val Acc=0.9807, F1=0.9849
#   Epoch  40: Train Acc=0.9891, Val Acc=0.9813, F1=0.9849
#   Epoch  50: Train Acc=0.9922, Val Acc=0.9858, F1=0.9887
#   Epoch  60: Train Acc=0.9962, Val Acc=0.9887, F1=0.9909
#   Epoch  70: Train Acc=0.9967, Val Acc=0.9887, F1=0.9906
#   Epoch  80: Train Acc=0.9984, Val Acc=0.9870, F1=0.9894
#   Early stopping at epoch 84
#   Best Val Acc: 0.9904
#
# [TPA Results]
#   Val Acc: 0.9904
#   Test Acc: 0.9621, F1: 0.9650
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9619, Val Acc=0.9683, F1=0.9730
#   Epoch  20: Train Acc=0.9717, Val Acc=0.9671, F1=0.9737
#   Epoch  30: Train Acc=0.9765, Val Acc=0.9688, F1=0.9742
#   Epoch  40: Train Acc=0.9854, Val Acc=0.9773, F1=0.9820
#   Epoch  50: Train Acc=0.9904, Val Acc=0.9847, F1=0.9875
#   Epoch  60: Train Acc=0.9931, Val Acc=0.9847, F1=0.9872
#   Epoch  70: Train Acc=0.9960, Val Acc=0.9853, F1=0.9879
#   Epoch  80: Train Acc=0.9955, Val Acc=0.9870, F1=0.9891
#   Early stopping at epoch 89
#   Best Val Acc: 0.9915
#
# [Pure-TPA Results]
#   Val Acc: 0.9915
#   Test Acc: 0.9514, F1: 0.9520
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 20%
# ================================================================================
#
# Loading SITTING_TO_LAYING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_LAYING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9520, Val Acc=0.9518, F1=0.9611
#   Epoch  20: Train Acc=0.9603, Val Acc=0.9598, F1=0.9678
#   Epoch  30: Train Acc=0.9617, Val Acc=0.9637, F1=0.9709
#   Epoch  40: Train Acc=0.9627, Val Acc=0.9609, F1=0.9689
#   Epoch  50: Train Acc=0.9634, Val Acc=0.9535, F1=0.9643
#   Epoch  60: Train Acc=0.9629, Val Acc=0.9586, F1=0.9677
#   Epoch  70: Train Acc=0.9651, Val Acc=0.9649, F1=0.9718
#   Epoch  80: Train Acc=0.9675, Val Acc=0.9609, F1=0.9692
#   Early stopping at epoch 83
#   Best Val Acc: 0.9700
#
# [GAP Results]
#   Val Acc: 0.9700
#   Test Acc: 0.9217, F1: 0.9266
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9649, Val Acc=0.9632, F1=0.9702
#   Epoch  20: Train Acc=0.9727, Val Acc=0.9666, F1=0.9733
#   Epoch  30: Train Acc=0.9826, Val Acc=0.9705, F1=0.9766
#   Epoch  40: Train Acc=0.9880, Val Acc=0.9819, F1=0.9854
#   Epoch  50: Train Acc=0.9926, Val Acc=0.9875, F1=0.9898
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9858, F1=0.9884
#   Epoch  70: Train Acc=0.9969, Val Acc=0.9921, F1=0.9937
#   Epoch  80: Train Acc=0.9979, Val Acc=0.9881, F1=0.9905
#   Epoch  90: Train Acc=0.9983, Val Acc=0.9870, F1=0.9895
#   Epoch 100: Train Acc=0.9990, Val Acc=0.9926, F1=0.9941
#   Best Val Acc: 0.9943
#
# [TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9649, F1: 0.9686
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9624, Val Acc=0.9609, F1=0.9692
#   Epoch  20: Train Acc=0.9719, Val Acc=0.9677, F1=0.9737
#   Epoch  30: Train Acc=0.9773, Val Acc=0.9728, F1=0.9783
#   Epoch  40: Train Acc=0.9803, Val Acc=0.9790, F1=0.9835
#   Epoch  50: Train Acc=0.9858, Val Acc=0.9824, F1=0.9859
#   Epoch  60: Train Acc=0.9874, Val Acc=0.9830, F1=0.9866
#   Epoch  70: Train Acc=0.9916, Val Acc=0.9819, F1=0.9858
#   Epoch  80: Train Acc=0.9928, Val Acc=0.9864, F1=0.9892
#   Epoch  90: Train Acc=0.9943, Val Acc=0.9898, F1=0.9919
#   Early stopping at epoch 93
#   Best Val Acc: 0.9921
#
# [Pure-TPA Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9570, F1: 0.9602
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 30%
# ================================================================================
#
# Loading SITTING_TO_LAYING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_LAYING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9515, Val Acc=0.9552, F1=0.9627
#   Epoch  20: Train Acc=0.9609, Val Acc=0.9609, F1=0.9686
#   Epoch  30: Train Acc=0.9605, Val Acc=0.9637, F1=0.9703
#   Epoch  40: Train Acc=0.9609, Val Acc=0.9615, F1=0.9695
#   Epoch  50: Train Acc=0.9619, Val Acc=0.9569, F1=0.9667
#   Early stopping at epoch 50
#   Best Val Acc: 0.9637
#
# [GAP Results]
#   Val Acc: 0.9637
#   Test Acc: 0.9248, F1: 0.9289
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9668, Val Acc=0.9609, F1=0.9699
#   Epoch  20: Train Acc=0.9761, Val Acc=0.9700, F1=0.9761
#   Epoch  30: Train Acc=0.9789, Val Acc=0.9728, F1=0.9787
#   Epoch  40: Train Acc=0.9840, Val Acc=0.9779, F1=0.9821
#   Epoch  50: Train Acc=0.9901, Val Acc=0.9836, F1=0.9868
#   Epoch  60: Train Acc=0.9943, Val Acc=0.9836, F1=0.9868
#   Epoch  70: Train Acc=0.9965, Val Acc=0.9921, F1=0.9936
#   Epoch  80: Train Acc=0.9976, Val Acc=0.9904, F1=0.9922
#   Epoch  90: Train Acc=0.9984, Val Acc=0.9909, F1=0.9928
#   Epoch 100: Train Acc=0.9990, Val Acc=0.9904, F1=0.9923
#   Best Val Acc: 0.9943
#
# [TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9587, F1: 0.9628
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9636, Val Acc=0.9603, F1=0.9677
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9643, F1=0.9709
#   Epoch  30: Train Acc=0.9766, Val Acc=0.9535, F1=0.9609
#   Epoch  40: Train Acc=0.9855, Val Acc=0.9802, F1=0.9841
#   Epoch  50: Train Acc=0.9899, Val Acc=0.9887, F1=0.9910
#   Epoch  60: Train Acc=0.9936, Val Acc=0.9841, F1=0.9873
#   Epoch  70: Train Acc=0.9943, Val Acc=0.9943, F1=0.9955
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9870, F1=0.9896
#   Epoch  90: Train Acc=0.9980, Val Acc=0.9921, F1=0.9937
#   Early stopping at epoch 90
#   Best Val Acc: 0.9943
#
# [Pure-TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9533, F1: 0.9546
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING - 40%
# ================================================================================
#
# Loading SITTING_TO_LAYING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_LAYING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9541, Val Acc=0.9535, F1=0.9608
#   Epoch  20: Train Acc=0.9582, Val Acc=0.9575, F1=0.9654
#   Epoch  30: Train Acc=0.9586, Val Acc=0.9609, F1=0.9682
#   Early stopping at epoch 39
#   Best Val Acc: 0.9637
#
# [GAP Results]
#   Val Acc: 0.9637
#   Test Acc: 0.9248, F1: 0.9284
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9623, Val Acc=0.9683, F1=0.9742
#   Epoch  20: Train Acc=0.9748, Val Acc=0.9739, F1=0.9793
#   Epoch  30: Train Acc=0.9799, Val Acc=0.9779, F1=0.9826
#   Epoch  40: Train Acc=0.9858, Val Acc=0.9813, F1=0.9849
#   Epoch  50: Train Acc=0.9884, Val Acc=0.9830, F1=0.9861
#   Epoch  60: Train Acc=0.9909, Val Acc=0.9853, F1=0.9880
#   Epoch  70: Train Acc=0.9943, Val Acc=0.9881, F1=0.9905
#   Epoch  80: Train Acc=0.9956, Val Acc=0.9921, F1=0.9937
#   Epoch  90: Train Acc=0.9970, Val Acc=0.9932, F1=0.9945
#   Epoch 100: Train Acc=0.9980, Val Acc=0.9943, F1=0.9955
#   Best Val Acc: 0.9960
#
# [TPA Results]
#   Val Acc: 0.9960
#   Test Acc: 0.9638, F1: 0.9676
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9617, Val Acc=0.9592, F1=0.9644
#   Epoch  20: Train Acc=0.9708, Val Acc=0.9739, F1=0.9796
#   Epoch  30: Train Acc=0.9769, Val Acc=0.9705, F1=0.9759
#   Epoch  40: Train Acc=0.9833, Val Acc=0.9717, F1=0.9780
#   Epoch  50: Train Acc=0.9843, Val Acc=0.9768, F1=0.9812
#   Epoch  60: Train Acc=0.9877, Val Acc=0.9813, F1=0.9850
#   Epoch  70: Train Acc=0.9908, Val Acc=0.9807, F1=0.9844
#   Epoch  80: Train Acc=0.9932, Val Acc=0.9915, F1=0.9930
#   Epoch  90: Train Acc=0.9946, Val Acc=0.9819, F1=0.9847
#   Epoch 100: Train Acc=0.9952, Val Acc=0.9955, F1=0.9961
#   Best Val Acc: 0.9955
#
# [Pure-TPA Results]
#   Val Acc: 0.9955
#   Test Acc: 0.9610, F1: 0.9633
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 10%
# ================================================================================
#
# Loading SITTING_TO_STANDING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_STANDING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9418, Val Acc=0.9343, F1=0.9439
#   Epoch  20: Train Acc=0.9471, Val Acc=0.9462, F1=0.9574
#   Epoch  30: Train Acc=0.9470, Val Acc=0.9541, F1=0.9619
#   Epoch  40: Train Acc=0.9483, Val Acc=0.9439, F1=0.9558
#   Epoch  50: Train Acc=0.9528, Val Acc=0.9445, F1=0.9567
#   Epoch  60: Train Acc=0.9548, Val Acc=0.9496, F1=0.9610
#   Epoch  70: Train Acc=0.9561, Val Acc=0.9592, F1=0.9663
#   Epoch  80: Train Acc=0.9588, Val Acc=0.9620, F1=0.9695
#   Epoch  90: Train Acc=0.9609, Val Acc=0.9643, F1=0.9710
#   Epoch 100: Train Acc=0.9598, Val Acc=0.9643, F1=0.9718
#   Best Val Acc: 0.9688
#
# [GAP Results]
#   Val Acc: 0.9688
#   Test Acc: 0.9171, F1: 0.9265
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9532, Val Acc=0.9558, F1=0.9632
#   Epoch  20: Train Acc=0.9745, Val Acc=0.9643, F1=0.9707
#   Epoch  30: Train Acc=0.9841, Val Acc=0.9756, F1=0.9800
#   Epoch  40: Train Acc=0.9904, Val Acc=0.9847, F1=0.9875
#   Epoch  50: Train Acc=0.9948, Val Acc=0.9887, F1=0.9908
#   Epoch  60: Train Acc=0.9967, Val Acc=0.9875, F1=0.9900
#   Epoch  70: Train Acc=0.9983, Val Acc=0.9858, F1=0.9887
#   Epoch  80: Train Acc=0.9987, Val Acc=0.9858, F1=0.9886
#   Early stopping at epoch 87
#   Best Val Acc: 0.9909
#
# [TPA Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9601, F1: 0.9638
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9520, Val Acc=0.9603, F1=0.9670
#   Epoch  20: Train Acc=0.9677, Val Acc=0.9632, F1=0.9714
#   Epoch  30: Train Acc=0.9786, Val Acc=0.9671, F1=0.9745
#   Epoch  40: Train Acc=0.9814, Val Acc=0.9705, F1=0.9765
#   Early stopping at epoch 43
#   Best Val Acc: 0.9802
#
# [Pure-TPA Results]
#   Val Acc: 0.9802
#   Test Acc: 0.9285, F1: 0.9300
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 20%
# ================================================================================
#
# Loading SITTING_TO_STANDING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_STANDING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9395, Val Acc=0.9309, F1=0.9418
#   Epoch  20: Train Acc=0.9494, Val Acc=0.9343, F1=0.9469
#   Epoch  30: Train Acc=0.9476, Val Acc=0.9371, F1=0.9492
#   Epoch  40: Train Acc=0.9504, Val Acc=0.9416, F1=0.9523
#   Epoch  50: Train Acc=0.9534, Val Acc=0.9331, F1=0.9475
#   Epoch  60: Train Acc=0.9558, Val Acc=0.9411, F1=0.9529
#   Early stopping at epoch 64
#   Best Val Acc: 0.9496
#
# [GAP Results]
#   Val Acc: 0.9496
#   Test Acc: 0.9140, F1: 0.9217
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9562, Val Acc=0.9428, F1=0.9537
#   Epoch  20: Train Acc=0.9751, Val Acc=0.9671, F1=0.9731
#   Epoch  30: Train Acc=0.9853, Val Acc=0.9819, F1=0.9854
#   Epoch  40: Train Acc=0.9898, Val Acc=0.9858, F1=0.9888
#   Epoch  50: Train Acc=0.9923, Val Acc=0.9943, F1=0.9954
#   Epoch  60: Train Acc=0.9962, Val Acc=0.9949, F1=0.9959
#   Epoch  70: Train Acc=0.9967, Val Acc=0.9932, F1=0.9945
#   Early stopping at epoch 79
#   Best Val Acc: 0.9949
#
# [TPA Results]
#   Val Acc: 0.9949
#   Test Acc: 0.9505, F1: 0.9532
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9556, Val Acc=0.9456, F1=0.9569
#   Epoch  20: Train Acc=0.9695, Val Acc=0.9654, F1=0.9730
#   Epoch  30: Train Acc=0.9766, Val Acc=0.9728, F1=0.9781
#   Epoch  40: Train Acc=0.9829, Val Acc=0.9802, F1=0.9836
#   Epoch  50: Train Acc=0.9870, Val Acc=0.9751, F1=0.9806
#   Epoch  60: Train Acc=0.9894, Val Acc=0.9824, F1=0.9862
#   Epoch  70: Train Acc=0.9914, Val Acc=0.9824, F1=0.9861
#   Epoch  80: Train Acc=0.9948, Val Acc=0.9853, F1=0.9883
#   Epoch  90: Train Acc=0.9933, Val Acc=0.9926, F1=0.9941
#   Early stopping at epoch 96
#   Best Val Acc: 0.9932
#
# [Pure-TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9426, F1: 0.9440
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 30%
# ================================================================================
#
# Loading SITTING_TO_STANDING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_STANDING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9364, Val Acc=0.9354, F1=0.9447
#   Epoch  20: Train Acc=0.9428, Val Acc=0.9439, F1=0.9547
#   Epoch  30: Train Acc=0.9443, Val Acc=0.9518, F1=0.9598
#   Epoch  40: Train Acc=0.9466, Val Acc=0.9388, F1=0.9518
#   Epoch  50: Train Acc=0.9503, Val Acc=0.9484, F1=0.9593
#   Epoch  60: Train Acc=0.9549, Val Acc=0.9547, F1=0.9641
#   Epoch  70: Train Acc=0.9578, Val Acc=0.9581, F1=0.9652
#   Epoch  80: Train Acc=0.9616, Val Acc=0.9626, F1=0.9693
#   Epoch  90: Train Acc=0.9641, Val Acc=0.9592, F1=0.9680
#   Epoch 100: Train Acc=0.9667, Val Acc=0.9552, F1=0.9654
#   Best Val Acc: 0.9660
#
# [GAP Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9186, F1: 0.9274
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9573, Val Acc=0.9547, F1=0.9624
#   Epoch  20: Train Acc=0.9695, Val Acc=0.9643, F1=0.9706
#   Epoch  30: Train Acc=0.9829, Val Acc=0.9807, F1=0.9844
#   Epoch  40: Train Acc=0.9887, Val Acc=0.9841, F1=0.9871
#   Epoch  50: Train Acc=0.9932, Val Acc=0.9830, F1=0.9864
#   Epoch  60: Train Acc=0.9956, Val Acc=0.9898, F1=0.9917
#   Epoch  70: Train Acc=0.9943, Val Acc=0.9802, F1=0.9837
#   Epoch  80: Train Acc=0.9974, Val Acc=0.9892, F1=0.9914
#   Early stopping at epoch 86
#   Best Val Acc: 0.9909
#
# [TPA Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9468, F1: 0.9514
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9581, Val Acc=0.9575, F1=0.9653
#   Epoch  20: Train Acc=0.9719, Val Acc=0.9705, F1=0.9760
#   Epoch  30: Train Acc=0.9759, Val Acc=0.9677, F1=0.9734
#   Epoch  40: Train Acc=0.9810, Val Acc=0.9700, F1=0.9761
#   Epoch  50: Train Acc=0.9878, Val Acc=0.9745, F1=0.9797
#   Epoch  60: Train Acc=0.9906, Val Acc=0.9847, F1=0.9874
#   Epoch  70: Train Acc=0.9931, Val Acc=0.9841, F1=0.9869
#   Epoch  80: Train Acc=0.9967, Val Acc=0.9841, F1=0.9871
#   Early stopping at epoch 81
#   Best Val Acc: 0.9887
#
# [Pure-TPA Results]
#   Val Acc: 0.9887
#   Test Acc: 0.9347, F1: 0.9369
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING - 40%
# ================================================================================
#
# Loading SITTING_TO_STANDING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/SITTING_TO_STANDING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9340, Val Acc=0.9377, F1=0.9455
#   Epoch  20: Train Acc=0.9379, Val Acc=0.9428, F1=0.9539
#   Epoch  30: Train Acc=0.9391, Val Acc=0.9473, F1=0.9565
#   Epoch  40: Train Acc=0.9433, Val Acc=0.9428, F1=0.9544
#   Epoch  50: Train Acc=0.9486, Val Acc=0.9110, F1=0.9332
#   Epoch  60: Train Acc=0.9525, Val Acc=0.9558, F1=0.9640
#   Epoch  70: Train Acc=0.9551, Val Acc=0.9501, F1=0.9591
#   Epoch  80: Train Acc=0.9585, Val Acc=0.9586, F1=0.9662
#   Epoch  90: Train Acc=0.9603, Val Acc=0.9603, F1=0.9677
#   Epoch 100: Train Acc=0.9622, Val Acc=0.9603, F1=0.9686
#   Best Val Acc: 0.9603
#
# [GAP Results]
#   Val Acc: 0.9603
#   Test Acc: 0.9372, F1: 0.9426
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9564, Val Acc=0.9439, F1=0.9514
#   Epoch  20: Train Acc=0.9763, Val Acc=0.9632, F1=0.9699
#   Epoch  30: Train Acc=0.9830, Val Acc=0.9779, F1=0.9822
#   Epoch  40: Train Acc=0.9872, Val Acc=0.9802, F1=0.9843
#   Epoch  50: Train Acc=0.9897, Val Acc=0.9892, F1=0.9913
#   Epoch  60: Train Acc=0.9963, Val Acc=0.9892, F1=0.9914
#   Epoch  70: Train Acc=0.9970, Val Acc=0.9864, F1=0.9890
#   Epoch  80: Train Acc=0.9989, Val Acc=0.9904, F1=0.9922
#   Epoch  90: Train Acc=0.9990, Val Acc=0.9898, F1=0.9918
#   Early stopping at epoch 91
#   Best Val Acc: 0.9938
#
# [TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9567, F1: 0.9596
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9593, Val Acc=0.9558, F1=0.9635
#   Epoch  20: Train Acc=0.9695, Val Acc=0.9326, F1=0.9498
#   Epoch  30: Train Acc=0.9741, Val Acc=0.9620, F1=0.9704
#   Epoch  40: Train Acc=0.9820, Val Acc=0.9768, F1=0.9813
#   Epoch  50: Train Acc=0.9867, Val Acc=0.9779, F1=0.9824
#   Epoch  60: Train Acc=0.9882, Val Acc=0.9773, F1=0.9819
#   Epoch  70: Train Acc=0.9899, Val Acc=0.9745, F1=0.9795
#   Epoch  80: Train Acc=0.9933, Val Acc=0.9870, F1=0.9894
#   Epoch  90: Train Acc=0.9948, Val Acc=0.9671, F1=0.9741
#   Early stopping at epoch 98
#   Best Val Acc: 0.9892
#
# [Pure-TPA Results]
#   Val Acc: 0.9892
#   Test Acc: 0.9446, F1: 0.9466
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 10%
# ================================================================================
#
# Loading LAYING_TO_SITTING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_SITTING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9532, Val Acc=0.9643, F1=0.9606
#   Epoch  20: Train Acc=0.9576, Val Acc=0.9660, F1=0.9626
#   Epoch  30: Train Acc=0.9615, Val Acc=0.9626, F1=0.9589
#   Early stopping at epoch 35
#   Best Val Acc: 0.9671
#
# [GAP Results]
#   Val Acc: 0.9671
#   Test Acc: 0.9225, F1: 0.9067
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9612, Val Acc=0.9671, F1=0.9637
#   Epoch  20: Train Acc=0.9694, Val Acc=0.9739, F1=0.9711
#   Epoch  30: Train Acc=0.9793, Val Acc=0.9739, F1=0.9712
#   Epoch  40: Train Acc=0.9871, Val Acc=0.9773, F1=0.9749
#   Epoch  50: Train Acc=0.9916, Val Acc=0.9887, F1=0.9875
#   Epoch  60: Train Acc=0.9959, Val Acc=0.9915, F1=0.9905
#   Epoch  70: Train Acc=0.9972, Val Acc=0.9881, F1=0.9867
#   Epoch  80: Train Acc=0.9980, Val Acc=0.9904, F1=0.9892
#   Epoch  90: Train Acc=0.9982, Val Acc=0.9909, F1=0.9899
#   Epoch 100: Train Acc=0.9983, Val Acc=0.9909, F1=0.9899
#   Best Val Acc: 0.9938
#
# [TPA Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9686, F1: 0.9630
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9637, Val Acc=0.9598, F1=0.9540
#   Epoch  20: Train Acc=0.9673, Val Acc=0.9683, F1=0.9649
#   Epoch  30: Train Acc=0.9742, Val Acc=0.9728, F1=0.9699
#   Epoch  40: Train Acc=0.9783, Val Acc=0.9603, F1=0.9551
#   Epoch  50: Train Acc=0.9792, Val Acc=0.9785, F1=0.9762
#   Epoch  60: Train Acc=0.9827, Val Acc=0.9802, F1=0.9781
#   Epoch  70: Train Acc=0.9858, Val Acc=0.9807, F1=0.9786
#   Epoch  80: Train Acc=0.9865, Val Acc=0.9762, F1=0.9735
#   Epoch  90: Train Acc=0.9897, Val Acc=0.9813, F1=0.9792
#   Epoch 100: Train Acc=0.9918, Val Acc=0.9796, F1=0.9774
#   Best Val Acc: 0.9841
#
# [Pure-TPA Results]
#   Val Acc: 0.9841
#   Test Acc: 0.9463, F1: 0.9360
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 20%
# ================================================================================
#
# Loading LAYING_TO_SITTING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_SITTING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9558, Val Acc=0.9496, F1=0.9434
#   Epoch  20: Train Acc=0.9599, Val Acc=0.9575, F1=0.9527
#   Epoch  30: Train Acc=0.9603, Val Acc=0.9632, F1=0.9593
#   Epoch  40: Train Acc=0.9602, Val Acc=0.9637, F1=0.9599
#   Early stopping at epoch 45
#   Best Val Acc: 0.9654
#
# [GAP Results]
#   Val Acc: 0.9654
#   Test Acc: 0.9287, F1: 0.9146
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9654, Val Acc=0.9632, F1=0.9593
#   Epoch  20: Train Acc=0.9695, Val Acc=0.9603, F1=0.9561
#   Epoch  30: Train Acc=0.9789, Val Acc=0.9609, F1=0.9567
#   Epoch  40: Train Acc=0.9850, Val Acc=0.9813, F1=0.9793
#   Epoch  50: Train Acc=0.9908, Val Acc=0.9841, F1=0.9824
#   Epoch  60: Train Acc=0.9942, Val Acc=0.9790, F1=0.9768
#   Early stopping at epoch 62
#   Best Val Acc: 0.9881
#
# [TPA Results]
#   Val Acc: 0.9881
#   Test Acc: 0.9528, F1: 0.9432
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9644, Val Acc=0.9615, F1=0.9568
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9694, F1=0.9662
#   Epoch  30: Train Acc=0.9768, Val Acc=0.9745, F1=0.9718
#   Epoch  40: Train Acc=0.9780, Val Acc=0.9756, F1=0.9730
#   Epoch  50: Train Acc=0.9817, Val Acc=0.9768, F1=0.9742
#   Epoch  60: Train Acc=0.9841, Val Acc=0.9768, F1=0.9743
#   Epoch  70: Train Acc=0.9863, Val Acc=0.9762, F1=0.9736
#   Early stopping at epoch 77
#   Best Val Acc: 0.9824
#
# [Pure-TPA Results]
#   Val Acc: 0.9824
#   Test Acc: 0.9511, F1: 0.9407
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 30%
# ================================================================================
#
# Loading LAYING_TO_SITTING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_SITTING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9541, Val Acc=0.9569, F1=0.9526
#   Epoch  20: Train Acc=0.9606, Val Acc=0.9581, F1=0.9541
#   Epoch  30: Train Acc=0.9622, Val Acc=0.9558, F1=0.9516
#   Epoch  40: Train Acc=0.9606, Val Acc=0.9558, F1=0.9511
#   Early stopping at epoch 43
#   Best Val Acc: 0.9632
#
# [GAP Results]
#   Val Acc: 0.9632
#   Test Acc: 0.9242, F1: 0.9096
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9658, Val Acc=0.9615, F1=0.9574
#   Epoch  20: Train Acc=0.9736, Val Acc=0.9615, F1=0.9573
#   Epoch  30: Train Acc=0.9761, Val Acc=0.9717, F1=0.9686
#   Epoch  40: Train Acc=0.9888, Val Acc=0.9785, F1=0.9762
#   Epoch  50: Train Acc=0.9925, Val Acc=0.9824, F1=0.9805
#   Epoch  60: Train Acc=0.9955, Val Acc=0.9853, F1=0.9837
#   Epoch  70: Train Acc=0.9966, Val Acc=0.9904, F1=0.9893
#   Epoch  80: Train Acc=0.9990, Val Acc=0.9858, F1=0.9843
#   Early stopping at epoch 81
#   Best Val Acc: 0.9909
#
# [TPA Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9604, F1: 0.9531
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9653, Val Acc=0.9609, F1=0.9566
#   Epoch  20: Train Acc=0.9731, Val Acc=0.9620, F1=0.9578
#   Epoch  30: Train Acc=0.9769, Val Acc=0.9666, F1=0.9630
#   Epoch  40: Train Acc=0.9810, Val Acc=0.9768, F1=0.9741
#   Epoch  50: Train Acc=0.9817, Val Acc=0.9739, F1=0.9711
#   Epoch  60: Train Acc=0.9821, Val Acc=0.9779, F1=0.9755
#   Epoch  70: Train Acc=0.9894, Val Acc=0.9745, F1=0.9717
#   Epoch  80: Train Acc=0.9914, Val Acc=0.9773, F1=0.9748
#   Epoch  90: Train Acc=0.9891, Val Acc=0.9688, F1=0.9655
#   Epoch 100: Train Acc=0.9942, Val Acc=0.9745, F1=0.9716
#   Best Val Acc: 0.9830
#
# [Pure-TPA Results]
#   Val Acc: 0.9830
#   Test Acc: 0.9426, F1: 0.9317
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING - 40%
# ================================================================================
#
# Loading LAYING_TO_SITTING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_SITTING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9585, Val Acc=0.9564, F1=0.9513
#   Epoch  20: Train Acc=0.9620, Val Acc=0.9513, F1=0.9461
#   Epoch  30: Train Acc=0.9626, Val Acc=0.9524, F1=0.9474
#   Epoch  40: Train Acc=0.9630, Val Acc=0.9524, F1=0.9472
#   Early stopping at epoch 44
#   Best Val Acc: 0.9609
#
# [GAP Results]
#   Val Acc: 0.9609
#   Test Acc: 0.9248, F1: 0.9097
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9670, Val Acc=0.9615, F1=0.9574
#   Epoch  20: Train Acc=0.9722, Val Acc=0.9683, F1=0.9649
#   Epoch  30: Train Acc=0.9780, Val Acc=0.9694, F1=0.9662
#   Epoch  40: Train Acc=0.9843, Val Acc=0.9773, F1=0.9749
#   Epoch  50: Train Acc=0.9912, Val Acc=0.9887, F1=0.9874
#   Epoch  60: Train Acc=0.9962, Val Acc=0.9881, F1=0.9868
#   Epoch  70: Train Acc=0.9972, Val Acc=0.9926, F1=0.9918
#   Epoch  80: Train Acc=0.9983, Val Acc=0.9909, F1=0.9899
#   Epoch  90: Train Acc=0.9994, Val Acc=0.9904, F1=0.9893
#   Early stopping at epoch 91
#   Best Val Acc: 0.9943
#
# [TPA Results]
#   Val Acc: 0.9943
#   Test Acc: 0.9556, F1: 0.9463
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9651, Val Acc=0.9581, F1=0.9528
#   Epoch  20: Train Acc=0.9735, Val Acc=0.9654, F1=0.9618
#   Epoch  30: Train Acc=0.9782, Val Acc=0.9722, F1=0.9692
#   Epoch  40: Train Acc=0.9807, Val Acc=0.9569, F1=0.9522
#   Epoch  50: Train Acc=0.9826, Val Acc=0.9717, F1=0.9686
#   Epoch  60: Train Acc=0.9865, Val Acc=0.9666, F1=0.9630
#   Epoch  70: Train Acc=0.9872, Val Acc=0.9881, F1=0.9868
#   Epoch  80: Train Acc=0.9898, Val Acc=0.9836, F1=0.9818
#   Epoch  90: Train Acc=0.9901, Val Acc=0.9841, F1=0.9824
#   Epoch 100: Train Acc=0.9919, Val Acc=0.9875, F1=0.9862
#   Best Val Acc: 0.9909
#
# [Pure-TPA Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9497, F1: 0.9394
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 10%
# ================================================================================
#
# Loading LAYING_TO_STANDING (10%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_STANDING_10pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9515, Val Acc=0.9615, F1=0.9571
#   Epoch  20: Train Acc=0.9586, Val Acc=0.9609, F1=0.9572
#   Epoch  30: Train Acc=0.9589, Val Acc=0.9586, F1=0.9546
#   Early stopping at epoch 33
#   Best Val Acc: 0.9671
#
# [GAP Results]
#   Val Acc: 0.9671
#   Test Acc: 0.9160, F1: 0.8991
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9630, Val Acc=0.9660, F1=0.9623
#   Epoch  20: Train Acc=0.9688, Val Acc=0.9643, F1=0.9604
#   Epoch  30: Train Acc=0.9762, Val Acc=0.9705, F1=0.9673
#   Epoch  40: Train Acc=0.9875, Val Acc=0.9796, F1=0.9773
#   Epoch  50: Train Acc=0.9916, Val Acc=0.9853, F1=0.9836
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9858, F1=0.9842
#   Epoch  70: Train Acc=0.9987, Val Acc=0.9870, F1=0.9855
#   Epoch  80: Train Acc=0.9989, Val Acc=0.9881, F1=0.9867
#   Epoch  90: Train Acc=0.9991, Val Acc=0.9915, F1=0.9906
#   Epoch 100: Train Acc=0.9986, Val Acc=0.9887, F1=0.9874
#   Best Val Acc: 0.9915
#
# [TPA Results]
#   Val Acc: 0.9915
#   Test Acc: 0.9584, F1: 0.9502
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9624, Val Acc=0.9666, F1=0.9627
#   Epoch  20: Train Acc=0.9683, Val Acc=0.9745, F1=0.9718
#   Epoch  30: Train Acc=0.9756, Val Acc=0.9717, F1=0.9687
#   Epoch  40: Train Acc=0.9787, Val Acc=0.9722, F1=0.9693
#   Epoch  50: Train Acc=0.9814, Val Acc=0.9790, F1=0.9767
#   Epoch  60: Train Acc=0.9833, Val Acc=0.9745, F1=0.9715
#   Epoch  70: Train Acc=0.9841, Val Acc=0.9853, F1=0.9837
#   Early stopping at epoch 76
#   Best Val Acc: 0.9858
#
# [Pure-TPA Results]
#   Val Acc: 0.9858
#   Test Acc: 0.9429, F1: 0.9311
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 20%
# ================================================================================
#
# Loading LAYING_TO_STANDING (20%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_STANDING_20pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9556, Val Acc=0.9462, F1=0.9401
#   Epoch  20: Train Acc=0.9599, Val Acc=0.9479, F1=0.9425
#   Epoch  30: Train Acc=0.9651, Val Acc=0.9479, F1=0.9429
#   Epoch  40: Train Acc=0.9633, Val Acc=0.9552, F1=0.9505
#   Early stopping at epoch 41
#   Best Val Acc: 0.9581
#
# [GAP Results]
#   Val Acc: 0.9581
#   Test Acc: 0.9307, F1: 0.9165
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9667, Val Acc=0.9507, F1=0.9442
#   Epoch  20: Train Acc=0.9721, Val Acc=0.9609, F1=0.9564
#   Epoch  30: Train Acc=0.9799, Val Acc=0.9671, F1=0.9635
#   Epoch  40: Train Acc=0.9850, Val Acc=0.9688, F1=0.9653
#   Epoch  50: Train Acc=0.9909, Val Acc=0.9728, F1=0.9698
#   Epoch  60: Train Acc=0.9945, Val Acc=0.9836, F1=0.9818
#   Epoch  70: Train Acc=0.9955, Val Acc=0.9841, F1=0.9824
#   Epoch  80: Train Acc=0.9976, Val Acc=0.9898, F1=0.9887
#   Epoch  90: Train Acc=0.9986, Val Acc=0.9904, F1=0.9893
#   Epoch 100: Train Acc=0.9986, Val Acc=0.9881, F1=0.9868
#   Best Val Acc: 0.9904
#
# [TPA Results]
#   Val Acc: 0.9904
#   Test Acc: 0.9567, F1: 0.9483
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9644, Val Acc=0.9575, F1=0.9531
#   Epoch  20: Train Acc=0.9698, Val Acc=0.9632, F1=0.9593
#   Epoch  30: Train Acc=0.9773, Val Acc=0.9615, F1=0.9574
#   Epoch  40: Train Acc=0.9820, Val Acc=0.9643, F1=0.9605
#   Epoch  50: Train Acc=0.9831, Val Acc=0.9620, F1=0.9580
#   Epoch  60: Train Acc=0.9872, Val Acc=0.9717, F1=0.9686
#   Epoch  70: Train Acc=0.9888, Val Acc=0.9739, F1=0.9711
#   Epoch  80: Train Acc=0.9911, Val Acc=0.9796, F1=0.9774
#   Epoch  90: Train Acc=0.9912, Val Acc=0.9841, F1=0.9824
#   Epoch 100: Train Acc=0.9932, Val Acc=0.9745, F1=0.9718
#   Best Val Acc: 0.9847
#
# [Pure-TPA Results]
#   Val Acc: 0.9847
#   Test Acc: 0.9499, F1: 0.9400
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 30%
# ================================================================================
#
# Loading LAYING_TO_STANDING (30%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_STANDING_30pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9517, Val Acc=0.9671, F1=0.9631
#   Epoch  20: Train Acc=0.9589, Val Acc=0.9609, F1=0.9567
#   Epoch  30: Train Acc=0.9586, Val Acc=0.9688, F1=0.9657
#   Epoch  40: Train Acc=0.9595, Val Acc=0.9643, F1=0.9604
#   Early stopping at epoch 43
#   Best Val Acc: 0.9700
#
# [GAP Results]
#   Val Acc: 0.9700
#   Test Acc: 0.9239, F1: 0.9092
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9599, Val Acc=0.9705, F1=0.9674
#   Epoch  20: Train Acc=0.9717, Val Acc=0.9734, F1=0.9706
#   Epoch  30: Train Acc=0.9763, Val Acc=0.9830, F1=0.9812
#   Epoch  40: Train Acc=0.9878, Val Acc=0.9847, F1=0.9830
#   Epoch  50: Train Acc=0.9904, Val Acc=0.9870, F1=0.9855
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9898, F1=0.9887
#   Epoch  70: Train Acc=0.9967, Val Acc=0.9921, F1=0.9912
#   Epoch  80: Train Acc=0.9983, Val Acc=0.9915, F1=0.9906
#   Epoch  90: Train Acc=0.9980, Val Acc=0.9909, F1=0.9900
#   Early stopping at epoch 91
#   Best Val Acc: 0.9955
#
# [TPA Results]
#   Val Acc: 0.9955
#   Test Acc: 0.9663, F1: 0.9603
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9640, Val Acc=0.9530, F1=0.9463
#   Epoch  20: Train Acc=0.9688, Val Acc=0.9734, F1=0.9701
#   Epoch  30: Train Acc=0.9755, Val Acc=0.9717, F1=0.9686
#   Epoch  40: Train Acc=0.9797, Val Acc=0.9756, F1=0.9729
#   Epoch  50: Train Acc=0.9812, Val Acc=0.9813, F1=0.9793
#   Epoch  60: Train Acc=0.9861, Val Acc=0.9847, F1=0.9830
#   Epoch  70: Train Acc=0.9887, Val Acc=0.9824, F1=0.9805
#   Epoch  80: Train Acc=0.9897, Val Acc=0.9853, F1=0.9835
#   Epoch  90: Train Acc=0.9925, Val Acc=0.9858, F1=0.9843
#   Epoch 100: Train Acc=0.9940, Val Acc=0.9898, F1=0.9887
#   Best Val Acc: 0.9904
#
# [Pure-TPA Results]
#   Val Acc: 0.9904
#   Test Acc: 0.9341, F1: 0.9252
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING - 40%
# ================================================================================
#
# Loading LAYING_TO_STANDING (40%)...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets_20/LAYING_TO_STANDING_40pct
#   Train: (8822, 9, 128), Test: (3536, 9, 128)
#
# Dataset splits:
#   Train: 7057, Val: 1765, Test: 3536
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9542, Val Acc=0.9541, F1=0.9482
#   Epoch  20: Train Acc=0.9592, Val Acc=0.9626, F1=0.9590
#   Epoch  30: Train Acc=0.9600, Val Acc=0.9592, F1=0.9551
#   Epoch  40: Train Acc=0.9616, Val Acc=0.9581, F1=0.9535
#   Early stopping at epoch 42
#   Best Val Acc: 0.9654
#
# [GAP Results]
#   Val Acc: 0.9654
#   Test Acc: 0.9219, F1: 0.9067
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9626, Val Acc=0.9666, F1=0.9630
#   Epoch  20: Train Acc=0.9711, Val Acc=0.9722, F1=0.9691
#   Epoch  30: Train Acc=0.9827, Val Acc=0.9779, F1=0.9755
#   Epoch  40: Train Acc=0.9908, Val Acc=0.9853, F1=0.9835
#   Epoch  50: Train Acc=0.9950, Val Acc=0.9813, F1=0.9792
#   Epoch  60: Train Acc=0.9966, Val Acc=0.9892, F1=0.9881
#   Epoch  70: Train Acc=0.9983, Val Acc=0.9887, F1=0.9874
#   Epoch  80: Train Acc=0.9987, Val Acc=0.9921, F1=0.9912
#   Epoch  90: Train Acc=0.9991, Val Acc=0.9870, F1=0.9855
#   Epoch 100: Train Acc=0.9990, Val Acc=0.9887, F1=0.9874
#   Early stopping at epoch 100
#   Best Val Acc: 0.9921
#
# [TPA Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9627, F1: 0.9554
#
# [Training Pure-TPA]
#   Epoch  10: Train Acc=0.9629, Val Acc=0.9592, F1=0.9538
#   Epoch  20: Train Acc=0.9721, Val Acc=0.9654, F1=0.9611
#   Epoch  30: Train Acc=0.9802, Val Acc=0.9541, F1=0.9491
#   Epoch  40: Train Acc=0.9787, Val Acc=0.9649, F1=0.9611
#   Epoch  50: Train Acc=0.9833, Val Acc=0.9768, F1=0.9740
#   Epoch  60: Train Acc=0.9875, Val Acc=0.9830, F1=0.9811
#   Epoch  70: Train Acc=0.9881, Val Acc=0.9722, F1=0.9693
#   Epoch  80: Train Acc=0.9922, Val Acc=0.9841, F1=0.9823
#   Epoch  90: Train Acc=0.9928, Val Acc=0.9881, F1=0.9866
#   Epoch 100: Train Acc=0.9945, Val Acc=0.9858, F1=0.9841
#   Best Val Acc: 0.9909
#
# [Pure-TPA Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9531, F1: 0.9434
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_comparison_results.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 72
# Transitions tested: 6
# Mix ratios tested: 4
# Models compared: 3 (GAP, TPA, Pure-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE
# ================================================================================
# GAP       : Acc=0.9260, F1=0.9232
# TPA       : Acc=0.9585, F1=0.9562
# Pure-TPA  : Acc=0.9463, F1=0.9427
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
