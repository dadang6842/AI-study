# %%
# -*- coding: utf-8 -*-
"""
Simplified Model Comparison: GAP, TPA, Gated-TPA
- TPA Top-k 마스킹 적용
- 프로토타입 다양성 페널티
- 로짓 수준 MoE 융합 (별도 분류기)
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    # 새로운 하이퍼파라미터
    diversity_weight: float = 5e-3  # 프로토타입 다양성 페널티 가중치
    use_logit_fusion: bool = True    # 로짓 수준 융합 사용 여부

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_dataset(base_dir: str, dataset_name: str):
    """
    Load pre-augmented dataset
    Args:
        base_dir: base directory containing all datasets
        dataset_name: e.g., "ORIGINAL", "STANDING_TO_SITTING_10pct", etc.
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, dataset_name)

    print(f"\nLoading {dataset_name}...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class BiLSTMBackbone(nn.Module):
    """BiLSTM backbone for all models
    Args:
        in_ch: input channels (default: 27)
        d_model: output dimension (default: 128)
        hidden_dim: LSTM hidden dimension (default: 64, bidirectional -> 128)
        num_layers: number of LSTM layers (default: 2)
        dropout: dropout rate (default: 0.1)
    """
    def __init__(self, in_ch=27, d_model=128, hidden_dim=64, num_layers=2, dropout=0.1):
        super().__init__()
        self.d_model = d_model

        # BiLSTM: hidden_dim=64 → 양방향이므로 출력은 128
        self.lstm = nn.LSTM(
            input_size=in_ch,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        # 투영층: BiLSTM 출력(128) → d_model(128)
        self.projection = nn.Linear(hidden_dim * 2, d_model)

        # 정규화 및 드롭아웃
        self.layer_norm = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # x: [B, C, T] → [B, T, C] (LSTM은 [B, T, C] 형태 입력)
        # x = x.transpose(1, 2)

        # BiLSTM
        lstm_out, _ = self.lstm(x)  # [B, T, hidden_dim*2=128]

        # 투영
        out = self.projection(lstm_out)  # [B, T, d_model=128]

        # 정규화 + 드롭아웃
        out = self.layer_norm(out)
        out = self.dropout(out)

        # [B, T, D] → [B, D, T] (기존 코드와의 호환성)
        return out.transpose(1, 2)

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=12):
        super().__init__()
        self.backbone = BiLSTMBackbone(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# Improved TPA with Top-k
# ========================
class ImprovedTPA(nn.Module):
    """개선된 TPA: Top-k 마스킹 + 다양성 정규화"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        """
        Args:
            x: [B, T, D]
        Returns:
            z_tpa: [B, D]
        """
        B, T, D = x.shape
        P = self.num_prototypes

        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)  # [B, H, P, d]
        Kh = split_heads(K, T)    # [B, H, T, d]
        Vh = split_heads(V, T)    # [B, H, T, d]

        # Qh = F.normalize(Qh, dim=-1)
        # Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / (self.head_dim ** 0.5)
        attn = F.softmax(scores, dim=-1)  # [B, H, P, T]
        attn = torch.nan_to_num(attn, nan=0.0)

        # ==================
        # Top-k 마스킹
        # ==================
        k = max(1, int(self.topk_ratio * T))
        vals, idx = attn.topk(k, dim=-1)  # [B, H, P, k]
        mask = torch.zeros_like(attn).scatter_(-1, idx, 1.0)
        attn = attn * mask
        # 재정규화
        attn = attn / (attn.sum(dim=-1, keepdim=True) + 1e-8)

        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)  # [B, H, P, d]
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        z_tpa = proto_tokens.mean(dim=1)  # [B, D]

        z = self.fuse(z_tpa)

        return z

    def compute_diversity_loss(self):
        """
        프로토타입 다양성 페널티
        Returns:
            diversity_loss: scalar
        """
        proto_norm = F.normalize(self.proto, dim=-1)  # [P, D]
        sim = proto_norm @ proto_norm.t()  # [P, P]
        # 대각선 제외하고 유사도를 최소화
        div_loss = (sim - torch.eye(sim.size(0), device=sim.device)).pow(2).mean()
        return div_loss

class TPAModel(nn.Module):
    """개선된 TPA 모델"""
    def __init__(self, d_model=128, num_classes=12, tpa_config=None):
        super().__init__()
        self.backbone = BiLSTMBackbone(d_model=d_model)

        self.tpa = ImprovedTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Improved Gated-TPA with Logit-level Fusion
# ========================
class ImprovedGatedTPAModel(nn.Module):
    """개선된 Gated-TPA: 로짓 수준 융합 + 별도 분류기"""
    def __init__(self, d_model=128, num_classes=12, tpa_config=None, use_logit_fusion=True):
        super().__init__()
        self.use_logit_fusion = use_logit_fusion
        self.backbone = BiLSTMBackbone(d_model=d_model)

        self.tpa = ImprovedTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        if use_logit_fusion:
            # 로짓 수준 융합 (별도 분류기)
            self.cls_gap = nn.Linear(d_model, num_classes)
            self.cls_tpa = nn.Linear(d_model, num_classes)

            # Gating mechanism
            self.gate = nn.Sequential(
                nn.Linear(d_model * 2, num_classes),
                nn.Sigmoid()
            )
        else:
            # 기존 feature 수준 융합
            self.gate = nn.Sequential(
                nn.Linear(d_model * 2, d_model),
                nn.Sigmoid()
            )
            self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]

        # GAP branch
        z_gap = features.mean(dim=1)  # [B, D]

        # TPA branch
        z_tpa = self.tpa(features)  # [B, D]

        if self.use_logit_fusion:
            # 로짓 수준 융합
            logits_gap = self.cls_gap(z_gap)  # [B, C]
            logits_tpa = self.cls_tpa(z_tpa)  # [B, C]

            # 게이팅 (클래스별 게이트)
            gate_input = torch.cat([z_gap, z_tpa], dim=-1)
            g = self.gate(gate_input)  # [B, C]

            # 가중 융합
            logits = g * logits_gap + (1 - g) * logits_tpa
        else:
            # 기존 feature 수준 융합
            gate_input = torch.cat([z_gap, z_tpa], dim=-1)
            g = self.gate(gate_input)  # [B, D]
            z = g * z_gap + (1 - g) * z_tpa
            logits = self.classifier(z)

        return logits

# ========================
# Training & Evaluation
# ========================
def train_one_epoch(model, loader, opt, cfg: Config, compute_diversity=True):
    """
    개선: 다양성 페널티 추가
    """
    model.train()
    total, correct, loss_sum, ce_loss_sum, div_loss_sum = 0, 0, 0.0, 0.0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        # Cross-entropy loss
        ce_loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)

        # Diversity loss (TPA 모델만)
        div_loss = torch.tensor(0.0, device=cfg.device)
        if compute_diversity and hasattr(model, 'tpa'):
            div_loss = model.tpa.compute_diversity_loss()

        # Total loss
        loss = ce_loss + cfg.diversity_weight * div_loss

        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)
            ce_loss_sum += ce_loss.item() * y.size(0)
            div_loss_sum += div_loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "ce_loss": ce_loss_sum / total if total > 0 else 0,
        "div_loss": div_loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

# ========================
# Model Complexity Analysis
# ========================
def count_parameters(model):
    """Count total and trainable parameters"""
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total_params, trainable_params

def estimate_flops(model, input_shape=(1, 100, 27), device='cuda'):
    """
    Estimate FLOPs using manual calculation
    For Conv1d: FLOPs = 2 * C_in * C_out * K * L_out
    For Linear: FLOPs = 2 * in_features * out_features
    """
    model.eval()
    total_flops = 0

    def conv1d_flops(module, input, output):
        batch_size, out_channels, out_length = output.shape
        kernel_size = module.kernel_size[0]
        in_channels = module.in_channels
        groups = module.groups

        flops_per_element = 2 * (in_channels // groups) * kernel_size
        total = flops_per_element * out_channels * out_length * batch_size

        nonlocal total_flops
        total_flops += total

    def linear_flops(module, input, output):
        batch_size = input[0].shape[0]
        in_features = module.in_features
        out_features = module.out_features

        total = 2 * in_features * out_features * batch_size

        nonlocal total_flops
        total_flops += total

    # Register hooks
    hooks = []
    for module in model.modules():
        if isinstance(module, nn.Conv1d):
            hooks.append(module.register_forward_hook(conv1d_flops))
        elif isinstance(module, nn.Linear):
            hooks.append(module.register_forward_hook(linear_flops))

    # Forward pass
    with torch.no_grad():
        x = torch.randn(input_shape).to(device)
        model(x)

    # Remove hooks
    for hook in hooks:
        hook.remove()

    return total_flops

def measure_inference_time(model, input_shape=(1, 100, 27), device='cuda', n_runs=100):
    """
    Measure average inference time over multiple runs
    """
    model.eval()
    x = torch.randn(input_shape).to(device)

    # Warmup
    with torch.no_grad():
        for _ in range(10):
            _ = model(x)

    # Synchronize GPU
    if device == 'cuda':
        torch.cuda.synchronize()

    # Measure
    start = time.time()
    with torch.no_grad():
        for _ in range(n_runs):
            _ = model(x)
            if device == 'cuda':
                torch.cuda.synchronize()
    end = time.time()

    avg_time = (end - start) / n_runs * 1000  # Convert to ms
    return avg_time

def analyze_model_complexity(model, model_name, cfg: Config, input_shape=(1, 100, 27)):
    """
    Complete model complexity analysis
    """
    print(f"\n{'='*80}")
    print(f"MODEL COMPLEXITY ANALYSIS: {model_name}")
    print(f"{'='*80}")

    # Parameters
    total_params, trainable_params = count_parameters(model)
    print(f"Total Parameters: {total_params:,}")
    print(f"Trainable Parameters: {trainable_params:,}")
    print(f"Model Size: {total_params * 4 / 1024 / 1024:.2f} MB (float32)")

    # FLOPs
    flops = estimate_flops(model, input_shape, cfg.device)
    print(f"FLOPs: {flops:,} ({flops / 1e6:.2f} MFLOPs)")

    # Inference time
    inference_time = measure_inference_time(model, input_shape, cfg.device, n_runs=100)
    print(f"Inference Time: {inference_time:.3f} ms (avg over 100 runs)")

    return {
        'model': model_name,
        'total_params': total_params,
        'trainable_params': trainable_params,
        'model_size_mb': total_params * 4 / 1024 / 1024,
        'flops': flops,
        'mflops': flops / 1e6,
        'inference_time_ms': inference_time
    }

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    # TPA 모델만 diversity loss 계산
    compute_diversity = 'TPA' in model_name

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg, compute_diversity)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            if compute_diversity:
                print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, "
                      f"CE={stats['ce_loss']:.4f}, Div={stats['div_loss']:.4f}, "
                      f"Val Acc={val_acc:.4f}, F1={val_f1:.4f}")
            else:
                print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, "
                      f"Loss={stats['loss']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(
            d_model=cfg.d_model,
            tpa_config=tpa_config
        ).to(cfg.device).float()
    elif model_name == "Gated-TPA":
        return ImprovedGatedTPAModel(
            d_model=cfg.d_model,
            tpa_config=tpa_config,
            use_logit_fusion=cfg.use_logit_fusion
        ).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(dataset_name: str, cfg: Config):
    """Run complete experiment for one dataset"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {dataset_name}")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_dataset(cfg.data_dir, dataset_name)

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    complexity_results = []
    model_names = ["GAP", "TPA", "Gated-TPA"]

    # First, analyze model complexity (only once, use first dataset)
    if dataset_name == "ORIGINAL":
        print(f"\n{'='*80}")
        print("MODEL COMPLEXITY COMPARISON")
        print(f"{'='*80}")

        for model_name in model_names:
            random.seed(SEED)
            np.random.seed(SEED)
            torch.manual_seed(SEED)

            model = create_model(model_name, cfg)
            complexity = analyze_model_complexity(model, model_name, cfg)
            complexity_results.append(complexity)

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Dataset': dataset_name,
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results, complexity_results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("SIMPLIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA")
    print("="*80)
    print("\n개선사항:")
    print("  1. TPA Top-k 마스킹 적용")
    print("  2. 프로토타입 다양성 페널티")
    print("  3. 로짓 수준 MoE 융합 (별도 분류기)")
    print("="*80)

    datasets = []

    transitions = [
        'Lying_TO_Standing',
        'Standing_TO_Walking',
        'Walking_TO_Standing',
        'Walking_TO_Running',
        'Running_TO_Walking',
        'Walking_TO_Ascending_stairs',
        'Walking_TO_Descending_stairs',
        'Ascending_stairs_TO_Walking',
        'Descending_stairs_TO_Walking'
    ]

    # 모든 전이에 대해 10%, 20%, 30%, 40% 추가
    mix_pcts = [10, 20, 30, 40]

    for transition in transitions:
        for pct in mix_pcts:
            datasets.append(f"{transition}_{pct}PCT")

    print(f"\nTotal datasets to test: {len(datasets)}")
    print(f"  - transitions: {len(transitions) * len(mix_pcts) + 2}")

    all_results = []
    all_complexity = []

    # Run experiments
    for i, dataset_name in enumerate(datasets, 1):
        print(f"\n[Progress: {i}/{len(datasets)}]")

        results, complexity = run_experiment(dataset_name, cfg)
        all_results.extend(results)
        if complexity:  # 첫 번째 데이터셋에서만 반환됨
            all_complexity = complexity

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'version': 'simplified_v1',
            'improvements': [
                'TPA Top-k masking',
                'Prototype diversity penalty',
                'Logit-level MoE fusion'
            ],
            'models': ['GAP', 'TPA', 'Gated-TPA'],
            'total_datasets': len(datasets),
            'datasets': datasets,
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads,
                'tpa_temperature': cfg.tpa_temperature,
                'tpa_topk_ratio': cfg.tpa_topk_ratio,
                'diversity_weight': cfg.diversity_weight,
                'use_logit_fusion': cfg.use_logit_fusion
            }
        },
        'model_complexity': all_complexity,
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "pamap2_tpa_transition_cnn_simplified.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Total datasets tested: {len(datasets)}")
    print(f"Models compared: 3 (GAP, TPA, Gated-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE (All Datasets)")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Gated-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:12s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    # Print model complexity table
    if all_complexity:
        print(f"\n{'='*80}")
        print("MODEL COMPLEXITY COMPARISON")
        print(f"{'='*80}")
        print(f"{'Model':<12} {'Params':<12} {'Size(MB)':<10} {'MFLOPs':<10} {'Time(ms)':<10}")
        print("-" * 80)
        for comp in all_complexity:
            print(f"{comp['model']:<12} {comp['total_params']:<12,} "
                  f"{comp['model_size_mb']:<10.2f} {comp['mflops']:<10.2f} "
                  f"{comp['inference_time_ms']:<10.3f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Mounted at /content/drive
#
# ================================================================================
# SIMPLIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA
# ================================================================================
#
# 개선사항:
#   1. TPA Top-k 마스킹 적용
#   2. 프로토타입 다양성 페널티
#   3. 로짓 수준 MoE 융합 (별도 분류기)
# ================================================================================
#
# Total datasets to test: 36
#   - transitions: 38
#
# [Progress: 1/36]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_10PCT
# ================================================================================
#
# Loading Lying_TO_Standing_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Lying_TO_Standing_10PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9622, Loss=0.4332, Val Acc=0.9519, F1=0.9428
#   Epoch  20: Train Acc=0.9887, Loss=0.3573, Val Acc=0.9683, F1=0.9633
#   Epoch  30: Train Acc=0.9953, Loss=0.3293, Val Acc=0.9744, F1=0.9709
#   Epoch  40: Train Acc=0.9967, Loss=0.3177, Val Acc=0.9756, F1=0.9724
#   Epoch  50: Train Acc=0.9976, Loss=0.3115, Val Acc=0.9759, F1=0.9722
#   Epoch  60: Train Acc=0.9981, Loss=0.3074, Val Acc=0.9768, F1=0.9725
#   Epoch  70: Train Acc=0.9980, Loss=0.3055, Val Acc=0.9772, F1=0.9738
#   Epoch  80: Train Acc=0.9976, Loss=0.3063, Val Acc=0.9753, F1=0.9711
#   Early stopping at epoch 88
#   Best Val Acc: 0.9782
#
# [GAP Results]
#   Val Acc: 0.9782
#   Test Acc: 0.9746, F1: 0.9703
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9606, CE=0.4394, Div=0.0065, Val Acc=0.9490, F1=0.9361
#   Epoch  20: Train Acc=0.9890, CE=0.3564, Div=0.0080, Val Acc=0.9700, F1=0.9651
#   Epoch  30: Train Acc=0.9965, CE=0.3298, Div=0.0045, Val Acc=0.9762, F1=0.9716
#   Epoch  40: Train Acc=0.9976, CE=0.3187, Div=0.0023, Val Acc=0.9784, F1=0.9740
#   Epoch  50: Train Acc=0.9979, CE=0.3141, Div=0.0008, Val Acc=0.9776, F1=0.9732
#   Epoch  60: Train Acc=0.9984, CE=0.3106, Div=0.0006, Val Acc=0.9788, F1=0.9753
#   Epoch  70: Train Acc=0.9985, CE=0.3083, Div=0.0003, Val Acc=0.9811, F1=0.9774
#   Epoch  80: Train Acc=0.9984, CE=0.3073, Div=0.0001, Val Acc=0.9798, F1=0.9770
#   Epoch  90: Train Acc=0.9985, CE=0.3058, Div=0.0001, Val Acc=0.9789, F1=0.9751
#   Early stopping at epoch 90
#   Best Val Acc: 0.9811
#
# [TPA Results]
#   Val Acc: 0.9811
#   Test Acc: 0.9812, F1: 0.9775
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9661, CE=0.4119, Div=0.0049, Val Acc=0.9541, F1=0.9435
#   Epoch  20: Train Acc=0.9906, CE=0.3404, Div=0.0024, Val Acc=0.9703, F1=0.9648
#   Epoch  30: Train Acc=0.9959, CE=0.3181, Div=0.0002, Val Acc=0.9728, F1=0.9672
#   Epoch  40: Train Acc=0.9977, CE=0.3097, Div=0.0002, Val Acc=0.9738, F1=0.9699
#   Epoch  50: Train Acc=0.9973, CE=0.3071, Div=0.0000, Val Acc=0.9750, F1=0.9708
#   Epoch  60: Train Acc=0.9976, CE=0.3054, Div=0.0000, Val Acc=0.9772, F1=0.9728
#   Epoch  70: Train Acc=0.9983, CE=0.3022, Div=0.0000, Val Acc=0.9759, F1=0.9715
#   Epoch  80: Train Acc=0.9982, CE=0.3029, Div=0.0000, Val Acc=0.9778, F1=0.9741
#   Epoch  90: Train Acc=0.9982, CE=0.3013, Div=0.0000, Val Acc=0.9782, F1=0.9748
#   Epoch 100: Train Acc=0.9988, CE=0.3002, Div=0.0000, Val Acc=0.9798, F1=0.9765
#   Best Val Acc: 0.9804
#
# [Gated-TPA Results]
#   Val Acc: 0.9804
#   Test Acc: 0.9767, F1: 0.9721
#
# [Progress: 2/36]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_20PCT
# ================================================================================
#
# Loading Lying_TO_Standing_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Lying_TO_Standing_20PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9625, Loss=0.4320, Val Acc=0.9493, F1=0.9363
#   Epoch  20: Train Acc=0.9892, Loss=0.3564, Val Acc=0.9643, F1=0.9562
#   Epoch  30: Train Acc=0.9951, Loss=0.3298, Val Acc=0.9689, F1=0.9626
#   Epoch  40: Train Acc=0.9966, Loss=0.3176, Val Acc=0.9709, F1=0.9654
#   Epoch  50: Train Acc=0.9980, Loss=0.3105, Val Acc=0.9741, F1=0.9689
#   Epoch  60: Train Acc=0.9979, Loss=0.3077, Val Acc=0.9747, F1=0.9696
#   Epoch  70: Train Acc=0.9978, Loss=0.3057, Val Acc=0.9747, F1=0.9690
#   Epoch  80: Train Acc=0.9982, Loss=0.3044, Val Acc=0.9753, F1=0.9709
#   Epoch  90: Train Acc=0.9985, Loss=0.3026, Val Acc=0.9765, F1=0.9721
#   Epoch 100: Train Acc=0.9976, Loss=0.3041, Val Acc=0.9753, F1=0.9712
#   Best Val Acc: 0.9772
#
# [GAP Results]
#   Val Acc: 0.9772
#   Test Acc: 0.9760, F1: 0.9711
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9590, CE=0.4426, Div=0.0076, Val Acc=0.9441, F1=0.9289
#   Epoch  20: Train Acc=0.9891, CE=0.3568, Div=0.0073, Val Acc=0.9690, F1=0.9622
#   Epoch  30: Train Acc=0.9961, CE=0.3308, Div=0.0044, Val Acc=0.9734, F1=0.9677
#   Epoch  40: Train Acc=0.9972, CE=0.3199, Div=0.0021, Val Acc=0.9762, F1=0.9717
#   Epoch  50: Train Acc=0.9983, CE=0.3136, Div=0.0015, Val Acc=0.9782, F1=0.9739
#   Epoch  60: Train Acc=0.9983, CE=0.3105, Div=0.0007, Val Acc=0.9795, F1=0.9754
#   Epoch  70: Train Acc=0.9984, CE=0.3087, Div=0.0004, Val Acc=0.9830, F1=0.9795
#   Epoch  80: Train Acc=0.9985, CE=0.3069, Div=0.0002, Val Acc=0.9810, F1=0.9773
#   Epoch  90: Train Acc=0.9988, CE=0.3060, Div=0.0002, Val Acc=0.9800, F1=0.9755
#   Early stopping at epoch 90
#   Best Val Acc: 0.9830
#
# [TPA Results]
#   Val Acc: 0.9830
#   Test Acc: 0.9802, F1: 0.9762
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9669, CE=0.4111, Div=0.0049, Val Acc=0.9478, F1=0.9357
#   Epoch  20: Train Acc=0.9896, CE=0.3423, Div=0.0014, Val Acc=0.9639, F1=0.9554
#   Epoch  30: Train Acc=0.9957, CE=0.3199, Div=0.0002, Val Acc=0.9709, F1=0.9647
#   Epoch  40: Train Acc=0.9971, CE=0.3110, Div=0.0000, Val Acc=0.9722, F1=0.9670
#   Epoch  50: Train Acc=0.9979, CE=0.3054, Div=0.0001, Val Acc=0.9743, F1=0.9693
#   Epoch  60: Train Acc=0.9977, CE=0.3043, Div=0.0002, Val Acc=0.9744, F1=0.9686
#   Epoch  70: Train Acc=0.9978, CE=0.3036, Div=0.0001, Val Acc=0.9741, F1=0.9691
#   Epoch  80: Train Acc=0.9976, CE=0.3040, Div=0.0001, Val Acc=0.9775, F1=0.9730
#   Epoch  90: Train Acc=0.9980, CE=0.3027, Div=0.0001, Val Acc=0.9765, F1=0.9718
#   Early stopping at epoch 95
#   Best Val Acc: 0.9778
#
# [Gated-TPA Results]
#   Val Acc: 0.9778
#   Test Acc: 0.9789, F1: 0.9750
#
# [Progress: 3/36]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_30PCT
# ================================================================================
#
# Loading Lying_TO_Standing_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Lying_TO_Standing_30PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9620, Loss=0.4357, Val Acc=0.9493, F1=0.9369
#   Epoch  20: Train Acc=0.9888, Loss=0.3583, Val Acc=0.9675, F1=0.9603
#   Epoch  30: Train Acc=0.9946, Loss=0.3302, Val Acc=0.9719, F1=0.9663
#   Epoch  40: Train Acc=0.9963, Loss=0.3180, Val Acc=0.9725, F1=0.9672
#   Epoch  50: Train Acc=0.9976, Loss=0.3114, Val Acc=0.9741, F1=0.9685
#   Epoch  60: Train Acc=0.9978, Loss=0.3085, Val Acc=0.9725, F1=0.9672
#   Early stopping at epoch 66
#   Best Val Acc: 0.9749
#
# [GAP Results]
#   Val Acc: 0.9749
#   Test Acc: 0.9738, F1: 0.9680
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9609, CE=0.4407, Div=0.0215, Val Acc=0.9433, F1=0.9268
#   Epoch  20: Train Acc=0.9883, CE=0.3575, Div=0.0102, Val Acc=0.9668, F1=0.9597
#   Epoch  30: Train Acc=0.9960, CE=0.3310, Div=0.0063, Val Acc=0.9719, F1=0.9655
#   Epoch  40: Train Acc=0.9976, CE=0.3198, Div=0.0026, Val Acc=0.9754, F1=0.9693
#   Epoch  50: Train Acc=0.9979, CE=0.3139, Div=0.0016, Val Acc=0.9762, F1=0.9703
#   Epoch  60: Train Acc=0.9980, CE=0.3109, Div=0.0009, Val Acc=0.9751, F1=0.9690
#   Epoch  70: Train Acc=0.9983, CE=0.3085, Div=0.0003, Val Acc=0.9798, F1=0.9739
#   Early stopping at epoch 77
#   Best Val Acc: 0.9798
#
# [TPA Results]
#   Val Acc: 0.9798
#   Test Acc: 0.9782, F1: 0.9738
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9656, CE=0.4147, Div=0.0017, Val Acc=0.9493, F1=0.9358
#   Epoch  20: Train Acc=0.9904, CE=0.3421, Div=0.0011, Val Acc=0.9653, F1=0.9569
#   Epoch  30: Train Acc=0.9958, CE=0.3186, Div=0.0000, Val Acc=0.9670, F1=0.9596
#   Epoch  40: Train Acc=0.9971, CE=0.3096, Div=0.0001, Val Acc=0.9700, F1=0.9620
#   Epoch  50: Train Acc=0.9977, CE=0.3063, Div=0.0000, Val Acc=0.9699, F1=0.9630
#   Epoch  60: Train Acc=0.9982, CE=0.3033, Div=0.0000, Val Acc=0.9727, F1=0.9659
#   Epoch  70: Train Acc=0.9981, CE=0.3031, Div=0.0000, Val Acc=0.9731, F1=0.9669
#   Epoch  80: Train Acc=0.9983, CE=0.3020, Div=0.0000, Val Acc=0.9731, F1=0.9663
#   Epoch  90: Train Acc=0.9986, CE=0.3007, Div=0.0000, Val Acc=0.9737, F1=0.9669
#   Early stopping at epoch 92
#   Best Val Acc: 0.9750
#
# [Gated-TPA Results]
#   Val Acc: 0.9750
#   Test Acc: 0.9770, F1: 0.9732
#
# [Progress: 4/36]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_40PCT
# ================================================================================
#
# Loading Lying_TO_Standing_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Lying_TO_Standing_40PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9609, Loss=0.4433, Val Acc=0.9512, F1=0.9400
#   Epoch  20: Train Acc=0.9879, Loss=0.3608, Val Acc=0.9689, F1=0.9620
#   Epoch  30: Train Acc=0.9946, Loss=0.3331, Val Acc=0.9732, F1=0.9677
#   Epoch  40: Train Acc=0.9968, Loss=0.3197, Val Acc=0.9769, F1=0.9724
#   Epoch  50: Train Acc=0.9975, Loss=0.3131, Val Acc=0.9781, F1=0.9742
#   Epoch  60: Train Acc=0.9971, Loss=0.3102, Val Acc=0.9798, F1=0.9768
#   Epoch  70: Train Acc=0.9980, Loss=0.3062, Val Acc=0.9778, F1=0.9738
#   Epoch  80: Train Acc=0.9983, Loss=0.3039, Val Acc=0.9800, F1=0.9766
#   Early stopping at epoch 89
#   Best Val Acc: 0.9820
#
# [GAP Results]
#   Val Acc: 0.9820
#   Test Acc: 0.9785, F1: 0.9743
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9586, CE=0.4460, Div=0.0250, Val Acc=0.9487, F1=0.9353
#   Epoch  20: Train Acc=0.9894, CE=0.3580, Div=0.0164, Val Acc=0.9710, F1=0.9652
#   Epoch  30: Train Acc=0.9959, CE=0.3314, Div=0.0076, Val Acc=0.9773, F1=0.9724
#   Epoch  40: Train Acc=0.9972, CE=0.3206, Div=0.0035, Val Acc=0.9792, F1=0.9742
#   Epoch  50: Train Acc=0.9979, CE=0.3143, Div=0.0018, Val Acc=0.9804, F1=0.9762
#   Epoch  60: Train Acc=0.9986, CE=0.3104, Div=0.0009, Val Acc=0.9801, F1=0.9762
#   Early stopping at epoch 62
#   Best Val Acc: 0.9811
#
# [TPA Results]
#   Val Acc: 0.9811
#   Test Acc: 0.9789, F1: 0.9755
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9630, CE=0.4233, Div=0.0089, Val Acc=0.9525, F1=0.9424
#   Epoch  20: Train Acc=0.9882, CE=0.3463, Div=0.0017, Val Acc=0.9710, F1=0.9658
#   Epoch  30: Train Acc=0.9956, CE=0.3197, Div=0.0002, Val Acc=0.9744, F1=0.9702
#   Epoch  40: Train Acc=0.9975, CE=0.3104, Div=0.0000, Val Acc=0.9766, F1=0.9727
#   Epoch  50: Train Acc=0.9976, CE=0.3067, Div=0.0000, Val Acc=0.9769, F1=0.9724
#   Epoch  60: Train Acc=0.9979, CE=0.3043, Div=0.0000, Val Acc=0.9791, F1=0.9758
#   Epoch  70: Train Acc=0.9979, CE=0.3030, Div=0.0000, Val Acc=0.9794, F1=0.9760
#   Epoch  80: Train Acc=0.9985, CE=0.3014, Div=0.0000, Val Acc=0.9785, F1=0.9751
#   Epoch  90: Train Acc=0.9987, CE=0.3004, Div=0.0000, Val Acc=0.9789, F1=0.9761
#   Epoch 100: Train Acc=0.9984, CE=0.3014, Div=0.0000, Val Acc=0.9795, F1=0.9762
#   Best Val Acc: 0.9808
#
# [Gated-TPA Results]
#   Val Acc: 0.9808
#   Test Acc: 0.9798, F1: 0.9760
#
# [Progress: 5/36]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_10PCT
# ================================================================================
#
# Loading Standing_TO_Walking_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Standing_TO_Walking_10PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9617, Loss=0.4351, Val Acc=0.9522, F1=0.9452
#   Epoch  20: Train Acc=0.9883, Loss=0.3567, Val Acc=0.9709, F1=0.9669
#   Epoch  30: Train Acc=0.9949, Loss=0.3296, Val Acc=0.9741, F1=0.9710
#   Epoch  40: Train Acc=0.9971, Loss=0.3161, Val Acc=0.9768, F1=0.9734
#   Epoch  50: Train Acc=0.9979, Loss=0.3105, Val Acc=0.9770, F1=0.9744
#   Epoch  60: Train Acc=0.9980, Loss=0.3073, Val Acc=0.9757, F1=0.9731
#   Early stopping at epoch 63
#   Best Val Acc: 0.9779
#
# [GAP Results]
#   Val Acc: 0.9779
#   Test Acc: 0.9726, F1: 0.9698
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9584, CE=0.4445, Div=0.0186, Val Acc=0.9501, F1=0.9420
#   Epoch  20: Train Acc=0.9886, CE=0.3575, Div=0.0088, Val Acc=0.9725, F1=0.9692
#   Epoch  30: Train Acc=0.9950, CE=0.3326, Div=0.0049, Val Acc=0.9781, F1=0.9754
#   Epoch  40: Train Acc=0.9973, CE=0.3202, Div=0.0022, Val Acc=0.9789, F1=0.9762
#   Epoch  50: Train Acc=0.9979, CE=0.3148, Div=0.0012, Val Acc=0.9813, F1=0.9789
#   Epoch  60: Train Acc=0.9984, CE=0.3104, Div=0.0006, Val Acc=0.9827, F1=0.9803
#   Epoch  70: Train Acc=0.9985, CE=0.3084, Div=0.0004, Val Acc=0.9825, F1=0.9809
#   Early stopping at epoch 79
#   Best Val Acc: 0.9839
#
# [TPA Results]
#   Val Acc: 0.9839
#   Test Acc: 0.9816, F1: 0.9795
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9655, CE=0.4144, Div=0.0055, Val Acc=0.9564, F1=0.9510
#   Epoch  20: Train Acc=0.9906, CE=0.3406, Div=0.0004, Val Acc=0.9694, F1=0.9670
#   Epoch  30: Train Acc=0.9961, CE=0.3184, Div=0.0000, Val Acc=0.9744, F1=0.9724
#   Epoch  40: Train Acc=0.9977, CE=0.3091, Div=0.0002, Val Acc=0.9751, F1=0.9729
#   Epoch  50: Train Acc=0.9980, CE=0.3054, Div=0.0000, Val Acc=0.9762, F1=0.9736
#   Epoch  60: Train Acc=0.9983, CE=0.3029, Div=0.0002, Val Acc=0.9770, F1=0.9748
#   Epoch  70: Train Acc=0.9982, CE=0.3030, Div=0.0000, Val Acc=0.9770, F1=0.9743
#   Epoch  80: Train Acc=0.9984, CE=0.3028, Div=0.0000, Val Acc=0.9769, F1=0.9746
#   Epoch  90: Train Acc=0.9980, CE=0.3023, Div=0.0000, Val Acc=0.9787, F1=0.9767
#   Epoch 100: Train Acc=0.9983, CE=0.3017, Div=0.0000, Val Acc=0.9787, F1=0.9755
#   Best Val Acc: 0.9816
#
# [Gated-TPA Results]
#   Val Acc: 0.9816
#   Test Acc: 0.9778, F1: 0.9755
#
# [Progress: 6/36]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_20PCT
# ================================================================================
#
# Loading Standing_TO_Walking_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Standing_TO_Walking_20PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9612, Loss=0.4365, Val Acc=0.9465, F1=0.9408
#   Epoch  20: Train Acc=0.9882, Loss=0.3580, Val Acc=0.9674, F1=0.9649
#   Epoch  30: Train Acc=0.9945, Loss=0.3301, Val Acc=0.9746, F1=0.9732
#   Epoch  40: Train Acc=0.9968, Loss=0.3176, Val Acc=0.9749, F1=0.9729
#   Epoch  50: Train Acc=0.9975, Loss=0.3109, Val Acc=0.9749, F1=0.9725
#   Epoch  60: Train Acc=0.9980, Loss=0.3073, Val Acc=0.9762, F1=0.9730
#   Epoch  70: Train Acc=0.9978, Loss=0.3059, Val Acc=0.9756, F1=0.9741
#   Epoch  80: Train Acc=0.9980, Loss=0.3047, Val Acc=0.9754, F1=0.9730
#   Early stopping at epoch 86
#   Best Val Acc: 0.9776
#
# [GAP Results]
#   Val Acc: 0.9776
#   Test Acc: 0.9760, F1: 0.9732
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9606, CE=0.4411, Div=0.0225, Val Acc=0.9447, F1=0.9345
#   Epoch  20: Train Acc=0.9881, CE=0.3576, Div=0.0067, Val Acc=0.9687, F1=0.9634
#   Epoch  30: Train Acc=0.9950, CE=0.3312, Div=0.0038, Val Acc=0.9735, F1=0.9698
#   Epoch  40: Train Acc=0.9974, CE=0.3195, Div=0.0022, Val Acc=0.9800, F1=0.9778
#   Epoch  50: Train Acc=0.9982, CE=0.3133, Div=0.0010, Val Acc=0.9778, F1=0.9751
#   Epoch  60: Train Acc=0.9985, CE=0.3102, Div=0.0007, Val Acc=0.9776, F1=0.9749
#   Early stopping at epoch 60
#   Best Val Acc: 0.9800
#
# [TPA Results]
#   Val Acc: 0.9800
#   Test Acc: 0.9781, F1: 0.9749
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9662, CE=0.4118, Div=0.0105, Val Acc=0.9494, F1=0.9420
#   Epoch  20: Train Acc=0.9903, CE=0.3409, Div=0.0014, Val Acc=0.9684, F1=0.9640
#   Epoch  30: Train Acc=0.9958, CE=0.3197, Div=0.0002, Val Acc=0.9721, F1=0.9693
#   Epoch  40: Train Acc=0.9976, CE=0.3100, Div=0.0001, Val Acc=0.9762, F1=0.9730
#   Epoch  50: Train Acc=0.9975, CE=0.3066, Div=0.0000, Val Acc=0.9751, F1=0.9717
#   Epoch  60: Train Acc=0.9981, CE=0.3034, Div=0.0000, Val Acc=0.9754, F1=0.9720
#   Epoch  70: Train Acc=0.9984, CE=0.3022, Div=0.0000, Val Acc=0.9766, F1=0.9727
#   Early stopping at epoch 79
#   Best Val Acc: 0.9789
#
# [Gated-TPA Results]
#   Val Acc: 0.9789
#   Test Acc: 0.9753, F1: 0.9723
#
# [Progress: 7/36]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_30PCT
# ================================================================================
#
# Loading Standing_TO_Walking_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Standing_TO_Walking_30PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9621, Loss=0.4362, Val Acc=0.9477, F1=0.9416
#   Epoch  20: Train Acc=0.9876, Loss=0.3587, Val Acc=0.9627, F1=0.9590
#   Epoch  30: Train Acc=0.9948, Loss=0.3304, Val Acc=0.9702, F1=0.9673
#   Epoch  40: Train Acc=0.9969, Loss=0.3176, Val Acc=0.9728, F1=0.9704
#   Epoch  50: Train Acc=0.9977, Loss=0.3119, Val Acc=0.9735, F1=0.9715
#   Epoch  60: Train Acc=0.9978, Loss=0.3089, Val Acc=0.9778, F1=0.9758
#   Epoch  70: Train Acc=0.9978, Loss=0.3070, Val Acc=0.9763, F1=0.9739
#   Epoch  80: Train Acc=0.9978, Loss=0.3050, Val Acc=0.9763, F1=0.9737
#   Early stopping at epoch 80
#   Best Val Acc: 0.9778
#
# [GAP Results]
#   Val Acc: 0.9778
#   Test Acc: 0.9767, F1: 0.9753
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9593, CE=0.4471, Div=0.0179, Val Acc=0.9437, F1=0.9324
#   Epoch  20: Train Acc=0.9881, CE=0.3594, Div=0.0089, Val Acc=0.9683, F1=0.9640
#   Epoch  30: Train Acc=0.9959, CE=0.3315, Div=0.0042, Val Acc=0.9751, F1=0.9716
#   Epoch  40: Train Acc=0.9974, CE=0.3194, Div=0.0014, Val Acc=0.9779, F1=0.9755
#   Epoch  50: Train Acc=0.9981, CE=0.3136, Div=0.0008, Val Acc=0.9787, F1=0.9764
#   Epoch  60: Train Acc=0.9982, CE=0.3113, Div=0.0005, Val Acc=0.9798, F1=0.9776
#   Epoch  70: Train Acc=0.9985, CE=0.3086, Div=0.0002, Val Acc=0.9803, F1=0.9782
#   Epoch  80: Train Acc=0.9985, CE=0.3072, Div=0.0001, Val Acc=0.9798, F1=0.9779
#   Early stopping at epoch 84
#   Best Val Acc: 0.9813
#
# [TPA Results]
#   Val Acc: 0.9813
#   Test Acc: 0.9807, F1: 0.9787
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9642, CE=0.4156, Div=0.0084, Val Acc=0.9439, F1=0.9369
#   Epoch  20: Train Acc=0.9895, CE=0.3433, Div=0.0008, Val Acc=0.9678, F1=0.9650
#   Epoch  30: Train Acc=0.9954, CE=0.3207, Div=0.0001, Val Acc=0.9731, F1=0.9698
#   Epoch  40: Train Acc=0.9971, CE=0.3111, Div=0.0000, Val Acc=0.9747, F1=0.9718
#   Epoch  50: Train Acc=0.9977, CE=0.3063, Div=0.0001, Val Acc=0.9738, F1=0.9708
#   Epoch  60: Train Acc=0.9980, CE=0.3040, Div=0.0000, Val Acc=0.9760, F1=0.9732
#   Epoch  70: Train Acc=0.9980, CE=0.3032, Div=0.0000, Val Acc=0.9762, F1=0.9728
#   Epoch  80: Train Acc=0.9985, CE=0.3016, Div=0.0000, Val Acc=0.9772, F1=0.9739
#   Early stopping at epoch 81
#   Best Val Acc: 0.9778
#
# [Gated-TPA Results]
#   Val Acc: 0.9778
#   Test Acc: 0.9764, F1: 0.9731
#
# [Progress: 8/36]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_40PCT
# ================================================================================
#
# Loading Standing_TO_Walking_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Standing_TO_Walking_40PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9617, Loss=0.4384, Val Acc=0.9465, F1=0.9372
#   Epoch  20: Train Acc=0.9890, Loss=0.3582, Val Acc=0.9672, F1=0.9609
#   Epoch  30: Train Acc=0.9954, Loss=0.3299, Val Acc=0.9721, F1=0.9678
#   Epoch  40: Train Acc=0.9974, Loss=0.3168, Val Acc=0.9699, F1=0.9657
#   Epoch  50: Train Acc=0.9974, Loss=0.3117, Val Acc=0.9750, F1=0.9713
#   Epoch  60: Train Acc=0.9977, Loss=0.3079, Val Acc=0.9744, F1=0.9702
#   Epoch  70: Train Acc=0.9981, Loss=0.3054, Val Acc=0.9751, F1=0.9700
#   Epoch  80: Train Acc=0.9984, Loss=0.3037, Val Acc=0.9766, F1=0.9724
#   Epoch  90: Train Acc=0.9983, Loss=0.3030, Val Acc=0.9750, F1=0.9705
#   Epoch 100: Train Acc=0.9989, Loss=0.3015, Val Acc=0.9769, F1=0.9730
#   Best Val Acc: 0.9778
#
# [GAP Results]
#   Val Acc: 0.9778
#   Test Acc: 0.9741, F1: 0.9706
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9606, CE=0.4410, Div=0.0135, Val Acc=0.9446, F1=0.9338
#   Epoch  20: Train Acc=0.9899, CE=0.3555, Div=0.0074, Val Acc=0.9697, F1=0.9635
#   Epoch  30: Train Acc=0.9961, CE=0.3287, Div=0.0026, Val Acc=0.9762, F1=0.9733
#   Epoch  40: Train Acc=0.9980, CE=0.3176, Div=0.0014, Val Acc=0.9768, F1=0.9730
#   Epoch  50: Train Acc=0.9985, CE=0.3122, Div=0.0004, Val Acc=0.9766, F1=0.9736
#   Epoch  60: Train Acc=0.9988, CE=0.3092, Div=0.0002, Val Acc=0.9795, F1=0.9768
#   Epoch  70: Train Acc=0.9989, CE=0.3074, Div=0.0002, Val Acc=0.9789, F1=0.9763
#   Epoch  80: Train Acc=0.9984, CE=0.3073, Div=0.0002, Val Acc=0.9810, F1=0.9788
#   Early stopping at epoch 86
#   Best Val Acc: 0.9817
#
# [TPA Results]
#   Val Acc: 0.9817
#   Test Acc: 0.9761, F1: 0.9732
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9650, CE=0.4149, Div=0.0032, Val Acc=0.9472, F1=0.9387
#   Epoch  20: Train Acc=0.9900, CE=0.3413, Div=0.0007, Val Acc=0.9672, F1=0.9615
#   Epoch  30: Train Acc=0.9959, CE=0.3174, Div=0.0001, Val Acc=0.9725, F1=0.9680
#   Epoch  40: Train Acc=0.9975, CE=0.3087, Div=0.0001, Val Acc=0.9731, F1=0.9680
#   Epoch  50: Train Acc=0.9981, CE=0.3045, Div=0.0000, Val Acc=0.9778, F1=0.9732
#   Epoch  60: Train Acc=0.9981, CE=0.3033, Div=0.0000, Val Acc=0.9770, F1=0.9733
#   Epoch  70: Train Acc=0.9988, CE=0.3010, Div=0.0000, Val Acc=0.9763, F1=0.9722
#   Epoch  80: Train Acc=0.9985, CE=0.3009, Div=0.0000, Val Acc=0.9792, F1=0.9762
#   Epoch  90: Train Acc=0.9988, CE=0.3010, Div=0.0001, Val Acc=0.9795, F1=0.9758
#   Epoch 100: Train Acc=0.9989, CE=0.2997, Div=0.0000, Val Acc=0.9789, F1=0.9765
#   Best Val Acc: 0.9800
#
# [Gated-TPA Results]
#   Val Acc: 0.9800
#   Test Acc: 0.9754, F1: 0.9721
#
# [Progress: 9/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Standing_10PCT
# ================================================================================
#
# Loading Walking_TO_Standing_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Standing_10PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9654, Loss=0.4263, Val Acc=0.9513, F1=0.9447
#   Epoch  20: Train Acc=0.9899, Loss=0.3526, Val Acc=0.9706, F1=0.9670
#   Epoch  30: Train Acc=0.9954, Loss=0.3261, Val Acc=0.9729, F1=0.9690
#   Epoch  40: Train Acc=0.9976, Loss=0.3147, Val Acc=0.9737, F1=0.9705
#   Epoch  50: Train Acc=0.9984, Loss=0.3091, Val Acc=0.9753, F1=0.9721
#   Epoch  60: Train Acc=0.9985, Loss=0.3055, Val Acc=0.9728, F1=0.9696
#   Epoch  70: Train Acc=0.9981, Loss=0.3052, Val Acc=0.9724, F1=0.9686
#   Early stopping at epoch 70
#   Best Val Acc: 0.9753
#
# [GAP Results]
#   Val Acc: 0.9753
#   Test Acc: 0.9749, F1: 0.9709
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9588, CE=0.4456, Div=0.0156, Val Acc=0.9444, F1=0.9340
#   Epoch  20: Train Acc=0.9889, CE=0.3575, Div=0.0100, Val Acc=0.9675, F1=0.9620
#   Epoch  30: Train Acc=0.9959, CE=0.3304, Div=0.0039, Val Acc=0.9731, F1=0.9684
#   Epoch  40: Train Acc=0.9978, CE=0.3184, Div=0.0020, Val Acc=0.9763, F1=0.9727
#   Epoch  50: Train Acc=0.9986, CE=0.3130, Div=0.0010, Val Acc=0.9773, F1=0.9739
#   Epoch  60: Train Acc=0.9988, CE=0.3094, Div=0.0004, Val Acc=0.9759, F1=0.9729
#   Epoch  70: Train Acc=0.9988, CE=0.3080, Div=0.0005, Val Acc=0.9781, F1=0.9754
#   Early stopping at epoch 74
#   Best Val Acc: 0.9795
#
# [TPA Results]
#   Val Acc: 0.9795
#   Test Acc: 0.9789, F1: 0.9752
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9656, CE=0.4106, Div=0.0028, Val Acc=0.9487, F1=0.9403
#   Epoch  20: Train Acc=0.9895, CE=0.3427, Div=0.0013, Val Acc=0.9634, F1=0.9574
#   Epoch  30: Train Acc=0.9958, CE=0.3195, Div=0.0004, Val Acc=0.9702, F1=0.9664
#   Epoch  40: Train Acc=0.9970, CE=0.3114, Div=0.0001, Val Acc=0.9725, F1=0.9691
#   Epoch  50: Train Acc=0.9984, CE=0.3058, Div=0.0000, Val Acc=0.9769, F1=0.9740
#   Epoch  60: Train Acc=0.9980, CE=0.3040, Div=0.0000, Val Acc=0.9712, F1=0.9675
#   Epoch  70: Train Acc=0.9980, CE=0.3034, Div=0.0000, Val Acc=0.9751, F1=0.9719
#   Early stopping at epoch 70
#   Best Val Acc: 0.9769
#
# [Gated-TPA Results]
#   Val Acc: 0.9769
#   Test Acc: 0.9754, F1: 0.9716
#
# [Progress: 10/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Standing_20PCT
# ================================================================================
#
# Loading Walking_TO_Standing_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Standing_20PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9649, Loss=0.4312, Val Acc=0.9494, F1=0.9405
#   Epoch  20: Train Acc=0.9894, Loss=0.3552, Val Acc=0.9681, F1=0.9635
#   Epoch  30: Train Acc=0.9947, Loss=0.3290, Val Acc=0.9721, F1=0.9677
#   Epoch  40: Train Acc=0.9968, Loss=0.3174, Val Acc=0.9744, F1=0.9714
#   Epoch  50: Train Acc=0.9977, Loss=0.3110, Val Acc=0.9765, F1=0.9740
#   Epoch  60: Train Acc=0.9977, Loss=0.3073, Val Acc=0.9750, F1=0.9722
#   Epoch  70: Train Acc=0.9982, Loss=0.3049, Val Acc=0.9757, F1=0.9724
#   Early stopping at epoch 79
#   Best Val Acc: 0.9778
#
# [GAP Results]
#   Val Acc: 0.9778
#   Test Acc: 0.9753, F1: 0.9717
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9593, CE=0.4433, Div=0.0230, Val Acc=0.9450, F1=0.9346
#   Epoch  20: Train Acc=0.9886, CE=0.3591, Div=0.0116, Val Acc=0.9689, F1=0.9645
#   Epoch  30: Train Acc=0.9956, CE=0.3308, Div=0.0047, Val Acc=0.9732, F1=0.9694
#   Epoch  40: Train Acc=0.9971, CE=0.3208, Div=0.0020, Val Acc=0.9768, F1=0.9735
#   Epoch  50: Train Acc=0.9984, CE=0.3146, Div=0.0012, Val Acc=0.9785, F1=0.9752
#   Epoch  60: Train Acc=0.9984, CE=0.3111, Div=0.0005, Val Acc=0.9782, F1=0.9755
#   Epoch  70: Train Acc=0.9985, CE=0.3090, Div=0.0004, Val Acc=0.9792, F1=0.9762
#   Epoch  80: Train Acc=0.9985, CE=0.3073, Div=0.0001, Val Acc=0.9801, F1=0.9776
#   Epoch  90: Train Acc=0.9987, CE=0.3063, Div=0.0002, Val Acc=0.9808, F1=0.9777
#   Epoch 100: Train Acc=0.9988, CE=0.3056, Div=0.0000, Val Acc=0.9792, F1=0.9767
#   Best Val Acc: 0.9823
#
# [TPA Results]
#   Val Acc: 0.9823
#   Test Acc: 0.9807, F1: 0.9779
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9653, CE=0.4112, Div=0.0025, Val Acc=0.9494, F1=0.9402
#   Epoch  20: Train Acc=0.9896, CE=0.3429, Div=0.0015, Val Acc=0.9684, F1=0.9632
#   Epoch  30: Train Acc=0.9950, CE=0.3210, Div=0.0008, Val Acc=0.9728, F1=0.9680
#   Epoch  40: Train Acc=0.9970, CE=0.3117, Div=0.0001, Val Acc=0.9734, F1=0.9691
#   Epoch  50: Train Acc=0.9971, CE=0.3080, Div=0.0000, Val Acc=0.9753, F1=0.9714
#   Epoch  60: Train Acc=0.9977, CE=0.3049, Div=0.0000, Val Acc=0.9768, F1=0.9733
#   Epoch  70: Train Acc=0.9981, CE=0.3028, Div=0.0002, Val Acc=0.9738, F1=0.9698
#   Epoch  80: Train Acc=0.9984, CE=0.3024, Div=0.0000, Val Acc=0.9759, F1=0.9720
#   Epoch  90: Train Acc=0.9983, CE=0.3017, Div=0.0000, Val Acc=0.9795, F1=0.9762
#   Epoch 100: Train Acc=0.9980, CE=0.3028, Div=0.0000, Val Acc=0.9759, F1=0.9719
#   Best Val Acc: 0.9795
#
# [Gated-TPA Results]
#   Val Acc: 0.9795
#   Test Acc: 0.9784, F1: 0.9753
#
# [Progress: 11/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Standing_30PCT
# ================================================================================
#
# Loading Walking_TO_Standing_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Standing_30PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9630, Loss=0.4321, Val Acc=0.9481, F1=0.9391
#   Epoch  20: Train Acc=0.9892, Loss=0.3550, Val Acc=0.9672, F1=0.9629
#   Epoch  30: Train Acc=0.9952, Loss=0.3287, Val Acc=0.9671, F1=0.9631
#   Epoch  40: Train Acc=0.9969, Loss=0.3168, Val Acc=0.9708, F1=0.9675
#   Epoch  50: Train Acc=0.9970, Loss=0.3112, Val Acc=0.9732, F1=0.9701
#   Epoch  60: Train Acc=0.9979, Loss=0.3077, Val Acc=0.9712, F1=0.9673
#   Epoch  70: Train Acc=0.9978, Loss=0.3059, Val Acc=0.9753, F1=0.9723
#   Epoch  80: Train Acc=0.9982, Loss=0.3038, Val Acc=0.9715, F1=0.9684
#   Epoch  90: Train Acc=0.9983, Loss=0.3037, Val Acc=0.9727, F1=0.9691
#   Early stopping at epoch 90
#   Best Val Acc: 0.9753
#
# [GAP Results]
#   Val Acc: 0.9753
#   Test Acc: 0.9741, F1: 0.9706
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9592, CE=0.4463, Div=0.0193, Val Acc=0.9444, F1=0.9348
#   Epoch  20: Train Acc=0.9878, CE=0.3597, Div=0.0140, Val Acc=0.9672, F1=0.9625
#   Epoch  30: Train Acc=0.9954, CE=0.3329, Div=0.0053, Val Acc=0.9743, F1=0.9710
#   Epoch  40: Train Acc=0.9976, CE=0.3205, Div=0.0025, Val Acc=0.9765, F1=0.9738
#   Epoch  50: Train Acc=0.9981, CE=0.3145, Div=0.0010, Val Acc=0.9772, F1=0.9749
#   Epoch  60: Train Acc=0.9980, CE=0.3117, Div=0.0004, Val Acc=0.9768, F1=0.9739
#   Epoch  70: Train Acc=0.9985, CE=0.3091, Div=0.0003, Val Acc=0.9787, F1=0.9763
#   Epoch  80: Train Acc=0.9983, CE=0.3080, Div=0.0002, Val Acc=0.9791, F1=0.9766
#   Epoch  90: Train Acc=0.9985, CE=0.3064, Div=0.0001, Val Acc=0.9808, F1=0.9786
#   Early stopping at epoch 94
#   Best Val Acc: 0.9808
#
# [TPA Results]
#   Val Acc: 0.9808
#   Test Acc: 0.9789, F1: 0.9759
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9652, CE=0.4114, Div=0.0026, Val Acc=0.9474, F1=0.9387
#   Epoch  20: Train Acc=0.9898, CE=0.3413, Div=0.0008, Val Acc=0.9651, F1=0.9608
#   Epoch  30: Train Acc=0.9957, CE=0.3197, Div=0.0002, Val Acc=0.9683, F1=0.9640
#   Epoch  40: Train Acc=0.9971, CE=0.3101, Div=0.0000, Val Acc=0.9740, F1=0.9708
#   Epoch  50: Train Acc=0.9976, CE=0.3063, Div=0.0000, Val Acc=0.9735, F1=0.9706
#   Epoch  60: Train Acc=0.9976, CE=0.3043, Div=0.0000, Val Acc=0.9760, F1=0.9729
#   Epoch  70: Train Acc=0.9978, CE=0.3039, Div=0.0000, Val Acc=0.9738, F1=0.9706
#   Epoch  80: Train Acc=0.9982, CE=0.3023, Div=0.0000, Val Acc=0.9751, F1=0.9722
#   Early stopping at epoch 89
#   Best Val Acc: 0.9772
#
# [Gated-TPA Results]
#   Val Acc: 0.9772
#   Test Acc: 0.9751, F1: 0.9715
#
# [Progress: 12/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Standing_40PCT
# ================================================================================
#
# Loading Walking_TO_Standing_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Standing_40PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9623, Loss=0.4385, Val Acc=0.9493, F1=0.9418
#   Epoch  20: Train Acc=0.9879, Loss=0.3591, Val Acc=0.9664, F1=0.9621
#   Epoch  30: Train Acc=0.9944, Loss=0.3305, Val Acc=0.9722, F1=0.9681
#   Epoch  40: Train Acc=0.9971, Loss=0.3177, Val Acc=0.9737, F1=0.9702
#   Epoch  50: Train Acc=0.9971, Loss=0.3125, Val Acc=0.9757, F1=0.9722
#   Epoch  60: Train Acc=0.9979, Loss=0.3073, Val Acc=0.9749, F1=0.9716
#   Epoch  70: Train Acc=0.9981, Loss=0.3060, Val Acc=0.9746, F1=0.9711
#   Early stopping at epoch 70
#   Best Val Acc: 0.9757
#
# [GAP Results]
#   Val Acc: 0.9757
#   Test Acc: 0.9756, F1: 0.9721
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9583, CE=0.4468, Div=0.0177, Val Acc=0.9453, F1=0.9359
#   Epoch  20: Train Acc=0.9874, CE=0.3609, Div=0.0104, Val Acc=0.9667, F1=0.9614
#   Epoch  30: Train Acc=0.9950, CE=0.3349, Div=0.0052, Val Acc=0.9728, F1=0.9691
#   Epoch  40: Train Acc=0.9974, CE=0.3219, Div=0.0023, Val Acc=0.9738, F1=0.9709
#   Epoch  50: Train Acc=0.9979, CE=0.3157, Div=0.0014, Val Acc=0.9784, F1=0.9754
#   Epoch  60: Train Acc=0.9983, CE=0.3125, Div=0.0011, Val Acc=0.9788, F1=0.9764
#   Epoch  70: Train Acc=0.9984, CE=0.3095, Div=0.0005, Val Acc=0.9794, F1=0.9768
#   Epoch  80: Train Acc=0.9984, CE=0.3080, Div=0.0002, Val Acc=0.9785, F1=0.9758
#   Epoch  90: Train Acc=0.9987, CE=0.3067, Div=0.0002, Val Acc=0.9803, F1=0.9776
#   Epoch 100: Train Acc=0.9984, CE=0.3061, Div=0.0000, Val Acc=0.9791, F1=0.9764
#   Best Val Acc: 0.9808
#
# [TPA Results]
#   Val Acc: 0.9808
#   Test Acc: 0.9822, F1: 0.9799
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9650, CE=0.4134, Div=0.0044, Val Acc=0.9482, F1=0.9390
#   Epoch  20: Train Acc=0.9882, CE=0.3451, Div=0.0029, Val Acc=0.9652, F1=0.9604
#   Epoch  30: Train Acc=0.9949, CE=0.3213, Div=0.0010, Val Acc=0.9687, F1=0.9642
#   Epoch  40: Train Acc=0.9966, CE=0.3121, Div=0.0000, Val Acc=0.9728, F1=0.9689
#   Epoch  50: Train Acc=0.9970, CE=0.3089, Div=0.0000, Val Acc=0.9751, F1=0.9717
#   Epoch  60: Train Acc=0.9981, CE=0.3051, Div=0.0000, Val Acc=0.9753, F1=0.9716
#   Epoch  70: Train Acc=0.9978, CE=0.3042, Div=0.0000, Val Acc=0.9738, F1=0.9695
#   Epoch  80: Train Acc=0.9980, CE=0.3031, Div=0.0000, Val Acc=0.9794, F1=0.9764
#   Epoch  90: Train Acc=0.9985, CE=0.3011, Div=0.0001, Val Acc=0.9775, F1=0.9742
#   Epoch 100: Train Acc=0.9980, CE=0.3023, Div=0.0000, Val Acc=0.9759, F1=0.9723
#   Best Val Acc: 0.9797
#
# [Gated-TPA Results]
#   Val Acc: 0.9797
#   Test Acc: 0.9784, F1: 0.9755
#
# [Progress: 13/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Running_10PCT
# ================================================================================
#
# Loading Walking_TO_Running_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Running_10PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9649, Loss=0.4273, Val Acc=0.9529, F1=0.9447
#   Epoch  20: Train Acc=0.9893, Loss=0.3531, Val Acc=0.9693, F1=0.9641
#   Epoch  30: Train Acc=0.9949, Loss=0.3276, Val Acc=0.9729, F1=0.9681
#   Epoch  40: Train Acc=0.9967, Loss=0.3158, Val Acc=0.9756, F1=0.9715
#   Epoch  50: Train Acc=0.9976, Loss=0.3102, Val Acc=0.9766, F1=0.9729
#   Epoch  60: Train Acc=0.9977, Loss=0.3072, Val Acc=0.9750, F1=0.9712
#   Early stopping at epoch 63
#   Best Val Acc: 0.9787
#
# [GAP Results]
#   Val Acc: 0.9787
#   Test Acc: 0.9756, F1: 0.9724
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9595, CE=0.4433, Div=0.0093, Val Acc=0.9450, F1=0.9334
#   Epoch  20: Train Acc=0.9898, CE=0.3560, Div=0.0103, Val Acc=0.9690, F1=0.9626
#   Epoch  30: Train Acc=0.9957, CE=0.3303, Div=0.0047, Val Acc=0.9738, F1=0.9690
#   Epoch  40: Train Acc=0.9973, CE=0.3194, Div=0.0020, Val Acc=0.9766, F1=0.9732
#   Epoch  50: Train Acc=0.9979, CE=0.3145, Div=0.0010, Val Acc=0.9785, F1=0.9749
#   Epoch  60: Train Acc=0.9980, CE=0.3109, Div=0.0004, Val Acc=0.9782, F1=0.9744
#   Epoch  70: Train Acc=0.9985, CE=0.3088, Div=0.0003, Val Acc=0.9807, F1=0.9776
#   Epoch  80: Train Acc=0.9983, CE=0.3074, Div=0.0002, Val Acc=0.9822, F1=0.9794
#   Epoch  90: Train Acc=0.9987, CE=0.3062, Div=0.0001, Val Acc=0.9817, F1=0.9785
#   Epoch 100: Train Acc=0.9985, CE=0.3059, Div=0.0001, Val Acc=0.9801, F1=0.9770
#   Best Val Acc: 0.9830
#
# [TPA Results]
#   Val Acc: 0.9830
#   Test Acc: 0.9789, F1: 0.9757
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9655, CE=0.4088, Div=0.0010, Val Acc=0.9512, F1=0.9421
#   Epoch  20: Train Acc=0.9915, CE=0.3377, Div=0.0010, Val Acc=0.9652, F1=0.9591
#   Epoch  30: Train Acc=0.9955, CE=0.3184, Div=0.0001, Val Acc=0.9708, F1=0.9665
#   Epoch  40: Train Acc=0.9976, CE=0.3095, Div=0.0000, Val Acc=0.9741, F1=0.9703
#   Epoch  50: Train Acc=0.9974, CE=0.3070, Div=0.0000, Val Acc=0.9728, F1=0.9686
#   Epoch  60: Train Acc=0.9979, CE=0.3043, Div=0.0000, Val Acc=0.9762, F1=0.9729
#   Epoch  70: Train Acc=0.9979, CE=0.3029, Div=0.0000, Val Acc=0.9749, F1=0.9718
#   Epoch  80: Train Acc=0.9985, CE=0.3016, Div=0.0000, Val Acc=0.9759, F1=0.9721
#   Epoch  90: Train Acc=0.9984, CE=0.3015, Div=0.0000, Val Acc=0.9772, F1=0.9742
#   Epoch 100: Train Acc=0.9988, CE=0.3000, Div=0.0000, Val Acc=0.9784, F1=0.9752
#   Best Val Acc: 0.9787
#
# [Gated-TPA Results]
#   Val Acc: 0.9787
#   Test Acc: 0.9750, F1: 0.9704
#
# [Progress: 14/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Running_20PCT
# ================================================================================
#
# Loading Walking_TO_Running_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Running_20PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9629, Loss=0.4328, Val Acc=0.9529, F1=0.9461
#   Epoch  20: Train Acc=0.9888, Loss=0.3553, Val Acc=0.9705, F1=0.9671
#   Epoch  30: Train Acc=0.9952, Loss=0.3296, Val Acc=0.9724, F1=0.9692
#   Epoch  40: Train Acc=0.9966, Loss=0.3170, Val Acc=0.9759, F1=0.9735
#   Epoch  50: Train Acc=0.9971, Loss=0.3116, Val Acc=0.9753, F1=0.9731
#   Epoch  60: Train Acc=0.9978, Loss=0.3082, Val Acc=0.9778, F1=0.9758
#   Epoch  70: Train Acc=0.9977, Loss=0.3066, Val Acc=0.9759, F1=0.9735
#   Early stopping at epoch 75
#   Best Val Acc: 0.9782
#
# [GAP Results]
#   Val Acc: 0.9782
#   Test Acc: 0.9744, F1: 0.9709
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9573, CE=0.4465, Div=0.0098, Val Acc=0.9463, F1=0.9362
#   Epoch  20: Train Acc=0.9880, CE=0.3602, Div=0.0082, Val Acc=0.9700, F1=0.9654
#   Epoch  30: Train Acc=0.9951, CE=0.3330, Div=0.0039, Val Acc=0.9746, F1=0.9705
#   Epoch  40: Train Acc=0.9972, CE=0.3207, Div=0.0023, Val Acc=0.9781, F1=0.9746
#   Epoch  50: Train Acc=0.9983, CE=0.3145, Div=0.0011, Val Acc=0.9807, F1=0.9778
#   Epoch  60: Train Acc=0.9982, CE=0.3107, Div=0.0006, Val Acc=0.9814, F1=0.9780
#   Epoch  70: Train Acc=0.9984, CE=0.3088, Div=0.0004, Val Acc=0.9836, F1=0.9809
#   Epoch  80: Train Acc=0.9984, CE=0.3075, Div=0.0003, Val Acc=0.9826, F1=0.9797
#   Epoch  90: Train Acc=0.9986, CE=0.3059, Div=0.0002, Val Acc=0.9823, F1=0.9789
#   Early stopping at epoch 96
#   Best Val Acc: 0.9839
#
# [TPA Results]
#   Val Acc: 0.9839
#   Test Acc: 0.9795, F1: 0.9763
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9659, CE=0.4093, Div=0.0048, Val Acc=0.9509, F1=0.9419
#   Epoch  20: Train Acc=0.9893, CE=0.3423, Div=0.0017, Val Acc=0.9677, F1=0.9627
#   Epoch  30: Train Acc=0.9951, CE=0.3201, Div=0.0002, Val Acc=0.9713, F1=0.9670
#   Epoch  40: Train Acc=0.9970, CE=0.3110, Div=0.0000, Val Acc=0.9738, F1=0.9694
#   Epoch  50: Train Acc=0.9981, CE=0.3066, Div=0.0000, Val Acc=0.9735, F1=0.9694
#   Epoch  60: Train Acc=0.9981, CE=0.3050, Div=0.0000, Val Acc=0.9732, F1=0.9692
#   Epoch  70: Train Acc=0.9981, CE=0.3034, Div=0.0000, Val Acc=0.9749, F1=0.9711
#   Epoch  80: Train Acc=0.9982, CE=0.3029, Div=0.0000, Val Acc=0.9757, F1=0.9721
#   Epoch  90: Train Acc=0.9986, CE=0.3015, Div=0.0000, Val Acc=0.9762, F1=0.9724
#   Epoch 100: Train Acc=0.9984, CE=0.3013, Div=0.0000, Val Acc=0.9776, F1=0.9743
#   Best Val Acc: 0.9784
#
# [Gated-TPA Results]
#   Val Acc: 0.9784
#   Test Acc: 0.9786, F1: 0.9752
#
# [Progress: 15/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Running_30PCT
# ================================================================================
#
# Loading Walking_TO_Running_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Running_30PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9640, Loss=0.4342, Val Acc=0.9482, F1=0.9395
#   Epoch  20: Train Acc=0.9891, Loss=0.3552, Val Acc=0.9696, F1=0.9651
#   Epoch  30: Train Acc=0.9958, Loss=0.3279, Val Acc=0.9741, F1=0.9704
#   Epoch  40: Train Acc=0.9974, Loss=0.3159, Val Acc=0.9737, F1=0.9704
#   Epoch  50: Train Acc=0.9977, Loss=0.3100, Val Acc=0.9760, F1=0.9722
#   Epoch  60: Train Acc=0.9979, Loss=0.3078, Val Acc=0.9753, F1=0.9716
#   Epoch  70: Train Acc=0.9981, Loss=0.3053, Val Acc=0.9747, F1=0.9705
#   Epoch  80: Train Acc=0.9982, Loss=0.3038, Val Acc=0.9754, F1=0.9715
#   Early stopping at epoch 87
#   Best Val Acc: 0.9776
#
# [GAP Results]
#   Val Acc: 0.9776
#   Test Acc: 0.9737, F1: 0.9706
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9568, CE=0.4472, Div=0.0202, Val Acc=0.9450, F1=0.9341
#   Epoch  20: Train Acc=0.9891, CE=0.3565, Div=0.0115, Val Acc=0.9665, F1=0.9608
#   Epoch  30: Train Acc=0.9963, CE=0.3302, Div=0.0039, Val Acc=0.9737, F1=0.9694
#   Epoch  40: Train Acc=0.9978, CE=0.3196, Div=0.0013, Val Acc=0.9749, F1=0.9714
#   Epoch  50: Train Acc=0.9981, CE=0.3139, Div=0.0007, Val Acc=0.9781, F1=0.9745
#   Early stopping at epoch 56
#   Best Val Acc: 0.9781
#
# [TPA Results]
#   Val Acc: 0.9781
#   Test Acc: 0.9765, F1: 0.9726
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9650, CE=0.4131, Div=0.0018, Val Acc=0.9529, F1=0.9442
#   Epoch  20: Train Acc=0.9898, CE=0.3411, Div=0.0011, Val Acc=0.9674, F1=0.9623
#   Epoch  30: Train Acc=0.9960, CE=0.3185, Div=0.0001, Val Acc=0.9700, F1=0.9655
#   Epoch  40: Train Acc=0.9976, CE=0.3091, Div=0.0000, Val Acc=0.9715, F1=0.9664
#   Epoch  50: Train Acc=0.9980, CE=0.3053, Div=0.0000, Val Acc=0.9729, F1=0.9687
#   Epoch  60: Train Acc=0.9979, CE=0.3042, Div=0.0001, Val Acc=0.9762, F1=0.9720
#   Epoch  70: Train Acc=0.9979, CE=0.3032, Div=0.0000, Val Acc=0.9750, F1=0.9704
#   Epoch  80: Train Acc=0.9985, CE=0.3017, Div=0.0000, Val Acc=0.9753, F1=0.9710
#   Epoch  90: Train Acc=0.9984, CE=0.3014, Div=0.0000, Val Acc=0.9749, F1=0.9705
#   Early stopping at epoch 92
#   Best Val Acc: 0.9768
#
# [Gated-TPA Results]
#   Val Acc: 0.9768
#   Test Acc: 0.9750, F1: 0.9714
#
# [Progress: 16/36]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Running_40PCT
# ================================================================================
#
# Loading Walking_TO_Running_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Walking_TO_Running_40PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9622, Loss=0.4386, Val Acc=0.9515, F1=0.9436
#   Epoch  20: Train Acc=0.9883, Loss=0.3583, Val Acc=0.9680, F1=0.9633
#   Epoch  30: Train Acc=0.9957, Loss=0.3288, Val Acc=0.9734, F1=0.9702
#   Epoch  40: Train Acc=0.9969, Loss=0.3169, Val Acc=0.9757, F1=0.9732
#   Epoch  50: Train Acc=0.9976, Loss=0.3107, Val Acc=0.9734, F1=0.9706
#   Epoch  60: Train Acc=0.9976, Loss=0.3081, Val Acc=0.9754, F1=0.9727
#   Epoch  70: Train Acc=0.9975, Loss=0.3066, Val Acc=0.9746, F1=0.9717
#   Epoch  80: Train Acc=0.9979, Loss=0.3055, Val Acc=0.9759, F1=0.9731
#   Early stopping at epoch 88
#   Best Val Acc: 0.9787
#
# [GAP Results]
#   Val Acc: 0.9787
#   Test Acc: 0.9751, F1: 0.9717
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9576, CE=0.4490, Div=0.0124, Val Acc=0.9481, F1=0.9390
#   Epoch  20: Train Acc=0.9882, CE=0.3605, Div=0.0061, Val Acc=0.9667, F1=0.9617
#   Epoch  30: Train Acc=0.9956, CE=0.3330, Div=0.0037, Val Acc=0.9735, F1=0.9699
#   Epoch  40: Train Acc=0.9971, CE=0.3212, Div=0.0025, Val Acc=0.9765, F1=0.9731
#   Epoch  50: Train Acc=0.9974, CE=0.3154, Div=0.0011, Val Acc=0.9778, F1=0.9745
#   Epoch  60: Train Acc=0.9982, CE=0.3114, Div=0.0004, Val Acc=0.9791, F1=0.9762
#   Epoch  70: Train Acc=0.9982, CE=0.3088, Div=0.0003, Val Acc=0.9782, F1=0.9754
#   Epoch  80: Train Acc=0.9980, CE=0.3083, Div=0.0002, Val Acc=0.9791, F1=0.9759
#   Epoch  90: Train Acc=0.9986, CE=0.3071, Div=0.0002, Val Acc=0.9826, F1=0.9801
#   Epoch 100: Train Acc=0.9984, CE=0.3066, Div=0.0001, Val Acc=0.9810, F1=0.9783
#   Best Val Acc: 0.9826
#
# [TPA Results]
#   Val Acc: 0.9826
#   Test Acc: 0.9819, F1: 0.9789
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9632, CE=0.4175, Div=0.0025, Val Acc=0.9498, F1=0.9407
#   Epoch  20: Train Acc=0.9892, CE=0.3438, Div=0.0008, Val Acc=0.9642, F1=0.9584
#   Epoch  30: Train Acc=0.9953, CE=0.3208, Div=0.0003, Val Acc=0.9693, F1=0.9646
#   Epoch  40: Train Acc=0.9967, CE=0.3111, Div=0.0000, Val Acc=0.9725, F1=0.9683
#   Epoch  50: Train Acc=0.9975, CE=0.3074, Div=0.0000, Val Acc=0.9724, F1=0.9686
#   Epoch  60: Train Acc=0.9973, CE=0.3068, Div=0.0000, Val Acc=0.9747, F1=0.9707
#   Epoch  70: Train Acc=0.9979, CE=0.3037, Div=0.0001, Val Acc=0.9759, F1=0.9724
#   Epoch  80: Train Acc=0.9981, CE=0.3029, Div=0.0001, Val Acc=0.9779, F1=0.9750
#   Epoch  90: Train Acc=0.9980, CE=0.3025, Div=0.0000, Val Acc=0.9784, F1=0.9761
#   Epoch 100: Train Acc=0.9978, CE=0.3034, Div=0.0001, Val Acc=0.9770, F1=0.9743
#   Best Val Acc: 0.9792
#
# [Gated-TPA Results]
#   Val Acc: 0.9792
#   Test Acc: 0.9780, F1: 0.9751
#
# [Progress: 17/36]
#
# ================================================================================
# EXPERIMENT: Running_TO_Walking_10PCT
# ================================================================================
#
# Loading Running_TO_Walking_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/pamap2_transition_datasets/Running_TO_Walking_10PCT
#   Train: (34192, 100, 27), Test: (8549, 100, 27)
#
# Dataset splits:
#   Train: 27353, Val: 6839, Test: 8549
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9648, Loss=0.4322, Val Acc=0.9462, F1=0.9383
#   Epoch  20: Train Acc=0.9893, Loss=0.3561, Val Acc=0.9674, F1=0.9613
#   Epoch  30: Train Acc=0.9951, Loss=0.3285, Val Acc=0.9737, F1=0.9693
#   Epoch  40: Train Acc=0.9974, Loss=0.3162, Val Acc=0.9763, F1=0.9731
#   Epoch  50: Train Acc=0.9977, Loss=0.3099, Val Acc=0.9763, F1=0.9725
#   Epoch  60: Train Acc=0.9981, Loss=0.3069, Val Acc=0.9775, F1=0.9747
#   Epoch  70: Train Acc=0.9984, Loss=0.3041, Val Acc=0.9776, F1=0.9752
#   Epoch  80: Train Acc=0.9984, Loss=0.3032, Val Acc=0.9754, F1=0.9740
#   Epoch  90: Train Acc=0.9985, Loss=0.3028, Val Acc=0.9791, F1=0.9771
#   Early stopping at epoch 93
#   Best Val Acc: 0.9795
#
# [GAP Results]
#   Val Acc: 0.9795
#   Test Acc: 0.9766, F1: 0.9748
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9648, CE=0.4348, Div=0.0302, Val Acc=0.9494, F1=0.9433
