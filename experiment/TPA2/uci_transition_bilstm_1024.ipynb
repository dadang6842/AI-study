# %%
# -*- coding: utf-8 -*-
"""unified_transition_1024.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1q8L0az2N02xlgQ_FLiQds-TEaFqLfsON
"""

# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Gated-TPA
Compare three models on 41 pre-augmented transition datasets
(1 original + 40 transition datasets)
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_dataset(base_dir: str, dataset_name: str):
    """
    Load pre-augmented dataset
    Args:
        base_dir: base directory containing all datasets
        dataset_name: e.g., "ORIGINAL", "STANDING_TO_SITTING_10pct", etc.
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, dataset_name)

    print(f"\nLoading {dataset_name}...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class BiLSTMBackbone(nn.Module):
    """BiLSTM backbone for all models
    Args:
        in_ch: input channels (default: 9)
        d_model: output dimension (default: 128)
        hidden_dim: LSTM hidden dimension (default: 64, bidirectional -> 128)
        num_layers: number of LSTM layers (default: 2)
        dropout: dropout rate (default: 0.1)
    """
    def __init__(self, in_ch=9, d_model=128, hidden_dim=64, num_layers=2, dropout=0.1):
        super().__init__()
        self.d_model = d_model

        # BiLSTM: hidden_dim=64 → 양방향이므로 출력은 128
        self.lstm = nn.LSTM(
            input_size=in_ch,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        # 투영층: BiLSTM 출력(128) → d_model(128)
        self.projection = nn.Linear(hidden_dim * 2, d_model)

        # 정규화 및 드롭아웃
        self.layer_norm = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # x: [B, C, T] → [B, T, C] (LSTM은 [B, T, C] 형태 입력)
        x = x.transpose(1, 2)

        # BiLSTM
        lstm_out, _ = self.lstm(x)  # [B, T, hidden_dim*2=128]

        # 투영
        out = self.projection(lstm_out)  # [B, T, d_model=128]

        # 정규화 + 드롭아웃
        out = self.layer_norm(out)
        out = self.dropout(out)

        # [B, T, D] → [B, D, T] (기존 코드와의 호환성)
        return out.transpose(1, 2)

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=6):
        super().__init__()
        self.backbone = BiLSTMBackbone(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# Pure-TPA
# ========================
class ProductionTPA(nn.Module):
    """Pure TPA"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        z_tpa = proto_tokens.mean(dim=1)

        z = self.fuse(z_tpa)

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = BiLSTMBackbone(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Gated-TPA
# ========================
class GatedTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = BiLSTMBackbone(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        # Gating mechanism
        self.gate = nn.Sequential(
            nn.Linear(d_model * 2, d_model),
            nn.Sigmoid()
        )

        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]

        # GAP branch
        z_gap = features.mean(dim=1)  # [B, D]

        # TPA branch
        z_tpa = self.tpa(features)  # [B, D]

        # Gating
        gate_input = torch.cat([z_gap, z_tpa], dim=-1)
        g = self.gate(gate_input)

        # Gated fusion
        z = g * z_gap + (1 - g) * z_tpa

        logits = self.classifier(z)
        return logits

# ========================
# Training & Evaluation
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Gated-TPA":
        return GatedTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(dataset_name: str, cfg: Config):
    """Run complete experiment for one dataset"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {dataset_name}")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_dataset(cfg.data_dir, dataset_name)

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Gated-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Dataset': dataset_name,
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA")
    print("Testing on 41 Datasets (1 Original + 40 Transition)")
    print("="*80)

    # Define all 41 datasets
    datasets = ["ORIGINAL"]  # 원본 데이터셋

    # 정적 활동 전이 (6개 × 4개 비율 = 24개)
    static_transitions = [
        "STANDING_TO_SITTING",
        "STANDING_TO_LAYING",
        "SITTING_TO_LAYING",
        "SITTING_TO_STANDING",
        "LAYING_TO_SITTING",
        "LAYING_TO_STANDING"
    ]

    # 걷기 활동 전이 (4개 × 4개 비율 = 16개)
    walking_transitions = [
        "WALKING_TO_WALKING_UPSTAIRS",
        "WALKING_TO_WALKING_DOWNSTAIRS",
        "WALKING_UPSTAIRS_TO_WALKING",
        "WALKING_DOWNSTAIRS_TO_WALKING"
    ]

    # 모든 전이에 대해 10%, 20%, 30%, 40% 추가
    mix_pcts = [10, 20, 30, 40]

    for transition in static_transitions + walking_transitions:
        for pct in mix_pcts:
            datasets.append(f"{transition}_{pct}pct")

    print(f"\nTotal datasets to test: {len(datasets)}")
    print(f"  - Original: 1")
    print(f"  - Static transitions: {len(static_transitions) * len(mix_pcts)}")
    print(f"  - Walking transitions: {len(walking_transitions) * len(mix_pcts)}")

    all_results = []

    # Run experiments
    for i, dataset_name in enumerate(datasets, 1):
        print(f"\n[Progress: {i}/{len(datasets)}]")
        results = run_experiment(dataset_name, cfg)
        all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Gated-TPA'],
            'total_datasets': len(datasets),
            'datasets': datasets,
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_comparison_41datasets_results.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Total datasets tested: {len(datasets)}")
    print(f"Models compared: 3 (GAP, TPA, Gated-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE (All Datasets)")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Gated-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:12s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Mounted at /content/drive
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA
# Testing on 41 Datasets (1 Original + 40 Transition)
# ================================================================================
#
# Total datasets to test: 41
#   - Original: 1
#   - Static transitions: 24
#   - Walking transitions: 16
#
# [Progress: 1/41]
#
# ================================================================================
# EXPERIMENT: ORIGINAL
# ================================================================================
#
# Loading ORIGINAL...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9487, Val Acc=0.9530, F1=0.9585
#   Epoch  20: Train Acc=0.9532, Val Acc=0.9617, F1=0.9675
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9617, F1=0.9683
#   Epoch  40: Train Acc=0.9567, Val Acc=0.9493, F1=0.9582
#   Epoch  50: Train Acc=0.9595, Val Acc=0.9561, F1=0.9622
#   Early stopping at epoch 52
#   Best Val Acc: 0.9648
#
# [TPA Results]
#   Val Acc: 0.9648
#   Test Acc: 0.9238, F1: 0.9283
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9355, Val Acc=0.9339, F1=0.9412
#   Epoch  20: Train Acc=0.9448, Val Acc=0.9450, F1=0.9524
#   Epoch  30: Train Acc=0.9593, Val Acc=0.9672, F1=0.9727
#   Epoch  40: Train Acc=0.9629, Val Acc=0.9561, F1=0.9637
#   Epoch  50: Train Acc=0.9632, Val Acc=0.9438, F1=0.9542
#   Early stopping at epoch 50
#   Best Val Acc: 0.9672
#
# [Gated-TPA Results]
#   Val Acc: 0.9672
#   Test Acc: 0.9324, F1: 0.9359
#
# [Progress: 7/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING_20pct
# ================================================================================
#
# Loading STANDING_TO_LAYING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8521, Val Acc=0.8609, F1=0.8558
#   Epoch  20: Train Acc=0.9243, Val Acc=0.9227, F1=0.9309
#   Epoch  30: Train Acc=0.9556, Val Acc=0.9363, F1=0.9438
#   Epoch  40: Train Acc=0.9573, Val Acc=0.9481, F1=0.9553
#   Epoch  50: Train Acc=0.9603, Val Acc=0.9543, F1=0.9616
#   Epoch  60: Train Acc=0.9604, Val Acc=0.9438, F1=0.9511
#   Early stopping at epoch 69
#   Best Val Acc: 0.9574
#
# [GAP Results]
#   Val Acc: 0.9574
#   Test Acc: 0.9182, F1: 0.9207
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9508, Val Acc=0.9357, F1=0.9434
#   Epoch  20: Train Acc=0.9576, Val Acc=0.9462, F1=0.9542
#   Epoch  30: Train Acc=0.9580, Val Acc=0.9438, F1=0.9520
#   Epoch  40: Train Acc=0.9593, Val Acc=0.9438, F1=0.9523
#   Early stopping at epoch 47
#   Best Val Acc: 0.9549
#
# [TPA Results]
#   Val Acc: 0.9549
#   Test Acc: 0.9278, F1: 0.9347
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9445, Val Acc=0.9320, F1=0.9403
#   Epoch  20: Train Acc=0.9558, Val Acc=0.9456, F1=0.9540
#   Epoch  30: Train Acc=0.9583, Val Acc=0.9524, F1=0.9603
#   Epoch  40: Train Acc=0.9626, Val Acc=0.9524, F1=0.9608
#   Epoch  50: Train Acc=0.9643, Val Acc=0.9456, F1=0.9554
#   Early stopping at epoch 58
#   Best Val Acc: 0.9574
#
# [Gated-TPA Results]
#   Val Acc: 0.9574
#   Test Acc: 0.9300, F1: 0.9320
#
# [Progress: 8/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING_30pct
# ================================================================================
#
# Loading STANDING_TO_LAYING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9417, Val Acc=0.9444, F1=0.9524
#   Epoch  20: Train Acc=0.9539, Val Acc=0.9586, F1=0.9653
#   Epoch  30: Train Acc=0.9569, Val Acc=0.9555, F1=0.9640
#   Epoch  40: Train Acc=0.9556, Val Acc=0.9617, F1=0.9680
#   Epoch  50: Train Acc=0.9610, Val Acc=0.9580, F1=0.9645
#   Epoch  60: Train Acc=0.9609, Val Acc=0.9654, F1=0.9705
#   Epoch  70: Train Acc=0.9634, Val Acc=0.9648, F1=0.9700
#   Epoch  80: Train Acc=0.9660, Val Acc=0.9493, F1=0.9578
#   Early stopping at epoch 81
#   Best Val Acc: 0.9722
#
# [Gated-TPA Results]
#   Val Acc: 0.9722
#   Test Acc: 0.9355, F1: 0.9412
#
# [Progress: 11/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING_20pct
# ================================================================================
#
# Loading SITTING_TO_LAYING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_LAYING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8746, Val Acc=0.8826, F1=0.8759
#   Epoch  20: Train Acc=0.9419, Val Acc=0.9425, F1=0.9489
#   Epoch  30: Train Acc=0.9510, Val Acc=0.9543, F1=0.9616
#   Epoch  40: Train Acc=0.9601, Val Acc=0.9468, F1=0.9563
#   Epoch  50: Train Acc=0.9580, Val Acc=0.9561, F1=0.9628
#   Epoch  60: Train Acc=0.9564, Val Acc=0.9561, F1=0.9631
#   Early stopping at epoch 61
#   Best Val Acc: 0.9580
#
# [GAP Results]
#   Val Acc: 0.9580
#   Test Acc: 0.9139, F1: 0.9186
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9510, Val Acc=0.9518, F1=0.9605
#   Epoch  20: Train Acc=0.9547, Val Acc=0.9524, F1=0.9616
#   Epoch  30: Train Acc=0.9546, Val Acc=0.9592, F1=0.9665
#   Epoch  40: Train Acc=0.9581, Val Acc=0.9574, F1=0.9651
#   Epoch  50: Train Acc=0.9615, Val Acc=0.9524, F1=0.9614
#   Early stopping at epoch 51
#   Best Val Acc: 0.9617
#
# [TPA Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9281, F1: 0.9365
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9490, Val Acc=0.9462, F1=0.9559
#   Epoch  20: Train Acc=0.9558, Val Acc=0.9555, F1=0.9637
#   Epoch  30: Train Acc=0.9575, Val Acc=0.9574, F1=0.9642
#   Epoch  40: Train Acc=0.9592, Val Acc=0.9598, F1=0.9671
#   Epoch  50: Train Acc=0.9606, Val Acc=0.9536, F1=0.9613
#   Epoch  60: Train Acc=0.9617, Val Acc=0.9604, F1=0.9665
#   Epoch  70: Train Acc=0.9658, Val Acc=0.9623, F1=0.9689
#   Epoch  80: Train Acc=0.9655, Val Acc=0.9642, F1=0.9699
#   Epoch  90: Train Acc=0.9654, Val Acc=0.9506, F1=0.9580
#   Epoch 100: Train Acc=0.9669, Val Acc=0.9666, F1=0.9721
#   Best Val Acc: 0.9716
#
# [Gated-TPA Results]
#   Val Acc: 0.9716
#   Test Acc: 0.9247, F1: 0.9325
#
# [Progress: 12/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING_30pct
# ================================================================================
#
# Loading SITTING_TO_LAYING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9504, Val Acc=0.9543, F1=0.9606
#   Epoch  20: Train Acc=0.9566, Val Acc=0.9654, F1=0.9712
#   Epoch  30: Train Acc=0.9563, Val Acc=0.9685, F1=0.9741
#   Early stopping at epoch 39
#   Best Val Acc: 0.9685
#
# [Gated-TPA Results]
#   Val Acc: 0.9685
#   Test Acc: 0.9312, F1: 0.9378
#
# [Progress: 14/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_10pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8616, Val Acc=0.8727, F1=0.8673
#   Epoch  20: Train Acc=0.9323, Val Acc=0.9345, F1=0.9409
#   Epoch  30: Train Acc=0.9482, Val Acc=0.9468, F1=0.9549
#   Epoch  40: Train Acc=0.9470, Val Acc=0.9518, F1=0.9598
#   Epoch  50: Train Acc=0.9522, Val Acc=0.9512, F1=0.9594
#   Epoch  60: Train Acc=0.9546, Val Acc=0.9512, F1=0.9591
#   Early stopping at epoch 61
#   Best Val Acc: 0.9524
#
# [GAP Results]
#   Val Acc: 0.9524
#   Test Acc: 0.8960, F1: 0.9008
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9443, Val Acc=0.9518, F1=0.9603
#   Epoch  20: Train Acc=0.9456, Val Acc=0.9425, F1=0.9517
#   Epoch  30: Train Acc=0.9530, Val Acc=0.9475, F1=0.9556
#   Epoch  40: Train Acc=0.9563, Val Acc=0.9561, F1=0.9637
#   Epoch  50: Train Acc=0.9572, Val Acc=0.9567, F1=0.9642
#   Epoch  60: Train Acc=0.9567, Val Acc=0.9561, F1=0.9638
#   Epoch  70: Train Acc=0.9620, Val Acc=0.9592, F1=0.9660
#   Epoch  80: Train Acc=0.9665, Val Acc=0.9629, F1=0.9687
#   Epoch  90: Train Acc=0.9705, Val Acc=0.9574, F1=0.9637
#   Epoch 100: Train Acc=0.9688, Val Acc=0.9611, F1=0.9671
#   Best Val Acc: 0.9672
#
# [TPA Results]
#   Val Acc: 0.9672
#   Test Acc: 0.9170, F1: 0.9246
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9428, Val Acc=0.9481, F1=0.9558
#   Epoch  20: Train Acc=0.9498, Val Acc=0.9481, F1=0.9567
#   Epoch  30: Train Acc=0.9491, Val Acc=0.9512, F1=0.9599
#   Epoch  40: Train Acc=0.9516, Val Acc=0.9512, F1=0.9592
#   Epoch  50: Train Acc=0.9533, Val Acc=0.9561, F1=0.9636
#   Epoch  60: Train Acc=0.9590, Val Acc=0.9419, F1=0.9491
#   Early stopping at epoch 67
#   Best Val Acc: 0.9586
#
# [Gated-TPA Results]
#   Val Acc: 0.9586
#   Test Acc: 0.9182, F1: 0.9266
#
# [Progress: 15/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_20pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8607, Val Acc=0.8696, F1=0.8634
#   Epoch  20: Train Acc=0.9283, Val Acc=0.9339, F1=0.9402
#   Epoch  30: Train Acc=0.9461, Val Acc=0.9512, F1=0.9589
#   Epoch  40: Train Acc=0.9478, Val Acc=0.9468, F1=0.9562
#   Epoch  50: Train Acc=0.9490, Val Acc=0.9413, F1=0.9493
#   Early stopping at epoch 58
#   Best Val Acc: 0.9530
#
# [GAP Results]
#   Val Acc: 0.9530
#   Test Acc: 0.9016, F1: 0.9072
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9433, Val Acc=0.9425, F1=0.9500
#   Epoch  20: Train Acc=0.9482, Val Acc=0.9450, F1=0.9531
#   Epoch  30: Train Acc=0.9478, Val Acc=0.9536, F1=0.9610
#   Early stopping at epoch 34
#   Best Val Acc: 0.9567
#
# [TPA Results]
#   Val Acc: 0.9567
#   Test Acc: 0.9136, F1: 0.9221
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9369, Val Acc=0.9468, F1=0.9533
#   Epoch  20: Train Acc=0.9493, Val Acc=0.9468, F1=0.9563
#   Epoch  30: Train Acc=0.9481, Val Acc=0.9536, F1=0.9618
#   Epoch  40: Train Acc=0.9532, Val Acc=0.9462, F1=0.9568
#   Epoch  50: Train Acc=0.9576, Val Acc=0.9580, F1=0.9648
#   Epoch  60: Train Acc=0.9604, Val Acc=0.9611, F1=0.9673
#   Epoch  70: Train Acc=0.9624, Val Acc=0.9561, F1=0.9642
#   Epoch  80: Train Acc=0.9651, Val Acc=0.9648, F1=0.9712
#   Epoch  90: Train Acc=0.9689, Val Acc=0.9611, F1=0.9681
#   Epoch 100: Train Acc=0.9694, Val Acc=0.9642, F1=0.9689
#   Best Val Acc: 0.9722
#
# [Gated-TPA Results]
#   Val Acc: 0.9722
#   Test Acc: 0.9210, F1: 0.9298
#
# [Progress: 16/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_30pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8624, Val Acc=0.8616, F1=0.8555
#   Epoch  20: Train Acc=0.9306, Val Acc=0.9283, F1=0.9354
#   Epoch  30: Train Acc=0.9445, Val Acc=0.9326, F1=0.9443
#   Epoch  40: Train Acc=0.9491, Val Acc=0.9370, F1=0.9471
#   Epoch  50: Train Acc=0.9555, Val Acc=0.9388, F1=0.9472
#   Epoch  60: Train Acc=0.9512, Val Acc=0.9431, F1=0.9523
#   Epoch  70: Train Acc=0.9535, Val Acc=0.9370, F1=0.9464
#   Epoch  80: Train Acc=0.9561, Val Acc=0.9431, F1=0.9522
#   Early stopping at epoch 80
#   Best Val Acc: 0.9431
#
# [GAP Results]
#   Val Acc: 0.9431
#   Test Acc: 0.8963, F1: 0.9021
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9419, Val Acc=0.9363, F1=0.9444
#   Epoch  20: Train Acc=0.9521, Val Acc=0.9400, F1=0.9487
#   Epoch  30: Train Acc=0.9542, Val Acc=0.9438, F1=0.9534
#   Early stopping at epoch 33
#   Best Val Acc: 0.9512
#
# [TPA Results]
#   Val Acc: 0.9512
#   Test Acc: 0.9040, F1: 0.9157
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9428, Val Acc=0.9363, F1=0.9445
#   Epoch  20: Train Acc=0.9530, Val Acc=0.9481, F1=0.9563
#   Epoch  30: Train Acc=0.9552, Val Acc=0.9400, F1=0.9488
#   Epoch  40: Train Acc=0.9559, Val Acc=0.9450, F1=0.9531
#   Early stopping at epoch 43
#   Best Val Acc: 0.9524
#
# [Gated-TPA Results]
#   Val Acc: 0.9524
#   Test Acc: 0.9102, F1: 0.9201
#
# [Progress: 17/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_40pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9493, Val Acc=0.9499, F1=0.9487
#   Epoch  20: Train Acc=0.9513, Val Acc=0.9654, F1=0.9649
#   Epoch  30: Train Acc=0.9564, Val Acc=0.9574, F1=0.9568
#   Early stopping at epoch 38
#   Best Val Acc: 0.9654
#
# [TPA Results]
#   Val Acc: 0.9654
#   Test Acc: 0.9247, F1: 0.9187
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9510, Val Acc=0.9431, F1=0.9411
#   Epoch  20: Train Acc=0.9539, Val Acc=0.9654, F1=0.9650
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9549, F1=0.9543
#   Early stopping at epoch 38
#   Best Val Acc: 0.9660
#
# [Gated-TPA Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9272, F1: 0.9212
#
# [Progress: 19/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_20pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8669, Val Acc=0.8745, F1=0.8572
#   Epoch  20: Train Acc=0.9352, Val Acc=0.9506, F1=0.9473
#   Epoch  30: Train Acc=0.9495, Val Acc=0.9549, F1=0.9536
#   Epoch  40: Train Acc=0.9516, Val Acc=0.9710, F1=0.9707
#   Epoch  50: Train Acc=0.9550, Val Acc=0.9697, F1=0.9694
#   Epoch  60: Train Acc=0.9544, Val Acc=0.9574, F1=0.9564
#   Early stopping at epoch 62
#   Best Val Acc: 0.9728
#
# [GAP Results]
#   Val Acc: 0.9728
#   Test Acc: 0.9263, F1: 0.9193
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9448, Val Acc=0.9629, F1=0.9614
#   Epoch  20: Train Acc=0.9536, Val Acc=0.9549, F1=0.9535
#   Epoch  30: Train Acc=0.9563, Val Acc=0.9623, F1=0.9616
#   Epoch  40: Train Acc=0.9556, Val Acc=0.9660, F1=0.9652
#   Epoch  50: Train Acc=0.9575, Val Acc=0.9642, F1=0.9632
#   Epoch  60: Train Acc=0.9598, Val Acc=0.9734, F1=0.9729
#   Epoch  70: Train Acc=0.9598, Val Acc=0.9679, F1=0.9672
#   Epoch  80: Train Acc=0.9617, Val Acc=0.9685, F1=0.9677
#   Epoch  90: Train Acc=0.9610, Val Acc=0.9672, F1=0.9667
#   Early stopping at epoch 94
#   Best Val Acc: 0.9747
#
# [TPA Results]
#   Val Acc: 0.9747
#   Test Acc: 0.9312, F1: 0.9261
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9445, Val Acc=0.9499, F1=0.9480
#   Epoch  20: Train Acc=0.9542, Val Acc=0.9561, F1=0.9550
#   Epoch  30: Train Acc=0.9541, Val Acc=0.9586, F1=0.9574
#   Epoch  40: Train Acc=0.9525, Val Acc=0.9555, F1=0.9541
#   Epoch  50: Train Acc=0.9567, Val Acc=0.9722, F1=0.9714
#   Early stopping at epoch 52
#   Best Val Acc: 0.9722
#
# [Gated-TPA Results]
#   Val Acc: 0.9722
#   Test Acc: 0.9093, F1: 0.9004
#
# [Progress: 20/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_30pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8666, Val Acc=0.8702, F1=0.8498
#   Epoch  20: Train Acc=0.9425, Val Acc=0.9388, F1=0.9346
#   Epoch  30: Train Acc=0.9555, Val Acc=0.9499, F1=0.9486
#   Epoch  40: Train Acc=0.9559, Val Acc=0.9530, F1=0.9521
#   Epoch  50: Train Acc=0.9578, Val Acc=0.9574, F1=0.9563
#   Epoch  60: Train Acc=0.9583, Val Acc=0.9493, F1=0.9482
#   Epoch  70: Train Acc=0.9578, Val Acc=0.9592, F1=0.9584
#   Epoch  80: Train Acc=0.9609, Val Acc=0.9574, F1=0.9562
#   Early stopping at epoch 82
#   Best Val Acc: 0.9635
#
# [GAP Results]
#   Val Acc: 0.9635
#   Test Acc: 0.9250, F1: 0.9178
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9488, Val Acc=0.9499, F1=0.9478
#   Epoch  20: Train Acc=0.9536, Val Acc=0.9512, F1=0.9502
#   Epoch  30: Train Acc=0.9587, Val Acc=0.9660, F1=0.9655
#   Epoch  40: Train Acc=0.9590, Val Acc=0.9586, F1=0.9579
#   Epoch  50: Train Acc=0.9614, Val Acc=0.9592, F1=0.9586
#   Early stopping at epoch 50
#   Best Val Acc: 0.9660
#
# [TPA Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9287, F1: 0.9225
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9468, Val Acc=0.9462, F1=0.9443
#   Epoch  20: Train Acc=0.9529, Val Acc=0.9506, F1=0.9494
#   Epoch  30: Train Acc=0.9569, Val Acc=0.9567, F1=0.9557
#   Epoch  40: Train Acc=0.9589, Val Acc=0.9617, F1=0.9608
#   Epoch  50: Train Acc=0.9576, Val Acc=0.9629, F1=0.9622
#   Epoch  60: Train Acc=0.9589, Val Acc=0.9586, F1=0.9576
#   Epoch  70: Train Acc=0.9623, Val Acc=0.9580, F1=0.9574
#   Early stopping at epoch 70
#   Best Val Acc: 0.9629
#
# [Gated-TPA Results]
#   Val Acc: 0.9629
#   Test Acc: 0.9241, F1: 0.9173
#
# [Progress: 21/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_40pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8660, Val Acc=0.8578, F1=0.8382
#   Epoch  20: Train Acc=0.9447, Val Acc=0.9394, F1=0.9359
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9407, F1=0.9394
#   Epoch  40: Train Acc=0.9561, Val Acc=0.9456, F1=0.9443
#   Epoch  50: Train Acc=0.9595, Val Acc=0.9549, F1=0.9540
#   Early stopping at epoch 55
#   Best Val Acc: 0.9580
#
# [GAP Results]
#   Val Acc: 0.9580
#   Test Acc: 0.9185, F1: 0.9110
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9478, Val Acc=0.9376, F1=0.9362
#   Epoch  20: Train Acc=0.9593, Val Acc=0.9444, F1=0.9431
#   Epoch  30: Train Acc=0.9592, Val Acc=0.9487, F1=0.9475
#   Epoch  40: Train Acc=0.9603, Val Acc=0.9481, F1=0.9465
#   Early stopping at epoch 47
#   Best Val Acc: 0.9611
#
# [TPA Results]
#   Val Acc: 0.9611
#   Test Acc: 0.9179, F1: 0.9103
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9485, Val Acc=0.9370, F1=0.9356
#   Epoch  20: Train Acc=0.9569, Val Acc=0.9549, F1=0.9546
#   Epoch  30: Train Acc=0.9603, Val Acc=0.9481, F1=0.9473
#   Epoch  40: Train Acc=0.9593, Val Acc=0.9555, F1=0.9548
#   Early stopping at epoch 43
#   Best Val Acc: 0.9598
#
# [Gated-TPA Results]
#   Val Acc: 0.9598
#   Test Acc: 0.9062, F1: 0.8971
#
# [Progress: 22/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING_10pct
# ================================================================================
#
# Loading LAYING_TO_STANDING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8691, Val Acc=0.8733, F1=0.8544
#   Epoch  20: Train Acc=0.9389, Val Acc=0.9456, F1=0.9415
#   Epoch  30: Train Acc=0.9536, Val Acc=0.9524, F1=0.9507
#   Epoch  40: Train Acc=0.9578, Val Acc=0.9592, F1=0.9584
#   Epoch  50: Train Acc=0.9547, Val Acc=0.9635, F1=0.9627
#   Early stopping at epoch 53
#   Best Val Acc: 0.9666
#
# [GAP Results]
#   Val Acc: 0.9666
#   Test Acc: 0.9136, F1: 0.9053
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9448, Val Acc=0.9481, F1=0.9457
#   Epoch  20: Train Acc=0.9547, Val Acc=0.9617, F1=0.9610
#   Epoch  30: Train Acc=0.9580, Val Acc=0.9691, F1=0.9687
#   Epoch  40: Train Acc=0.9612, Val Acc=0.9691, F1=0.9687
#   Early stopping at epoch 49
#   Best Val Acc: 0.9697
#
# [TPA Results]
#   Val Acc: 0.9697
#   Test Acc: 0.9281, F1: 0.9232
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9490, Val Acc=0.9604, F1=0.9598
#   Epoch  20: Train Acc=0.9567, Val Acc=0.9666, F1=0.9661
#   Epoch  30: Train Acc=0.9556, Val Acc=0.9617, F1=0.9610
#   Epoch  40: Train Acc=0.9572, Val Acc=0.9549, F1=0.9540
#   Early stopping at epoch 40
#   Best Val Acc: 0.9666
#
# [Gated-TPA Results]
#   Val Acc: 0.9666
#   Test Acc: 0.8960, F1: 0.8850
#
# [Progress: 23/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING_20pct
# ================================================================================
#
# Loading LAYING_TO_STANDING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8705, Val Acc=0.8659, F1=0.8498
#   Epoch  20: Train Acc=0.9406, Val Acc=0.9388, F1=0.9354
#   Epoch  30: Train Acc=0.9544, Val Acc=0.9574, F1=0.9565
#   Epoch  40: Train Acc=0.9549, Val Acc=0.9580, F1=0.9572
#   Epoch  50: Train Acc=0.9576, Val Acc=0.9549, F1=0.9543
#   Epoch  60: Train Acc=0.9581, Val Acc=0.9536, F1=0.9528
#   Early stopping at epoch 68
#   Best Val Acc: 0.9598
#
# [GAP Results]
#   Val Acc: 0.9598
#   Test Acc: 0.9158, F1: 0.9064
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9495, Val Acc=0.9382, F1=0.9359
#   Epoch  20: Train Acc=0.9549, Val Acc=0.9493, F1=0.9480
#   Epoch  30: Train Acc=0.9578, Val Acc=0.9592, F1=0.9585
#   Epoch  40: Train Acc=0.9614, Val Acc=0.9592, F1=0.9585
#   Epoch  50: Train Acc=0.9620, Val Acc=0.9561, F1=0.9554
#   Epoch  60: Train Acc=0.9618, Val Acc=0.9574, F1=0.9568
#   Early stopping at epoch 66
#   Best Val Acc: 0.9617
#
# [TPA Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9303, F1: 0.9244
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9502, Val Acc=0.9425, F1=0.9408
#   Epoch  20: Train Acc=0.9535, Val Acc=0.9561, F1=0.9557
#   Epoch  30: Train Acc=0.9559, Val Acc=0.9617, F1=0.9611
#   Epoch  40: Train Acc=0.9603, Val Acc=0.9592, F1=0.9585
#   Epoch  50: Train Acc=0.9578, Val Acc=0.9481, F1=0.9469
#   Early stopping at epoch 50
#   Best Val Acc: 0.9617
#
# [Gated-TPA Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9068, F1: 0.8978
#
# [Progress: 24/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING_30pct
# ================================================================================
#
# Loading LAYING_TO_STANDING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8678, Val Acc=0.8826, F1=0.8682
#   Epoch  20: Train Acc=0.9442, Val Acc=0.9419, F1=0.9381
#   Epoch  30: Train Acc=0.9549, Val Acc=0.9574, F1=0.9563
#   Epoch  40: Train Acc=0.9564, Val Acc=0.9561, F1=0.9549
#   Epoch  50: Train Acc=0.9590, Val Acc=0.9543, F1=0.9531
#   Early stopping at epoch 57
#   Best Val Acc: 0.9604
#
# [GAP Results]
#   Val Acc: 0.9604
#   Test Acc: 0.9136, F1: 0.9047
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9462, Val Acc=0.9518, F1=0.9500
#   Epoch  20: Train Acc=0.9559, Val Acc=0.9574, F1=0.9564
#   Epoch  30: Train Acc=0.9595, Val Acc=0.9530, F1=0.9520
#   Epoch  40: Train Acc=0.9604, Val Acc=0.9611, F1=0.9606
#   Epoch  50: Train Acc=0.9604, Val Acc=0.9598, F1=0.9592
#   Epoch  60: Train Acc=0.9617, Val Acc=0.9506, F1=0.9495
#   Early stopping at epoch 64
#   Best Val Acc: 0.9617
#
# [TPA Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9293, F1: 0.9242
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9499, Val Acc=0.9506, F1=0.9490
#   Epoch  20: Train Acc=0.9570, Val Acc=0.9468, F1=0.9452
#   Epoch  30: Train Acc=0.9581, Val Acc=0.9549, F1=0.9541
#   Epoch  40: Train Acc=0.9587, Val Acc=0.9617, F1=0.9610
#   Epoch  50: Train Acc=0.9592, Val Acc=0.9617, F1=0.9609
#   Epoch  60: Train Acc=0.9615, Val Acc=0.9611, F1=0.9605
#   Early stopping at epoch 61
#   Best Val Acc: 0.9635
#
# [Gated-TPA Results]
#   Val Acc: 0.9635
#   Test Acc: 0.9253, F1: 0.9183
#
# [Progress: 25/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING_40pct
# ================================================================================
#
# Loading LAYING_TO_STANDING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8650, Val Acc=0.8714, F1=0.8518
#   Epoch  20: Train Acc=0.9428, Val Acc=0.9499, F1=0.9466
#   Epoch  30: Train Acc=0.9512, Val Acc=0.9592, F1=0.9574
#   Epoch  40: Train Acc=0.9542, Val Acc=0.9468, F1=0.9443
#   Epoch  50: Train Acc=0.9547, Val Acc=0.9660, F1=0.9654
#   Epoch  60: Train Acc=0.9589, Val Acc=0.9635, F1=0.9626
#   Epoch  70: Train Acc=0.9617, Val Acc=0.9611, F1=0.9597
#   Early stopping at epoch 70
#   Best Val Acc: 0.9660
#
# [GAP Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9124, F1: 0.9036
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9481, Val Acc=0.9425, F1=0.9396
#   Epoch  20: Train Acc=0.9521, Val Acc=0.9586, F1=0.9581
#   Epoch  30: Train Acc=0.9566, Val Acc=0.9481, F1=0.9460
#   Epoch  40: Train Acc=0.9563, Val Acc=0.9598, F1=0.9593
#   Early stopping at epoch 46
#   Best Val Acc: 0.9648
#
# [TPA Results]
#   Val Acc: 0.9648
#   Test Acc: 0.9259, F1: 0.9200
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9484, Val Acc=0.9561, F1=0.9548
#   Epoch  20: Train Acc=0.9547, Val Acc=0.9617, F1=0.9611
#   Epoch  30: Train Acc=0.9566, Val Acc=0.9567, F1=0.9555
#   Early stopping at epoch 37
#   Best Val Acc: 0.9666
#
# [Gated-TPA Results]
#   Val Acc: 0.9666
#   Test Acc: 0.9164, F1: 0.9094
#
# [Progress: 26/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_WALKING_UPSTAIRS_10pct
# ================================================================================
#
# Loading WALKING_TO_WALKING_UPSTAIRS_10pct...
# ...
#   Epoch  10: Train Acc=0.9468, Val Acc=0.9543, F1=0.9537
#   Epoch  20: Train Acc=0.9581, Val Acc=0.9555, F1=0.9547
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9623, F1=0.9618
#   Early stopping at epoch 39
#   Best Val Acc: 0.9642
#
# [Gated-TPA Results]
#   Val Acc: 0.9642
#   Test Acc: 0.9241, F1: 0.9205
#
# [Progress: 34/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_10pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8684, Val Acc=0.8659, F1=0.8579
#   Epoch  20: Train Acc=0.9433, Val Acc=0.9320, F1=0.9287
#   Epoch  30: Train Acc=0.9558, Val Acc=0.9419, F1=0.9407
#   Epoch  40: Train Acc=0.9610, Val Acc=0.9512, F1=0.9505
#   Epoch  50: Train Acc=0.9589, Val Acc=0.9475, F1=0.9466
#   Early stopping at epoch 59
#   Best Val Acc: 0.9524
#
# [GAP Results]
#   Val Acc: 0.9524
#   Test Acc: 0.9016, F1: 0.9000
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9512, Val Acc=0.9431, F1=0.9418
#   Epoch  20: Train Acc=0.9572, Val Acc=0.9487, F1=0.9479
#   Epoch  30: Train Acc=0.9589, Val Acc=0.9555, F1=0.9550
#   Epoch  40: Train Acc=0.9578, Val Acc=0.9506, F1=0.9498
#   Epoch  50: Train Acc=0.9606, Val Acc=0.9555, F1=0.9550
#   Epoch  60: Train Acc=0.9614, Val Acc=0.9543, F1=0.9536
#   Early stopping at epoch 64
#   Best Val Acc: 0.9574
#
# [TPA Results]
#   Val Acc: 0.9574
#   Test Acc: 0.9327, F1: 0.9295
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9499, Val Acc=0.9518, F1=0.9512
#   Epoch  20: Train Acc=0.9576, Val Acc=0.9518, F1=0.9509
#   Epoch  30: Train Acc=0.9556, Val Acc=0.9536, F1=0.9528
#   Epoch  40: Train Acc=0.9592, Val Acc=0.9555, F1=0.9547
#   Epoch  50: Train Acc=0.9589, Val Acc=0.9536, F1=0.9529
#   Epoch  60: Train Acc=0.9634, Val Acc=0.9617, F1=0.9610
#   Epoch  70: Train Acc=0.9677, Val Acc=0.9617, F1=0.9608
#   Epoch  80: Train Acc=0.9703, Val Acc=0.9623, F1=0.9617
#   Epoch  90: Train Acc=0.9723, Val Acc=0.9629, F1=0.9623
#   Epoch 100: Train Acc=0.9751, Val Acc=0.9635, F1=0.9630
#   Best Val Acc: 0.9703
#
# [Gated-TPA Results]
#   Val Acc: 0.9703
#   Test Acc: 0.9269, F1: 0.9230
#
# [Progress: 35/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_20pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8521, Val Acc=0.8517, F1=0.8457
#   Epoch  20: Train Acc=0.9358, Val Acc=0.9363, F1=0.9342
#   Epoch  30: Train Acc=0.9533, Val Acc=0.9388, F1=0.9370
#   Epoch  40: Train Acc=0.9550, Val Acc=0.9499, F1=0.9494
#   Epoch  50: Train Acc=0.9570, Val Acc=0.9487, F1=0.9476
#   Early stopping at epoch 55
#   Best Val Acc: 0.9604
#
# [GAP Results]
#   Val Acc: 0.9604
#   Test Acc: 0.9065, F1: 0.9042
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9445, Val Acc=0.9394, F1=0.9378
#   Epoch  20: Train Acc=0.9524, Val Acc=0.9493, F1=0.9485
#   Epoch  30: Train Acc=0.9561, Val Acc=0.9499, F1=0.9489
#   Epoch  40: Train Acc=0.9576, Val Acc=0.9623, F1=0.9618
#   Epoch  50: Train Acc=0.9600, Val Acc=0.9400, F1=0.9377
#   Epoch  60: Train Acc=0.9609, Val Acc=0.9530, F1=0.9524
#   Early stopping at epoch 60
#   Best Val Acc: 0.9623
#
# [TPA Results]
#   Val Acc: 0.9623
#   Test Acc: 0.9232, F1: 0.9187
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9448, Val Acc=0.9499, F1=0.9495
#   Epoch  20: Train Acc=0.9576, Val Acc=0.9376, F1=0.9347
#   Epoch  30: Train Acc=0.9564, Val Acc=0.9506, F1=0.9492
#   Epoch  40: Train Acc=0.9564, Val Acc=0.9586, F1=0.9580
#   Early stopping at epoch 49
#   Best Val Acc: 0.9629
#
# [Gated-TPA Results]
#   Val Acc: 0.9629
#   Test Acc: 0.9195, F1: 0.9144
#
# [Progress: 36/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8501, Val Acc=0.8529, F1=0.8473
#   Epoch  20: Train Acc=0.9294, Val Acc=0.9326, F1=0.9312
#   Epoch  30: Train Acc=0.9542, Val Acc=0.9543, F1=0.9537
#   Epoch  40: Train Acc=0.9566, Val Acc=0.9543, F1=0.9537
#   Epoch  50: Train Acc=0.9587, Val Acc=0.9499, F1=0.9493
#   Early stopping at epoch 59
#   Best Val Acc: 0.9623
#
# [GAP Results]
#   Val Acc: 0.9623
#   Test Acc: 0.9031, F1: 0.9007
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9448, Val Acc=0.9574, F1=0.9569
#   Epoch  20: Train Acc=0.9481, Val Acc=0.9326, F1=0.9308
#   Epoch  30: Train Acc=0.9542, Val Acc=0.9493, F1=0.9481
#   Epoch  40: Train Acc=0.9566, Val Acc=0.9518, F1=0.9509
#   Early stopping at epoch 46
#   Best Val Acc: 0.9629
#
# [TPA Results]
#   Val Acc: 0.9629
#   Test Acc: 0.9266, F1: 0.9224
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9476, Val Acc=0.9493, F1=0.9486
#   Epoch  20: Train Acc=0.9559, Val Acc=0.9524, F1=0.9516
#   Epoch  30: Train Acc=0.9566, Val Acc=0.9567, F1=0.9561
#   Epoch  40: Train Acc=0.9564, Val Acc=0.9586, F1=0.9580
#   Early stopping at epoch 45
#   Best Val Acc: 0.9642
#
# [Gated-TPA Results]
#   Val Acc: 0.9642
#   Test Acc: 0.9256, F1: 0.9218
#
# [Progress: 37/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8448, Val Acc=0.8436, F1=0.8375
#   Epoch  20: Train Acc=0.9232, Val Acc=0.9190, F1=0.9183
#   Epoch  30: Train Acc=0.9518, Val Acc=0.9481, F1=0.9476
#   Epoch  40: Train Acc=0.9559, Val Acc=0.9493, F1=0.9484
#   Epoch  50: Train Acc=0.9542, Val Acc=0.9586, F1=0.9579
#   Epoch  60: Train Acc=0.9597, Val Acc=0.9611, F1=0.9606
#   Epoch  70: Train Acc=0.9593, Val Acc=0.9635, F1=0.9633
#   Epoch  80: Train Acc=0.9604, Val Acc=0.9598, F1=0.9595
#   Epoch  90: Train Acc=0.9627, Val Acc=0.9635, F1=0.9632
#   Early stopping at epoch 93
#   Best Val Acc: 0.9660
#
# [GAP Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9090, F1: 0.9067
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9388, Val Acc=0.9438, F1=0.9434
#   Epoch  20: Train Acc=0.9502, Val Acc=0.9598, F1=0.9594
#   Epoch  30: Train Acc=0.9539, Val Acc=0.9518, F1=0.9513
#   Epoch  40: Train Acc=0.9584, Val Acc=0.9623, F1=0.9619
#   Epoch  50: Train Acc=0.9580, Val Acc=0.9611, F1=0.9606
#   Epoch  60: Train Acc=0.9563, Val Acc=0.9574, F1=0.9567
#   Early stopping at epoch 65
#   Best Val Acc: 0.9629
#
# [TPA Results]
#   Val Acc: 0.9629
#   Test Acc: 0.9284, F1: 0.9255
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9409, Val Acc=0.9413, F1=0.9408
#   Epoch  20: Train Acc=0.9539, Val Acc=0.9580, F1=0.9575
#   Epoch  30: Train Acc=0.9553, Val Acc=0.9660, F1=0.9656
#   Epoch  40: Train Acc=0.9580, Val Acc=0.9561, F1=0.9551
#   Epoch  50: Train Acc=0.9570, Val Acc=0.9623, F1=0.9618
#   Early stopping at epoch 50
#   Best Val Acc: 0.9660
#
# [Gated-TPA Results]
#   Val Acc: 0.9660
#   Test Acc: 0.9185, F1: 0.9164
#
# [Progress: 38/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_10pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8768, Val Acc=0.8844, F1=0.8766
#   Epoch  20: Train Acc=0.9280, Val Acc=0.9444, F1=0.9426
#   Epoch  30: Train Acc=0.9535, Val Acc=0.9425, F1=0.9407
#   Epoch  40: Train Acc=0.9547, Val Acc=0.9530, F1=0.9521
#   Epoch  50: Train Acc=0.9575, Val Acc=0.9580, F1=0.9574
#   Epoch  60: Train Acc=0.9570, Val Acc=0.9604, F1=0.9599
#   Epoch  70: Train Acc=0.9620, Val Acc=0.9604, F1=0.9599
#   Early stopping at epoch 77
#   Best Val Acc: 0.9617
#
# [GAP Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9108, F1: 0.9056
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9505, Val Acc=0.9499, F1=0.9484
#   Epoch  20: Train Acc=0.9546, Val Acc=0.9617, F1=0.9612
#   Epoch  30: Train Acc=0.9558, Val Acc=0.9629, F1=0.9624
#   Epoch  40: Train Acc=0.9561, Val Acc=0.9604, F1=0.9599
#   Epoch  50: Train Acc=0.9587, Val Acc=0.9487, F1=0.9470
#   Epoch  60: Train Acc=0.9576, Val Acc=0.9574, F1=0.9565
#   Early stopping at epoch 62
#   Best Val Acc: 0.9635
#
# [TPA Results]
#   Val Acc: 0.9635
#   Test Acc: 0.9367, F1: 0.9333
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9479, Val Acc=0.9506, F1=0.9497
#   Epoch  20: Train Acc=0.9563, Val Acc=0.9574, F1=0.9565
#   Epoch  30: Train Acc=0.9581, Val Acc=0.9623, F1=0.9617
#   Epoch  40: Train Acc=0.9576, Val Acc=0.9617, F1=0.9611
#   Epoch  50: Train Acc=0.9606, Val Acc=0.9623, F1=0.9618
#   Epoch  60: Train Acc=0.9629, Val Acc=0.9567, F1=0.9558
#   Early stopping at epoch 67
#   Best Val Acc: 0.9648
#
# [Gated-TPA Results]
#   Val Acc: 0.9648
#   Test Acc: 0.9204, F1: 0.9164
#
# [Progress: 39/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_20pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8671, Val Acc=0.8745, F1=0.8665
#   Epoch  20: Train Acc=0.9360, Val Acc=0.9333, F1=0.9305
#   Epoch  30: Train Acc=0.9525, Val Acc=0.9370, F1=0.9342
#   Epoch  40: Train Acc=0.9578, Val Acc=0.9555, F1=0.9548
#   Epoch  50: Train Acc=0.9581, Val Acc=0.9493, F1=0.9482
#   Epoch  60: Train Acc=0.9615, Val Acc=0.9561, F1=0.9554
#   Early stopping at epoch 61
#   Best Val Acc: 0.9567
#
# [GAP Results]
#   Val Acc: 0.9567
#   Test Acc: 0.9108, F1: 0.9067
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9508, Val Acc=0.9481, F1=0.9467
#   Epoch  20: Train Acc=0.9570, Val Acc=0.9536, F1=0.9528
#   Epoch  30: Train Acc=0.9564, Val Acc=0.9512, F1=0.9503
#   Epoch  40: Train Acc=0.9586, Val Acc=0.9493, F1=0.9484
#   Epoch  50: Train Acc=0.9580, Val Acc=0.9555, F1=0.9548
#   Early stopping at epoch 54
#   Best Val Acc: 0.9586
#
# [TPA Results]
#   Val Acc: 0.9586
#   Test Acc: 0.9241, F1: 0.9209
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9504, Val Acc=0.9450, F1=0.9437
#   Epoch  20: Train Acc=0.9541, Val Acc=0.9530, F1=0.9521
#   Epoch  30: Train Acc=0.9580, Val Acc=0.9598, F1=0.9592
#   Epoch  40: Train Acc=0.9598, Val Acc=0.9567, F1=0.9561
#   Epoch  50: Train Acc=0.9604, Val Acc=0.9586, F1=0.9580
#   Early stopping at epoch 58
#   Best Val Acc: 0.9623
#
# [Gated-TPA Results]
#   Val Acc: 0.9623
#   Test Acc: 0.9300, F1: 0.9258
#
# [Progress: 40/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8598, Val Acc=0.8721, F1=0.8606
#   Epoch  20: Train Acc=0.9247, Val Acc=0.9339, F1=0.9300
#   Epoch  30: Train Acc=0.9459, Val Acc=0.9567, F1=0.9548
#   Epoch  40: Train Acc=0.9538, Val Acc=0.9679, F1=0.9674
#   Epoch  50: Train Acc=0.9584, Val Acc=0.9629, F1=0.9623
#   Epoch  60: Train Acc=0.9567, Val Acc=0.9666, F1=0.9658
#   Early stopping at epoch 64
#   Best Val Acc: 0.9685
#
# [GAP Results]
#   Val Acc: 0.9685
#   Test Acc: 0.9179, F1: 0.9135
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9470, Val Acc=0.9524, F1=0.9507
#   Epoch  20: Train Acc=0.9498, Val Acc=0.9580, F1=0.9572
#   Epoch  30: Train Acc=0.9573, Val Acc=0.9617, F1=0.9607
#   Epoch  40: Train Acc=0.9549, Val Acc=0.9567, F1=0.9554
#   Early stopping at epoch 45
#   Best Val Acc: 0.9703
#
# [TPA Results]
#   Val Acc: 0.9703
#   Test Acc: 0.9198, F1: 0.9169
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9422, Val Acc=0.9524, F1=0.9513
#   Epoch  20: Train Acc=0.9538, Val Acc=0.9703, F1=0.9698
#   Epoch  30: Train Acc=0.9567, Val Acc=0.9648, F1=0.9640
#   Epoch  40: Train Acc=0.9569, Val Acc=0.9617, F1=0.9610
#   Early stopping at epoch 49
#   Best Val Acc: 0.9716
#
# [Gated-TPA Results]
#   Val Acc: 0.9716
#   Test Acc: 0.9047, F1: 0.8980
#
# [Progress: 41/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8542, Val Acc=0.8455, F1=0.8352
#   Epoch  20: Train Acc=0.9192, Val Acc=0.9221, F1=0.9191
#   Epoch  30: Train Acc=0.9462, Val Acc=0.9363, F1=0.9343
#   Epoch  40: Train Acc=0.9570, Val Acc=0.9431, F1=0.9420
#   Epoch  50: Train Acc=0.9590, Val Acc=0.9567, F1=0.9560
#   Early stopping at epoch 57
#   Best Val Acc: 0.9586
#
# [GAP Results]
#   Val Acc: 0.9586
#   Test Acc: 0.9053, F1: 0.9003
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9484, Val Acc=0.9351, F1=0.9334
#   Epoch  20: Train Acc=0.9559, Val Acc=0.9518, F1=0.9509
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9475, F1=0.9465
#   Epoch  40: Train Acc=0.9580, Val Acc=0.9518, F1=0.9511
#   Epoch  50: Train Acc=0.9590, Val Acc=0.9567, F1=0.9561
#   Early stopping at epoch 54
#   Best Val Acc: 0.9574
#
# [TPA Results]
#   Val Acc: 0.9574
#   Test Acc: 0.9207, F1: 0.9180
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9481, Val Acc=0.9512, F1=0.9499
#   Epoch  20: Train Acc=0.9581, Val Acc=0.9555, F1=0.9549
#   Epoch  30: Train Acc=0.9572, Val Acc=0.9407, F1=0.9390
#   Epoch  40: Train Acc=0.9549, Val Acc=0.9586, F1=0.9580
#   Epoch  50: Train Acc=0.9592, Val Acc=0.9506, F1=0.9499
#   Early stopping at epoch 59
#   Best Val Acc: 0.9604
#
# [Gated-TPA Results]
#   Val Acc: 0.9604
#   Test Acc: 0.9232, F1: 0.9202
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_comparison_41datasets_results.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 123
# Total datasets tested: 41
# Models compared: 3 (GAP, TPA, Gated-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE (All Datasets)
# ================================================================================
# GAP         : Acc=0.9104, F1=0.9084
# TPA         : Acc=0.9243, F1=0.9245
# Gated-TPA   : Acc=0.9210, F1=0.9198
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
