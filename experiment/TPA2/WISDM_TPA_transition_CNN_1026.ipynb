# %%
# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Gated-TPA
Compare three models on 41 pre-augmented transition datasets
(1 original + 40 transition datasets)
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_dataset(base_dir: str, dataset_name: str):
    """
    Load pre-augmented dataset
    Args:
        base_dir: base directory containing all datasets
        dataset_name: e.g., "ORIGINAL", "STANDING_TO_SITTING_10pct", etc.
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, dataset_name)

    print(f"\nLoading {dataset_name}...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class ConvBNAct(nn.Module):
    def __init__(self, c_in, c_out, k, s=1, p=None, g=1):
        super().__init__()
        self.c = nn.Conv1d(c_in, c_out, k, s, k//2 if p is None else p, groups=g, bias=False)
        self.bn = nn.BatchNorm1d(c_out)
        self.act = nn.GELU()

    def forward(self, x):
        return self.act(self.bn(self.c(x)))

class MultiPathCNN(nn.Module):
    """Shared backbone for all models"""
    def __init__(self, in_ch=3, d_model=128, branches=(3,5,9,15), stride=2):
        super().__init__()
        h = d_model // 2
        self.pre = ConvBNAct(in_ch, h, 1)
        self.branches = nn.ModuleList([
            nn.Sequential(ConvBNAct(h, h, k, stride, g=h), ConvBNAct(h, h, 1))
            for k in branches
        ])
        self.post = ConvBNAct(len(branches)*h, d_model, 1)

    def forward(self, x):
        return self.post(torch.cat([b(self.pre(x)) for b in self.branches], dim=1))

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=6):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# Pure-TPA
# ========================
class ProductionTPA(nn.Module):
    """Pure TPA"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        z_tpa = proto_tokens.mean(dim=1)

        z = self.fuse(z_tpa)

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Gated-TPA
# ========================
class GatedTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        # Gating mechanism
        self.gate = nn.Sequential(
            nn.Linear(d_model * 2, d_model),
            nn.Sigmoid()
        )

        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]

        # GAP branch
        z_gap = features.mean(dim=1)  # [B, D]

        # TPA branch
        z_tpa = self.tpa(features)  # [B, D]

        # Gating
        gate_input = torch.cat([z_gap, z_tpa], dim=-1)
        g = self.gate(gate_input)

        # Gated fusion
        z = g * z_gap + (1 - g) * z_tpa

        logits = self.classifier(z)
        return logits

# ========================
# Training & Evaluation
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Gated-TPA":
        return GatedTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(dataset_name: str, cfg: Config):
    """Run complete experiment for one dataset"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {dataset_name}")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_dataset(cfg.data_dir, dataset_name)

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Gated-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Dataset': dataset_name,
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA")
    print("Testing on 41 Datasets (1 Original + 40 Transition)")
    print("="*80)

    # Define all 41 datasets
    datasets = ["ORIGINAL"]  # 원본 데이터셋

    transitions = [
        "STANDING_TO_SITTING",
        "SITTING_TO_STANDING",
        "STANDING_TO_WALKING",
        "WALKING_TO_STANDING",
        "WALKING_TO_JOGGING",
        "JOGGING_TO_WALKING",
        "WALKING_TO_UPSTAIRS",
        "WALKING_TO_DOWNSTAIRS",
        "UPSTAIRS_TO_WALKING",
        "DOWNSTAIRS_TO_WALKING"
    ]

    # 모든 전이에 대해 10%, 20%, 30%, 40% 추가
    mix_pcts = [10, 20, 30, 40]

    for transition in transitions:
        for pct in mix_pcts:
            datasets.append(f"{transition}_{pct}pct")

    print(f"\nTotal datasets to test: {len(datasets)}")
    print(f"  - Original: 1")
    print(f"  - transitions: {len(transitions) * len(mix_pcts)}")

    all_results = []

    # Run experiments
    for i, dataset_name in enumerate(datasets, 1):
        print(f"\n[Progress: {i}/{len(datasets)}]")
        results = run_experiment(dataset_name, cfg)
        all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Gated-TPA'],
            'total_datasets': len(datasets),
            'datasets': datasets,
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_transition_wisdm_cnn.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Total datasets tested: {len(datasets)}")
    print(f"Models compared: 3 (GAP, TPA, Gated-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE (All Datasets)")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Gated-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:12s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA
# Testing on 41 Datasets (1 Original + 40 Transition)
# ================================================================================
#
# Total datasets to test: 41
#   - Original: 1
#   - transitions: 40
#
# [Progress: 1/41]
#
# ================================================================================
# EXPERIMENT: ORIGINAL
# ================================================================================
#
# Loading ORIGINAL...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/ORIGINAL
#   Train: (21960, 200, 3), Test: (5491, 200, 3)
#
# Dataset splits:
#   Train: 17568, Val: 4392, Test: 5491
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9550, Val Acc=0.9599, F1=0.9416
#   Epoch  20: Train Acc=0.9808, Val Acc=0.9800, F1=0.9682
#   Epoch  30: Train Acc=0.9872, Val Acc=0.9825, F1=0.9771
#   Epoch  40: Train Acc=0.9902, Val Acc=0.9882, F1=0.9829
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9898, F1=0.9853
#   Epoch  60: Train Acc=0.9932, Val Acc=0.9902, F1=0.9860
#   Epoch  70: Train Acc=0.9949, Val Acc=0.9902, F1=0.9850
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9907, F1=0.9858
#   Epoch  90: Train Acc=0.9958, Val Acc=0.9913, F1=0.9872
#   Epoch 100: Train Acc=0.9959, Val Acc=0.9904, F1=0.9863
#   Best Val Acc: 0.9925
#
# [GAP Results]
#   Val Acc: 0.9925
#   Test Acc: 0.9920, F1: 0.9869
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9921, Val Acc=0.9809, F1=0.9665
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9800, F1=0.9643
#   Epoch  30: Train Acc=0.9976, Val Acc=0.9809, F1=0.9665
#   Epoch  40: Train Acc=0.9980, Val Acc=0.9832, F1=0.9746
#   Epoch  50: Train Acc=0.9988, Val Acc=0.9843, F1=0.9756
#   Epoch  60: Train Acc=0.9989, Val Acc=0.9825, F1=0.9729
#   Epoch  70: Train Acc=0.9995, Val Acc=0.9832, F1=0.9744
#   Early stopping at epoch 73
#   Best Val Acc: 0.9850
#
# [TPA Results]
#   Val Acc: 0.9850
#   Test Acc: 0.9863, F1: 0.9776
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9906, Val Acc=0.9802, F1=0.9655
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9816, F1=0.9733
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9832, F1=0.9743
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9822, F1=0.9739
#   Epoch  50: Train Acc=0.9988, Val Acc=0.9825, F1=0.9729
#   Epoch  60: Train Acc=0.9995, Val Acc=0.9820, F1=0.9723
#   Early stopping at epoch 63
#   Best Val Acc: 0.9836
#
# [Gated-TPA Results]
#   Val Acc: 0.9836
#   Test Acc: 0.9862, F1: 0.9783
#
# [Progress: 2/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING_10pct
# ================================================================================
#
# Loading STANDING_TO_SITTING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_SITTING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9624, Val Acc=0.9663, F1=0.9471
#   Epoch  20: Train Acc=0.9823, Val Acc=0.9822, F1=0.9714
#   Epoch  30: Train Acc=0.9879, Val Acc=0.9872, F1=0.9794
#   Epoch  40: Train Acc=0.9909, Val Acc=0.9888, F1=0.9812
#   Epoch  50: Train Acc=0.9931, Val Acc=0.9911, F1=0.9860
#   Epoch  60: Train Acc=0.9943, Val Acc=0.9913, F1=0.9862
#   Epoch  70: Train Acc=0.9956, Val Acc=0.9913, F1=0.9865
#   Epoch  80: Train Acc=0.9957, Val Acc=0.9911, F1=0.9862
#   Epoch  90: Train Acc=0.9967, Val Acc=0.9930, F1=0.9892
#   Epoch 100: Train Acc=0.9973, Val Acc=0.9928, F1=0.9888
#   Best Val Acc: 0.9930
#
# [GAP Results]
#   Val Acc: 0.9930
#   Test Acc: 0.9935, F1: 0.9897
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9927, Val Acc=0.9839, F1=0.9737
#   Epoch  20: Train Acc=0.9966, Val Acc=0.9851, F1=0.9766
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9845, F1=0.9759
#   Early stopping at epoch 38
#   Best Val Acc: 0.9851
#
# [TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9874, F1: 0.9796
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9885, Val Acc=0.9801, F1=0.9700
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9853, F1=0.9783
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9865, F1=0.9800
#   Epoch  40: Train Acc=0.9985, Val Acc=0.9863, F1=0.9800
#   Early stopping at epoch 46
#   Best Val Acc: 0.9876
#
# [Gated-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9868, F1: 0.9797
#
# [Progress: 3/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING_20pct
# ================================================================================
#
# Loading STANDING_TO_SITTING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_SITTING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9606, Val Acc=0.9659, F1=0.9471
#   Epoch  20: Train Acc=0.9824, Val Acc=0.9795, F1=0.9666
#   Epoch  30: Train Acc=0.9879, Val Acc=0.9845, F1=0.9757
#   Epoch  40: Train Acc=0.9904, Val Acc=0.9861, F1=0.9772
#   Epoch  50: Train Acc=0.9927, Val Acc=0.9888, F1=0.9820
#   Epoch  60: Train Acc=0.9943, Val Acc=0.9892, F1=0.9824
#   Epoch  70: Train Acc=0.9953, Val Acc=0.9892, F1=0.9821
#   Early stopping at epoch 74
#   Best Val Acc: 0.9899
#
# [GAP Results]
#   Val Acc: 0.9899
#   Test Acc: 0.9902, F1: 0.9842
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9919, Val Acc=0.9808, F1=0.9702
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9824, F1=0.9707
#   Epoch  30: Train Acc=0.9984, Val Acc=0.9834, F1=0.9745
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9828, F1=0.9733
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9828, F1=0.9731
#   Early stopping at epoch 51
#   Best Val Acc: 0.9859
#
# [TPA Results]
#   Val Acc: 0.9859
#   Test Acc: 0.9877, F1: 0.9799
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9922, Val Acc=0.9816, F1=0.9709
#   Epoch  20: Train Acc=0.9969, Val Acc=0.9853, F1=0.9776
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9849, F1=0.9774
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9830, F1=0.9745
#   Early stopping at epoch 45
#   Best Val Acc: 0.9870
#
# [Gated-TPA Results]
#   Val Acc: 0.9870
#   Test Acc: 0.9851, F1: 0.9764
#
# [Progress: 4/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING_30pct
# ================================================================================
#
# Loading STANDING_TO_SITTING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_SITTING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9596, Val Acc=0.9619, F1=0.9401
#   Epoch  20: Train Acc=0.9812, Val Acc=0.9822, F1=0.9704
#   Epoch  30: Train Acc=0.9869, Val Acc=0.9855, F1=0.9750
#   Epoch  40: Train Acc=0.9897, Val Acc=0.9874, F1=0.9772
#   Epoch  50: Train Acc=0.9919, Val Acc=0.9899, F1=0.9826
#   Epoch  60: Train Acc=0.9935, Val Acc=0.9894, F1=0.9817
#   Epoch  70: Train Acc=0.9940, Val Acc=0.9917, F1=0.9856
#   Epoch  80: Train Acc=0.9948, Val Acc=0.9915, F1=0.9860
#   Epoch  90: Train Acc=0.9957, Val Acc=0.9917, F1=0.9855
#   Epoch 100: Train Acc=0.9963, Val Acc=0.9923, F1=0.9868
#   Best Val Acc: 0.9932
#
# [GAP Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9930, F1: 0.9889
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9905, Val Acc=0.9820, F1=0.9691
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9857, F1=0.9780
#   Epoch  30: Train Acc=0.9986, Val Acc=0.9853, F1=0.9761
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9855, F1=0.9773
#   Early stopping at epoch 41
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9861, F1: 0.9777
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9895, Val Acc=0.9808, F1=0.9666
#   Epoch  20: Train Acc=0.9953, Val Acc=0.9857, F1=0.9763
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9886, F1=0.9824
#   Epoch  40: Train Acc=0.9985, Val Acc=0.9855, F1=0.9779
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9861, F1=0.9784
#   Early stopping at epoch 50
#   Best Val Acc: 0.9886
#
# [Gated-TPA Results]
#   Val Acc: 0.9886
#   Test Acc: 0.9849, F1: 0.9770
#
# [Progress: 5/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_SITTING_40pct
# ================================================================================
#
# Loading STANDING_TO_SITTING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_SITTING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9597, Val Acc=0.9607, F1=0.9367
#   Epoch  20: Train Acc=0.9797, Val Acc=0.9808, F1=0.9680
#   Epoch  30: Train Acc=0.9859, Val Acc=0.9849, F1=0.9742
#   Epoch  40: Train Acc=0.9891, Val Acc=0.9878, F1=0.9785
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9905, F1=0.9839
#   Epoch  60: Train Acc=0.9932, Val Acc=0.9905, F1=0.9841
#   Epoch  70: Train Acc=0.9945, Val Acc=0.9911, F1=0.9853
#   Epoch  80: Train Acc=0.9955, Val Acc=0.9907, F1=0.9842
#   Epoch  90: Train Acc=0.9962, Val Acc=0.9909, F1=0.9853
#   Epoch 100: Train Acc=0.9961, Val Acc=0.9911, F1=0.9853
#   Best Val Acc: 0.9919
#
# [GAP Results]
#   Val Acc: 0.9919
#   Test Acc: 0.9921, F1: 0.9860
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9920, Val Acc=0.9816, F1=0.9704
#   Epoch  20: Train Acc=0.9967, Val Acc=0.9845, F1=0.9753
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9843, F1=0.9753
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9853, F1=0.9773
#   Early stopping at epoch 46
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9849, F1: 0.9766
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9900, Val Acc=0.9826, F1=0.9707
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9849, F1=0.9742
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9845, F1=0.9749
#   Early stopping at epoch 38
#   Best Val Acc: 0.9865
#
# [Gated-TPA Results]
#   Val Acc: 0.9865
#   Test Acc: 0.9856, F1: 0.9773
#
# [Progress: 6/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_10pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/SITTING_TO_STANDING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9562, Val Acc=0.9567, F1=0.9278
#   Epoch  20: Train Acc=0.9803, Val Acc=0.9812, F1=0.9704
#   Epoch  30: Train Acc=0.9882, Val Acc=0.9872, F1=0.9787
#   Epoch  40: Train Acc=0.9897, Val Acc=0.9890, F1=0.9826
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9921, F1=0.9864
#   Epoch  60: Train Acc=0.9935, Val Acc=0.9919, F1=0.9861
#   Epoch  70: Train Acc=0.9939, Val Acc=0.9911, F1=0.9850
#   Epoch  80: Train Acc=0.9949, Val Acc=0.9932, F1=0.9875
#   Epoch  90: Train Acc=0.9953, Val Acc=0.9928, F1=0.9874
#   Early stopping at epoch 99
#   Best Val Acc: 0.9932
#
# [GAP Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9902, F1: 0.9839
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9883, Val Acc=0.9851, F1=0.9736
#   Epoch  20: Train Acc=0.9959, Val Acc=0.9886, F1=0.9823
#   Epoch  30: Train Acc=0.9976, Val Acc=0.9897, F1=0.9842
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9909, F1=0.9863
#   Early stopping at epoch 49
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9846, F1: 0.9760
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9896, Val Acc=0.9880, F1=0.9789
#   Epoch  20: Train Acc=0.9962, Val Acc=0.9880, F1=0.9797
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9903, F1=0.9842
#   Epoch  40: Train Acc=0.9982, Val Acc=0.9874, F1=0.9793
#   Early stopping at epoch 44
#   Best Val Acc: 0.9907
#
# [Gated-TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9864, F1: 0.9798
#
# [Progress: 7/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_20pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/SITTING_TO_STANDING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9575, Val Acc=0.9594, F1=0.9319
#   Epoch  20: Train Acc=0.9795, Val Acc=0.9776, F1=0.9611
#   Epoch  30: Train Acc=0.9881, Val Acc=0.9849, F1=0.9726
#   Epoch  40: Train Acc=0.9901, Val Acc=0.9872, F1=0.9771
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9876, F1=0.9781
#   Epoch  60: Train Acc=0.9934, Val Acc=0.9888, F1=0.9804
#   Epoch  70: Train Acc=0.9939, Val Acc=0.9888, F1=0.9801
#   Epoch  80: Train Acc=0.9947, Val Acc=0.9882, F1=0.9794
#   Epoch  90: Train Acc=0.9952, Val Acc=0.9899, F1=0.9823
#   Epoch 100: Train Acc=0.9964, Val Acc=0.9888, F1=0.9802
#   Best Val Acc: 0.9905
#
# [GAP Results]
#   Val Acc: 0.9905
#   Test Acc: 0.9902, F1: 0.9840
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9900, Val Acc=0.9812, F1=0.9656
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9801, F1=0.9651
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9834, F1=0.9710
#   Epoch  40: Train Acc=0.9990, Val Acc=0.9847, F1=0.9757
#   Epoch  50: Train Acc=0.9994, Val Acc=0.9839, F1=0.9738
#   Epoch  60: Train Acc=0.9991, Val Acc=0.9849, F1=0.9758
#   Epoch  70: Train Acc=0.9994, Val Acc=0.9851, F1=0.9767
#   Early stopping at epoch 73
#   Best Val Acc: 0.9863
#
# [TPA Results]
#   Val Acc: 0.9863
#   Test Acc: 0.9839, F1: 0.9757
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9904, Val Acc=0.9843, F1=0.9702
#   Epoch  20: Train Acc=0.9973, Val Acc=0.9847, F1=0.9731
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9857, F1=0.9765
#   Epoch  40: Train Acc=0.9982, Val Acc=0.9855, F1=0.9763
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9874, F1=0.9787
#   Early stopping at epoch 58
#   Best Val Acc: 0.9876
#
# [Gated-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9836, F1: 0.9738
#
# [Progress: 8/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_30pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/SITTING_TO_STANDING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9552, Val Acc=0.9609, F1=0.9363
#   Epoch  20: Train Acc=0.9786, Val Acc=0.9810, F1=0.9679
#   Epoch  30: Train Acc=0.9851, Val Acc=0.9868, F1=0.9772
#   Epoch  40: Train Acc=0.9886, Val Acc=0.9880, F1=0.9798
#   Epoch  50: Train Acc=0.9897, Val Acc=0.9899, F1=0.9827
#   Epoch  60: Train Acc=0.9917, Val Acc=0.9901, F1=0.9832
#   Epoch  70: Train Acc=0.9935, Val Acc=0.9907, F1=0.9841
#   Epoch  80: Train Acc=0.9940, Val Acc=0.9905, F1=0.9832
#   Epoch  90: Train Acc=0.9950, Val Acc=0.9903, F1=0.9834
#   Epoch 100: Train Acc=0.9952, Val Acc=0.9905, F1=0.9835
#   Best Val Acc: 0.9923
#
# [GAP Results]
#   Val Acc: 0.9923
#   Test Acc: 0.9911, F1: 0.9849
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9879, Val Acc=0.9832, F1=0.9706
#   Epoch  20: Train Acc=0.9950, Val Acc=0.9841, F1=0.9726
#   Epoch  30: Train Acc=0.9968, Val Acc=0.9888, F1=0.9831
#   Epoch  40: Train Acc=0.9980, Val Acc=0.9874, F1=0.9803
#   Epoch  50: Train Acc=0.9981, Val Acc=0.9857, F1=0.9776
#   Early stopping at epoch 50
#   Best Val Acc: 0.9888
#
# [TPA Results]
#   Val Acc: 0.9888
#   Test Acc: 0.9844, F1: 0.9747
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9884, Val Acc=0.9834, F1=0.9727
#   Epoch  20: Train Acc=0.9972, Val Acc=0.9857, F1=0.9771
#   Epoch  30: Train Acc=0.9977, Val Acc=0.9872, F1=0.9801
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9834, F1=0.9740
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9834, F1=0.9743
#   Early stopping at epoch 50
#   Best Val Acc: 0.9872
#
# [Gated-TPA Results]
#   Val Acc: 0.9872
#   Test Acc: 0.9851, F1: 0.9746
#
# [Progress: 9/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_40pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/SITTING_TO_STANDING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9550, Val Acc=0.9578, F1=0.9295
#   Epoch  20: Train Acc=0.9781, Val Acc=0.9762, F1=0.9580
#   Epoch  30: Train Acc=0.9854, Val Acc=0.9826, F1=0.9685
#   Epoch  40: Train Acc=0.9883, Val Acc=0.9855, F1=0.9736
#   Epoch  50: Train Acc=0.9901, Val Acc=0.9886, F1=0.9801
#   Epoch  60: Train Acc=0.9915, Val Acc=0.9897, F1=0.9820
#   Epoch  70: Train Acc=0.9921, Val Acc=0.9901, F1=0.9820
#   Epoch  80: Train Acc=0.9937, Val Acc=0.9890, F1=0.9810
#   Epoch  90: Train Acc=0.9946, Val Acc=0.9897, F1=0.9827
#   Epoch 100: Train Acc=0.9956, Val Acc=0.9909, F1=0.9852
#   Best Val Acc: 0.9921
#
# [GAP Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9907, F1: 0.9835
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9910, Val Acc=0.9810, F1=0.9691
#   Epoch  20: Train Acc=0.9958, Val Acc=0.9826, F1=0.9737
#   Epoch  30: Train Acc=0.9974, Val Acc=0.9843, F1=0.9765
#   Epoch  40: Train Acc=0.9985, Val Acc=0.9845, F1=0.9778
#   Early stopping at epoch 49
#   Best Val Acc: 0.9849
#
# [TPA Results]
#   Val Acc: 0.9849
#   Test Acc: 0.9863, F1: 0.9765
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9906, Val Acc=0.9849, F1=0.9735
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9845, F1=0.9754
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9847, F1=0.9759
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9841, F1=0.9760
#   Early stopping at epoch 44
#   Best Val Acc: 0.9861
#
# [Gated-TPA Results]
#   Val Acc: 0.9861
#   Test Acc: 0.9838, F1: 0.9732
#
# [Progress: 10/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_WALKING_10pct
# ================================================================================
#
# Loading STANDING_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_WALKING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9621, Val Acc=0.9704, F1=0.9565
#   Epoch  20: Train Acc=0.9824, Val Acc=0.9847, F1=0.9778
#   Epoch  30: Train Acc=0.9875, Val Acc=0.9892, F1=0.9829
#   Epoch  40: Train Acc=0.9899, Val Acc=0.9905, F1=0.9849
#   Epoch  50: Train Acc=0.9923, Val Acc=0.9925, F1=0.9892
#   Epoch  60: Train Acc=0.9943, Val Acc=0.9930, F1=0.9895
#   Epoch  70: Train Acc=0.9950, Val Acc=0.9932, F1=0.9904
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9930, F1=0.9897
#   Epoch  90: Train Acc=0.9962, Val Acc=0.9936, F1=0.9908
#   Epoch 100: Train Acc=0.9968, Val Acc=0.9942, F1=0.9920
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9919, F1: 0.9874
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9907, Val Acc=0.9882, F1=0.9805
#   Epoch  20: Train Acc=0.9950, Val Acc=0.9886, F1=0.9830
#   Epoch  30: Train Acc=0.9976, Val Acc=0.9880, F1=0.9818
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9888, F1=0.9831
#   Early stopping at epoch 42
#   Best Val Acc: 0.9903
#
# [TPA Results]
#   Val Acc: 0.9903
#   Test Acc: 0.9874, F1: 0.9804
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9882, Val Acc=0.9826, F1=0.9742
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9861, F1=0.9796
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9859, F1=0.9792
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9857, F1=0.9794
#   Early stopping at epoch 42
#   Best Val Acc: 0.9880
#
# [Gated-TPA Results]
#   Val Acc: 0.9880
#   Test Acc: 0.9856, F1: 0.9768
#
# [Progress: 11/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_WALKING_20pct
# ================================================================================
#
# Loading STANDING_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_WALKING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9611, Val Acc=0.9673, F1=0.9488
#   Epoch  20: Train Acc=0.9823, Val Acc=0.9826, F1=0.9716
#   Epoch  30: Train Acc=0.9879, Val Acc=0.9878, F1=0.9797
#   Epoch  40: Train Acc=0.9900, Val Acc=0.9882, F1=0.9801
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9897, F1=0.9827
#   Epoch  60: Train Acc=0.9935, Val Acc=0.9919, F1=0.9879
#   Epoch  70: Train Acc=0.9943, Val Acc=0.9923, F1=0.9880
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9925, F1=0.9892
#   Epoch  90: Train Acc=0.9960, Val Acc=0.9928, F1=0.9884
#   Early stopping at epoch 96
#   Best Val Acc: 0.9938
#
# [GAP Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9937, F1: 0.9906
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9919, Val Acc=0.9837, F1=0.9732
#   Epoch  20: Train Acc=0.9972, Val Acc=0.9855, F1=0.9783
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9855, F1=0.9783
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9865, F1=0.9794
#   Early stopping at epoch 44
#   Best Val Acc: 0.9878
#
# [TPA Results]
#   Val Acc: 0.9878
#   Test Acc: 0.9864, F1: 0.9798
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9890, Val Acc=0.9803, F1=0.9684
#   Epoch  20: Train Acc=0.9962, Val Acc=0.9870, F1=0.9818
#   Epoch  30: Train Acc=0.9984, Val Acc=0.9857, F1=0.9802
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9859, F1=0.9792
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9868, F1=0.9799
#   Epoch  60: Train Acc=0.9990, Val Acc=0.9861, F1=0.9797
#   Epoch  70: Train Acc=0.9992, Val Acc=0.9851, F1=0.9765
#   Early stopping at epoch 76
#   Best Val Acc: 0.9886
#
# [Gated-TPA Results]
#   Val Acc: 0.9886
#   Test Acc: 0.9823, F1: 0.9743
#
# [Progress: 12/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_WALKING_30pct
# ================================================================================
#
# Loading STANDING_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_WALKING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9602, Val Acc=0.9605, F1=0.9386
#   Epoch  20: Train Acc=0.9818, Val Acc=0.9801, F1=0.9680
#   Epoch  30: Train Acc=0.9874, Val Acc=0.9849, F1=0.9762
#   Epoch  40: Train Acc=0.9897, Val Acc=0.9870, F1=0.9780
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9894, F1=0.9837
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9909, F1=0.9857
#   Epoch  70: Train Acc=0.9955, Val Acc=0.9894, F1=0.9823
#   Epoch  80: Train Acc=0.9955, Val Acc=0.9909, F1=0.9856
#   Epoch  90: Train Acc=0.9958, Val Acc=0.9913, F1=0.9860
#   Epoch 100: Train Acc=0.9965, Val Acc=0.9919, F1=0.9875
#   Best Val Acc: 0.9923
#
# [GAP Results]
#   Val Acc: 0.9923
#   Test Acc: 0.9919, F1: 0.9870
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9912, Val Acc=0.9808, F1=0.9685
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9853, F1=0.9771
#   Epoch  30: Train Acc=0.9984, Val Acc=0.9870, F1=0.9796
#   Epoch  40: Train Acc=0.9993, Val Acc=0.9837, F1=0.9742
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9849, F1=0.9766
#   Early stopping at epoch 50
#   Best Val Acc: 0.9870
#
# [TPA Results]
#   Val Acc: 0.9870
#   Test Acc: 0.9859, F1: 0.9790
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9883, Val Acc=0.9799, F1=0.9675
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9847, F1=0.9759
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9834, F1=0.9729
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9849, F1=0.9775
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9851, F1=0.9778
#   Early stopping at epoch 58
#   Best Val Acc: 0.9865
#
# [Gated-TPA Results]
#   Val Acc: 0.9865
#   Test Acc: 0.9861, F1: 0.9801
#
# [Progress: 13/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_WALKING_40pct
# ================================================================================
#
# Loading STANDING_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/STANDING_TO_WALKING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9595, Val Acc=0.9652, F1=0.9461
#   Epoch  20: Train Acc=0.9789, Val Acc=0.9834, F1=0.9737
#   Epoch  30: Train Acc=0.9862, Val Acc=0.9878, F1=0.9795
#   Epoch  40: Train Acc=0.9892, Val Acc=0.9888, F1=0.9818
#   Epoch  50: Train Acc=0.9910, Val Acc=0.9899, F1=0.9833
#   Epoch  60: Train Acc=0.9924, Val Acc=0.9915, F1=0.9865
#   Epoch  70: Train Acc=0.9942, Val Acc=0.9917, F1=0.9867
#   Epoch  80: Train Acc=0.9950, Val Acc=0.9919, F1=0.9873
#   Epoch  90: Train Acc=0.9957, Val Acc=0.9928, F1=0.9887
#   Epoch 100: Train Acc=0.9959, Val Acc=0.9925, F1=0.9880
#   Best Val Acc: 0.9928
#
# [GAP Results]
#   Val Acc: 0.9928
#   Test Acc: 0.9906, F1: 0.9852
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9907, Val Acc=0.9839, F1=0.9744
#   Epoch  20: Train Acc=0.9957, Val Acc=0.9851, F1=0.9762
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9865, F1=0.9794
#   Epoch  40: Train Acc=0.9984, Val Acc=0.9855, F1=0.9764
#   Early stopping at epoch 47
#   Best Val Acc: 0.9880
#
# [TPA Results]
#   Val Acc: 0.9880
#   Test Acc: 0.9831, F1: 0.9761
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9883, Val Acc=0.9837, F1=0.9740
#   Epoch  20: Train Acc=0.9959, Val Acc=0.9882, F1=0.9810
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9872, F1=0.9792
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9882, F1=0.9817
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9853, F1=0.9746
#   Early stopping at epoch 59
#   Best Val Acc: 0.9890
#
# [Gated-TPA Results]
#   Val Acc: 0.9890
#   Test Acc: 0.9856, F1: 0.9787
#
# [Progress: 14/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_STANDING_10pct
# ================================================================================
#
# Loading WALKING_TO_STANDING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_STANDING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9608, Val Acc=0.9667, F1=0.9470
#   Epoch  20: Train Acc=0.9819, Val Acc=0.9828, F1=0.9678
#   Epoch  30: Train Acc=0.9878, Val Acc=0.9855, F1=0.9720
#   Epoch  40: Train Acc=0.9901, Val Acc=0.9882, F1=0.9758
#   Epoch  50: Train Acc=0.9927, Val Acc=0.9892, F1=0.9809
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9901, F1=0.9820
#   Epoch  70: Train Acc=0.9949, Val Acc=0.9913, F1=0.9847
#   Epoch  80: Train Acc=0.9962, Val Acc=0.9925, F1=0.9860
#   Epoch  90: Train Acc=0.9970, Val Acc=0.9915, F1=0.9842
#   Epoch 100: Train Acc=0.9971, Val Acc=0.9923, F1=0.9857
#   Best Val Acc: 0.9938
#
# [GAP Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9932, F1: 0.9881
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9928, Val Acc=0.9839, F1=0.9687
#   Epoch  20: Train Acc=0.9963, Val Acc=0.9859, F1=0.9706
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9843, F1=0.9690
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9849, F1=0.9697
#   Epoch  50: Train Acc=0.9994, Val Acc=0.9882, F1=0.9791
#   Early stopping at epoch 55
#   Best Val Acc: 0.9886
#
# [TPA Results]
#   Val Acc: 0.9886
#   Test Acc: 0.9874, F1: 0.9807
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9917, Val Acc=0.9832, F1=0.9673
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9845, F1=0.9694
#   Epoch  30: Train Acc=0.9974, Val Acc=0.9870, F1=0.9779
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9851, F1=0.9744
#   Epoch  50: Train Acc=0.9985, Val Acc=0.9880, F1=0.9792
#   Epoch  60: Train Acc=0.9991, Val Acc=0.9855, F1=0.9757
#   Early stopping at epoch 66
#   Best Val Acc: 0.9886
#
# [Gated-TPA Results]
#   Val Acc: 0.9886
#   Test Acc: 0.9876, F1: 0.9802
#
# [Progress: 15/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_STANDING_20pct
# ================================================================================
#
# Loading WALKING_TO_STANDING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_STANDING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9611, Val Acc=0.9640, F1=0.9417
#   Epoch  20: Train Acc=0.9826, Val Acc=0.9849, F1=0.9718
#   Epoch  30: Train Acc=0.9876, Val Acc=0.9884, F1=0.9763
#   Epoch  40: Train Acc=0.9904, Val Acc=0.9919, F1=0.9855
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9942, F1=0.9897
#   Epoch  60: Train Acc=0.9940, Val Acc=0.9948, F1=0.9908
#   Epoch  70: Train Acc=0.9952, Val Acc=0.9946, F1=0.9897
#   Epoch  80: Train Acc=0.9954, Val Acc=0.9948, F1=0.9910
#   Epoch  90: Train Acc=0.9965, Val Acc=0.9938, F1=0.9887
#   Epoch 100: Train Acc=0.9968, Val Acc=0.9944, F1=0.9893
#   Best Val Acc: 0.9957
#
# [GAP Results]
#   Val Acc: 0.9957
#   Test Acc: 0.9934, F1: 0.9888
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9911, Val Acc=0.9847, F1=0.9666
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9853, F1=0.9677
#   Epoch  30: Train Acc=0.9977, Val Acc=0.9870, F1=0.9736
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9876, F1=0.9768
#   Epoch  50: Train Acc=0.9993, Val Acc=0.9888, F1=0.9795
#   Epoch  60: Train Acc=0.9993, Val Acc=0.9882, F1=0.9776
#   Early stopping at epoch 69
#   Best Val Acc: 0.9897
#
# [TPA Results]
#   Val Acc: 0.9897
#   Test Acc: 0.9866, F1: 0.9791
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9908, Val Acc=0.9865, F1=0.9709
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9888, F1=0.9780
#   Epoch  30: Train Acc=0.9984, Val Acc=0.9907, F1=0.9834
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9894, F1=0.9815
#   Early stopping at epoch 43
#   Best Val Acc: 0.9907
#
# [Gated-TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9873, F1: 0.9782
#
# [Progress: 16/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_STANDING_30pct
# ================================================================================
#
# Loading WALKING_TO_STANDING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_STANDING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9625, Val Acc=0.9663, F1=0.9449
#   Epoch  20: Train Acc=0.9831, Val Acc=0.9855, F1=0.9714
#   Epoch  30: Train Acc=0.9887, Val Acc=0.9861, F1=0.9728
#   Epoch  40: Train Acc=0.9912, Val Acc=0.9901, F1=0.9798
#   Epoch  50: Train Acc=0.9931, Val Acc=0.9903, F1=0.9807
#   Epoch  60: Train Acc=0.9946, Val Acc=0.9921, F1=0.9849
#   Epoch  70: Train Acc=0.9958, Val Acc=0.9919, F1=0.9842
#   Epoch  80: Train Acc=0.9962, Val Acc=0.9928, F1=0.9866
#   Early stopping at epoch 83
#   Best Val Acc: 0.9938
#
# [GAP Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9899, F1: 0.9829
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9935, Val Acc=0.9832, F1=0.9676
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9841, F1=0.9716
#   Epoch  30: Train Acc=0.9986, Val Acc=0.9861, F1=0.9762
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9857, F1=0.9754
#   Epoch  50: Train Acc=0.9991, Val Acc=0.9863, F1=0.9775
#   Epoch  60: Train Acc=0.9995, Val Acc=0.9868, F1=0.9783
#   Epoch  70: Train Acc=0.9994, Val Acc=0.9868, F1=0.9763
#   Epoch  80: Train Acc=0.9995, Val Acc=0.9863, F1=0.9767
#   Epoch  90: Train Acc=0.9995, Val Acc=0.9868, F1=0.9783
#   Epoch 100: Train Acc=0.9996, Val Acc=0.9861, F1=0.9778
#   Best Val Acc: 0.9880
#
# [TPA Results]
#   Val Acc: 0.9880
#   Test Acc: 0.9833, F1: 0.9722
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9921, Val Acc=0.9853, F1=0.9737
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9863, F1=0.9777
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9868, F1=0.9776
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9872, F1=0.9783
#   Epoch  50: Train Acc=0.9995, Val Acc=0.9859, F1=0.9760
#   Early stopping at epoch 57
#   Best Val Acc: 0.9888
#
# [Gated-TPA Results]
#   Val Acc: 0.9888
#   Test Acc: 0.9861, F1: 0.9758
#
# [Progress: 17/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_STANDING_40pct
# ================================================================================
#
# Loading WALKING_TO_STANDING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_STANDING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9612, Val Acc=0.9615, F1=0.9404
#   Epoch  20: Train Acc=0.9822, Val Acc=0.9830, F1=0.9711
#   Epoch  30: Train Acc=0.9878, Val Acc=0.9859, F1=0.9741
#   Epoch  40: Train Acc=0.9905, Val Acc=0.9901, F1=0.9844
#   Epoch  50: Train Acc=0.9931, Val Acc=0.9915, F1=0.9853
#   Epoch  60: Train Acc=0.9940, Val Acc=0.9925, F1=0.9872
#   Epoch  70: Train Acc=0.9956, Val Acc=0.9923, F1=0.9870
#   Epoch  80: Train Acc=0.9961, Val Acc=0.9936, F1=0.9890
#   Epoch  90: Train Acc=0.9967, Val Acc=0.9938, F1=0.9893
#   Early stopping at epoch 98
#   Best Val Acc: 0.9938
#
# [GAP Results]
#   Val Acc: 0.9938
#   Test Acc: 0.9904, F1: 0.9817
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9933, Val Acc=0.9830, F1=0.9664
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9870, F1=0.9739
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9876, F1=0.9773
#   Early stopping at epoch 31
#   Best Val Acc: 0.9882
#
# [TPA Results]
#   Val Acc: 0.9882
#   Test Acc: 0.9820, F1: 0.9670
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9920, Val Acc=0.9824, F1=0.9681
#   Epoch  20: Train Acc=0.9970, Val Acc=0.9874, F1=0.9798
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9861, F1=0.9759
#   Epoch  40: Train Acc=0.9980, Val Acc=0.9859, F1=0.9763
#   Early stopping at epoch 45
#   Best Val Acc: 0.9878
#
# [Gated-TPA Results]
#   Val Acc: 0.9878
#   Test Acc: 0.9833, F1: 0.9721
#
# [Progress: 18/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_JOGGING_10pct
# ================================================================================
#
# Loading WALKING_TO_JOGGING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_JOGGING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9617, Val Acc=0.9607, F1=0.9349
#   Epoch  20: Train Acc=0.9819, Val Acc=0.9820, F1=0.9645
#   Epoch  30: Train Acc=0.9884, Val Acc=0.9878, F1=0.9729
#   Epoch  40: Train Acc=0.9905, Val Acc=0.9919, F1=0.9854
#   Epoch  50: Train Acc=0.9927, Val Acc=0.9934, F1=0.9877
#   Epoch  60: Train Acc=0.9945, Val Acc=0.9940, F1=0.9900
#   Epoch  70: Train Acc=0.9952, Val Acc=0.9936, F1=0.9894
#   Epoch  80: Train Acc=0.9957, Val Acc=0.9950, F1=0.9905
#   Epoch  90: Train Acc=0.9962, Val Acc=0.9950, F1=0.9915
#   Epoch 100: Train Acc=0.9972, Val Acc=0.9952, F1=0.9916
#   Best Val Acc: 0.9957
#
# [GAP Results]
#   Val Acc: 0.9957
#   Test Acc: 0.9894, F1: 0.9822
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9930, Val Acc=0.9828, F1=0.9666
#   Epoch  20: Train Acc=0.9969, Val Acc=0.9857, F1=0.9765
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9863, F1=0.9771
#   Epoch  40: Train Acc=0.9995, Val Acc=0.9861, F1=0.9779
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9859, F1=0.9771
#   Early stopping at epoch 57
#   Best Val Acc: 0.9876
#
# [TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9864, F1: 0.9785
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9916, Val Acc=0.9822, F1=0.9637
#   Epoch  20: Train Acc=0.9975, Val Acc=0.9859, F1=0.9777
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9843, F1=0.9746
#   Epoch  40: Train Acc=0.9993, Val Acc=0.9872, F1=0.9792
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9863, F1=0.9788
#   Epoch  60: Train Acc=0.9995, Val Acc=0.9849, F1=0.9765
#   Epoch  70: Train Acc=0.9995, Val Acc=0.9853, F1=0.9772
#   Early stopping at epoch 78
#   Best Val Acc: 0.9878
#
# [Gated-TPA Results]
#   Val Acc: 0.9878
#   Test Acc: 0.9846, F1: 0.9745
#
# [Progress: 19/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_JOGGING_20pct
# ================================================================================
#
# Loading WALKING_TO_JOGGING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_JOGGING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9592, Val Acc=0.9640, F1=0.9417
#   Epoch  20: Train Acc=0.9804, Val Acc=0.9824, F1=0.9700
#   Epoch  30: Train Acc=0.9867, Val Acc=0.9859, F1=0.9749
#   Epoch  40: Train Acc=0.9894, Val Acc=0.9909, F1=0.9856
#   Epoch  50: Train Acc=0.9918, Val Acc=0.9917, F1=0.9859
#   Epoch  60: Train Acc=0.9937, Val Acc=0.9928, F1=0.9875
#   Epoch  70: Train Acc=0.9949, Val Acc=0.9925, F1=0.9872
#   Early stopping at epoch 76
#   Best Val Acc: 0.9930
#
# [GAP Results]
#   Val Acc: 0.9930
#   Test Acc: 0.9912, F1: 0.9849
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9922, Val Acc=0.9810, F1=0.9672
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9824, F1=0.9693
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9841, F1=0.9752
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9849, F1=0.9761
#   Epoch  50: Train Acc=0.9986, Val Acc=0.9816, F1=0.9699
#   Epoch  60: Train Acc=0.9992, Val Acc=0.9830, F1=0.9722
#   Early stopping at epoch 60
#   Best Val Acc: 0.9849
#
# [TPA Results]
#   Val Acc: 0.9849
#   Test Acc: 0.9859, F1: 0.9779
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9894, Val Acc=0.9793, F1=0.9619
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9810, F1=0.9655
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9814, F1=0.9700
#   Early stopping at epoch 35
#   Best Val Acc: 0.9834
#
# [Gated-TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9866, F1: 0.9756
#
# [Progress: 20/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_JOGGING_30pct
# ================================================================================
#
# Loading WALKING_TO_JOGGING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_JOGGING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9606, Val Acc=0.9599, F1=0.9353
#   Epoch  20: Train Acc=0.9816, Val Acc=0.9805, F1=0.9667
#   Epoch  30: Train Acc=0.9874, Val Acc=0.9853, F1=0.9725
#   Epoch  40: Train Acc=0.9895, Val Acc=0.9878, F1=0.9767
#   Epoch  50: Train Acc=0.9923, Val Acc=0.9886, F1=0.9812
#   Epoch  60: Train Acc=0.9944, Val Acc=0.9901, F1=0.9840
#   Epoch  70: Train Acc=0.9952, Val Acc=0.9911, F1=0.9857
#   Epoch  80: Train Acc=0.9959, Val Acc=0.9899, F1=0.9833
#   Epoch  90: Train Acc=0.9971, Val Acc=0.9907, F1=0.9852
#   Epoch 100: Train Acc=0.9962, Val Acc=0.9903, F1=0.9841
#   Best Val Acc: 0.9921
#
# [GAP Results]
#   Val Acc: 0.9921
#   Test Acc: 0.9904, F1: 0.9824
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9912, Val Acc=0.9830, F1=0.9697
#   Epoch  20: Train Acc=0.9967, Val Acc=0.9834, F1=0.9709
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9859, F1=0.9774
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9851, F1=0.9770
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9857, F1=0.9781
#   Early stopping at epoch 50
#   Best Val Acc: 0.9859
#
# [TPA Results]
#   Val Acc: 0.9859
#   Test Acc: 0.9854, F1: 0.9763
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9899, Val Acc=0.9830, F1=0.9700
#   Epoch  20: Train Acc=0.9969, Val Acc=0.9853, F1=0.9766
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9868, F1=0.9797
#   Epoch  40: Train Acc=0.9985, Val Acc=0.9872, F1=0.9809
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9868, F1=0.9786
#   Epoch  60: Train Acc=0.9984, Val Acc=0.9830, F1=0.9734
#   Early stopping at epoch 67
#   Best Val Acc: 0.9882
#
# [Gated-TPA Results]
#   Val Acc: 0.9882
#   Test Acc: 0.9858, F1: 0.9764
#
# [Progress: 21/41]
#
# ================================================================================
# EXPERIMENT: WALKING_TO_JOGGING_40pct
# ================================================================================
#
# Loading WALKING_TO_JOGGING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/WALKING_TO_JOGGING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9580, Val Acc=0.9636, F1=0.9421
#   Epoch  20: Train Acc=0.9799, Val Acc=0.9816, F1=0.9675
#   Epoch  30: Train Acc=0.9862, Val Acc=0.9845, F1=0.9712
#   Epoch  40: Train Acc=0.9895, Val Acc=0.9878, F1=0.9804
#   Epoch  50: Train Acc=0.9911, Val Acc=0.9884, F1=0.9811
#   Epoch  60: Train Acc=0.9927, Val Acc=0.9888, F1=0.9823
#   Epoch  70: Train Acc=0.9942, Val Acc=0.9901, F1=0.9838
#   Epoch  80: Train Acc=0.9938, Val Acc=0.9901, F1=0.9848
#   Early stopping at epoch 81
#   Best Val Acc: 0.9907
#
# [GAP Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9884, F1: 0.9815
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9910, Val Acc=0.9826, F1=0.9679
#   Epoch  20: Train Acc=0.9959, Val Acc=0.9837, F1=0.9691
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9769
#   Early stopping at epoch 36
#   Best Val Acc: 0.9855
#
# [TPA Results]
#   Val Acc: 0.9855
#   Test Acc: 0.9818, F1: 0.9669
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9888, Val Acc=0.9814, F1=0.9649
#   Epoch  20: Train Acc=0.9967, Val Acc=0.9808, F1=0.9626
#   Epoch  30: Train Acc=0.9980, Val Acc=0.9863, F1=0.9780
#   Epoch  40: Train Acc=0.9990, Val Acc=0.9847, F1=0.9756
#   Epoch  50: Train Acc=0.9986, Val Acc=0.9861, F1=0.9770
#   Epoch  60: Train Acc=0.9988, Val Acc=0.9857, F1=0.9754
#   Early stopping at epoch 61
#   Best Val Acc: 0.9870
#
# [Gated-TPA Results]
#   Val Acc: 0.9870
#   Test Acc: 0.9858, F1: 0.9762
#
# [Progress: 22/41]
#
# ================================================================================
# EXPERIMENT: JOGGING_TO_WALKING_10pct
# ================================================================================
#
# Loading JOGGING_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/JOGGING_TO_WALKING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9598, Val Acc=0.9652, F1=0.9414
#   Epoch  20: Train Acc=0.9824, Val Acc=0.9830, F1=0.9671
#   Epoch  30: Train Acc=0.9886, Val Acc=0.9870, F1=0.9723
#   Epoch  40: Train Acc=0.9901, Val Acc=0.9872, F1=0.9730
#   Epoch  50: Train Acc=0.9927, Val Acc=0.9878, F1=0.9742
#   Epoch  60: Train Acc=0.9939, Val Acc=0.9907, F1=0.9835
#   Epoch  70: Train Acc=0.9954, Val Acc=0.9911, F1=0.9843
#   Epoch  80: Train Acc=0.9956, Val Acc=0.9936, F1=0.9885
#   Epoch  90: Train Acc=0.9960, Val Acc=0.9899, F1=0.9822
#   Epoch 100: Train Acc=0.9970, Val Acc=0.9928, F1=0.9868
#   Best Val Acc: 0.9940
#
# [GAP Results]
#   Val Acc: 0.9940
#   Test Acc: 0.9912, F1: 0.9856
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9926, Val Acc=0.9843, F1=0.9676
#   Epoch  20: Train Acc=0.9963, Val Acc=0.9847, F1=0.9696
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9855, F1=0.9740
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9872, F1=0.9791
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9853, F1=0.9740
#   Early stopping at epoch 53
#   Best Val Acc: 0.9874
#
# [TPA Results]
#   Val Acc: 0.9874
#   Test Acc: 0.9859, F1: 0.9757
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9916, Val Acc=0.9820, F1=0.9658
#   Epoch  20: Train Acc=0.9975, Val Acc=0.9853, F1=0.9747
#   Epoch  30: Train Acc=0.9987, Val Acc=0.9863, F1=0.9776
#   Epoch  40: Train Acc=0.9994, Val Acc=0.9841, F1=0.9738
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9865, F1=0.9784
#   Epoch  60: Train Acc=0.9994, Val Acc=0.9847, F1=0.9738
#   Early stopping at epoch 61
#   Best Val Acc: 0.9876
#
# [Gated-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9849, F1: 0.9749
#
# [Progress: 23/41]
#
# ================================================================================
# EXPERIMENT: JOGGING_TO_WALKING_20pct
# ================================================================================
#
# Loading JOGGING_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/JOGGING_TO_WALKING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9588, Val Acc=0.9632, F1=0.9416
#   Epoch  20: Train Acc=0.9810, Val Acc=0.9783, F1=0.9623
#   Epoch  30: Train Acc=0.9870, Val Acc=0.9830, F1=0.9690
#   Epoch  40: Train Acc=0.9900, Val Acc=0.9878, F1=0.9791
#   Epoch  50: Train Acc=0.9922, Val Acc=0.9861, F1=0.9731
#   Epoch  60: Train Acc=0.9934, Val Acc=0.9886, F1=0.9806
#   Epoch  70: Train Acc=0.9946, Val Acc=0.9882, F1=0.9796
#   Epoch  80: Train Acc=0.9959, Val Acc=0.9903, F1=0.9826
#   Epoch  90: Train Acc=0.9957, Val Acc=0.9892, F1=0.9809
#   Epoch 100: Train Acc=0.9964, Val Acc=0.9901, F1=0.9826
#   Best Val Acc: 0.9917
#
# [GAP Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9935, F1: 0.9891
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9916, Val Acc=0.9776, F1=0.9555
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9824, F1=0.9670
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9828, F1=0.9697
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9861, F1=0.9789
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9837, F1=0.9745
#   Epoch  60: Train Acc=0.9991, Val Acc=0.9837, F1=0.9738
#   Early stopping at epoch 60
#   Best Val Acc: 0.9861
#
# [TPA Results]
#   Val Acc: 0.9861
#   Test Acc: 0.9873, F1: 0.9801
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9905, Val Acc=0.9828, F1=0.9682
#   Epoch  20: Train Acc=0.9960, Val Acc=0.9865, F1=0.9742
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9855, F1=0.9773
#   Epoch  40: Train Acc=0.9982, Val Acc=0.9878, F1=0.9810
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9847, F1=0.9763
#   Epoch  60: Train Acc=0.9993, Val Acc=0.9863, F1=0.9774
#   Epoch  70: Train Acc=0.9993, Val Acc=0.9855, F1=0.9757
#   Early stopping at epoch 74
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9868, F1: 0.9786
#
# [Progress: 24/41]
#
# ================================================================================
# EXPERIMENT: JOGGING_TO_WALKING_30pct
# ================================================================================
#
# Loading JOGGING_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/JOGGING_TO_WALKING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9590, Val Acc=0.9596, F1=0.9310
#   Epoch  20: Train Acc=0.9813, Val Acc=0.9799, F1=0.9605
#   Epoch  30: Train Acc=0.9871, Val Acc=0.9861, F1=0.9704
#   Epoch  40: Train Acc=0.9898, Val Acc=0.9874, F1=0.9729
#   Epoch  50: Train Acc=0.9916, Val Acc=0.9909, F1=0.9840
#   Epoch  60: Train Acc=0.9935, Val Acc=0.9903, F1=0.9826
#   Epoch  70: Train Acc=0.9940, Val Acc=0.9905, F1=0.9832
#   Epoch  80: Train Acc=0.9951, Val Acc=0.9911, F1=0.9847
#   Epoch  90: Train Acc=0.9958, Val Acc=0.9919, F1=0.9858
#   Epoch 100: Train Acc=0.9961, Val Acc=0.9911, F1=0.9846
#   Best Val Acc: 0.9923
#
# [GAP Results]
#   Val Acc: 0.9923
#   Test Acc: 0.9927, F1: 0.9883
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9918, Val Acc=0.9810, F1=0.9636
#   Epoch  20: Train Acc=0.9966, Val Acc=0.9808, F1=0.9647
#   Epoch  30: Train Acc=0.9976, Val Acc=0.9822, F1=0.9670
#   Epoch  40: Train Acc=0.9984, Val Acc=0.9839, F1=0.9760
#   Early stopping at epoch 45
#   Best Val Acc: 0.9849
#
# [TPA Results]
#   Val Acc: 0.9849
#   Test Acc: 0.9828, F1: 0.9721
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9914, Val Acc=0.9799, F1=0.9625
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9843, F1=0.9750
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9845, F1=0.9754
#   Early stopping at epoch 39
#   Best Val Acc: 0.9849
#
# [Gated-TPA Results]
#   Val Acc: 0.9849
#   Test Acc: 0.9853, F1: 0.9762
#
# [Progress: 25/41]
#
# ================================================================================
# EXPERIMENT: JOGGING_TO_WALKING_40pct
# ================================================================================
#
# Loading JOGGING_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/JOGGING_TO_WALKING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9592, Val Acc=0.9584, F1=0.9357
#   Epoch  20: Train Acc=0.9800, Val Acc=0.9812, F1=0.9683
#   Epoch  30: Train Acc=0.9871, Val Acc=0.9853, F1=0.9748
#   Epoch  40: Train Acc=0.9904, Val Acc=0.9878, F1=0.9799
#   Epoch  50: Train Acc=0.9919, Val Acc=0.9878, F1=0.9786
#   Epoch  60: Train Acc=0.9932, Val Acc=0.9888, F1=0.9816
#   Epoch  70: Train Acc=0.9945, Val Acc=0.9888, F1=0.9822
#   Epoch  80: Train Acc=0.9954, Val Acc=0.9892, F1=0.9817
#   Early stopping at epoch 89
#   Best Val Acc: 0.9903
#
# [GAP Results]
#   Val Acc: 0.9903
# ...
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9556, Val Acc=0.9636, F1=0.9464
#   Epoch  20: Train Acc=0.9819, Val Acc=0.9818, F1=0.9711
#   Epoch  30: Train Acc=0.9865, Val Acc=0.9888, F1=0.9783
#   Epoch  40: Train Acc=0.9899, Val Acc=0.9899, F1=0.9797
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9938, F1=0.9911
#   Epoch  60: Train Acc=0.9937, Val Acc=0.9919, F1=0.9843
#   Epoch  70: Train Acc=0.9945, Val Acc=0.9940, F1=0.9912
#   Epoch  80: Train Acc=0.9953, Val Acc=0.9942, F1=0.9913
#   Early stopping at epoch 82
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9929, F1: 0.9885
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9917, Val Acc=0.9822, F1=0.9689
#   Epoch  20: Train Acc=0.9963, Val Acc=0.9837, F1=0.9724
#   Epoch  30: Train Acc=0.9981, Val Acc=0.9878, F1=0.9835
#   Epoch  40: Train Acc=0.9990, Val Acc=0.9870, F1=0.9810
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9843, F1=0.9729
#   Early stopping at epoch 54
#   Best Val Acc: 0.9882
#
# [TPA Results]
#   Val Acc: 0.9882
#   Test Acc: 0.9871, F1: 0.9824
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9909, Val Acc=0.9820, F1=0.9694
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9863, F1=0.9753
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9853, F1=0.9761
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9859, F1=0.9801
#   Epoch  50: Train Acc=0.9990, Val Acc=0.9870, F1=0.9808
#   Epoch  60: Train Acc=0.9994, Val Acc=0.9861, F1=0.9803
#   Epoch  70: Train Acc=0.9996, Val Acc=0.9876, F1=0.9818
#   Epoch  80: Train Acc=0.9995, Val Acc=0.9878, F1=0.9826
#   Early stopping at epoch 87
#   Best Val Acc: 0.9890
#
# [Gated-TPA Results]
#   Val Acc: 0.9890
#   Test Acc: 0.9861, F1: 0.9789
#
# [Progress: 35/41]
#
# ================================================================================
# EXPERIMENT: UPSTAIRS_TO_WALKING_20pct
# ================================================================================
#
# Loading UPSTAIRS_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/UPSTAIRS_TO_WALKING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9542, Val Acc=0.9576, F1=0.9384
#   Epoch  20: Train Acc=0.9803, Val Acc=0.9801, F1=0.9684
#   Epoch  30: Train Acc=0.9868, Val Acc=0.9843, F1=0.9738
#   Epoch  40: Train Acc=0.9906, Val Acc=0.9880, F1=0.9841
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9886, F1=0.9847
#   Epoch  60: Train Acc=0.9937, Val Acc=0.9884, F1=0.9847
#   Epoch  70: Train Acc=0.9944, Val Acc=0.9901, F1=0.9869
#   Epoch  80: Train Acc=0.9952, Val Acc=0.9894, F1=0.9866
#   Early stopping at epoch 83
#   Best Val Acc: 0.9905
#
# [GAP Results]
#   Val Acc: 0.9905
#   Test Acc: 0.9925, F1: 0.9896
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9906, Val Acc=0.9801, F1=0.9692
#   Epoch  20: Train Acc=0.9957, Val Acc=0.9799, F1=0.9691
#   Epoch  30: Train Acc=0.9972, Val Acc=0.9832, F1=0.9767
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9824, F1=0.9754
#   Epoch  50: Train Acc=0.9991, Val Acc=0.9832, F1=0.9760
#   Early stopping at epoch 53
#   Best Val Acc: 0.9841
#
# [TPA Results]
#   Val Acc: 0.9841
#   Test Acc: 0.9859, F1: 0.9783
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9905, Val Acc=0.9799, F1=0.9656
#   Epoch  20: Train Acc=0.9963, Val Acc=0.9810, F1=0.9682
#   Epoch  30: Train Acc=0.9986, Val Acc=0.9805, F1=0.9739
#   Epoch  40: Train Acc=0.9989, Val Acc=0.9803, F1=0.9730
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9816, F1=0.9756
#   Early stopping at epoch 51
#   Best Val Acc: 0.9837
#
# [Gated-TPA Results]
#   Val Acc: 0.9837
#   Test Acc: 0.9841, F1: 0.9759
#
# [Progress: 36/41]
#
# ================================================================================
# EXPERIMENT: UPSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading UPSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/UPSTAIRS_TO_WALKING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9513, Val Acc=0.9582, F1=0.9438
#   Epoch  20: Train Acc=0.9789, Val Acc=0.9791, F1=0.9710
#   Epoch  30: Train Acc=0.9853, Val Acc=0.9843, F1=0.9754
#   Epoch  40: Train Acc=0.9886, Val Acc=0.9861, F1=0.9816
#   Epoch  50: Train Acc=0.9919, Val Acc=0.9878, F1=0.9837
#   Epoch  60: Train Acc=0.9931, Val Acc=0.9880, F1=0.9838
#   Epoch  70: Train Acc=0.9935, Val Acc=0.9894, F1=0.9859
#   Epoch  80: Train Acc=0.9946, Val Acc=0.9892, F1=0.9841
#   Epoch  90: Train Acc=0.9951, Val Acc=0.9894, F1=0.9860
#   Epoch 100: Train Acc=0.9963, Val Acc=0.9903, F1=0.9877
#   Best Val Acc: 0.9907
#
# [GAP Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9921, F1: 0.9893
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9904, Val Acc=0.9791, F1=0.9671
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9803, F1=0.9724
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9830, F1=0.9768
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9834, F1=0.9766
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9837, F1=0.9753
#   Early stopping at epoch 52
#   Best Val Acc: 0.9837
#
# [TPA Results]
#   Val Acc: 0.9837
#   Test Acc: 0.9859, F1: 0.9789
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9892, Val Acc=0.9787, F1=0.9664
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9822, F1=0.9746
#   Epoch  30: Train Acc=0.9974, Val Acc=0.9828, F1=0.9778
#   Early stopping at epoch 36
#   Best Val Acc: 0.9830
#
# [Gated-TPA Results]
#   Val Acc: 0.9830
#   Test Acc: 0.9838, F1: 0.9730
#
# [Progress: 37/41]
#
# ================================================================================
# EXPERIMENT: UPSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading UPSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/UPSTAIRS_TO_WALKING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9465, Val Acc=0.9478, F1=0.9300
#   Epoch  20: Train Acc=0.9769, Val Acc=0.9700, F1=0.9570
#   Epoch  30: Train Acc=0.9848, Val Acc=0.9795, F1=0.9673
#   Epoch  40: Train Acc=0.9888, Val Acc=0.9824, F1=0.9704
#   Epoch  50: Train Acc=0.9900, Val Acc=0.9832, F1=0.9786
#   Epoch  60: Train Acc=0.9918, Val Acc=0.9853, F1=0.9805
#   Epoch  70: Train Acc=0.9936, Val Acc=0.9878, F1=0.9833
#   Epoch  80: Train Acc=0.9943, Val Acc=0.9870, F1=0.9829
#   Epoch  90: Train Acc=0.9946, Val Acc=0.9876, F1=0.9830
#   Epoch 100: Train Acc=0.9953, Val Acc=0.9874, F1=0.9824
#   Best Val Acc: 0.9897
#
# [GAP Results]
#   Val Acc: 0.9897
#   Test Acc: 0.9901, F1: 0.9877
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9898, Val Acc=0.9739, F1=0.9581
#   Epoch  20: Train Acc=0.9957, Val Acc=0.9758, F1=0.9616
#   Epoch  30: Train Acc=0.9977, Val Acc=0.9795, F1=0.9718
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9779, F1=0.9676
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9764, F1=0.9676
#   Early stopping at epoch 57
#   Best Val Acc: 0.9810
#
# [TPA Results]
#   Val Acc: 0.9810
#   Test Acc: 0.9839, F1: 0.9770
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9901, Val Acc=0.9774, F1=0.9641
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9805, F1=0.9719
#   Epoch  30: Train Acc=0.9977, Val Acc=0.9808, F1=0.9759
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9814, F1=0.9752
#   Early stopping at epoch 43
#   Best Val Acc: 0.9830
#
# [Gated-TPA Results]
#   Val Acc: 0.9830
#   Test Acc: 0.9861, F1: 0.9806
#
# [Progress: 38/41]
#
# ================================================================================
# EXPERIMENT: DOWNSTAIRS_TO_WALKING_10pct
# ================================================================================
#
# Loading DOWNSTAIRS_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/DOWNSTAIRS_TO_WALKING_10pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9598, Val Acc=0.9656, F1=0.9529
#   Epoch  20: Train Acc=0.9799, Val Acc=0.9770, F1=0.9674
#   Epoch  30: Train Acc=0.9861, Val Acc=0.9859, F1=0.9770
#   Epoch  40: Train Acc=0.9902, Val Acc=0.9901, F1=0.9869
#   Epoch  50: Train Acc=0.9922, Val Acc=0.9872, F1=0.9783
#   Epoch  60: Train Acc=0.9933, Val Acc=0.9932, F1=0.9904
#   Epoch  70: Train Acc=0.9952, Val Acc=0.9923, F1=0.9889
#   Epoch  80: Train Acc=0.9955, Val Acc=0.9921, F1=0.9890
#   Epoch  90: Train Acc=0.9963, Val Acc=0.9921, F1=0.9891
#   Epoch 100: Train Acc=0.9972, Val Acc=0.9934, F1=0.9906
#   Best Val Acc: 0.9940
#
# [GAP Results]
#   Val Acc: 0.9940
#   Test Acc: 0.9914, F1: 0.9865
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9923, Val Acc=0.9824, F1=0.9696
#   Epoch  20: Train Acc=0.9965, Val Acc=0.9841, F1=0.9723
#   Epoch  30: Train Acc=0.9984, Val Acc=0.9849, F1=0.9781
#   Early stopping at epoch 35
#   Best Val Acc: 0.9863
#
# [TPA Results]
#   Val Acc: 0.9863
#   Test Acc: 0.9825, F1: 0.9723
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9904, Val Acc=0.9814, F1=0.9696
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9837, F1=0.9707
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9847, F1=0.9773
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9853, F1=0.9791
#   Early stopping at epoch 46
#   Best Val Acc: 0.9863
#
# [Gated-TPA Results]
#   Val Acc: 0.9863
#   Test Acc: 0.9828, F1: 0.9750
#
# [Progress: 39/41]
#
# ================================================================================
# EXPERIMENT: DOWNSTAIRS_TO_WALKING_20pct
# ================================================================================
#
# Loading DOWNSTAIRS_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/DOWNSTAIRS_TO_WALKING_20pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9573, Val Acc=0.9613, F1=0.9481
#   Epoch  20: Train Acc=0.9794, Val Acc=0.9839, F1=0.9759
#   Epoch  30: Train Acc=0.9857, Val Acc=0.9874, F1=0.9792
#   Epoch  40: Train Acc=0.9894, Val Acc=0.9899, F1=0.9817
#   Epoch  50: Train Acc=0.9919, Val Acc=0.9917, F1=0.9876
#   Epoch  60: Train Acc=0.9933, Val Acc=0.9936, F1=0.9901
#   Epoch  70: Train Acc=0.9945, Val Acc=0.9921, F1=0.9880
#   Epoch  80: Train Acc=0.9950, Val Acc=0.9928, F1=0.9889
#   Early stopping at epoch 80
#   Best Val Acc: 0.9936
#
# [GAP Results]
#   Val Acc: 0.9936
#   Test Acc: 0.9909, F1: 0.9876
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9907, Val Acc=0.9816, F1=0.9716
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9839, F1=0.9745
#   Epoch  30: Train Acc=0.9987, Val Acc=0.9849, F1=0.9786
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9841, F1=0.9773
#   Epoch  50: Train Acc=0.9995, Val Acc=0.9851, F1=0.9794
#   Early stopping at epoch 58
#   Best Val Acc: 0.9863
#
# [TPA Results]
#   Val Acc: 0.9863
#   Test Acc: 0.9854, F1: 0.9794
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9904, Val Acc=0.9837, F1=0.9737
#   Epoch  20: Train Acc=0.9968, Val Acc=0.9839, F1=0.9744
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9863, F1=0.9818
#   Early stopping at epoch 37
#   Best Val Acc: 0.9863
#
# [Gated-TPA Results]
#   Val Acc: 0.9863
#   Test Acc: 0.9844, F1: 0.9742
#
# [Progress: 40/41]
#
# ================================================================================
# EXPERIMENT: DOWNSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading DOWNSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/DOWNSTAIRS_TO_WALKING_30pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9538, Val Acc=0.9586, F1=0.9473
#   Epoch  20: Train Acc=0.9775, Val Acc=0.9785, F1=0.9693
#   Epoch  30: Train Acc=0.9841, Val Acc=0.9845, F1=0.9759
#   Epoch  40: Train Acc=0.9891, Val Acc=0.9847, F1=0.9753
#   Epoch  50: Train Acc=0.9904, Val Acc=0.9876, F1=0.9837
#   Epoch  60: Train Acc=0.9929, Val Acc=0.9890, F1=0.9859
#   Epoch  70: Train Acc=0.9938, Val Acc=0.9907, F1=0.9882
#   Early stopping at epoch 77
#   Best Val Acc: 0.9909
#
# [GAP Results]
#   Val Acc: 0.9909
#   Test Acc: 0.9916, F1: 0.9883
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9919, Val Acc=0.9748, F1=0.9622
#   Epoch  20: Train Acc=0.9964, Val Acc=0.9832, F1=0.9758
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9857, F1=0.9788
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9855, F1=0.9815
#   Epoch  50: Train Acc=0.9987, Val Acc=0.9851, F1=0.9797
#   Early stopping at epoch 58
#   Best Val Acc: 0.9865
#
# [TPA Results]
#   Val Acc: 0.9865
#   Test Acc: 0.9839, F1: 0.9805
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9890, Val Acc=0.9810, F1=0.9684
#   Epoch  20: Train Acc=0.9959, Val Acc=0.9808, F1=0.9708
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9839, F1=0.9802
#   Epoch  40: Train Acc=0.9987, Val Acc=0.9841, F1=0.9799
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9863, F1=0.9834
#   Epoch  60: Train Acc=0.9988, Val Acc=0.9857, F1=0.9815
#   Epoch  70: Train Acc=0.9993, Val Acc=0.9851, F1=0.9808
#   Early stopping at epoch 77
#   Best Val Acc: 0.9865
#
# [Gated-TPA Results]
#   Val Acc: 0.9865
#   Test Acc: 0.9858, F1: 0.9813
#
# [Progress: 41/41]
#
# ================================================================================
# EXPERIMENT: DOWNSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading DOWNSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/wisdm_transition_datasets/DOWNSTAIRS_TO_WALKING_40pct
#   Train: (24156, 200, 3), Test: (6040, 200, 3)
#
# Dataset splits:
#   Train: 19324, Val: 4832, Test: 6040
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9498, Val Acc=0.9520, F1=0.9391
#   Epoch  20: Train Acc=0.9751, Val Acc=0.9733, F1=0.9608
#   Epoch  30: Train Acc=0.9829, Val Acc=0.9797, F1=0.9677
#   Epoch  40: Train Acc=0.9874, Val Acc=0.9812, F1=0.9690
#   Epoch  50: Train Acc=0.9895, Val Acc=0.9851, F1=0.9817
#   Epoch  60: Train Acc=0.9909, Val Acc=0.9878, F1=0.9854
#   Epoch  70: Train Acc=0.9927, Val Acc=0.9878, F1=0.9849
#   Epoch  80: Train Acc=0.9935, Val Acc=0.9884, F1=0.9863
#   Epoch  90: Train Acc=0.9943, Val Acc=0.9890, F1=0.9875
#   Epoch 100: Train Acc=0.9953, Val Acc=0.9901, F1=0.9878
#   Best Val Acc: 0.9901
#
# [GAP Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9902, F1: 0.9873
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9901, Val Acc=0.9748, F1=0.9622
#   Epoch  20: Train Acc=0.9961, Val Acc=0.9768, F1=0.9629
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9779, F1=0.9640
#   Epoch  40: Train Acc=0.9986, Val Acc=0.9795, F1=0.9760
#   Epoch  50: Train Acc=0.9989, Val Acc=0.9791, F1=0.9731
#   Epoch  60: Train Acc=0.9992, Val Acc=0.9803, F1=0.9768
#   Epoch  70: Train Acc=0.9991, Val Acc=0.9797, F1=0.9771
#   Early stopping at epoch 71
#   Best Val Acc: 0.9820
#
# [TPA Results]
#   Val Acc: 0.9820
#   Test Acc: 0.9863, F1: 0.9806
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9880, Val Acc=0.9758, F1=0.9614
#   Epoch  20: Train Acc=0.9952, Val Acc=0.9824, F1=0.9794
#   Epoch  30: Train Acc=0.9978, Val Acc=0.9814, F1=0.9780
#   Epoch  40: Train Acc=0.9984, Val Acc=0.9826, F1=0.9781
#   Epoch  50: Train Acc=0.9991, Val Acc=0.9785, F1=0.9735
#   Epoch  60: Train Acc=0.9989, Val Acc=0.9785, F1=0.9741
#   Early stopping at epoch 60
#   Best Val Acc: 0.9826
#
# [Gated-TPA Results]
#   Val Acc: 0.9826
#   Test Acc: 0.9844, F1: 0.9807
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_transition_wisdm_cnn.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 123
# Total datasets tested: 41
# Models compared: 3 (GAP, TPA, Gated-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE (All Datasets)
# ================================================================================
# GAP         : Acc=0.9913, F1=0.9860
# TPA         : Acc=0.9853, F1=0.9768
# Gated-TPA   : Acc=0.9851, F1=0.9765
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
