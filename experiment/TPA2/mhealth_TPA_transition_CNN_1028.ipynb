# %%
# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Gated-TPA
Compare three models on 41 pre-augmented transition datasets
(1 original + 40 transition datasets)
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_dataset(base_dir: str, dataset_name: str):
    """
    Load pre-augmented dataset
    Args:
        base_dir: base directory containing all datasets
        dataset_name: e.g., "ORIGINAL", "Standing_TO_Sitting_10PCT", etc.
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, dataset_name)

    print(f"\nLoading {dataset_name}...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class ConvBNAct(nn.Module):
    def __init__(self, c_in, c_out, k, s=1, p=None, g=1):
        super().__init__()
        self.c = nn.Conv1d(c_in, c_out, k, s, k//2 if p is None else p, groups=g, bias=False)
        self.bn = nn.BatchNorm1d(c_out)
        self.act = nn.GELU()

    def forward(self, x):
        return self.act(self.bn(self.c(x)))

class MultiPathCNN(nn.Module):
    """Shared backbone for all models"""
    def __init__(self, in_ch=23, d_model=128, branches=(3,5,9,15), stride=2):
        super().__init__()
        h = d_model // 2
        self.pre = ConvBNAct(in_ch, h, 1)
        self.branches = nn.ModuleList([
            nn.Sequential(ConvBNAct(h, h, k, stride, g=h), ConvBNAct(h, h, 1))
            for k in branches
        ])
        self.post = ConvBNAct(len(branches)*h, d_model, 1)

    def forward(self, x):
        return self.post(torch.cat([b(self.pre(x)) for b in self.branches], dim=1))

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=12):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# Pure-TPA
# ========================
class ProductionTPA(nn.Module):
    """Pure TPA"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        z_tpa = proto_tokens.mean(dim=1)

        z = self.fuse(z_tpa)

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=12, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Gated-TPA
# ========================
class GatedTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=12, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        # Gating mechanism
        self.gate = nn.Sequential(
            nn.Linear(d_model * 2, d_model),
            nn.Sigmoid()
        )

        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        # x shape: [B, T, C] -> transpose to [B, C, T] for Conv1d
        x = x.transpose(1, 2)  # [B, C, T]
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]

        # GAP branch
        z_gap = features.mean(dim=1)  # [B, D]

        # TPA branch
        z_tpa = self.tpa(features)  # [B, D]

        # Gating
        gate_input = torch.cat([z_gap, z_tpa], dim=-1)
        g = self.gate(gate_input)

        # Gated fusion
        z = g * z_gap + (1 - g) * z_tpa

        logits = self.classifier(z)
        return logits

# ========================
# Training & Evaluation
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Gated-TPA":
        return GatedTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(dataset_name: str, cfg: Config):
    """Run complete experiment for one dataset"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {dataset_name}")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_dataset(cfg.data_dir, dataset_name)

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Gated-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Dataset': dataset_name,
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA")
    print("="*80)

    datasets = ["ORIGINAL"]  # 원본 데이터셋

    transitions = [
        'Standing_TO_Sitting',
        'Sitting_TO_Standing',
        'Sitting_TO_Lying',
        'Lying_TO_Sitting',
        'Standing_TO_Lying',
        'Lying_TO_Standing',
        'Standing_TO_Walking',
        'Walking_TO_Standing',
        'Walking_TO_Jogging',
        'Jogging_TO_Walking',
        'Walking_TO_Climbing_stairs',
        'Climbing_stairs_TO_Walking'
    ]
    # 모든 전이에 대해 10%, 20%, 30%, 40% 추가
    mix_pcts = [10, 20, 30, 40]

    for transition in transitions:
        for pct in mix_pcts:
            datasets.append(f"{transition}_{pct}PCT")

    print(f"\nTotal datasets to test: {len(datasets)}")
    print(f"  - Original: 1")
    print(f"  - transitions: {len(transitions) * len(mix_pcts)}")

    all_results = []

    # Run experiments
    for i, dataset_name in enumerate(datasets, 1):
        print(f"\n[Progress: {i}/{len(datasets)}]")
        results = run_experiment(dataset_name, cfg)
        all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Gated-TPA'],
            'total_datasets': len(datasets),
            'datasets': datasets,
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_transition_mhealth_cnn.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Total datasets tested: {len(datasets)}")
    print(f"Models compared: 3 (GAP, TPA, Gated-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE (All Datasets)")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Gated-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:12s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA
# ================================================================================
#
# Total datasets to test: 49
#   - Original: 1
#   - transitions: 48
#
# [Progress: 1/49]
#
# ================================================================================
# EXPERIMENT: ORIGINAL
# ================================================================================
#
# Loading ORIGINAL...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/ORIGINAL
#   Train: (2744, 200, 23), Test: (686, 200, 23)
#
# Dataset splits:
#   Train: 2195, Val: 549, Test: 686
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8369, Val Acc=0.8834, F1=0.8746
#   Epoch  20: Train Acc=0.9403, Val Acc=0.9454, F1=0.9438
#   Epoch  30: Train Acc=0.9731, Val Acc=0.9690, F1=0.9704
#   Epoch  40: Train Acc=0.9818, Val Acc=0.9945, F1=0.9949
#   Epoch  50: Train Acc=0.9868, Val Acc=0.9964, F1=0.9966
#   Epoch  60: Train Acc=0.9923, Val Acc=0.9964, F1=0.9966
#   Epoch  70: Train Acc=0.9904, Val Acc=0.9982, F1=0.9983
#   Epoch  80: Train Acc=0.9932, Val Acc=0.9964, F1=0.9966
#   Early stopping at epoch 86
#   Best Val Acc: 1.0000
#
# [GAP Results]
#   Val Acc: 1.0000
#   Test Acc: 0.9942, F1: 0.9905
#
# [Training TPA]
#   Epoch  10: Train Acc=0.8948, Val Acc=0.8944, F1=0.8335
#   Epoch  20: Train Acc=0.9886, Val Acc=0.9836, F1=0.9829
#   Epoch  30: Train Acc=0.9982, Val Acc=0.9872, F1=0.9848
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9800, F1=0.9746
#   Epoch  50: Train Acc=0.9991, Val Acc=0.9854, F1=0.9832
#   Early stopping at epoch 50
#   Best Val Acc: 0.9872
#
# [TPA Results]
#   Val Acc: 0.9872
#   Test Acc: 0.9796, F1: 0.9752
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.8993, Val Acc=0.9180, F1=0.8776
#   Epoch  20: Train Acc=0.9886, Val Acc=0.9781, F1=0.9740
#   Epoch  30: Train Acc=0.9977, Val Acc=0.9836, F1=0.9846
#   Epoch  40: Train Acc=0.9991, Val Acc=0.9818, F1=0.9812
#   Epoch  50: Train Acc=0.9991, Val Acc=0.9854, F1=0.9863
#   Epoch  60: Train Acc=0.9995, Val Acc=0.9854, F1=0.9847
#   Epoch  70: Train Acc=1.0000, Val Acc=0.9818, F1=0.9812
#   Early stopping at epoch 75
#   Best Val Acc: 0.9891
#
# [Gated-TPA Results]
#   Val Acc: 0.9891
#   Test Acc: 0.9840, F1: 0.9809
#
# [Progress: 2/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Sitting_10PCT
# ================================================================================
#
# Loading Standing_TO_Sitting_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Sitting_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8293, Val Acc=0.8626, F1=0.8315
#   Epoch  20: Train Acc=0.9478, Val Acc=0.9421, F1=0.9383
#   Epoch  30: Train Acc=0.9735, Val Acc=0.9752, F1=0.9746
#   Epoch  40: Train Acc=0.9872, Val Acc=0.9834, F1=0.9833
#   Epoch  50: Train Acc=0.9884, Val Acc=0.9868, F1=0.9853
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9901, F1=0.9879
#   Early stopping at epoch 65
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9921, F1: 0.9936
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9114, Val Acc=0.9040, F1=0.8361
#   Epoch  20: Train Acc=0.9892, Val Acc=0.9818, F1=0.9795
#   Epoch  30: Train Acc=0.9959, Val Acc=0.9851, F1=0.9830
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9868, F1=0.9852
#   Early stopping at epoch 49
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9841, F1: 0.9814
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.8989, Val Acc=0.9123, F1=0.8473
#   Epoch  20: Train Acc=0.9901, Val Acc=0.9752, F1=0.9718
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9834, F1=0.9817
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9801, F1=0.9772
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9851, F1=0.9835
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9851, F1=0.9839
#   Early stopping at epoch 68
#   Best Val Acc: 0.9868
#
# [Gated-TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9841, F1: 0.9835
#
# [Progress: 3/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Sitting_20PCT
# ================================================================================
#
# Loading Standing_TO_Sitting_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Sitting_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8273, Val Acc=0.8493, F1=0.8226
#   Epoch  20: Train Acc=0.9441, Val Acc=0.9553, F1=0.9560
#   Epoch  30: Train Acc=0.9747, Val Acc=0.9719, F1=0.9748
#   Epoch  40: Train Acc=0.9859, Val Acc=0.9801, F1=0.9820
#   Epoch  50: Train Acc=0.9896, Val Acc=0.9801, F1=0.9820
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9934, F1=0.9929
#   Early stopping at epoch 65
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9907, F1: 0.9909
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9159, Val Acc=0.9189, F1=0.8545
#   Epoch  20: Train Acc=0.9930, Val Acc=0.9785, F1=0.9754
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9752, F1=0.9733
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9834, F1=0.9821
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9801, F1=0.9769
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9801, F1=0.9787
#   Early stopping at epoch 60
#   Best Val Acc: 0.9834
#
# [TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9868, F1: 0.9865
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9010, Val Acc=0.9205, F1=0.8852
#   Epoch  20: Train Acc=0.9859, Val Acc=0.9901, F1=0.9880
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9934, F1=0.9932
#   Epoch  40: Train Acc=0.9971, Val Acc=0.9934, F1=0.9932
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9917, F1=0.9914
#   Early stopping at epoch 58
#   Best Val Acc: 0.9950
#
# [Gated-TPA Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9894, F1: 0.9875
#
# [Progress: 4/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Sitting_30PCT
# ================================================================================
#
# Loading Standing_TO_Sitting_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Sitting_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8393, Val Acc=0.8444, F1=0.7980
#   Epoch  20: Train Acc=0.9379, Val Acc=0.9470, F1=0.9434
#   Epoch  30: Train Acc=0.9722, Val Acc=0.9768, F1=0.9794
#   Epoch  40: Train Acc=0.9892, Val Acc=0.9851, F1=0.9879
#   Epoch  50: Train Acc=0.9884, Val Acc=0.9834, F1=0.9844
#   Epoch  60: Train Acc=0.9921, Val Acc=0.9901, F1=0.9896
#   Epoch  70: Train Acc=0.9942, Val Acc=0.9917, F1=0.9908
#   Epoch  80: Train Acc=0.9950, Val Acc=0.9917, F1=0.9913
#   Epoch  90: Train Acc=0.9959, Val Acc=0.9934, F1=0.9925
#   Epoch 100: Train Acc=0.9959, Val Acc=0.9950, F1=0.9921
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9987, F1: 0.9973
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9213, Val Acc=0.9321, F1=0.8665
#   Epoch  20: Train Acc=0.9925, Val Acc=0.9685, F1=0.9617
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9818, F1=0.9771
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9851, F1=0.9809
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9834, F1=0.9792
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9834, F1=0.9792
#   Early stopping at epoch 68
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9841, F1: 0.9820
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9043, Val Acc=0.9288, F1=0.8938
#   Epoch  20: Train Acc=0.9872, Val Acc=0.9818, F1=0.9771
#   Epoch  30: Train Acc=0.9971, Val Acc=0.9851, F1=0.9837
#   Epoch  40: Train Acc=0.9971, Val Acc=0.9851, F1=0.9837
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9868, F1=0.9859
#   Early stopping at epoch 51
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9801, F1: 0.9801
#
# [Progress: 5/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Sitting_40PCT
# ================================================================================
#
# Loading Standing_TO_Sitting_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Sitting_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8505, Val Acc=0.8675, F1=0.8462
#   Epoch  20: Train Acc=0.9449, Val Acc=0.9487, F1=0.9451
#   Epoch  30: Train Acc=0.9739, Val Acc=0.9801, F1=0.9789
#   Epoch  40: Train Acc=0.9884, Val Acc=0.9851, F1=0.9841
#   Epoch  50: Train Acc=0.9884, Val Acc=0.9884, F1=0.9867
#   Epoch  60: Train Acc=0.9930, Val Acc=0.9917, F1=0.9893
#   Early stopping at epoch 65
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9894, F1: 0.9892
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9221, Val Acc=0.9205, F1=0.8545
#   Epoch  20: Train Acc=0.9901, Val Acc=0.9785, F1=0.9729
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9785, F1=0.9729
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9768, F1=0.9698
#   Early stopping at epoch 40
#   Best Val Acc: 0.9785
#
# [TPA Results]
#   Val Acc: 0.9785
#   Test Acc: 0.9775, F1: 0.9779
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9027, Val Acc=0.9139, F1=0.8772
#   Epoch  20: Train Acc=0.9892, Val Acc=0.9752, F1=0.9713
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9801, F1=0.9770
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9818, F1=0.9783
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9818, F1=0.9783
#   Early stopping at epoch 59
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9775, F1: 0.9762
#
# [Progress: 6/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Standing_10PCT
# ================================================================================
#
# Loading Sitting_TO_Standing_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Standing_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7635, Val Acc=0.7848, F1=0.7578
#   Epoch  20: Train Acc=0.9449, Val Acc=0.9354, F1=0.9354
#   Epoch  30: Train Acc=0.9809, Val Acc=0.9785, F1=0.9781
#   Epoch  40: Train Acc=0.9863, Val Acc=0.9834, F1=0.9828
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9901, F1=0.9882
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9901, F1=0.9882
#   Epoch  70: Train Acc=0.9934, Val Acc=0.9884, F1=0.9874
#   Early stopping at epoch 72
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9947, F1: 0.9936
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9225, Val Acc=0.9222, F1=0.8546
#   Epoch  20: Train Acc=0.9913, Val Acc=0.9785, F1=0.9777
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9752, F1=0.9751
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9785, F1=0.9781
#   Early stopping at epoch 44
#   Best Val Acc: 0.9834
#
# [TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9788, F1: 0.9759
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9242, Val Acc=0.9371, F1=0.9242
#   Epoch  20: Train Acc=0.9925, Val Acc=0.9719, F1=0.9720
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9768, F1=0.9773
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9768, F1=0.9771
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9768, F1=0.9773
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9785, F1=0.9790
#   Early stopping at epoch 65
#   Best Val Acc: 0.9801
#
# [Gated-TPA Results]
#   Val Acc: 0.9801
#   Test Acc: 0.9828, F1: 0.9815
#
# [Progress: 7/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Standing_20PCT
# ================================================================================
#
# Loading Sitting_TO_Standing_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Standing_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7875, Val Acc=0.8228, F1=0.7973
#   Epoch  20: Train Acc=0.9408, Val Acc=0.9454, F1=0.9439
#   Epoch  30: Train Acc=0.9801, Val Acc=0.9702, F1=0.9672
#   Epoch  40: Train Acc=0.9826, Val Acc=0.9851, F1=0.9830
#   Epoch  50: Train Acc=0.9892, Val Acc=0.9884, F1=0.9881
#   Epoch  60: Train Acc=0.9930, Val Acc=0.9950, F1=0.9932
#   Epoch  70: Train Acc=0.9954, Val Acc=0.9950, F1=0.9932
#   Early stopping at epoch 75
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9934, F1: 0.9935
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9114, Val Acc=0.9222, F1=0.8534
#   Epoch  20: Train Acc=0.9946, Val Acc=0.9868, F1=0.9847
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9851, F1=0.9830
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9884, F1=0.9884
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9801, F1=0.9807
#   Early stopping at epoch 58
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9828, F1: 0.9802
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9205, Val Acc=0.9305, F1=0.9089
#   Epoch  20: Train Acc=0.9884, Val Acc=0.9735, F1=0.9699
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9801, F1=0.9776
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9834, F1=0.9814
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9834, F1=0.9810
#   Early stopping at epoch 53
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9841, F1: 0.9849
#
# [Progress: 8/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Standing_30PCT
# ================================================================================
#
# Loading Sitting_TO_Standing_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Standing_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8053, Val Acc=0.8079, F1=0.7725
#   Epoch  20: Train Acc=0.9432, Val Acc=0.9536, F1=0.9537
#   Epoch  30: Train Acc=0.9805, Val Acc=0.9752, F1=0.9743
#   Epoch  40: Train Acc=0.9809, Val Acc=0.9868, F1=0.9866
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9967, F1=0.9970
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9983, F1=0.9987
#   Early stopping at epoch 64
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9907, F1: 0.9908
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9109, Val Acc=0.9371, F1=0.8782
#   Epoch  20: Train Acc=0.9963, Val Acc=0.9934, F1=0.9940
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9901, F1=0.9910
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9868, F1=0.9854
#   Early stopping at epoch 40
#   Best Val Acc: 0.9934
#
# [TPA Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9775, F1: 0.9720
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9163, Val Acc=0.9354, F1=0.8909
#   Epoch  20: Train Acc=0.9876, Val Acc=0.9818, F1=0.9833
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9834, F1=0.9855
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9851, F1=0.9868
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9801, F1=0.9824
#   Early stopping at epoch 51
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9801, F1: 0.9776
#
# [Progress: 9/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Standing_40PCT
# ================================================================================
#
# Loading Sitting_TO_Standing_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Standing_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8070, Val Acc=0.8295, F1=0.8062
#   Epoch  20: Train Acc=0.9408, Val Acc=0.9487, F1=0.9466
#   Epoch  30: Train Acc=0.9776, Val Acc=0.9801, F1=0.9796
#   Epoch  40: Train Acc=0.9834, Val Acc=0.9884, F1=0.9865
#   Epoch  50: Train Acc=0.9913, Val Acc=0.9950, F1=0.9933
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9950, F1=0.9933
#   Early stopping at epoch 64
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9974, F1: 0.9973
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9138, Val Acc=0.9338, F1=0.8661
#   Epoch  20: Train Acc=0.9925, Val Acc=0.9851, F1=0.9851
#   Epoch  30: Train Acc=0.9959, Val Acc=0.9868, F1=0.9853
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9868, F1=0.9849
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9884, F1=0.9857
#   Early stopping at epoch 56
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9894, F1: 0.9898
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9184, Val Acc=0.9172, F1=0.8762
#   Epoch  20: Train Acc=0.9892, Val Acc=0.9818, F1=0.9804
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9846
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9851, F1=0.9846
#   Early stopping at epoch 44
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9921, F1: 0.9924
#
# [Progress: 10/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Lying_10PCT
# ================================================================================
#
# Loading Sitting_TO_Lying_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Lying_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7278, Val Acc=0.7450, F1=0.7077
#   Epoch  20: Train Acc=0.9482, Val Acc=0.9321, F1=0.9284
#   Epoch  30: Train Acc=0.9793, Val Acc=0.9801, F1=0.9781
#   Epoch  40: Train Acc=0.9863, Val Acc=0.9851, F1=0.9830
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9917, F1=0.9898
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9950, F1=0.9932
#   Epoch  70: Train Acc=0.9954, Val Acc=0.9934, F1=0.9915
#   Early stopping at epoch 75
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9947, F1: 0.9921
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9143, Val Acc=0.9123, F1=0.8414
#   Epoch  20: Train Acc=0.9909, Val Acc=0.9768, F1=0.9705
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9768, F1=0.9705
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9801, F1=0.9760
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9851, F1=0.9829
#   Epoch  60: Train Acc=0.9996, Val Acc=0.9785, F1=0.9724
#   Epoch  70: Train Acc=0.9992, Val Acc=0.9818, F1=0.9781
#   Early stopping at epoch 70
#   Best Val Acc: 0.9851
#
# [TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9868, F1: 0.9857
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9242, Val Acc=0.9321, F1=0.8917
#   Epoch  20: Train Acc=0.9863, Val Acc=0.9719, F1=0.9640
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9785, F1=0.9763
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9768, F1=0.9732
#   Early stopping at epoch 49
#   Best Val Acc: 0.9834
#
# [Gated-TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9828, F1: 0.9831
#
# [Progress: 11/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Lying_20PCT
# ================================================================================
#
# Loading Sitting_TO_Lying_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Lying_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7403, Val Acc=0.7715, F1=0.7304
#   Epoch  20: Train Acc=0.9457, Val Acc=0.9421, F1=0.9426
#   Epoch  30: Train Acc=0.9793, Val Acc=0.9768, F1=0.9767
#   Epoch  40: Train Acc=0.9867, Val Acc=0.9868, F1=0.9868
#   Epoch  50: Train Acc=0.9913, Val Acc=0.9950, F1=0.9953
#   Epoch  60: Train Acc=0.9954, Val Acc=0.9967, F1=0.9970
#   Early stopping at epoch 68
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9947, F1: 0.9907
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9060, Val Acc=0.9073, F1=0.8387
#   Epoch  20: Train Acc=0.9938, Val Acc=0.9834, F1=0.9837
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9842
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9868, F1=0.9859
#   Early stopping at epoch 44
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9815, F1: 0.9752
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9229, Val Acc=0.9305, F1=0.9001
#   Epoch  20: Train Acc=0.9905, Val Acc=0.9768, F1=0.9755
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9768, F1=0.9741
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9818, F1=0.9820
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9768, F1=0.9756
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9785, F1=0.9785
#   Early stopping at epoch 61
#   Best Val Acc: 0.9834
#
# [Gated-TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9828, F1: 0.9769
#
# [Progress: 12/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Lying_30PCT
# ================================================================================
#
# Loading Sitting_TO_Lying_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Lying_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7345, Val Acc=0.7632, F1=0.7330
#   Epoch  20: Train Acc=0.9432, Val Acc=0.9570, F1=0.9575
#   Epoch  30: Train Acc=0.9789, Val Acc=0.9801, F1=0.9796
#   Epoch  40: Train Acc=0.9830, Val Acc=0.9934, F1=0.9936
#   Epoch  50: Train Acc=0.9930, Val Acc=0.9934, F1=0.9921
#   Epoch  60: Train Acc=0.9925, Val Acc=0.9950, F1=0.9938
#   Epoch  70: Train Acc=0.9934, Val Acc=0.9950, F1=0.9938
#   Early stopping at epoch 71
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9868, F1: 0.9849
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9130, Val Acc=0.9305, F1=0.8616
#   Epoch  20: Train Acc=0.9909, Val Acc=0.9834, F1=0.9768
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9851, F1=0.9786
#   Epoch  40: Train Acc=0.9979, Val Acc=0.9851, F1=0.9799
#   Early stopping at epoch 41
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9801, F1: 0.9736
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9097, Val Acc=0.9371, F1=0.9169
#   Epoch  20: Train Acc=0.9901, Val Acc=0.9834, F1=0.9763
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9868, F1=0.9835
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9884, F1=0.9869
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9884, F1=0.9867
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9834, F1=0.9801
#   Early stopping at epoch 62
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9881, F1: 0.9852
#
# [Progress: 13/49]
#
# ================================================================================
# EXPERIMENT: Sitting_TO_Lying_40PCT
# ================================================================================
#
# Loading Sitting_TO_Lying_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Sitting_TO_Lying_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7581, Val Acc=0.7715, F1=0.7469
#   Epoch  20: Train Acc=0.9470, Val Acc=0.9570, F1=0.9584
#   Epoch  30: Train Acc=0.9785, Val Acc=0.9834, F1=0.9832
#   Epoch  40: Train Acc=0.9872, Val Acc=0.9934, F1=0.9931
#   Epoch  50: Train Acc=0.9934, Val Acc=0.9983, F1=0.9982
#   Epoch  60: Train Acc=0.9942, Val Acc=0.9983, F1=0.9982
#   Early stopping at epoch 67
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9947, F1: 0.9945
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9093, Val Acc=0.9255, F1=0.8570
#   Epoch  20: Train Acc=0.9909, Val Acc=0.9884, F1=0.9870
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9834, F1=0.9817
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9868, F1=0.9839
#   Early stopping at epoch 40
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9841, F1: 0.9835
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9122, Val Acc=0.9305, F1=0.9009
#   Epoch  20: Train Acc=0.9892, Val Acc=0.9768, F1=0.9736
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9801, F1=0.9773
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9818, F1=0.9790
#   Early stopping at epoch 43
#   Best Val Acc: 0.9834
#
# [Gated-TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9828, F1: 0.9824
#
# [Progress: 14/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Sitting_10PCT
# ================================================================================
#
# Loading Lying_TO_Sitting_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Sitting_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8210, Val Acc=0.8642, F1=0.8458
#   Epoch  20: Train Acc=0.9565, Val Acc=0.9404, F1=0.9356
#   Epoch  30: Train Acc=0.9772, Val Acc=0.9719, F1=0.9711
#   Epoch  40: Train Acc=0.9876, Val Acc=0.9901, F1=0.9902
#   Epoch  50: Train Acc=0.9909, Val Acc=0.9967, F1=0.9970
#   Epoch  60: Train Acc=0.9954, Val Acc=0.9983, F1=0.9987
#   Epoch  70: Train Acc=0.9975, Val Acc=0.9967, F1=0.9970
#   Epoch  80: Train Acc=0.9967, Val Acc=0.9917, F1=0.9919
#   Early stopping at epoch 80
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9907, F1: 0.9891
#
# [Training TPA]
#   Epoch  10: Train Acc=0.8981, Val Acc=0.9222, F1=0.8536
#   Epoch  20: Train Acc=0.9925, Val Acc=0.9785, F1=0.9751
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9785, F1=0.9750
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9752, F1=0.9701
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9752, F1=0.9697
#   Early stopping at epoch 53
#   Best Val Acc: 0.9801
#
# [TPA Results]
#   Val Acc: 0.9801
#   Test Acc: 0.9841, F1: 0.9783
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9068, Val Acc=0.9387, F1=0.9076
#   Epoch  20: Train Acc=0.9896, Val Acc=0.9901, F1=0.9885
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9884, F1=0.9867
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9901, F1=0.9880
#   Early stopping at epoch 41
#   Best Val Acc: 0.9917
#
# [Gated-TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9828, F1: 0.9783
#
# [Progress: 15/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Sitting_20PCT
# ================================================================================
#
# Loading Lying_TO_Sitting_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Sitting_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8364, Val Acc=0.8526, F1=0.8291
#   Epoch  20: Train Acc=0.9507, Val Acc=0.9404, F1=0.9321
#   Epoch  30: Train Acc=0.9747, Val Acc=0.9719, F1=0.9694
#   Epoch  40: Train Acc=0.9880, Val Acc=0.9834, F1=0.9817
#   Epoch  50: Train Acc=0.9913, Val Acc=0.9950, F1=0.9932
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9901, F1=0.9881
#   Epoch  70: Train Acc=0.9959, Val Acc=0.9917, F1=0.9898
#   Epoch  80: Train Acc=0.9946, Val Acc=0.9917, F1=0.9898
#   Early stopping at epoch 85
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9987, F1: 0.9986
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9060, Val Acc=0.9156, F1=0.8468
#   Epoch  20: Train Acc=0.9896, Val Acc=0.9818, F1=0.9780
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9818, F1=0.9780
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9818, F1=0.9780
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9768, F1=0.9713
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9868, F1=0.9812
#   Early stopping at epoch 62
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9868, F1: 0.9860
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9035, Val Acc=0.9139, F1=0.8740
#   Epoch  20: Train Acc=0.9843, Val Acc=0.9834, F1=0.9828
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9818, F1=0.9803
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9834, F1=0.9820
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9801, F1=0.9786
#   Early stopping at epoch 52
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9907, F1: 0.9897
#
# [Progress: 16/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Sitting_30PCT
# ================================================================================
#
# Loading Lying_TO_Sitting_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Sitting_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8198, Val Acc=0.8692, F1=0.8564
#   Epoch  20: Train Acc=0.9515, Val Acc=0.9553, F1=0.9489
#   Epoch  30: Train Acc=0.9756, Val Acc=0.9735, F1=0.9727
#   Epoch  40: Train Acc=0.9851, Val Acc=0.9901, F1=0.9902
#   Epoch  50: Train Acc=0.9954, Val Acc=0.9901, F1=0.9882
#   Epoch  60: Train Acc=0.9954, Val Acc=0.9950, F1=0.9949
#   Epoch  70: Train Acc=0.9959, Val Acc=0.9950, F1=0.9949
#   Early stopping at epoch 74
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9907, F1: 0.9870
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9060, Val Acc=0.9007, F1=0.8314
#   Epoch  20: Train Acc=0.9942, Val Acc=0.9801, F1=0.9771
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9801, F1=0.9777
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9785, F1=0.9761
#   Early stopping at epoch 44
#   Best Val Acc: 0.9834
#
# [TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9762, F1: 0.9735
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9060, Val Acc=0.9123, F1=0.8863
#   Epoch  20: Train Acc=0.9880, Val Acc=0.9735, F1=0.9672
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9785, F1=0.9761
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9801, F1=0.9794
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9752, F1=0.9743
#   Early stopping at epoch 57
#   Best Val Acc: 0.9801
#
# [Gated-TPA Results]
#   Val Acc: 0.9801
#   Test Acc: 0.9735, F1: 0.9718
#
# [Progress: 17/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Sitting_40PCT
# ================================================================================
#
# Loading Lying_TO_Sitting_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Sitting_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8351, Val Acc=0.8808, F1=0.8700
#   Epoch  20: Train Acc=0.9437, Val Acc=0.9520, F1=0.9493
#   Epoch  30: Train Acc=0.9714, Val Acc=0.9818, F1=0.9811
#   Epoch  40: Train Acc=0.9818, Val Acc=0.9901, F1=0.9898
#   Epoch  50: Train Acc=0.9938, Val Acc=0.9934, F1=0.9932
#   Epoch  60: Train Acc=0.9925, Val Acc=1.0000, F1=1.0000
#   Epoch  70: Train Acc=0.9942, Val Acc=1.0000, F1=1.0000
#   Early stopping at epoch 79
#   Best Val Acc: 1.0000
#
# [GAP Results]
#   Val Acc: 1.0000
#   Test Acc: 0.9934, F1: 0.9935
#
# [Training TPA]
#   Epoch  10: Train Acc=0.8985, Val Acc=0.9321, F1=0.8642
#   Epoch  20: Train Acc=0.9901, Val Acc=0.9735, F1=0.9695
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9752, F1=0.9713
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9768, F1=0.9730
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9801, F1=0.9763
#   Early stopping at epoch 57
#   Best Val Acc: 0.9851
#
# [TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9748, F1: 0.9701
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9018, Val Acc=0.9106, F1=0.8710
#   Epoch  20: Train Acc=0.9838, Val Acc=0.9818, F1=0.9804
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9785, F1=0.9782
#   Epoch  40: Train Acc=0.9975, Val Acc=0.9868, F1=0.9868
#   Early stopping at epoch 41
#   Best Val Acc: 0.9868
#
# [Gated-TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9735, F1: 0.9728
#
# [Progress: 18/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Lying_10PCT
# ================================================================================
#
# Loading Standing_TO_Lying_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Lying_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8517, Val Acc=0.8675, F1=0.8413
#   Epoch  20: Train Acc=0.9461, Val Acc=0.9503, F1=0.9436
#   Epoch  30: Train Acc=0.9731, Val Acc=0.9818, F1=0.9803
#   Epoch  40: Train Acc=0.9859, Val Acc=0.9901, F1=0.9899
#   Epoch  50: Train Acc=0.9901, Val Acc=0.9917, F1=0.9889
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9950, F1=0.9937
#   Epoch  70: Train Acc=0.9946, Val Acc=0.9950, F1=0.9914
#   Early stopping at epoch 74
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9934, F1: 0.9945
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9192, Val Acc=0.9205, F1=0.8538
#   Epoch  20: Train Acc=0.9934, Val Acc=0.9801, F1=0.9726
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9834, F1=0.9783
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9851, F1=0.9781
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9818, F1=0.9747
#   Early stopping at epoch 55
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9775, F1: 0.9749
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9035, Val Acc=0.9172, F1=0.8689
#   Epoch  20: Train Acc=0.9867, Val Acc=0.9702, F1=0.9631
#   Epoch  30: Train Acc=0.9950, Val Acc=0.9785, F1=0.9764
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9785, F1=0.9764
#   Early stopping at epoch 49
#   Best Val Acc: 0.9818
#
# [Gated-TPA Results]
#   Val Acc: 0.9818
#   Test Acc: 0.9828, F1: 0.9846
#
# [Progress: 19/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Lying_20PCT
# ================================================================================
#
# Loading Standing_TO_Lying_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Lying_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8438, Val Acc=0.8841, F1=0.8580
#   Epoch  20: Train Acc=0.9403, Val Acc=0.9652, F1=0.9642
#   Epoch  30: Train Acc=0.9702, Val Acc=0.9868, F1=0.9875
#   Epoch  40: Train Acc=0.9847, Val Acc=0.9917, F1=0.9936
#   Epoch  50: Train Acc=0.9876, Val Acc=0.9934, F1=0.9949
#   Epoch  60: Train Acc=0.9930, Val Acc=0.9967, F1=0.9954
#   Early stopping at epoch 65
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9947, F1: 0.9939
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9134, Val Acc=0.9255, F1=0.8618
#   Epoch  20: Train Acc=0.9888, Val Acc=0.9818, F1=0.9773
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9801, F1=0.9780
#   Epoch  40: Train Acc=0.9979, Val Acc=0.9768, F1=0.9745
#   Early stopping at epoch 41
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9841, F1: 0.9839
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.8985, Val Acc=0.9255, F1=0.8782
#   Epoch  20: Train Acc=0.9888, Val Acc=0.9868, F1=0.9842
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9884, F1=0.9871
#   Early stopping at epoch 38
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9854, F1: 0.9823
#
# [Progress: 20/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Lying_30PCT
# ================================================================================
#
# Loading Standing_TO_Lying_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Lying_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8418, Val Acc=0.8758, F1=0.8354
#   Epoch  20: Train Acc=0.9490, Val Acc=0.9553, F1=0.9520
#   Epoch  30: Train Acc=0.9747, Val Acc=0.9752, F1=0.9745
#   Epoch  40: Train Acc=0.9876, Val Acc=0.9884, F1=0.9905
#   Epoch  50: Train Acc=0.9884, Val Acc=0.9868, F1=0.9888
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9917, F1=0.9928
#   Early stopping at epoch 65
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9921, F1: 0.9912
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9047, Val Acc=0.9222, F1=0.8572
#   Epoch  20: Train Acc=0.9884, Val Acc=0.9901, F1=0.9885
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9917, F1=0.9918
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9901, F1=0.9901
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9868, F1=0.9851
#   Early stopping at epoch 55
#   Best Val Acc: 0.9950
#
# [TPA Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9828, F1: 0.9788
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9022, Val Acc=0.9189, F1=0.8618
#   Epoch  20: Train Acc=0.9872, Val Acc=0.9801, F1=0.9772
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9838
#   Epoch  40: Train Acc=0.9971, Val Acc=0.9801, F1=0.9791
#   Early stopping at epoch 43
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9894, F1: 0.9876
#
# [Progress: 21/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Lying_40PCT
# ================================================================================
#
# Loading Standing_TO_Lying_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Lying_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8372, Val Acc=0.8609, F1=0.8381
#   Epoch  20: Train Acc=0.9432, Val Acc=0.9586, F1=0.9558
#   Epoch  30: Train Acc=0.9710, Val Acc=0.9851, F1=0.9857
#   Epoch  40: Train Acc=0.9867, Val Acc=0.9917, F1=0.9931
#   Epoch  50: Train Acc=0.9867, Val Acc=0.9934, F1=0.9949
#   Epoch  60: Train Acc=0.9921, Val Acc=1.0000, F1=1.0000
#   Epoch  70: Train Acc=0.9925, Val Acc=0.9967, F1=0.9975
#   Epoch  80: Train Acc=0.9975, Val Acc=0.9983, F1=0.9987
#   Early stopping at epoch 80
#   Best Val Acc: 1.0000
#
# [GAP Results]
#   Val Acc: 1.0000
#   Test Acc: 0.9974, F1: 0.9976
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9093, Val Acc=0.9205, F1=0.8560
#   Epoch  20: Train Acc=0.9905, Val Acc=0.9768, F1=0.9726
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9785, F1=0.9741
#   Epoch  40: Train Acc=0.9971, Val Acc=0.9801, F1=0.9758
#   Epoch  50: Train Acc=0.9988, Val Acc=0.9801, F1=0.9758
#   Early stopping at epoch 57
#   Best Val Acc: 0.9834
#
# [TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9748, F1: 0.9736
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9022, Val Acc=0.9189, F1=0.8888
#   Epoch  20: Train Acc=0.9863, Val Acc=0.9719, F1=0.9698
#   Epoch  30: Train Acc=0.9967, Val Acc=0.9768, F1=0.9747
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9768, F1=0.9747
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9768, F1=0.9747
#   Early stopping at epoch 59
#   Best Val Acc: 0.9785
#
# [Gated-TPA Results]
#   Val Acc: 0.9785
#   Test Acc: 0.9881, F1: 0.9883
#
# [Progress: 22/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_10PCT
# ================================================================================
#
# Loading Lying_TO_Standing_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Standing_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8186, Val Acc=0.8526, F1=0.8272
#   Epoch  20: Train Acc=0.9536, Val Acc=0.9586, F1=0.9549
#   Epoch  30: Train Acc=0.9760, Val Acc=0.9818, F1=0.9811
#   Epoch  40: Train Acc=0.9855, Val Acc=0.9884, F1=0.9880
#   Epoch  50: Train Acc=0.9925, Val Acc=0.9967, F1=0.9951
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9967, F1=0.9951
#   Early stopping at epoch 65
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9894, F1: 0.9865
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9027, Val Acc=0.9139, F1=0.8449
#   Epoch  20: Train Acc=0.9917, Val Acc=0.9834, F1=0.9797
#   Epoch  30: Train Acc=0.9992, Val Acc=0.9868, F1=0.9847
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9868, F1=0.9847
#   Early stopping at epoch 47
#   Best Val Acc: 0.9901
#
# [TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9828, F1: 0.9812
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9138, Val Acc=0.9205, F1=0.8891
#   Epoch  20: Train Acc=0.9872, Val Acc=0.9801, F1=0.9777
#   Epoch  30: Train Acc=0.9992, Val Acc=0.9917, F1=0.9919
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9868, F1=0.9866
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9901, F1=0.9902
#   Early stopping at epoch 50
#   Best Val Acc: 0.9917
#
# [Gated-TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9762, F1: 0.9727
#
# [Progress: 23/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_20PCT
# ================================================================================
#
# Loading Lying_TO_Standing_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Standing_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8542, Val Acc=0.8758, F1=0.8565
#   Epoch  20: Train Acc=0.9528, Val Acc=0.9520, F1=0.9458
#   Epoch  30: Train Acc=0.9751, Val Acc=0.9702, F1=0.9693
#   Epoch  40: Train Acc=0.9859, Val Acc=0.9917, F1=0.9899
#   Epoch  50: Train Acc=0.9942, Val Acc=0.9884, F1=0.9832
#   Epoch  60: Train Acc=0.9946, Val Acc=0.9917, F1=0.9885
#   Epoch  70: Train Acc=0.9954, Val Acc=0.9934, F1=0.9902
#   Early stopping at epoch 73
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9974, F1: 0.9962
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9056, Val Acc=0.9238, F1=0.8545
#   Epoch  20: Train Acc=0.9930, Val Acc=0.9801, F1=0.9787
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9868, F1=0.9872
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9884, F1=0.9880
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9884, F1=0.9885
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9901, F1=0.9902
#   Early stopping at epoch 65
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9907, F1: 0.9877
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9039, Val Acc=0.9272, F1=0.8881
#   Epoch  20: Train Acc=0.9909, Val Acc=0.9785, F1=0.9729
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9830
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9868, F1=0.9847
#   Early stopping at epoch 45
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9854, F1: 0.9825
#
# [Progress: 24/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_30PCT
# ================================================================================
#
# Loading Lying_TO_Standing_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Standing_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8505, Val Acc=0.8924, F1=0.8786
#   Epoch  20: Train Acc=0.9503, Val Acc=0.9503, F1=0.9460
#   Epoch  30: Train Acc=0.9739, Val Acc=0.9702, F1=0.9679
#   Epoch  40: Train Acc=0.9826, Val Acc=0.9901, F1=0.9898
#   Epoch  50: Train Acc=0.9925, Val Acc=0.9950, F1=0.9932
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9934, F1=0.9932
#   Early stopping at epoch 65
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9960, F1: 0.9950
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9159, Val Acc=0.9205, F1=0.8522
#   Epoch  20: Train Acc=0.9938, Val Acc=0.9851, F1=0.9796
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9868, F1=0.9835
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9884, F1=0.9852
#   Early stopping at epoch 41
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9801, F1: 0.9797
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9118, Val Acc=0.9288, F1=0.8932
#   Epoch  20: Train Acc=0.9959, Val Acc=0.9834, F1=0.9779
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9851, F1=0.9815
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9818, F1=0.9773
#   Early stopping at epoch 44
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9748, F1: 0.9751
#
# [Progress: 25/49]
#
# ================================================================================
# EXPERIMENT: Lying_TO_Standing_40PCT
# ================================================================================
#
# Loading Lying_TO_Standing_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Lying_TO_Standing_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8703, Val Acc=0.8791, F1=0.8578
#   Epoch  20: Train Acc=0.9495, Val Acc=0.9454, F1=0.9409
#   Epoch  30: Train Acc=0.9698, Val Acc=0.9702, F1=0.9694
#   Epoch  40: Train Acc=0.9805, Val Acc=0.9884, F1=0.9885
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9884, F1=0.9885
#   Epoch  60: Train Acc=0.9946, Val Acc=0.9934, F1=0.9936
#   Epoch  70: Train Acc=0.9946, Val Acc=0.9950, F1=0.9953
#   Early stopping at epoch 72
#   Best Val Acc: 0.9950
#
# [GAP Results]
#   Val Acc: 0.9950
#   Test Acc: 0.9974, F1: 0.9960
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9143, Val Acc=0.9139, F1=0.8446
#   Epoch  20: Train Acc=0.9921, Val Acc=0.9834, F1=0.9829
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9801, F1=0.9795
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9801, F1=0.9798
#   Early stopping at epoch 40
#   Best Val Acc: 0.9834
#
# [TPA Results]
#   Val Acc: 0.9834
#   Test Acc: 0.9841, F1: 0.9816
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.8998, Val Acc=0.9189, F1=0.8872
#   Epoch  20: Train Acc=0.9880, Val Acc=0.9801, F1=0.9801
#   Epoch  30: Train Acc=0.9992, Val Acc=0.9818, F1=0.9820
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9834, F1=0.9837
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9834, F1=0.9837
#   Early stopping at epoch 56
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9801, F1: 0.9802
#
# [Progress: 26/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_10PCT
# ================================================================================
#
# Loading Standing_TO_Walking_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Walking_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8343, Val Acc=0.8626, F1=0.8163
#   Epoch  20: Train Acc=0.9457, Val Acc=0.9437, F1=0.9390
#   Epoch  30: Train Acc=0.9698, Val Acc=0.9752, F1=0.9774
#   Epoch  40: Train Acc=0.9892, Val Acc=0.9801, F1=0.9835
#   Epoch  50: Train Acc=0.9892, Val Acc=0.9851, F1=0.9878
#   Epoch  60: Train Acc=0.9946, Val Acc=0.9901, F1=0.9915
#   Early stopping at epoch 65
#   Best Val Acc: 0.9917
#
# [GAP Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9934, F1: 0.9916
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9118, Val Acc=0.9040, F1=0.8368
#   Epoch  20: Train Acc=0.9921, Val Acc=0.9785, F1=0.9727
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9801, F1=0.9717
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9834, F1=0.9752
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9851, F1=0.9769
#   Epoch  60: Train Acc=0.9996, Val Acc=0.9851, F1=0.9769
#   Epoch  70: Train Acc=1.0000, Val Acc=0.9834, F1=0.9751
#   Early stopping at epoch 72
#   Best Val Acc: 0.9868
#
# [TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9801, F1: 0.9762
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.8989, Val Acc=0.8891, F1=0.8232
#   Epoch  20: Train Acc=0.9872, Val Acc=0.9785, F1=0.9705
#   Epoch  30: Train Acc=0.9963, Val Acc=0.9818, F1=0.9786
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9785, F1=0.9750
#   Epoch  50: Train Acc=0.9988, Val Acc=0.9801, F1=0.9772
#   Early stopping at epoch 55
#   Best Val Acc: 0.9868
#
# [Gated-TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9934, F1: 0.9932
#
# [Progress: 27/49]
#
# ================================================================================
# EXPERIMENT: Standing_TO_Walking_20PCT
# ================================================================================
#
# Loading Standing_TO_Walking_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Standing_TO_Walking_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8289, Val Acc=0.8460, F1=0.7984
#   Epoch  20: Train Acc=0.9412, Val Acc=0.9487, F1=0.9413
#   Epoch  30: Train Acc=0.9743, Val Acc=0.9735, F1=0.9746
#   Epoch  40: Train Acc=0.9863, Val Acc=0.9818, F1=0.9833
#   Epoch  50: Train Acc=0.9872, Val Acc=0.9834, F1=0.9847
#   Epoch  60: Train Acc=0.9950, Val Acc=0.9917, F1=0.9916
#   Early stopping at epoch 65
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9907, F1: 0.9910
#
# [Training TPA]
# ...
#
# [TPA Results]
#   Val Acc: 0.9752
#   Test Acc: 0.9801, F1: 0.9771
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9072, Val Acc=0.9222, F1=0.8674
#   Epoch  20: Train Acc=0.9867, Val Acc=0.9785, F1=0.9701
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9818, F1=0.9776
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9818, F1=0.9757
#   Early stopping at epoch 43
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9828, F1: 0.9810
#
# [Progress: 42/49]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Climbing_stairs_10PCT
# ================================================================================
#
# Loading Walking_TO_Climbing_stairs_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Walking_TO_Climbing_stairs_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8521, Val Acc=0.8659, F1=0.8379
#   Epoch  20: Train Acc=0.9416, Val Acc=0.9503, F1=0.9480
#   Epoch  30: Train Acc=0.9756, Val Acc=0.9702, F1=0.9691
#   Epoch  40: Train Acc=0.9838, Val Acc=0.9868, F1=0.9864
#   Epoch  50: Train Acc=0.9876, Val Acc=0.9917, F1=0.9915
#   Epoch  60: Train Acc=0.9921, Val Acc=0.9917, F1=0.9914
#   Epoch  70: Train Acc=0.9942, Val Acc=0.9934, F1=0.9932
#   Early stopping at epoch 71
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9987, F1: 0.9986
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9325, Val Acc=0.9354, F1=0.9336
#   Epoch  20: Train Acc=0.9913, Val Acc=0.9785, F1=0.9777
#   Epoch  30: Train Acc=0.9963, Val Acc=0.9785, F1=0.9777
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9801, F1=0.9794
#   Epoch  50: Train Acc=0.9988, Val Acc=0.9801, F1=0.9794
#   Early stopping at epoch 52
#   Best Val Acc: 0.9851
#
# [TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9947, F1: 0.9944
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9171, Val Acc=0.9487, F1=0.9466
#   Epoch  20: Train Acc=0.9847, Val Acc=0.9801, F1=0.9793
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9868, F1=0.9862
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9868, F1=0.9863
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9851, F1=0.9846
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9851, F1=0.9845
#   Early stopping at epoch 69
#   Best Val Acc: 0.9917
#
# [Gated-TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9907, F1: 0.9909
#
# [Progress: 43/49]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Climbing_stairs_20PCT
# ================================================================================
#
# Loading Walking_TO_Climbing_stairs_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Walking_TO_Climbing_stairs_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8579, Val Acc=0.8659, F1=0.8363
#   Epoch  20: Train Acc=0.9482, Val Acc=0.9487, F1=0.9462
#   Epoch  30: Train Acc=0.9764, Val Acc=0.9752, F1=0.9741
#   Epoch  40: Train Acc=0.9863, Val Acc=0.9901, F1=0.9898
#   Epoch  50: Train Acc=0.9913, Val Acc=0.9950, F1=0.9949
#   Epoch  60: Train Acc=0.9942, Val Acc=0.9967, F1=0.9966
#   Epoch  70: Train Acc=0.9950, Val Acc=0.9983, F1=0.9983
#   Epoch  80: Train Acc=0.9963, Val Acc=0.9967, F1=0.9966
#   Early stopping at epoch 82
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9960, F1: 0.9961
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9254, Val Acc=0.9603, F1=0.9588
#   Epoch  20: Train Acc=0.9946, Val Acc=0.9851, F1=0.9845
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9884, F1=0.9878
#   Early stopping at epoch 38
#   Best Val Acc: 0.9934
#
# [TPA Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9815, F1: 0.9810
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9296, Val Acc=0.9487, F1=0.9465
#   Epoch  20: Train Acc=0.9859, Val Acc=0.9834, F1=0.9825
#   Epoch  30: Train Acc=0.9954, Val Acc=0.9851, F1=0.9842
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9868, F1=0.9861
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9901, F1=0.9896
#   Epoch  60: Train Acc=1.0000, Val Acc=0.9901, F1=0.9896
#   Early stopping at epoch 64
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9907, F1: 0.9906
#
# [Progress: 44/49]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Climbing_stairs_30PCT
# ================================================================================
#
# Loading Walking_TO_Climbing_stairs_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Walking_TO_Climbing_stairs_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8571, Val Acc=0.8808, F1=0.8611
#   Epoch  20: Train Acc=0.9424, Val Acc=0.9536, F1=0.9531
#   Epoch  30: Train Acc=0.9789, Val Acc=0.9818, F1=0.9822
#   Epoch  40: Train Acc=0.9884, Val Acc=0.9901, F1=0.9908
#   Epoch  50: Train Acc=0.9913, Val Acc=0.9917, F1=0.9926
#   Epoch  60: Train Acc=0.9942, Val Acc=0.9950, F1=0.9957
#   Epoch  70: Train Acc=0.9942, Val Acc=0.9967, F1=0.9971
#   Epoch  80: Train Acc=0.9971, Val Acc=0.9967, F1=0.9971
#   Early stopping at epoch 81
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9934, F1: 0.9932
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9238, Val Acc=0.9520, F1=0.9516
#   Epoch  20: Train Acc=0.9934, Val Acc=0.9868, F1=0.9863
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9884, F1=0.9879
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9884, F1=0.9880
#   Epoch  50: Train Acc=0.9992, Val Acc=0.9917, F1=0.9913
#   Early stopping at epoch 53
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9788, F1: 0.9782
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9242, Val Acc=0.9437, F1=0.9438
#   Epoch  20: Train Acc=0.9913, Val Acc=0.9884, F1=0.9885
#   Epoch  30: Train Acc=0.9971, Val Acc=0.9851, F1=0.9851
#   Epoch  40: Train Acc=0.9983, Val Acc=0.9901, F1=0.9897
#   Epoch  50: Train Acc=0.9983, Val Acc=0.9917, F1=0.9915
#   Epoch  60: Train Acc=0.9996, Val Acc=0.9934, F1=0.9932
#   Epoch  70: Train Acc=1.0000, Val Acc=0.9917, F1=0.9914
#   Early stopping at epoch 79
#   Best Val Acc: 0.9934
#
# [Gated-TPA Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9788, F1: 0.9781
#
# [Progress: 45/49]
#
# ================================================================================
# EXPERIMENT: Walking_TO_Climbing_stairs_40PCT
# ================================================================================
#
# Loading Walking_TO_Climbing_stairs_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Walking_TO_Climbing_stairs_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8683, Val Acc=0.8907, F1=0.8763
#   Epoch  20: Train Acc=0.9437, Val Acc=0.9520, F1=0.9501
#   Epoch  30: Train Acc=0.9772, Val Acc=0.9768, F1=0.9760
#   Epoch  40: Train Acc=0.9855, Val Acc=0.9934, F1=0.9935
#   Epoch  50: Train Acc=0.9896, Val Acc=0.9917, F1=0.9917
#   Epoch  60: Train Acc=0.9954, Val Acc=0.9917, F1=0.9917
#   Early stopping at epoch 60
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9881, F1: 0.9881
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9209, Val Acc=0.9371, F1=0.9348
#   Epoch  20: Train Acc=0.9942, Val Acc=0.9884, F1=0.9878
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9917, F1=0.9916
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9901, F1=0.9898
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9868, F1=0.9864
#   Early stopping at epoch 50
#   Best Val Acc: 0.9917
#
# [TPA Results]
#   Val Acc: 0.9917
#   Test Acc: 0.9762, F1: 0.9761
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9221, Val Acc=0.9487, F1=0.9475
#   Epoch  20: Train Acc=0.9942, Val Acc=0.9818, F1=0.9810
#   Epoch  30: Train Acc=0.9979, Val Acc=0.9868, F1=0.9862
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9834, F1=0.9828
#   Epoch  50: Train Acc=0.9996, Val Acc=0.9851, F1=0.9847
#   Early stopping at epoch 50
#   Best Val Acc: 0.9868
#
# [Gated-TPA Results]
#   Val Acc: 0.9868
#   Test Acc: 0.9801, F1: 0.9799
#
# [Progress: 46/49]
#
# ================================================================================
# EXPERIMENT: Climbing_stairs_TO_Walking_10PCT
# ================================================================================
#
# Loading Climbing_stairs_TO_Walking_10PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Climbing_stairs_TO_Walking_10PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7465, Val Acc=0.7450, F1=0.7281
#   Epoch  20: Train Acc=0.9470, Val Acc=0.9536, F1=0.9501
#   Epoch  30: Train Acc=0.9735, Val Acc=0.9834, F1=0.9815
#   Epoch  40: Train Acc=0.9863, Val Acc=0.9950, F1=0.9953
#   Epoch  50: Train Acc=0.9921, Val Acc=0.9917, F1=0.9902
#   Epoch  60: Train Acc=0.9917, Val Acc=0.9967, F1=0.9949
#   Epoch  70: Train Acc=0.9959, Val Acc=0.9983, F1=0.9983
#   Epoch  80: Train Acc=0.9946, Val Acc=0.9950, F1=0.9937
#   Early stopping at epoch 81
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9960, F1: 0.9946
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9238, Val Acc=0.9305, F1=0.8649
#   Epoch  20: Train Acc=0.9967, Val Acc=0.9851, F1=0.9797
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9834, F1=0.9780
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9851, F1=0.9821
#   Early stopping at epoch 46
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9828, F1: 0.9796
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9267, Val Acc=0.9454, F1=0.9071
#   Epoch  20: Train Acc=0.9901, Val Acc=0.9834, F1=0.9798
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9834, F1=0.9820
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9818, F1=0.9788
#   Early stopping at epoch 48
#   Best Val Acc: 0.9851
#
# [Gated-TPA Results]
#   Val Acc: 0.9851
#   Test Acc: 0.9815, F1: 0.9789
#
# [Progress: 47/49]
#
# ================================================================================
# EXPERIMENT: Climbing_stairs_TO_Walking_20PCT
# ================================================================================
#
# Loading Climbing_stairs_TO_Walking_20PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Climbing_stairs_TO_Walking_20PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.7775, Val Acc=0.7533, F1=0.7364
#   Epoch  20: Train Acc=0.9482, Val Acc=0.9487, F1=0.9471
#   Epoch  30: Train Acc=0.9772, Val Acc=0.9851, F1=0.9823
#   Epoch  40: Train Acc=0.9888, Val Acc=0.9917, F1=0.9902
#   Epoch  50: Train Acc=0.9925, Val Acc=0.9917, F1=0.9869
#   Epoch  60: Train Acc=0.9938, Val Acc=0.9934, F1=0.9904
#   Early stopping at epoch 65
#   Best Val Acc: 0.9934
#
# [GAP Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9881, F1: 0.9867
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9184, Val Acc=0.9371, F1=0.8711
#   Epoch  20: Train Acc=0.9954, Val Acc=0.9851, F1=0.9772
#   Epoch  30: Train Acc=0.9996, Val Acc=0.9818, F1=0.9727
#   Epoch  40: Train Acc=1.0000, Val Acc=0.9834, F1=0.9745
#   Early stopping at epoch 45
#   Best Val Acc: 0.9884
#
# [TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9907, F1: 0.9881
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9263, Val Acc=0.9520, F1=0.9271
#   Epoch  20: Train Acc=0.9917, Val Acc=0.9851, F1=0.9816
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9884, F1=0.9847
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9868, F1=0.9830
#   Early stopping at epoch 48
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9815, F1: 0.9790
#
# [Progress: 48/49]
#
# ================================================================================
# EXPERIMENT: Climbing_stairs_TO_Walking_30PCT
# ================================================================================
#
# Loading Climbing_stairs_TO_Walking_30PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Climbing_stairs_TO_Walking_30PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8268, Val Acc=0.8262, F1=0.8183
#   Epoch  20: Train Acc=0.9457, Val Acc=0.9520, F1=0.9506
#   Epoch  30: Train Acc=0.9747, Val Acc=0.9702, F1=0.9724
#   Epoch  40: Train Acc=0.9884, Val Acc=0.9868, F1=0.9867
#   Epoch  50: Train Acc=0.9901, Val Acc=0.9967, F1=0.9970
#   Epoch  60: Train Acc=0.9888, Val Acc=0.9950, F1=0.9953
#   Early stopping at epoch 64
#   Best Val Acc: 0.9967
#
# [GAP Results]
#   Val Acc: 0.9967
#   Test Acc: 0.9934, F1: 0.9939
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9271, Val Acc=0.9238, F1=0.8587
#   Epoch  20: Train Acc=0.9930, Val Acc=0.9868, F1=0.9851
#   Epoch  30: Train Acc=0.9988, Val Acc=0.9901, F1=0.9881
#   Epoch  40: Train Acc=0.9996, Val Acc=0.9868, F1=0.9835
#   Early stopping at epoch 42
#   Best Val Acc: 0.9901
#
# [TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9881, F1: 0.9858
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9196, Val Acc=0.9205, F1=0.8768
#   Epoch  20: Train Acc=0.9905, Val Acc=0.9868, F1=0.9851
#   Epoch  30: Train Acc=0.9983, Val Acc=0.9884, F1=0.9864
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9917, F1=0.9914
#   Early stopping at epoch 47
#   Best Val Acc: 0.9934
#
# [Gated-TPA Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9775, F1: 0.9729
#
# [Progress: 49/49]
#
# ================================================================================
# EXPERIMENT: Climbing_stairs_TO_Walking_40PCT
# ================================================================================
#
# Loading Climbing_stairs_TO_Walking_40PCT...
#   Path: /content/drive/MyDrive/AI_data/TPA2/mhealth_transition_datasets/Climbing_stairs_TO_Walking_40PCT
#   Train: (3018, 200, 23), Test: (755, 200, 23)
#
# Dataset splits:
#   Train: 2414, Val: 604, Test: 755
#
# [Training GAP]
#   Epoch  10: Train Acc=0.8409, Val Acc=0.8526, F1=0.8355
#   Epoch  20: Train Acc=0.9428, Val Acc=0.9536, F1=0.9543
#   Epoch  30: Train Acc=0.9764, Val Acc=0.9801, F1=0.9796
#   Epoch  40: Train Acc=0.9905, Val Acc=0.9901, F1=0.9886
#   Epoch  50: Train Acc=0.9917, Val Acc=0.9983, F1=0.9971
#   Epoch  60: Train Acc=0.9917, Val Acc=0.9983, F1=0.9971
#   Early stopping at epoch 62
#   Best Val Acc: 0.9983
#
# [GAP Results]
#   Val Acc: 0.9983
#   Test Acc: 0.9881, F1: 0.9874
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9188, Val Acc=0.9354, F1=0.8853
#   Epoch  20: Train Acc=0.9938, Val Acc=0.9818, F1=0.9782
#   Epoch  30: Train Acc=0.9996, Val Acc=0.9851, F1=0.9816
#   Epoch  40: Train Acc=0.9992, Val Acc=0.9901, F1=0.9868
#   Epoch  50: Train Acc=1.0000, Val Acc=0.9917, F1=0.9884
#   Epoch  60: Train Acc=0.9996, Val Acc=0.9901, F1=0.9867
#   Early stopping at epoch 68
#   Best Val Acc: 0.9934
#
# [TPA Results]
#   Val Acc: 0.9934
#   Test Acc: 0.9868, F1: 0.9851
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9221, Val Acc=0.9454, F1=0.9212
#   Epoch  20: Train Acc=0.9930, Val Acc=0.9768, F1=0.9730
#   Epoch  30: Train Acc=0.9975, Val Acc=0.9868, F1=0.9832
#   Epoch  40: Train Acc=0.9988, Val Acc=0.9884, F1=0.9850
#   Early stopping at epoch 48
#   Best Val Acc: 0.9884
#
# [Gated-TPA Results]
#   Val Acc: 0.9884
#   Test Acc: 0.9788, F1: 0.9772
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_transition_mhealth_cnn.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 147
# Total datasets tested: 49
# Models compared: 3 (GAP, TPA, Gated-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE (All Datasets)
# ================================================================================
# GAP         : Acc=0.9937, F1=0.9930
# TPA         : Acc=0.9826, F1=0.9803
# Gated-TPA   : Acc=0.9832, F1=0.9818
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
