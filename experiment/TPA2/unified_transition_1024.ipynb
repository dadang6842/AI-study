# %%
# -*- coding: utf-8 -*-
"""Unified Model Comparison: GAP, TPA, Gated-TPA
Compare three models on 41 pre-augmented transition datasets
(1 original + 40 transition datasets)
"""

from google.colab import drive
drive.mount('/content/drive')

import os, random, time, copy, json
import numpy as np
from typing import Tuple, Dict, List
from dataclasses import dataclass

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# ========================
# Config & Reproducibility
# ========================
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

@dataclass
class Config:
    data_dir: str = "/content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets"
    save_dir: str = "/content/drive/MyDrive/AI_data/TPA2"

    epochs: int = 100
    batch_size: int = 128
    lr: float = 1e-4
    weight_decay: float = 1e-4
    grad_clip: float = 1.0
    label_smoothing: float = 0.05

    patience: int = 20
    min_delta: float = 0.0001
    val_split: float = 0.2

    d_model: int = 128

    # TPA hyperparameters
    tpa_num_prototypes: int = 16
    tpa_heads: int = 4
    tpa_dropout: float = 0.1
    tpa_temperature: float = 0.07
    tpa_topk_ratio: float = 0.25

    device: str = "cuda" if torch.cuda.is_available() else "cpu"
    num_workers: int = 2

cfg = Config()

# ========================
# Dataset Class
# ========================
class PreloadedDataset(Dataset):
    """Dataset for pre-loaded numpy arrays"""
    def __init__(self, X: np.ndarray, y: np.ndarray):
        super().__init__()
        self.X = torch.from_numpy(X).float()

        # Label 범위 확인 및 조정 (1-6 -> 0-5)
        if y.min() >= 1:
            y = y - 1

        self.y = torch.from_numpy(y).long()

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# ========================
# Data Loading Functions
# ========================
def load_dataset(base_dir: str, dataset_name: str):
    """
    Load pre-augmented dataset
    Args:
        base_dir: base directory containing all datasets
        dataset_name: e.g., "ORIGINAL", "STANDING_TO_SITTING_10pct", etc.
    Returns:
        train_dataset, test_dataset
    """
    dataset_dir = os.path.join(base_dir, dataset_name)

    print(f"\nLoading {dataset_name}...")
    print(f"  Path: {dataset_dir}")

    # Load data
    X_train = np.load(os.path.join(dataset_dir, "X_train.npy"))
    y_train = np.load(os.path.join(dataset_dir, "y_train.npy"))
    X_test = np.load(os.path.join(dataset_dir, "X_test.npy"))
    y_test = np.load(os.path.join(dataset_dir, "y_test.npy"))

    print(f"  Train: {X_train.shape}, Test: {X_test.shape}")

    train_dataset = PreloadedDataset(X_train, y_train)
    test_dataset = PreloadedDataset(X_test, y_test)

    return train_dataset, test_dataset

# ========================
# Model Components
# ========================
class ConvBNAct(nn.Module):
    def __init__(self, c_in, c_out, k, s=1, p=None, g=1):
        super().__init__()
        self.c = nn.Conv1d(c_in, c_out, k, s, k//2 if p is None else p, groups=g, bias=False)
        self.bn = nn.BatchNorm1d(c_out)
        self.act = nn.GELU()

    def forward(self, x):
        return self.act(self.bn(self.c(x)))

class MultiPathCNN(nn.Module):
    """Shared backbone for all models"""
    def __init__(self, in_ch=9, d_model=128, branches=(3,5,9,15), stride=2):
        super().__init__()
        h = d_model // 2
        self.pre = ConvBNAct(in_ch, h, 1)
        self.branches = nn.ModuleList([
            nn.Sequential(ConvBNAct(h, h, k, stride, g=h), ConvBNAct(h, h, 1))
            for k in branches
        ])
        self.post = ConvBNAct(len(branches)*h, d_model, 1)

    def forward(self, x):
        return self.post(torch.cat([b(self.pre(x)) for b in self.branches], dim=1))

# ========================
# GAP Model
# ========================
class GAPModel(nn.Module):
    """Baseline: Global Average Pooling"""
    def __init__(self, d_model=128, num_classes=6):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.fc = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        pooled = features.mean(dim=1)  # [B, D]
        logits = self.fc(pooled)
        return logits

# ========================
# Pure-TPA
# ========================
class ProductionTPA(nn.Module):
    """Pure TPA"""
    def __init__(self, dim, num_prototypes=16, heads=4, dropout=0.1,
                 temperature=0.07, topk_ratio=0.25):
        super().__init__()
        assert dim % heads == 0

        self.dim = dim
        self.heads = heads
        self.head_dim = dim // heads
        self.num_prototypes = num_prototypes
        self.temperature = temperature
        self.topk_ratio = topk_ratio

        self.proto = nn.Parameter(torch.randn(num_prototypes, dim) * 0.02)

        self.pre_norm = nn.LayerNorm(dim)

        self.q_proj = nn.Linear(dim, dim, bias=False)
        self.k_proj = nn.Linear(dim, dim, bias=False)
        self.v_proj = nn.Linear(dim, dim, bias=False)

        self.fuse = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(dim, dim)
        )

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, D = x.shape
        P = self.num_prototypes

        x_norm = self.pre_norm(x)

        K = self.k_proj(x_norm)
        V = self.v_proj(x_norm)
        Qp = self.q_proj(self.proto).unsqueeze(0).expand(B, -1, -1)

        def split_heads(t, length):
            return t.view(B, length, self.heads, self.head_dim).transpose(1, 2)

        Qh = split_heads(Qp, P)
        Kh = split_heads(K, T)
        Vh = split_heads(V, T)

        Qh = F.normalize(Qh, dim=-1)
        Kh = F.normalize(Kh, dim=-1)

        scores = torch.matmul(Qh, Kh.transpose(-2, -1)) / self.temperature
        attn = F.softmax(scores, dim=-1)
        attn = torch.nan_to_num(attn, nan=0.0)
        attn = self.dropout(attn)

        proto_tokens = torch.matmul(attn, Vh)
        proto_tokens = proto_tokens.transpose(1, 2).contiguous().view(B, P, D)

        z_tpa = proto_tokens.mean(dim=1)

        z = self.fuse(z_tpa)

        return z

class TPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )
        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]
        z = self.tpa(features)  # [B, D]
        logits = self.classifier(z)
        return logits

# ========================
# Gated-TPA
# ========================
class GatedTPAModel(nn.Module):
    def __init__(self, d_model=128, num_classes=6, tpa_config=None):
        super().__init__()
        self.backbone = MultiPathCNN(d_model=d_model)
        self.tpa = ProductionTPA(
            dim=d_model,
            num_prototypes=tpa_config['num_prototypes'],
            heads=tpa_config['heads'],
            dropout=tpa_config['dropout'],
            temperature=tpa_config['temperature'],
            topk_ratio=tpa_config['topk_ratio']
        )

        # Gating mechanism
        self.gate = nn.Sequential(
            nn.Linear(d_model * 2, d_model),
            nn.Sigmoid()
        )

        self.classifier = nn.Linear(d_model, num_classes)

    def forward(self, x):
        fmap = self.backbone(x)  # [B, D, T]
        features = fmap.transpose(1, 2)  # [B, T, D]

        # GAP branch
        z_gap = features.mean(dim=1)  # [B, D]

        # TPA branch
        z_tpa = self.tpa(features)  # [B, D]

        # Gating
        gate_input = torch.cat([z_gap, z_tpa], dim=-1)
        g = self.gate(gate_input)

        # Gated fusion
        z = g * z_gap + (1 - g) * z_tpa

        logits = self.classifier(z)
        return logits

# ========================
# Training & Evaluation
# ========================
def train_one_epoch(model, loader, opt, cfg: Config):
    model.train()
    total, correct, loss_sum = 0, 0, 0.0

    for x, y in loader:
        x, y = x.to(cfg.device).float(), y.to(cfg.device)

        opt.zero_grad(set_to_none=True)
        logits = model(x)

        loss = F.cross_entropy(logits, y, label_smoothing=cfg.label_smoothing)
        if torch.isnan(loss):
            continue

        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip)
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(dim=-1)
            correct += (pred == y).sum().item()
            total += y.size(0)
            loss_sum += loss.item() * y.size(0)

    return {
        "loss": loss_sum / total if total > 0 else 0,
        "acc": correct / total if total > 0 else 0
    }

@torch.no_grad()
def evaluate(model, loader, cfg: Config):
    model.eval()
    ys, ps = [], []

    for x, y in loader:
        x, y = x.to(cfg.device), y.to(cfg.device)
        logits = model(x)
        ps.append(logits.argmax(dim=-1).cpu().numpy())
        ys.append(y.cpu().numpy())

    y_true, y_pred = np.concatenate(ys), np.concatenate(ps)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average='macro')

    return acc, f1

def train_model(model, train_loader, val_loader, cfg: Config, model_name: str):
    """Train a single model"""
    print(f"\n[Training {model_name}]")

    opt = torch.optim.AdamW(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    best_acc, best_wts = 0.0, None
    patience_counter = 0

    for epoch in range(1, cfg.epochs + 1):
        stats = train_one_epoch(model, train_loader, opt, cfg)
        val_acc, val_f1 = evaluate(model, val_loader, cfg)

        if val_acc > best_acc + cfg.min_delta:
            best_acc = val_acc
            best_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1

        if epoch % 10 == 0:
            print(f"  Epoch {epoch:3d}: Train Acc={stats['acc']:.4f}, Val Acc={val_acc:.4f}, F1={val_f1:.4f}")

        if patience_counter >= cfg.patience:
            print(f"  Early stopping at epoch {epoch}")
            break

    if best_wts:
        model.load_state_dict(best_wts)

    print(f"  Best Val Acc: {best_acc:.4f}")
    return best_acc

def create_model(model_name: str, cfg: Config):
    """Create model by name"""
    tpa_config = {
        'num_prototypes': cfg.tpa_num_prototypes,
        'heads': cfg.tpa_heads,
        'dropout': cfg.tpa_dropout,
        'temperature': cfg.tpa_temperature,
        'topk_ratio': cfg.tpa_topk_ratio
    }

    if model_name == "GAP":
        return GAPModel(d_model=cfg.d_model).to(cfg.device).float()
    elif model_name == "TPA":
        return TPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    elif model_name == "Gated-TPA":
        return GatedTPAModel(d_model=cfg.d_model, tpa_config=tpa_config).to(cfg.device).float()
    else:
        raise ValueError(f"Unknown model: {model_name}")

# ========================
# Main Experiment
# ========================
def run_experiment(dataset_name: str, cfg: Config):
    """Run complete experiment for one dataset"""

    print(f"\n{'='*80}")
    print(f"EXPERIMENT: {dataset_name}")
    print(f"{'='*80}")

    # Load data
    train_dataset, test_dataset = load_dataset(cfg.data_dir, dataset_name)

    # Split train into train/val using indices
    n_total = len(train_dataset)
    indices = np.arange(n_total)

    # Get labels for stratification
    y_labels = train_dataset.y.numpy()

    train_indices, val_indices = train_test_split(
        indices,
        test_size=cfg.val_split,
        random_state=SEED,
        stratify=y_labels
    )

    # Create subsets using Subset
    from torch.utils.data import Subset
    train_subset = Subset(train_dataset, train_indices)
    val_subset = Subset(train_dataset, val_indices)

    # Create data loaders
    g = torch.Generator(device='cpu').manual_seed(SEED)
    train_loader = DataLoader(train_subset, cfg.batch_size, shuffle=True,
                              num_workers=cfg.num_workers, generator=g)
    val_loader = DataLoader(val_subset, cfg.batch_size, num_workers=cfg.num_workers)
    test_loader = DataLoader(test_dataset, cfg.batch_size, num_workers=cfg.num_workers)

    print(f"\nDataset splits:")
    print(f"  Train: {len(train_subset)}, Val: {len(val_subset)}, Test: {len(test_dataset)}")

    # Train and evaluate all models
    results = []
    model_names = ["GAP", "TPA", "Gated-TPA"]

    for model_name in model_names:
        # Reset seed for each model
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)

        # Create and train model
        model = create_model(model_name, cfg)
        best_val_acc = train_model(model, train_loader, val_loader, cfg, model_name)

        # Evaluate on test set
        test_acc, test_f1 = evaluate(model, test_loader, cfg)

        print(f"\n[{model_name} Results]")
        print(f"  Val Acc: {best_val_acc:.4f}")
        print(f"  Test Acc: {test_acc:.4f}, F1: {test_f1:.4f}")

        results.append({
            'Model': model_name,
            'Dataset': dataset_name,
            'Val_Accuracy': float(best_val_acc),
            'Test_Accuracy': float(test_acc),
            'Test_F1_Score': float(test_f1)
        })

    return results

# ========================
# Run All Experiments
# ========================
if __name__ == "__main__":
    print("\n" + "="*80)
    print("UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA")
    print("Testing on 41 Datasets (1 Original + 40 Transition)")
    print("="*80)

    # Define all 41 datasets
    datasets = ["ORIGINAL"]  # 원본 데이터셋

    # 정적 활동 전이 (6개 × 4개 비율 = 24개)
    static_transitions = [
        "STANDING_TO_SITTING",
        "STANDING_TO_LAYING",
        "SITTING_TO_LAYING",
        "SITTING_TO_STANDING",
        "LAYING_TO_SITTING",
        "LAYING_TO_STANDING"
    ]

    # 걷기 활동 전이 (4개 × 4개 비율 = 16개)
    walking_transitions = [
        "WALKING_TO_WALKING_UPSTAIRS",
        "WALKING_TO_WALKING_DOWNSTAIRS",
        "WALKING_UPSTAIRS_TO_WALKING",
        "WALKING_DOWNSTAIRS_TO_WALKING"
    ]

    # 모든 전이에 대해 10%, 20%, 30%, 40% 추가
    mix_pcts = [10, 20, 30, 40]

    for transition in static_transitions + walking_transitions:
        for pct in mix_pcts:
            datasets.append(f"{transition}_{pct}pct")

    print(f"\nTotal datasets to test: {len(datasets)}")
    print(f"  - Original: 1")
    print(f"  - Static transitions: {len(static_transitions) * len(mix_pcts)}")
    print(f"  - Walking transitions: {len(walking_transitions) * len(mix_pcts)}")

    all_results = []

    # Run experiments
    for i, dataset_name in enumerate(datasets, 1):
        print(f"\n[Progress: {i}/{len(datasets)}]")
        results = run_experiment(dataset_name, cfg)
        all_results.extend(results)

    # Save all results
    print(f"\n{'='*80}")
    print("SAVING RESULTS")
    print(f"{'='*80}")

    results_dict = {
        'experiment_info': {
            'date': time.strftime('%Y-%m-%d %H:%M:%S'),
            'models': ['GAP', 'TPA', 'Gated-TPA'],
            'total_datasets': len(datasets),
            'datasets': datasets,
            'config': {
                'epochs': cfg.epochs,
                'batch_size': cfg.batch_size,
                'lr': cfg.lr,
                'd_model': cfg.d_model,
                'tpa_num_prototypes': cfg.tpa_num_prototypes,
                'tpa_heads': cfg.tpa_heads
            }
        },
        'results': all_results
    }

    # Save to JSON
    json_path = os.path.join(cfg.save_dir, "unified_comparison_41datasets_results.json")
    with open(json_path, 'w') as f:
        json.dump(results_dict, f, indent=2)

    print(f"\nResults saved to: {json_path}")

    # Print summary
    print(f"\n{'='*80}")
    print("SUMMARY")
    print(f"{'='*80}")
    print(f"Total experiments: {len(all_results)}")
    print(f"Total datasets tested: {len(datasets)}")
    print(f"Models compared: 3 (GAP, TPA, Gated-TPA)")

    # Calculate average performance per model
    print(f"\n{'='*80}")
    print("AVERAGE PERFORMANCE (All Datasets)")
    print(f"{'='*80}")

    for model_name in ['GAP', 'TPA', 'Gated-TPA']:
        model_results = [r for r in all_results if r['Model'] == model_name]
        avg_acc = np.mean([r['Test_Accuracy'] for r in model_results])
        avg_f1 = np.mean([r['Test_F1_Score'] for r in model_results])
        print(f"{model_name:12s}: Acc={avg_acc:.4f}, F1={avg_f1:.4f}")

    print(f"\n{'='*80}")
    print("EXPERIMENT COMPLETE")
    print(f"{'='*80}")
# Out:
# Mounted at /content/drive
#
# ================================================================================
# UNIFIED MODEL COMPARISON: GAP vs TPA vs Gated-TPA
# Testing on 41 Datasets (1 Original + 40 Transition)
# ================================================================================
#
# Total datasets to test: 41
#   - Original: 1
#   - Static transitions: 24
#   - Walking transitions: 16
#
# [Progress: 1/41]
#
# ================================================================================
# EXPERIMENT: ORIGINAL
# ================================================================================
#
# Loading ORIGINAL...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/ORIGINAL
#   Train: (7352, 9, 128), Test: (2947, 9, 128)
#
# Dataset splits:
#   Train: 5881, Val: 1471, Test: 2947
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9459, Val Acc=0.9409, F1=0.9444
#   Epoch  20: Train Acc=0.9488, Val Acc=0.9606, F1=0.9636
#   Epoch  30: Train Acc=0.9520, Val Acc=0.9551, F1=0.9585
#   Epoch  40: Train Acc=0.9520, Val Acc=0.9551, F1=0.9585
#   Early stopping at epoch 47
#   Best Val Acc: 0.9640
#
# [GAP Results]
#   Val Acc: 0.9640
#   Test Acc: 0.9128, F1: 0.9127
#
# [Training TPA]
#   Epoch  10: Train Acc=0.
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9541, Val Acc=0.9623, F1=0.9685
#   Epoch  20: Train Acc=0.9632, Val Acc=0.9672, F1=0.9725
#   Epoch  30: Train Acc=0.9697, Val Acc=0.9765, F1=0.9801
#   Epoch  40: Train Acc=0.9773, Val Acc=0.9728, F1=0.9771
#   Epoch  50: Train Acc=0.9832, Val Acc=0.9790, F1=0.9824
#   Epoch  60: Train Acc=0.9852, Val Acc=0.9790, F1=0.9823
#   Epoch  70: Train Acc=0.9878, Val Acc=0.9778, F1=0.9812
#   Epoch  80: Train Acc=0.9862, Val Acc=0.9821, F1=0.9847
#   Epoch  90: Train Acc=0.9912, Val Acc=0.9858, F1=0.9879
#   Early stopping at epoch 97
#   Best Val Acc: 0.9876
#
# [Gated-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9401, F1: 0.9400
#
# [Progress: 6/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING_10pct
# ================================================================================
#
# Loading STANDING_TO_LAYING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9371, Val Acc=0.9357, F1=0.9419
#   Epoch  20: Train Acc=0.9482, Val Acc=0.9481, F1=0.9554
#   Epoch  30: Train Acc=0.9564, Val Acc=0.9604, F1=0.9665
#   Epoch  40: Train Acc=0.9581, Val Acc=0.9536, F1=0.9598
#   Early stopping at epoch 43
#   Best Val Acc: 0.9635
#
# [GAP Results]
#   Val Acc: 0.9635
#   Test Acc: 0.9142, F1: 0.9154
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9620, Val Acc=0.9642, F1=0.9696
#   Epoch  20: Train Acc=0.9691, Val Acc=0.9679, F1=0.9726
#   Epoch  30: Train Acc=0.9750, Val Acc=0.9728, F1=0.9763
#   Epoch  40: Train Acc=0.9797, Val Acc=0.9778, F1=0.9806
#   Epoch  50: Train Acc=0.9845, Val Acc=0.9771, F1=0.9806
#   Epoch  60: Train Acc=0.9876, Val Acc=0.9802, F1=0.9826
#   Epoch  70: Train Acc=0.9898, Val Acc=0.9790, F1=0.9819
#   Epoch  80: Train Acc=0.9920, Val Acc=0.9821, F1=0.9845
#   Epoch  90: Train Acc=0.9918, Val Acc=0.9870, F1=0.9887
#   Epoch 100: Train Acc=0.9920, Val Acc=0.9870, F1=0.9887
#   Best Val Acc: 0.9889
#
# [TPA Results]
#   Val Acc: 0.9889
#   Test Acc: 0.9429, F1: 0.9431
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9615, Val Acc=0.9604, F1=0.9665
#   Epoch  20: Train Acc=0.9691, Val Acc=0.9642, F1=0.9694
#   Epoch  30: Train Acc=0.9736, Val Acc=0.9710, F1=0.9748
#   Epoch  40: Train Acc=0.9804, Val Acc=0.9753, F1=0.9791
#   Epoch  50: Train Acc=0.9841, Val Acc=0.9815, F1=0.9842
#   Epoch  60: Train Acc=0.9861, Val Acc=0.9858, F1=0.9877
#   Epoch  70: Train Acc=0.9884, Val Acc=0.9845, F1=0.9866
#   Epoch  80: Train Acc=0.9892, Val Acc=0.9864, F1=0.9880
#   Epoch  90: Train Acc=0.9883, Val Acc=0.9883, F1=0.9897
#   Early stopping at epoch 98
#   Best Val Acc: 0.9901
#
# [Gated-TPA Results]
#   Val Acc: 0.9901
#   Test Acc: 0.9432, F1: 0.9418
#
# [Progress: 7/41]
#
# ================================================================================
# EXPERIMENT: STANDING_TO_LAYING_20pct
# ================================================================================
#
# Loading STANDING_TO_LAYING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/STANDING_TO_LAYING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.
#   Epoch  60: Train Acc=0.9819, Val Acc=0.9771, F1=0.9813
#   Epoch  70: Train Acc=0.9842, Val Acc=0.9858, F1=0.9883
#   Epoch  80: Train Acc=0.9883, Val Acc=0.9821, F1=0.9850
#   Epoch  90: Train Acc=0.9890, Val Acc=0.9876, F1=0.9897
#   Epoch 100: Train Acc=0.9906, Val Acc=0.9864, F1=0.9887
#   Best Val Acc: 0.9876
#
# [Gated-TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9321, F1: 0.9331
#
# [Progress: 11/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING_20pct
# ================================================================================
#
# Loading SITTING_TO_LAYING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_LAYING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9459, Val Acc=0.9518, F1=0.9588
#   Epoch  20: Train Acc=0.9535, Val Acc=0.9567, F1=0.9645
#   Epoch  30: Train Acc=0.9580, Val Acc=0.9592, F1=0.9663
#   Epoch  40: Train Acc=0.9572, Val Acc=0.9592, F1=0.9665
#   Epoch  50: Train Acc=0.9584, Val Acc=0.9567, F1=0.9645
#   Early stopping at epoch 54
#   Best Val Acc: 0.9617
#
# [GAP Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9306, F1: 0.9359
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9651, Val Acc=0.9611, F1=0.9678
#   Epoch  20: Train Acc=0.9661, Val Acc=0.9623, F1=0.9689
#   Epoch  30: Train Acc=0.9740, Val Acc=0.9716, F1=0.9764
#   Epoch  40: Train Acc=0.9754, Val Acc=0.9703, F1=0.9752
#   Epoch  50: Train Acc=0.9801, Val Acc=0.9747, F1=0.9790
#   Epoch  60: Train Acc=0.9813, Val Acc=0.9734, F1=0.9778
#   Epoch  70: Train Acc=0.9838, Val Acc=0.9784, F1=0.9820
#   Epoch  80: Train Acc=0.9859, Val Acc=0.9759, F1=0.9798
#   Epoch  90: Train Acc=0.9879, Val Acc=0.9821, F1=0.9850
#   Epoch 100: Train Acc=0.9901, Val Acc=0.9827, F1=0.9856
#   Best Val Acc: 0.9889
#
# [TPA Results]
#   Val Acc: 0.9889
#   Test Acc: 0.9392, F1: 0.9417
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9637, Val Acc=0.9567, F1=0.9647
#   Epoch  20: Train Acc=0.9649, Val Acc=0.9629, F1=0.9695
#   Epoch  30: Train Acc=0.9706, Val Acc=0.9629, F1=0.9694
#   Epoch  40: Train Acc=0.9762, Val Acc=0.9691, F1=0.9741
#   Epoch  50: Train Acc=0.9808, Val Acc=0.9648, F1=0.9710
#   Epoch  60: Train Acc=0.9816, Val Acc=0.9759, F1=0.9798
#   Epoch  70: Train Acc=0.9822, Val Acc=0.9821, F1=0.9849
#   Epoch  80: Train Acc=0.9892, Val Acc=0.9839, F1=0.9864
#   Epoch  90: Train Acc=0.9881, Val Acc=0.9845, F1=0.9872
#   Epoch 100: Train Acc=0.9913, Val Acc=0.9864, F1=0.9882
#   Best Val Acc: 0.9883
#
# [Gated-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9414, F1: 0.9430
#
# [Progress: 12/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_LAYING_30pct
# ================================================================================
#
# Loading SITTING_TO_LAYING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9512, Val Acc=0.9555, F1=0.9627
#   Epoch  20: Train Acc=0.9657, Val Acc=0.9617, F1=0.9680
#   Epoch  30: Train Acc=0.9731, Val Acc=0.9691, F1=0.9741
#   Epoch  40: Train Acc=0.9780, Val Acc=0.9734, F1=0.9778
#   Epoch  50: Train Acc=0.9833, Val Acc=0.9734, F1=0.9781
#   Epoch  60: Train Acc=0.9830, Val Acc=0.9722, F1=0.9771
#   Epoch  70: Train Acc=0.9872, Val Acc=0.9784, F1=0.9818
#   Epoch  80: Train Acc=0.9884, Val Acc=0.9802, F1=0.9837
#   Epoch  90: Train Acc=0.9862, Val Acc=0.9790, F1=0.9823
#   Epoch 100: Train Acc=0.9912, Val Acc=0.9815, F1=0.9843
#   Best Val Acc: 0.9864
#
# [Gated-TPA Results]
#   Val Acc: 0.9864
#   Test Acc: 0.9321, F1: 0.9330
#
# [Progress: 15/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_20pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9375, Val Acc=0.9518, F1=0.9595
#   Epoch  20: Train Acc=0.9433, Val Acc=0.9493, F1=0.9580
#   Epoch  30: Train Acc=0.9468, Val Acc=0.9506, F1=0.9586
#   Early stopping at epoch 30
#   Best Val Acc: 0.9518
#
# [GAP Results]
#   Val Acc: 0.9518
#   Test Acc: 0.8797, F1: 0.8847
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9539, Val Acc=0.9536, F1=0.9615
#   Epoch  20: Train Acc=0.9648, Val Acc=0.9648, F1=0.9705
#   Epoch  30: Train Acc=0.9739, Val Acc=0.9734, F1=0.9779
#   Epoch  40: Train Acc=0.9777, Val Acc=0.9778, F1=0.9813
#   Epoch  50: Train Acc=0.9801, Val Acc=0.9747, F1=0.9790
#   Epoch  60: Train Acc=0.9870, Val Acc=0.9790, F1=0.9824
#   Epoch  70: Train Acc=0.9861, Val Acc=0.9833, F1=0.9858
#   Epoch  80: Train Acc=0.9898, Val Acc=0.9895, F1=0.9909
#   Epoch  90: Train Acc=0.9893, Val Acc=0.9876, F1=0.9894
#   Epoch 100: Train Acc=0.9890, Val Acc=0.9864, F1=0.9885
#   Best Val Acc: 0.9907
#
# [TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9330, F1: 0.9363
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9515, Val Acc=0.9574, F1=0.9647
#   Epoch  20: Train Acc=0.9643, Val Acc=0.9654, F1=0.9712
#   Epoch  30: Train Acc=0.9657, Val Acc=0.9660, F1=0.9717
#   Epoch  40: Train Acc=0.9759, Val Acc=0.9716, F1=0.9761
#   Epoch  50: Train Acc=0.9801, Val Acc=0.9759, F1=0.9799
#   Epoch  60: Train Acc=0.9842, Val Acc=0.9821, F1=0.9848
#   Epoch  70: Train Acc=0.9861, Val Acc=0.9808, F1=0.9837
#   Epoch  80: Train Acc=0.9883, Val Acc=0.9808, F1=0.9837
#   Epoch  90: Train Acc=0.9893, Val Acc=0.9827, F1=0.9854
#   Early stopping at epoch 98
#   Best Val Acc: 0.9852
#
# [Gated-TPA Results]
#   Val Acc: 0.9852
#   Test Acc: 0.9281, F1: 0.9319
#
# [Progress: 16/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_30pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9403, Val Acc=0.9413, F1=0.9495
#   Epoch  20: Train Acc=0.9478, Val Acc=0.9400, F1=0.9503
#   Epoch  30: Train Acc=0.9481, Val Acc=0.9376, F1=0.9479
#   Early stopping at epoch 31
#   Best Val Acc: 0.9438
#
# [GAP Results]
#   Val Acc: 0.9438
#   Test Acc: 0.8855, F1: 0.8909
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9566, Val Acc=0.9462, F1=0.9544
#   Epoch  20: Train Acc=0.9634, Val Acc=0.9518, F1=0.9589
#   Epoch  30: Train Acc=0.9688, Val Acc=0.9604, F1=0.9669
#   Epoch  40: Train Acc=0.9750, Val Acc=0.9697, F1=0.9748
#   Epoch  50: Train Acc=0.9790, Val Acc=0.9703, F1=0.9757
#   Epoch  60: Train Acc=0.9861, Val Acc=0.9747, F1=0.9787
#   Epoch  70: Train Acc=0.9875, Val Acc=0.9759, F1=0.9799
#   Epoch  80: Train Acc=0.9900, Val Acc=0.9815, F1=0.9845
#   Epoch  90: Train Acc=0.9910, Val Acc=0.9796, F1=0.9827
#   Epoch 100: Train Acc=0.9912, Val Acc=0.9784, F1=0.9819
#   Best Val Acc: 0.9845
#
# [TPA Results]
#   Val Acc: 0.9845
#   Test Acc: 0.9263, F1: 0.9298
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9566, Val Acc=0.9438, F1=0.9519
#   Epoch  20: Train Acc=0.9629, Val Acc=0.9549, F1=0.9618
#   Epoch  30: Train Acc=0.9706, Val Acc=0.9617, F1=0.9685
#   Epoch  40: Train Acc=0.9745, Val Acc=0.9598, F1=0.9659
#   Epoch  50: Train Acc=0.9793, Val Acc=0.9728, F1=0.9773
#   Epoch  60: Train Acc=0.9844, Val Acc=0.9753, F1=0.9794
#   Epoch  70: Train Acc=0.9892, Val Acc=0.9833, F1=0.9863
#   Epoch  80: Train Acc=0.9883, Val Acc=0.9858, F1=0.9881
#   Epoch  90: Train Acc=0.9883, Val Acc=0.9808, F1=0.9837
#   Epoch 100: Train Acc=0.9927, Val Acc=0.9815, F1=0.9845
#   Early stopping at epoch 100
#   Best Val Acc: 0.9858
#
# [Gated-TPA Results]
#   Val Acc: 0.9858
#   Test Acc: 0.9176, F1: 0.9193
#
# [Progress: 17/41]
#
# ================================================================================
# EXPERIMENT: SITTING_TO_STANDING_40pct
# ================================================================================
#
# Loading SITTING_TO_STANDING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/SITTING_TO_STANDING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9366, Val Acc=0.9425, F1=0.9521
#   Epoch  20: Train Acc=0.9405, Val Acc=0.9413, F1=0.9520
#   Epoch  30: Train Acc=0.9414, Val Acc=0.9438, F1=0.9531
#   Early stopping at epoch 39
#   Best Val Acc: 0.9468
#
# [GAP Results]
#   Val Acc: 0.9468
#   Test Acc: 0.8979, F1: 0.9053
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9552, Val Acc=0.9543, F1=0.9617
#   Epoch  20: Train Acc=0.9655, Val Acc=0.9635, F1=0.9698
#   Epoch  30: Train Acc=0.9723, Val Acc=0.9617, F1=0.9677
#   Epoch  40: Train Acc=0.9807, Val Acc=0.9604, F1=0.9673
#   Epoch  50: Train Acc=0.9835, Val Acc=0.9765, F1=0.9803
#   Epoch  60: Train Acc=0.9853, Val Acc=0.9759, F1=0.9800
#   Epoch  70: Train Acc=0.9875, Val Acc=0.9697, F1=0.9742
#   Epoch  80: Train Acc=0.9904, Val Acc=0.9821, F1=0.9850
#   Epoch  90: Train Acc=0.9903, Val Acc=0.9808, F1=0.9841
#   Early stopping at epoch 93
#   Best Val Acc: 0.9852
#
# [TPA Results]
#   Val Acc: 0.9852
#   Test Acc: 0.9383, F1: 0.9398
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9556, Val Acc=0.9530, F1=0.9599
#   Epoch  20: Train Acc=0.9672, Val Acc=0.9629, F1=0.9691
#   Epoch  30: Train Acc=0.9719, Val Acc=0.9623, F1=0.9690
#   Epoch  40: Train Acc=0.9757, Val Acc=0.9691, F1=0.9742
#   Epoch  50: Train Acc=0.9779, Val Acc=0.9679, F1=0.9731
#   Epoch  60: Train Acc=0.9842, Val Acc=0.9710, F1=0.9754
#   Epoch  70: Train Acc=0.9841, Val Acc=0.9672, F1=0.9728
#   Epoch  80: Train Acc=0.9879, Val Acc=0.9728, F1=0.9772
#   Epoch  90: Train Acc=0.9849, Val Acc=0.9765, F1=0.9804
#   Epoch 100: Train Acc=0.9896, Val Acc=0.9765, F1=0.9802
#   Best Val Acc: 0.9790
#
# [Gated-TPA Results]
#   Val Acc: 0.9790
#   Test Acc: 0.9358, F1: 0.9380
#
# [Progress: 18/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_10pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9456, Val Acc=0.9506, F1=0.9494
#   Epoch  20: Train Acc=0.9544, Val Acc=0.9617, F1=0.9612
#   Epoch  30: Train Acc=0.9550, Val Acc=0.9623, F1=0.9617
#   Epoch  40: Train Acc=0.9575, Val Acc=0.9549, F1=0.9541
#   Epoch  50: Train Acc=0.9576, Val Acc=0.9611, F1=0.9605
#   Early stopping at epoch 57
#   Best Val Acc: 0.9654
#
# [GAP Results]
#   Val Acc: 0.9654
#   Test Acc: 0.9207, F1: 0.9133
#
# [Training TPA]
#   Epoch  10: Train Acc=0.
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9604, Val Acc=0.9654, F1=0.9646
#   Epoch  20: Train Acc=0.9668, Val Acc=0.9728, F1=0.9722
#   Epoch  30: Train Acc=0.9674, Val Acc=0.9734, F1=0.9730
#   Epoch  40: Train Acc=0.9726, Val Acc=0.9784, F1=0.9779
#   Epoch  50: Train Acc=0.9810, Val Acc=0.9821, F1=0.9817
#   Epoch  60: Train Acc=0.9856, Val Acc=0.9839, F1=0.9835
#   Epoch  70: Train Acc=0.9835, Val Acc=0.9870, F1=0.9867
#   Epoch  80: Train Acc=0.9881, Val Acc=0.9876, F1=0.9873
#   Epoch  90: Train Acc=0.9917, Val Acc=0.9858, F1=0.9853
#   Epoch 100: Train Acc=0.9917, Val Acc=0.9932, F1=0.9930
#   Best Val Acc: 0.9932
#
# [Gated-TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9358, F1: 0.9285
#
# [Progress: 20/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_30pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9490, Val Acc=0.9487, F1=0.9465
#   Epoch  20: Train Acc=0.9530, Val Acc=0.9536, F1=0.9528
#   Epoch  30: Train Acc=0.9549, Val Acc=0.9543, F1=0.9534
#   Epoch  40: Train Acc=0.9566, Val Acc=0.9580, F1=0.9573
#   Epoch  50: Train Acc=0.9559, Val Acc=0.9555, F1=0.9547
#   Early stopping at epoch 52
#   Best Val Acc: 0.9623
#
# [GAP Results]
#   Val Acc: 0.9623
#   Test Acc: 0.9216, F1: 0.9139
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9584, Val Acc=0.9574, F1=0.9563
#   Epoch  20: Train Acc=0.9658, Val Acc=0.9672, F1=0.9667
#   Epoch  30: Train Acc=0.9719, Val Acc=0.9666, F1=0.9660
#   Epoch  40: Train Acc=0.9731, Val Acc=0.9697, F1=0.9691
#   Epoch  50: Train Acc=0.9825, Val Acc=0.9790, F1=0.9787
#   Epoch  60: Train Acc=0.9895, Val Acc=0.9815, F1=0.9812
#   Epoch  70: Train Acc=0.9889, Val Acc=0.9839, F1=0.9837
#   Epoch  80: Train Acc=0.9907, Val Acc=0.9802, F1=0.9799
#   Epoch  90: Train Acc=0.9934, Val Acc=0.9864, F1=0.9862
#   Epoch 100: Train Acc=0.9958, Val Acc=0.9870, F1=0.9868
#   Best Val Acc: 0.9883
#
# [TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9367, F1: 0.9298
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9592, Val Acc=0.9611, F1=0.9604
#   Epoch  20: Train Acc=0.9666, Val Acc=0.9648, F1=0.9641
#   Epoch  30: Train Acc=0.9720, Val Acc=0.9648, F1=0.9643
#   Epoch  40: Train Acc=0.9763, Val Acc=0.9747, F1=0.9743
#   Epoch  50: Train Acc=0.9802, Val Acc=0.9753, F1=0.9749
#   Epoch  60: Train Acc=0.9855, Val Acc=0.9784, F1=0.9779
#   Epoch  70: Train Acc=0.9866, Val Acc=0.9827, F1=0.9824
#   Epoch  80: Train Acc=0.9912, Val Acc=0.9864, F1=0.9860
#   Epoch  90: Train Acc=0.9921, Val Acc=0.9920, F1=0.9917
#   Epoch 100: Train Acc=0.9910, Val Acc=0.9876, F1=0.9875
#   Best Val Acc: 0.9932
#
# [Gated-TPA Results]
#   Val Acc: 0.9932
#   Test Acc: 0.9321, F1: 0.9246
#
# [Progress: 21/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_SITTING_40pct
# ================================================================================
#
# Loading LAYING_TO_SITTING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_SITTING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9487, Val Acc=0.9376, F1=0.9359
#   Epoch  20: Train Acc=0.9556, Val Acc=0.9456, F1=0.9451
#   Epoch  30: Train Acc=0.9575, Val Acc=0.9561, F1=0.9555
#   Epoch  40: Train Acc=0.9587, Val Acc=0.9561, F1=0.9555
#   Epoch  50: Train Acc=0.9604, Val Acc=0.9555, F1=0.9549
#   Early stopping at epoch 57
#   Best Val Acc: 0.9567
#
# [GAP Results]
#   Val Acc: 0.9567
#   Test Acc: 0.9148, F1: 0.9067
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9603, Val Acc=0.9481, F1=0.9470
#   Epoch  20: Train Acc=0.9657, Val Acc=0.9580, F1=0.9574
#   Epoch  30: Train Acc=0.9720, Val Acc=0.9697, F1=0.9693
#   Epoch  40: Train Acc=0.9767, Val Acc=0.9740, F1=0.9737
#   Epoch  50: Train Acc=0.9799, Val Acc=0.9771, F1=0.9767
#   Epoch  60: Train Acc=0.9828, Val Acc=0.9845, F1=0.9843
#   Epoch  70: Train Acc=0.9845, Val Acc=0.9858, F1=0.9856
#   Epoch  80: Train Acc=0.9853, Val Acc=0.9839, F1=0.9837
#   Epoch  90: Train Acc=0.9892, Val Acc=0.9852, F1=0.9850
#   Early stopping at epoch 98
#   Best Val Acc: 0.9876
#
# [TPA Results]
#   Val Acc: 0.9876
#   Test Acc: 0.9435, F1: 0.9378
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9612, Val Acc=0.9604, F1=0.9599
#   Epoch  20: Train Acc=0.9661, Val Acc=0.9629, F1=0.9624
#   Epoch  30: Train Acc=0.9708, Val Acc=0.9672, F1=0.9669
#   Epoch  40: Train Acc=0.9757, Val Acc=0.9747, F1=0.9743
#   Epoch  50: Train Acc=0.9841, Val Acc=0.9802, F1=0.9799
#   Epoch  60: Train Acc=0.9861, Val Acc=0.9808, F1=0.9804
#   Epoch  70: Train Acc=0.9887, Val Acc=0.9784, F1=0.9779
#   Early stopping at epoch 75
#   Best Val Acc: 0.9833
#
# [Gated-TPA Results]
#   Val Acc: 0.9833
#   Test Acc: 0.9405, F1: 0.9345
#
# [Progress: 22/41]
#
# ================================================================================
# EXPERIMENT: LAYING_TO_STANDING_10pct
# ================================================================================
#
# Loading LAYING_TO_STANDING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/LAYING_TO_STANDING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9468, Val Acc=0.9611, F1=0.9595
#   Epoch  20: Train Acc=0.9530, Val Acc=0.9623, F1=0.9620
#   Epoch  30: Train Acc=0.9558, Val Acc=0.9635, F1=0.9630
#   Epoch  40: Train Acc=0.9578, Val Acc=0.9623, F1=0.9617
#   Early stopping at epoch 49
#   Best Val Acc: 0.9679
#
# [GAP Results]
#   Val Acc: 0.9679
#   Test Acc: 0.9247, F1: 0.9172
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9593, Val Acc=0.9635, F1=0.9630
#   Epoch  20: Train Acc=0.9649, Val Acc=0.9679, F1=0.9674
# ...
#   Epoch  30: Train Acc=0.9746, Val Acc=0.9654, F1=0.9651
#   Epoch  40: Train Acc=0.9759, Val Acc=0.9679, F1=0.9676
#   Epoch  50: Train Acc=0.9827, Val Acc=0.9740, F1=0.9737
#   Epoch  60: Train Acc=0.9858, Val Acc=0.9716, F1=0.9712
#   Epoch  70: Train Acc=0.9884, Val Acc=0.9790, F1=0.9788
#   Epoch  80: Train Acc=0.9898, Val Acc=0.9808, F1=0.9807
#   Epoch  90: Train Acc=0.9920, Val Acc=0.9845, F1=0.9845
#   Epoch 100: Train Acc=0.9941, Val Acc=0.9845, F1=0.9845
#   Best Val Acc: 0.9889
#
# [TPA Results]
#   Val Acc: 0.9889
#   Test Acc: 0.9442, F1: 0.9408
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9583, Val Acc=0.9536, F1=0.9527
#   Epoch  20: Train Acc=0.9663, Val Acc=0.9598, F1=0.9594
#   Epoch  30: Train Acc=0.9716, Val Acc=0.9629, F1=0.9625
#   Epoch  40: Train Acc=0.9763, Val Acc=0.9710, F1=0.9706
#   Epoch  50: Train Acc=0.9805, Val Acc=0.9710, F1=0.9705
#   Epoch  60: Train Acc=0.9853, Val Acc=0.9778, F1=0.9775
#   Epoch  70: Train Acc=0.9870, Val Acc=0.9771, F1=0.9769
#   Epoch  80: Train Acc=0.9890, Val Acc=0.9747, F1=0.9742
#   Epoch  90: Train Acc=0.9903, Val Acc=0.9778, F1=0.9776
#   Epoch 100: Train Acc=0.9927, Val Acc=0.9815, F1=0.9814
#   Best Val Acc: 0.9827
#
# [Gated-TPA Results]
#   Val Acc: 0.9827
#   Test Acc: 0.9330, F1: 0.9298
#
# [Progress: 36/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9487, Val Acc=0.9518, F1=0.9511
#   Epoch  20: Train Acc=0.9572, Val Acc=0.9586, F1=0.9580
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9518, F1=0.9511
#   Epoch  40: Train Acc=0.9573, Val Acc=0.9574, F1=0.9568
#   Early stopping at epoch 48
#   Best Val Acc: 0.9617
#
# [GAP Results]
#   Val Acc: 0.9617
#   Test Acc: 0.9222, F1: 0.9181
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9589, Val Acc=0.9512, F1=0.9498
#   Epoch  20: Train Acc=0.9657, Val Acc=0.9536, F1=0.9522
#   Epoch  30: Train Acc=0.9717, Val Acc=0.9691, F1=0.9686
#   Epoch  40: Train Acc=0.9750, Val Acc=0.9759, F1=0.9756
#   Epoch  50: Train Acc=0.9779, Val Acc=0.9796, F1=0.9793
#   Epoch  60: Train Acc=0.9819, Val Acc=0.9790, F1=0.9787
#   Epoch  70: Train Acc=0.9850, Val Acc=0.9845, F1=0.9843
#   Epoch  80: Train Acc=0.9859, Val Acc=0.9864, F1=0.9862
#   Epoch  90: Train Acc=0.9909, Val Acc=0.9870, F1=0.9868
#   Epoch 100: Train Acc=0.9901, Val Acc=0.9895, F1=0.9894
#   Best Val Acc: 0.9913
#
# [TPA Results]
#   Val Acc: 0.9913
#   Test Acc: 0.9389, F1: 0.9349
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9580, Val Acc=0.9518, F1=0.9507
#   Epoch  20: Train Acc=0.9641, Val Acc=0.9598, F1=0.9590
#   Epoch  30: Train Acc=0.9700, Val Acc=0.9611, F1=0.9604
#   Epoch  40: Train Acc=0.9734, Val Acc=0.9765, F1=0.9761
#   Epoch  50: Train Acc=0.9796, Val Acc=0.9815, F1=0.9812
#   Epoch  60: Train Acc=0.9821, Val Acc=0.9771, F1=0.9767
#   Epoch  70: Train Acc=0.9855, Val Acc=0.9845, F1=0.9844
#   Epoch  80: Train Acc=0.9878, Val Acc=0.9883, F1=0.9882
#   Epoch  90: Train Acc=0.9903, Val Acc=0.9870, F1=0.9870
#   Early stopping at epoch 93
#   Best Val Acc: 0.9883
#
# [Gated-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9327, F1: 0.9299
#
# [Progress: 37/41]
#
# ================================================================================
# EXPERIMENT: WALKING_UPSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading WALKING_UPSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_UPSTAIRS_TO_WALKING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9451, Val Acc=0.9456, F1=0.9453
#   Epoch  20: Train Acc=0.9544, Val Acc=0.9604, F1=0.9601
#   Epoch  30: Train Acc=0.9561, Val Acc=0.9648, F1=0.9643
#   Epoch  40: Train Acc=0.9578, Val Acc=0.9604, F1=0.9599
#   Epoch  50: Train Acc=0.9587, Val Acc=0.9642, F1=0.9637
#   Early stopping at epoch 50
#   Best Val Acc: 0.9648
#
# [GAP Results]
#   Val Acc: 0.9648
#   Test Acc: 0.9192, F1: 0.9159
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9590, Val Acc=0.9617, F1=0.9613
#   Epoch  20: Train Acc=0.9635, Val Acc=0.9660, F1=0.9657
#   Epoch  30: Train Acc=0.9716, Val Acc=0.9734, F1=0.9731
#   Epoch  40: Train Acc=0.9743, Val Acc=0.9710, F1=0.9707
#   Epoch  50: Train Acc=0.9805, Val Acc=0.9753, F1=0.9751
#   Epoch  60: Train Acc=0.9838, Val Acc=0.9778, F1=0.9776
#   Epoch  70: Train Acc=0.9836, Val Acc=0.9784, F1=0.9782
#   Epoch  80: Train Acc=0.9850, Val Acc=0.9778, F1=0.9776
#   Epoch  90: Train Acc=0.9884, Val Acc=0.9821, F1=0.9820
#   Epoch 100: Train Acc=0.9917, Val Acc=0.9821, F1=0.9820
#   Best Val Acc: 0.9839
#
# [TPA Results]
#   Val Acc: 0.9839
#   Test Acc: 0.9306, F1: 0.9274
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9610, Val Acc=0.9586, F1=0.9580
#   Epoch  20: Train Acc=0.9641, Val Acc=0.9611, F1=0.9603
#   Epoch  30: Train Acc=0.9660, Val Acc=0.9660, F1=0.9655
#   Epoch  40: Train Acc=0.9726, Val Acc=0.9685, F1=0.9681
#   Epoch  50: Train Acc=0.9799, Val Acc=0.9771, F1=0.9768
#   Epoch  60: Train Acc=0.9814, Val Acc=0.9642, F1=0.9631
#   Epoch  70: Train Acc=0.9849, Val Acc=0.9796, F1=0.9794
#   Epoch  80: Train Acc=0.9890, Val Acc=0.9839, F1=0.9837
#   Epoch  90: Train Acc=0.9895, Val Acc=0.9827, F1=0.9827
#   Epoch 100: Train Acc=0.9904, Val Acc=0.9833, F1=0.9832
#   Best Val Acc: 0.9858
#
# [Gated-TPA Results]
#   Val Acc: 0.9858
#   Test Acc: 0.9272, F1: 0.9259
#
# [Progress: 38/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_10pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_10pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_10pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9484, Val Acc=0.9580, F1=0.9573
#   Epoch  20: Train Acc=0.9550, Val Acc=0.9524, F1=0.9513
#   Epoch  30: Train Acc=0.9553, Val Acc=0.9617, F1=0.9611
#   Epoch  40: Train Acc=0.9573, Val Acc=0.9611, F1=0.9605
#   Epoch  50: Train Acc=0.9580, Val Acc=0.9561, F1=0.9554
#   Early stopping at epoch 53
#   Best Val Acc: 0.9629
#
# [GAP Results]
#   Val Acc: 0.9629
#   Test Acc: 0.9241, F1: 0.9206
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9590, Val Acc=0.9629, F1=0.9622
#   Epoch  20: Train Acc=0.9652, Val Acc=0.9672, F1=0.9666
#   Epoch  30: Train Acc=0.9682, Val Acc=0.9672, F1=0.9667
#   Epoch  40: Train Acc=0.9733, Val Acc=0.9722, F1=0.9718
#   Epoch  50: Train Acc=0.9791, Val Acc=0.9790, F1=0.9787
#   Epoch  60: Train Acc=0.9845, Val Acc=0.9808, F1=0.9806
#   Epoch  70: Train Acc=0.9876, Val Acc=0.9852, F1=0.9850
#   Epoch  80: Train Acc=0.9892, Val Acc=0.9821, F1=0.9818
#   Epoch  90: Train Acc=0.9907, Val Acc=0.9839, F1=0.9837
#   Epoch 100: Train Acc=0.9924, Val Acc=0.9883, F1=0.9881
#   Best Val Acc: 0.9907
#
# [TPA Results]
#   Val Acc: 0.9907
#   Test Acc: 0.9417, F1: 0.9399
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9584, Val Acc=0.9623, F1=0.9617
#   Epoch  20: Train Acc=0.9626, Val Acc=0.9654, F1=0.9648
#   Epoch  30: Train Acc=0.9635, Val Acc=0.9685, F1=0.9678
#   Epoch  40: Train Acc=0.9731, Val Acc=0.9710, F1=0.9705
#   Epoch  50: Train Acc=0.9818, Val Acc=0.9833, F1=0.9831
#   Epoch  60: Train Acc=0.9852, Val Acc=0.9815, F1=0.9811
#   Epoch  70: Train Acc=0.9879, Val Acc=0.9870, F1=0.9868
#   Epoch  80: Train Acc=0.9900, Val Acc=0.9876, F1=0.9875
#   Epoch  90: Train Acc=0.9923, Val Acc=0.9876, F1=0.9875
#   Early stopping at epoch 93
#   Best Val Acc: 0.9883
#
# [Gated-TPA Results]
#   Val Acc: 0.9883
#   Test Acc: 0.9408, F1: 0.9385
#
# [Progress: 39/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_20pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_20pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_20pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9487, Val Acc=0.9450, F1=0.9438
#   Epoch  20: Train Acc=0.9549, Val Acc=0.9493, F1=0.9484
#   Epoch  30: Train Acc=0.9570, Val Acc=0.9493, F1=0.9483
#   Epoch  40: Train Acc=0.9600, Val Acc=0.9506, F1=0.9496
#   Epoch  50: Train Acc=0.9583, Val Acc=0.9567, F1=0.9561
#   Early stopping at epoch 53
#   Best Val Acc: 0.9580
#
# [GAP Results]
#   Val Acc: 0.9580
#   Test Acc: 0.9219, F1: 0.9184
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9598, Val Acc=0.9598, F1=0.9592
#   Epoch  20: Train Acc=0.9657, Val Acc=0.9598, F1=0.9587
#   Epoch  30: Train Acc=0.9712, Val Acc=0.9672, F1=0.9667
#   Epoch  40: Train Acc=0.9754, Val Acc=0.9685, F1=0.9679
#   Epoch  50: Train Acc=0.9788, Val Acc=0.9771, F1=0.9767
#   Epoch  60: Train Acc=0.9808, Val Acc=0.9796, F1=0.9793
#   Epoch  70: Train Acc=0.9884, Val Acc=0.9808, F1=0.9806
#   Epoch  80: Train Acc=0.9907, Val Acc=0.9778, F1=0.9774
#   Epoch  90: Train Acc=0.9915, Val Acc=0.9815, F1=0.9812
#   Epoch 100: Train Acc=0.9913, Val Acc=0.9833, F1=0.9831
#   Best Val Acc: 0.9870
#
# [TPA Results]
#   Val Acc: 0.9870
#   Test Acc: 0.9411, F1: 0.9392
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9589, Val Acc=0.9592, F1=0.9586
#   Epoch  20: Train Acc=0.9663, Val Acc=0.9635, F1=0.9630
#   Epoch  30: Train Acc=0.9686, Val Acc=0.9648, F1=0.9642
#   Epoch  40: Train Acc=0.9725, Val Acc=0.9685, F1=0.9678
#   Epoch  50: Train Acc=0.9799, Val Acc=0.9778, F1=0.9774
#   Epoch  60: Train Acc=0.9833, Val Acc=0.9790, F1=0.9787
#   Epoch  70: Train Acc=0.9839, Val Acc=0.9802, F1=0.9799
#   Epoch  80: Train Acc=0.9895, Val Acc=0.9815, F1=0.9811
#   Epoch  90: Train Acc=0.9876, Val Acc=0.9833, F1=0.9830
#   Epoch 100: Train Acc=0.9926, Val Acc=0.9845, F1=0.9843
#   Best Val Acc: 0.9852
#
# [Gated-TPA Results]
#   Val Acc: 0.9852
#   Test Acc: 0.9340, F1: 0.9307
#
# [Progress: 40/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_30pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_30pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_30pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9440, Val Acc=0.9586, F1=0.9581
#   Epoch  20: Train Acc=0.9546, Val Acc=0.9623, F1=0.9617
#   Epoch  30: Train Acc=0.9541, Val Acc=0.9660, F1=0.9655
#   Epoch  40: Train Acc=0.9558, Val Acc=0.9703, F1=0.9699
#   Epoch  50: Train Acc=0.9578, Val Acc=0.9697, F1=0.9693
#   Epoch  60: Train Acc=0.9583, Val Acc=0.9734, F1=0.9730
#   Epoch  70: Train Acc=0.9583, Val Acc=0.9703, F1=0.9699
#   Epoch  80: Train Acc=0.9600, Val Acc=0.9728, F1=0.9724
#   Epoch  90: Train Acc=0.9626, Val Acc=0.9722, F1=0.9718
#   Early stopping at epoch 93
#   Best Val Acc: 0.9740
#
# [GAP Results]
#   Val Acc: 0.9740
#   Test Acc: 0.9374, F1: 0.9342
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9580, Val Acc=0.9691, F1=0.9686
#   Epoch  20: Train Acc=0.9638, Val Acc=0.9722, F1=0.9718
#   Epoch  30: Train Acc=0.9716, Val Acc=0.9784, F1=0.9780
#   Epoch  40: Train Acc=0.9748, Val Acc=0.9827, F1=0.9825
#   Epoch  50: Train Acc=0.9824, Val Acc=0.9845, F1=0.9843
#   Epoch  60: Train Acc=0.9819, Val Acc=0.9876, F1=0.9875
#   Epoch  70: Train Acc=0.9866, Val Acc=0.9913, F1=0.9912
#   Epoch  80: Train Acc=0.9889, Val Acc=0.9864, F1=0.9862
#   Epoch  90: Train Acc=0.9907, Val Acc=0.9901, F1=0.9900
#   Epoch 100: Train Acc=0.9907, Val Acc=0.9895, F1=0.9893
#   Best Val Acc: 0.9957
#
# [TPA Results]
#   Val Acc: 0.9957
#   Test Acc: 0.9300, F1: 0.9294
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9572, Val Acc=0.9716, F1=0.9713
#   Epoch  20: Train Acc=0.9627, Val Acc=0.9710, F1=0.9706
#   Epoch  30: Train Acc=0.9686, Val Acc=0.9753, F1=0.9750
#   Epoch  40: Train Acc=0.9737, Val Acc=0.9765, F1=0.9762
#   Epoch  50: Train Acc=0.9793, Val Acc=0.9802, F1=0.9800
#   Epoch  60: Train Acc=0.9836, Val Acc=0.9833, F1=0.9831
#   Epoch  70: Train Acc=0.9836, Val Acc=0.9821, F1=0.9818
#   Epoch  80: Train Acc=0.9872, Val Acc=0.9895, F1=0.9893
#   Epoch  90: Train Acc=0.9893, Val Acc=0.9870, F1=0.9869
#   Epoch 100: Train Acc=0.9920, Val Acc=0.9883, F1=0.9881
#   Early stopping at epoch 100
#   Best Val Acc: 0.9895
#
# [Gated-TPA Results]
#   Val Acc: 0.9895
#   Test Acc: 0.9377, F1: 0.9354
#
# [Progress: 41/41]
#
# ================================================================================
# EXPERIMENT: WALKING_DOWNSTAIRS_TO_WALKING_40pct
# ================================================================================
#
# Loading WALKING_DOWNSTAIRS_TO_WALKING_40pct...
#   Path: /content/drive/MyDrive/AI_data/TPA2/uci_har_transition_datasets/WALKING_DOWNSTAIRS_TO_WALKING_40pct
#   Train: (8087, 9, 128), Test: (3241, 9, 128)
#
# Dataset splits:
#   Train: 6469, Val: 1618, Test: 3241
#
# [Training GAP]
#   Epoch  10: Train Acc=0.9454, Val Acc=0.9351, F1=0.9344
#   Epoch  20: Train Acc=0.9549, Val Acc=0.9456, F1=0.9449
#   Epoch  30: Train Acc=0.9569, Val Acc=0.9567, F1=0.9561
#   Epoch  40: Train Acc=0.9595, Val Acc=0.9499, F1=0.9491
#   Epoch  50: Train Acc=0.9600, Val Acc=0.9536, F1=0.9530
#   Epoch  60: Train Acc=0.9609, Val Acc=0.9580, F1=0.9574
#   Early stopping at epoch 66
#   Best Val Acc: 0.9592
#
# [GAP Results]
#   Val Acc: 0.9592
#   Test Acc: 0.9219, F1: 0.9186
#
# [Training TPA]
#   Epoch  10: Train Acc=0.9600, Val Acc=0.9506, F1=0.9497
#   Epoch  20: Train Acc=0.9668, Val Acc=0.9580, F1=0.9574
#   Epoch  30: Train Acc=0.9683, Val Acc=0.9654, F1=0.9649
#   Epoch  40: Train Acc=0.9719, Val Acc=0.9685, F1=0.9681
#   Epoch  50: Train Acc=0.9793, Val Acc=0.9740, F1=0.9737
#   Epoch  60: Train Acc=0.9801, Val Acc=0.9710, F1=0.9707
#   Epoch  70: Train Acc=0.9835, Val Acc=0.9778, F1=0.9775
#   Epoch  80: Train Acc=0.9850, Val Acc=0.9833, F1=0.9832
#   Epoch  90: Train Acc=0.9853, Val Acc=0.9833, F1=0.9831
#   Early stopping at epoch 94
#   Best Val Acc: 0.9839
#
# [TPA Results]
#   Val Acc: 0.9839
#   Test Acc: 0.9293, F1: 0.9284
#
# [Training Gated-TPA]
#   Epoch  10: Train Acc=0.9595, Val Acc=0.9506, F1=0.9498
#   Epoch  20: Train Acc=0.9654, Val Acc=0.9580, F1=0.9572
#   Epoch  30: Train Acc=0.9695, Val Acc=0.9666, F1=0.9661
#   Epoch  40: Train Acc=0.9751, Val Acc=0.9691, F1=0.9687
#   Epoch  50: Train Acc=0.9801, Val Acc=0.9734, F1=0.9730
#   Epoch  60: Train Acc=0.9830, Val Acc=0.9734, F1=0.9730
#   Epoch  70: Train Acc=0.9844, Val Acc=0.9759, F1=0.9756
#   Epoch  80: Train Acc=0.9847, Val Acc=0.9716, F1=0.9711
#   Epoch  90: Train Acc=0.9875, Val Acc=0.9716, F1=0.9712
#   Epoch 100: Train Acc=0.9918, Val Acc=0.9790, F1=0.9785
#   Best Val Acc: 0.9833
#
# [Gated-TPA Results]
#   Val Acc: 0.9833
#   Test Acc: 0.9398, F1: 0.9376
#
# ================================================================================
# SAVING RESULTS
# ================================================================================
#
# Results saved to: /content/drive/MyDrive/AI_data/TPA2/unified_comparison_41datasets_results.json
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total experiments: 123
# Total datasets tested: 41
# Models compared: 3 (GAP, TPA, Gated-TPA)
#
# ================================================================================
# AVERAGE PERFORMANCE (All Datasets)
# ================================================================================
# GAP         : Acc=0.9201, F1=0.9182
# TPA         : Acc=0.9377, F1=0.9359
# Gated-TPA   : Acc=0.9357, F1=0.9335
#
# ================================================================================
# EXPERIMENT COMPLETE
# ================================================================================
