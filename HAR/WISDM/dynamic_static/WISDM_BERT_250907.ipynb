# %% [markdown]
# # WISDM HAR - BERT
#
# - 정적, 동적 활동을 분리하여 학습
#
# 1.  동적 활동(Dynamic Activities) 모델: 'Walking', 'Jogging', 'Upstairs', 'Downstairs'
# 2.  정적 활동(Static Activities) 모델: 'Sitting', 'Standing'

# %%
# !pip install -q torchinfo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import warnings
warnings.filterwarnings('ignore')

# GPU 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def load_and_preprocess_data(file_path):
    """WISDM HAR 데이터 로드 및 전처리"""
    df = pd.read_csv(file_path)

    df['x-axis'] = df['x-axis'].astype('float32')
    df['y-axis'] = df['y-axis'].astype('float32')
    df['z-axis'] = df['z-axis'].astype('float32')

    return df

# %%
class WISDMDataset(Dataset):
    def __init__(self, data, window_size=128, scaler=None):
        self.window_size = window_size
        self.data = []
        self.labels = []

        self.activity_encoder = LabelEncoder()

        # sliding window
        for user in data['user'].unique():
            user_data = data[data['user'] == user]
            sensor_data = user_data[['x-axis', 'y-axis', 'z-axis']].values
            activity_labels = user_data['activity'].values

            for i in range(0, len(sensor_data) - window_size + 1, window_size // 2):
                window = sensor_data[i:i + window_size]
                labels_in_window = activity_labels[i:i + window_size]

                if len(window) == window_size:
                    # 최빈값을 label로
                    # Counter(labels_in_window).most_common(1) -> [('Walking', 120)]과 같은 형태
                    most_common_label = Counter(labels_in_window).most_common(1)[0][0]

                    self.data.append(window)
                    self.labels.append(most_common_label)

        # label encoding
        self.encoded_labels = self.activity_encoder.fit_transform(self.labels)

        # scaling
        self.data = np.array(self.data)
        original_shape = self.data.shape
        if scaler is None:
            self.scaler = StandardScaler()
            self.data = self.scaler.fit_transform(self.data.reshape(-1, 3)).reshape(original_shape) # StandardSclaer는 2차원 입력을 받음
        else:
            self.scaler = scaler
            self.data = self.scaler.transform(self.data.reshape(-1, 3)).reshape(original_shape)

        print(f"Dataset created with {len(self.data)} samples.")
        print(f"... Activity distribution: {Counter(self.labels)}\n") # Counter: 각 항목이 몇 개씩 들어 있는지 세서 딕셔너리 형태로 알려줌

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # [길이 128, 채널 3] 형태의 데이터를 [채널 3, 길이 128]로 변환
        data_tensor = torch.FloatTensor(self.data[idx]).transpose(0, 1)
        label_tensor = torch.LongTensor([self.encoded_labels[idx]])[0]
        return data_tensor, label_tensor

# %% [markdown]
# [CLS] 토큰
# - 입력 시퀀스의 맨 앞에 추가하는 토큰
# - BERT는 입력된 시퀀스 길이와 동일한 길이의 출력 시퀀스를 반환
# - 우리는 하나의 분류 작업을 수행해야 함, 따라서 여러 개의 출력 벡터를 대표 벡터로 요약해야 함 -> [CLS] 토큰
# - 학습 과정을 통해 모든 토큰들을 참조하며 정보를 집약
# - [CLS]만 분류기에 넣어 최종 활동을 예측
#
# BERT의 positional encoding
# - 학습 가능한 파라미터를 사용(nn.Parameter): 역전파를 통해 각 위치(0~32번)을 표현하는 최적의 벡터값을 스스로 학습하게 만듦
# - 고정된 시퀀스 길이에 효과적

# %%
class BERT_HAR_Model(nn.Module):
    def __init__(self, num_classes, input_channels=3, d_model=128, n_head=8, num_encoder_layers=4, dim_feedforward=512, dropout=0.1):
        super(BERT_HAR_Model, self).__init__()
        self.d_model = d_model

        # 1. 스템 (Stem): 임베딩과 다운샘플링 수행
        # Input: (B, 3, 128)
        self.stem = nn.Sequential(
            nn.Conv1d(input_channels, d_model, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm1d(d_model),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        )
        # Stem 출력: (B, d_model, 32)
        self.seq_len_after_stem = 128 // 4  # 32

        # 2. [CLS] 토큰: 분류를 위해 시퀀스 맨 앞에 추가할 학습 가능한 토큰
        self.cls_token = nn.Parameter(torch.zeros(1, 1, d_model))

        # 3. 포지셔널 인코딩: [CLS] 토큰 포함 (1) + 스템 통과 후 시퀀스 길이 (32) = 33
        self.pos_encoder = nn.Parameter(torch.zeros(1, self.seq_len_after_stem + 1, d_model))

        # 4. Transformer 인코더 스택
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=n_head,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True  # 입력 텐서 형식을 (Batch, SeqLen, Features)로 지정
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer=encoder_layer,
            num_layers=num_encoder_layers
        )

        # 5. 분류기 헤드 (Classifier Head)
        self.classifier = nn.Sequential(
            nn.Linear(d_model, 128),  # BERT 출력 차원(d_model)을 받음
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        # x: (B, 3, 128)

        # 1. 스템 (패치 임베딩)
        x = self.stem(x)  # (B, d_model=128, 32)

        # 2. Transformer 입력 형식으로 변경 (B, S, E)
        x = x.permute(0, 2, 1)  # (B, 32, 128)

        # 3. [CLS] 토큰 추가 (배치 크기만큼 복제하여 맨 앞에 concat)
        cls_tokens = self.cls_token.expand(x.shape[0], -1, -1)  # (B, 1, 128)
        x = torch.cat((cls_tokens, x), dim=1)  # (B, 33, 128)

        # 4. 포지셔널 인코딩 추가
        x = x + self.pos_encoder  # (B, 33, 128)

        # 5. Transformer 인코더 통과
        x = self.transformer_encoder(x)  # (B, 33, 128)

        # 6. [CLS] 토큰의 출력(인덱스 0)만 사용하여 분류 수행
        cls_output = x[:, 0, :]  # (B, 128)

        # 7. 분류기 통과
        output = self.classifier(cls_output)  # (B, num_classes)

        return output

# %%
def train_model(model, train_loader, val_loader, num_epochs, model_save_path, class_weights=None, patience=10):
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5) # 손실이 개선되지 않으면 학습률을 낮춤

    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    best_val_loss = float('inf') # 가장 좋았던 검증 손실을 저장하는 변수
    early_stop_counter = 0

    for epoch in range(num_epochs):
        # 훈련 단계
        model.train()
        train_loss = 0.0
        correct_train, total_train = 0, 0
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optimizer.zero_grad() # 이전 그래디언트 초기화
            outputs = model(data) # 순전파
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) # 그래디언트 폭주 방지를 위한 gradient clipping
            optimizer.step() # 가중치 업데이트
            train_loss += loss.item()

            # 훈련 정확도 계산
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        # 검증 단계
        model.eval()
        val_loss, correct_val, total_val = 0.0, 0, 0
        with torch.no_grad():
            for data, labels in val_loader:
                data, labels = data.to(device), labels.to(device)
                outputs = model(data)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        avg_train_loss = train_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = correct_val / total_val

        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(train_accuracy)
        history['val_loss'].append(avg_val_loss)
        history['val_acc'].append(val_accuracy)
        scheduler.step(avg_val_loss)

        # 최고 성능 모델 저장 (Early Stopping 기준)
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), model_save_path) # 지정된 경로에 모델 저장
            early_stop_counter = 0  # 카운터 초기화
        else:
            early_stop_counter += 1 # 성능이 개선되지 않으면 카운터 증가

        if early_stop_counter >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs.")
            break # 훈련 중단

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Train Accuracy: {train_accuracy:.4f},  Val Accuracy: {val_accuracy:.4f}')

    return history

# %%
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
# 모델 평가
def evaluate_model(model, test_loader, dataset):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            all_preds.extend(torch.argmax(outputs, 1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    print(f"\nAccuracy: {accuracy_score(all_labels, all_preds):.4f}")
    print(classification_report(all_labels, all_preds, target_names=dataset.activity_encoder.classes_, digits=4))
    plot_confusion_matrix(all_labels, all_preds, dataset.activity_encoder.classes_)

# %%
def plot_training_history(history, title):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    fig.suptitle(title, fontsize=16)

    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Validation Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epoch'); ax1.legend(); ax1.grid(True)

    ax2.plot(history['train_acc'], label='Training Accuracy', color='blue')
    ax2.plot(history['val_acc'], label='Validation Accuracy', color='green')
    ax2.set_title('Training and Validation Accuracy')
    ax2.set_xlabel('Epoch'); ax2.legend(); ax2.grid(True)

    plt.show()

# %% [markdown]
# ### `run_experiment` 함수의 역할
# parameter
# - `activity_type`: "Dynamic" 또는 "Static"
# - `activities`: 해당 실험에 사용할 활동 목록
# - `full_df`: 전체 데이터프레임
# - `num_epochs`: 훈련 에포크 수
#
# 함수 동작 과정
# 1.  주어진 활동 목록으로 원본 데이터를 필터링
# 2.  피험자 ID를 기준으로 훈련/검증/테스트 데이터프레임으로 나눔
# 3.  데이터셋, 데이터로더 생성(스케일러 데이터 유출 방지 로직 포함)
# 4.  분류할 클래스 수에 맞춰 모델을 생성
# 5.  모델을 훈련하고, 최고 성능 모델을 저장
# 6.  저장된 최고 모델로 최종 평가를 수행하고, 훈련 과정을 시각화

# %%
def run_experiment(activity_type, activities, full_df, num_epochs=30):
    print("="*60)
    print(f"### STARTING EXPERIMENT FOR: {activity_type.upper()} ACTIVITIES ###")
    print("="*60)

    # 1. 실험에 맞는 데이터만 필터링
    df = full_df[full_df['activity'].isin(activities)].copy()
    print(f"Filtered data for {activity_type} activities. Total rows: {len(df)}")

    # 2. 피험자 ID 기준으로 데이터프레임 분할
    train_df = df[df['user'] <= 28]
    val_df = df[(df['user'] > 28) & (df['user'] <= 32)]
    test_df = df[(df['user'] > 32) & (df['user'] <= 36)]

    # 3. 데이터셋 및 데이터로더 생성
    print("\nCreating datasets...")
    train_dataset = WISDMDataset(train_df, window_size=128)
    fitted_scaler = train_dataset.scaler
    val_dataset = WISDMDataset(val_df, window_size=128, scaler=fitted_scaler)
    test_dataset = WISDMDataset(test_df, window_size=128, scaler=fitted_scaler)

    class_weights = compute_class_weight(
        'balanced',
        classes=np.unique(train_dataset.encoded_labels),
        y=train_dataset.encoded_labels
    )
    class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

    print(f"Class Weights for {activity_type}: {train_dataset.activity_encoder.classes_}")
    print(f"Calculated weights: {class_weights.cpu().numpy()}")
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    # 4. 모델 생성
    num_classes = len(activities)
    model = BERT_HAR_Model(
        num_classes=num_classes,
        input_channels=3,
        d_model=128,               # Transformer 모델 차원
        n_head=8,                  # 어텐션 헤드 수
        num_encoder_layers=4,      # 인코더 레이어 수
        dim_feedforward=512,       # FFN 은닉층 크기
        dropout=0.1
    ).to(device)
    print(f"Model for {activity_type} created with {num_classes} output classes.")

    print("\n--- Model Summary ---")
    print(summary(model, input_size=(64, 3, 128))) # (batch_size, channels, sequence_length)
    print("---------------------\n")

    # 5. 모델 훈련
    print(f"--- Training {activity_type} Model ---")
    model_save_path = f'best_model_{activity_type.lower()}.pth'
    history = train_model(model, train_loader, val_loader, num_epochs, model_save_path, class_weights, patience=20)

    # 6. 최종 평가 및 시각화
    print(f"\n--- Final Evaluation for {activity_type} Model ---")
    model.load_state_dict(torch.load(model_save_path))
    evaluate_model(model, test_loader, test_dataset)
    plot_training_history(history, f'Training History for {activity_type} Activities')
    print("\n")

if __name__ == '__main__':
    file_path = '/content/drive/MyDrive/AI_data/WISDM_HAR.csv'
    full_data = load_and_preprocess_data(file_path)

    # dynamic activities
    dynamic_activities = ['Walking', 'Jogging', 'Upstairs', 'Downstairs']
    run_experiment('Dynamic', dynamic_activities, full_data, num_epochs=100)

    # static activities
    static_activities = ['Sitting', 'Standing']
    run_experiment('Static', static_activities, full_data, num_epochs=100)
# Out:
# ============================================================
# ### STARTING EXPERIMENT FOR: DYNAMIC ACTIVITIES ###
# ============================================================
# Filtered data for Dynamic activities. Total rows: 978132
#
# Creating datasets...
# Dataset created with 11642 samples.
# ... Activity distribution: Counter({'Walking': 5026, 'Jogging': 4007, 'Upstairs': 1464, 'Downstairs': 1145})
#
# Dataset created with 1952 samples.
# ... Activity distribution: Counter({'Walking': 846, 'Jogging': 610, 'Upstairs': 276, 'Downstairs': 220})
#
# Dataset created with 1637 samples.
# ... Activity distribution: Counter({'Walking': 648, 'Jogging': 631, 'Upstairs': 179, 'Downstairs': 179})
#
# Class Weights for Dynamic: ['Downstairs' 'Jogging' 'Upstairs' 'Walking']
# Calculated weights: [2.5419214  0.7263539  1.9880464  0.57908875]
# Model for Dynamic created with 4 output classes.
#
# --- Model Summary ---
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# BERT_HAR_Model                                [64, 4]                   4,352
# ├─Sequential: 1-1                             [64, 128, 32]             --
# │    └─Conv1d: 2-1                            [64, 128, 64]             2,688
# │    └─BatchNorm1d: 2-2                       [64, 128, 64]             256
# │    └─ReLU: 2-3                              [64, 128, 64]             --
# │    └─MaxPool1d: 2-4                         [64, 128, 32]             --
# ├─TransformerEncoder: 1-2                     [64, 33, 128]             --
# │    └─ModuleList: 2-5                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-2      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-3      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-4      [64, 33, 128]             198,272
# ├─Sequential: 1-3                             [64, 4]                   --
# │    └─Linear: 2-6                            [64, 128]                 16,512
# │    └─ReLU: 2-7                              [64, 128]                 --
# │    └─Dropout: 2-8                           [64, 128]                 --
# │    └─Linear: 2-9                            [64, 4]                   516
# ===============================================================================================
# Total params: 817,412
# Trainable params: 817,412
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 45.97
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 69.01
# Params size (MB): 2.20
# Estimated Total Size (MB): 71.31
# ===============================================================================================
# ---------------------
#
# --- Training Dynamic Model ---
# Epoch [1/100], Train Loss: 0.7459, Val Loss: 0.6640, Train Accuracy: 0.7693,  Val Accuracy: 0.7951
# Epoch [2/100], Train Loss: 0.3446, Val Loss: 0.5298, Train Accuracy: 0.9232,  Val Accuracy: 0.8340
# Epoch [3/100], Train Loss: 0.2681, Val Loss: 1.0807, Train Accuracy: 0.9463,  Val Accuracy: 0.8222
# Epoch [4/100], Train Loss: 0.1936, Val Loss: 1.3934, Train Accuracy: 0.9607,  Val Accuracy: 0.8130
# Epoch [5/100], Train Loss: 0.1576, Val Loss: 1.1704, Train Accuracy: 0.9717,  Val Accuracy: 0.8089
# Epoch [6/100], Train Loss: 0.1368, Val Loss: 1.3662, Train Accuracy: 0.9722,  Val Accuracy: 0.7802
# Epoch [7/100], Train Loss: 0.1165, Val Loss: 1.2114, Train Accuracy: 0.9790,  Val Accuracy: 0.7997
# Epoch [8/100], Train Loss: 0.0886, Val Loss: 1.0715, Train Accuracy: 0.9821,  Val Accuracy: 0.8089
# Epoch [9/100], Train Loss: 0.0430, Val Loss: 1.5782, Train Accuracy: 0.9913,  Val Accuracy: 0.7987
# Epoch [10/100], Train Loss: 0.0268, Val Loss: 1.5844, Train Accuracy: 0.9953,  Val Accuracy: 0.8084
# Epoch [11/100], Train Loss: 0.0221, Val Loss: 1.7625, Train Accuracy: 0.9963,  Val Accuracy: 0.8064
# Epoch [12/100], Train Loss: 0.0225, Val Loss: 1.1574, Train Accuracy: 0.9954,  Val Accuracy: 0.8258
# Epoch [13/100], Train Loss: 0.0176, Val Loss: 0.9267, Train Accuracy: 0.9973,  Val Accuracy: 0.8453
# Epoch [14/100], Train Loss: 0.0133, Val Loss: 1.4420, Train Accuracy: 0.9971,  Val Accuracy: 0.8058
# Epoch [15/100], Train Loss: 0.0093, Val Loss: 1.7492, Train Accuracy: 0.9984,  Val Accuracy: 0.8084
# Epoch [16/100], Train Loss: 0.0028, Val Loss: 1.9435, Train Accuracy: 0.9993,  Val Accuracy: 0.8166
# Epoch [17/100], Train Loss: 0.0040, Val Loss: 2.0899, Train Accuracy: 0.9995,  Val Accuracy: 0.8156
# Epoch [18/100], Train Loss: 0.0052, Val Loss: 2.5319, Train Accuracy: 0.9991,  Val Accuracy: 0.7930
# Epoch [19/100], Train Loss: 0.0073, Val Loss: 2.1314, Train Accuracy: 0.9985,  Val Accuracy: 0.8058
# Epoch [20/100], Train Loss: 0.0056, Val Loss: 2.1306, Train Accuracy: 0.9989,  Val Accuracy: 0.8002
# Epoch [21/100], Train Loss: 0.0020, Val Loss: 1.9814, Train Accuracy: 0.9997,  Val Accuracy: 0.8212
# Early stopping triggered after 22 epochs.
#
# --- Final Evaluation for Dynamic Model ---
#
# Accuracy: 0.8210
#               precision    recall  f1-score   support
#
#   Downstairs     0.5424    0.7151    0.6169       179
#      Jogging     1.0000    0.7750    0.8732       631
#     Upstairs     0.4804    0.8212    0.6062       179
#      Walking     0.9571    0.8951    0.9250       648
#
#     accuracy                         0.8210      1637
#    macro avg     0.7450    0.8016    0.7553      1637
# weighted avg     0.8762    0.8210    0.8365      1637
# ============================================================
# ### STARTING EXPERIMENT FOR: STATIC ACTIVITIES ###
# ============================================================
# Filtered data for Static activities. Total rows: 108333
#
# Creating datasets...
# Dataset created with 1152 samples.
# ... Activity distribution: Counter({'Sitting': 646, 'Standing': 506})
#
# Dataset created with 276 samples.
# ... Activity distribution: Counter({'Sitting': 140, 'Standing': 136})
#
# Dataset created with 226 samples.
# ... Activity distribution: Counter({'Sitting': 135, 'Standing': 91})
#
# Class Weights for Static: ['Sitting' 'Standing']
# Calculated weights: [0.89164084 1.1383399 ]
# Model for Static created with 2 output classes.
#
# --- Model Summary ---
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# BERT_HAR_Model                                [64, 2]                   4,352
# ├─Sequential: 1-1                             [64, 128, 32]             --
# │    └─Conv1d: 2-1                            [64, 128, 64]             2,688
# │    └─BatchNorm1d: 2-2                       [64, 128, 64]             256
# │    └─ReLU: 2-3                              [64, 128, 64]             --
# │    └─MaxPool1d: 2-4                         [64, 128, 32]             --
# ├─TransformerEncoder: 1-2                     [64, 33, 128]             --
# │    └─ModuleList: 2-5                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-2      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-3      [64, 33, 128]             198,272
# │    │    └─TransformerEncoderLayer: 3-4      [64, 33, 128]             198,272
# ├─Sequential: 1-3                             [64, 2]                   --
# │    └─Linear: 2-6                            [64, 128]                 16,512
# │    └─ReLU: 2-7                              [64, 128]                 --
# │    └─Dropout: 2-8                           [64, 128]                 --
# │    └─Linear: 2-9                            [64, 2]                   258
# ===============================================================================================
# Total params: 817,154
# Trainable params: 817,154
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 45.95
# ===============================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 69.01
# Params size (MB): 2.19
# Estimated Total Size (MB): 71.30
# ===============================================================================================
# ---------------------
#
# --- Training Static Model ---
# Epoch [1/100], Train Loss: 0.1517, Val Loss: 1.5778, Train Accuracy: 0.9497,  Val Accuracy: 0.8080
# Epoch [2/100], Train Loss: 0.1242, Val Loss: 0.3503, Train Accuracy: 0.9688,  Val Accuracy: 0.8551
# Epoch [3/100], Train Loss: 0.0836, Val Loss: 0.7068, Train Accuracy: 0.9722,  Val Accuracy: 0.7899
# Epoch [4/100], Train Loss: 0.0744, Val Loss: 0.6672, Train Accuracy: 0.9783,  Val Accuracy: 0.7935
# Epoch [5/100], Train Loss: 0.0760, Val Loss: 1.6167, Train Accuracy: 0.9635,  Val Accuracy: 0.8442
# Epoch [6/100], Train Loss: 0.0826, Val Loss: 2.0487, Train Accuracy: 0.9783,  Val Accuracy: 0.8442
# Epoch [7/100], Train Loss: 0.1054, Val Loss: 1.9885, Train Accuracy: 0.9783,  Val Accuracy: 0.7681
# Epoch [8/100], Train Loss: 0.0836, Val Loss: 1.3871, Train Accuracy: 0.9809,  Val Accuracy: 0.8007
# Epoch [9/100], Train Loss: 0.0812, Val Loss: 0.8103, Train Accuracy: 0.9800,  Val Accuracy: 0.8225
# Epoch [10/100], Train Loss: 0.0536, Val Loss: 1.1684, Train Accuracy: 0.9852,  Val Accuracy: 0.8442
# Epoch [11/100], Train Loss: 0.0531, Val Loss: 0.8596, Train Accuracy: 0.9852,  Val Accuracy: 0.7971
# Epoch [12/100], Train Loss: 0.0607, Val Loss: 1.0235, Train Accuracy: 0.9818,  Val Accuracy: 0.8007
# Epoch [13/100], Train Loss: 0.0548, Val Loss: 0.8768, Train Accuracy: 0.9887,  Val Accuracy: 0.7971
# Epoch [14/100], Train Loss: 0.0493, Val Loss: 1.0973, Train Accuracy: 0.9896,  Val Accuracy: 0.8007
# Epoch [15/100], Train Loss: 0.0475, Val Loss: 0.6121, Train Accuracy: 0.9878,  Val Accuracy: 0.8732
# Epoch [16/100], Train Loss: 0.0371, Val Loss: 1.0426, Train Accuracy: 0.9922,  Val Accuracy: 0.8659
# Epoch [17/100], Train Loss: 0.0514, Val Loss: 0.4732, Train Accuracy: 0.9861,  Val Accuracy: 0.8913
# Epoch [18/100], Train Loss: 0.0472, Val Loss: 0.4494, Train Accuracy: 0.9870,  Val Accuracy: 0.8949
# Epoch [19/100], Train Loss: 0.0547, Val Loss: 0.5827, Train Accuracy: 0.9887,  Val Accuracy: 0.8841
# Epoch [20/100], Train Loss: 0.0499, Val Loss: 0.5808, Train Accuracy: 0.9896,  Val Accuracy: 0.8841
# Epoch [21/100], Train Loss: 0.0480, Val Loss: 0.6302, Train Accuracy: 0.9887,  Val Accuracy: 0.8841
# Early stopping triggered after 22 epochs.
#
# --- Final Evaluation for Static Model ---
#
# Accuracy: 0.9912
#               precision    recall  f1-score   support
#
#      Sitting     0.9854    1.0000    0.9926       135
#     Standing     1.0000    0.9780    0.9889        91
#
#     accuracy                         0.9912       226
#    macro avg     0.9927    0.9890    0.9908       226
# weighted avg     0.9913    0.9912    0.9911       226
