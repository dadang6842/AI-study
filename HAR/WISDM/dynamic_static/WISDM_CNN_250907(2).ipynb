# %% [markdown]
# # WISDM HAR - CNN
#
# - 정적, 동적 활동을 분리하여 학습
#
# 1.  동적 활동(Dynamic Activities) 모델: 'Walking', 'Jogging', 'Upstairs', 'Downstairs'
# 2.  정적 활동(Static Activities) 모델: 'Sitting', 'Standing'

# %%
# !pip install -q torchinfo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import warnings
warnings.filterwarnings('ignore')

# GPU 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def load_and_preprocess_data(file_path):
    """WISDM HAR 데이터 로드 및 전처리"""
    df = pd.read_csv(file_path)

    df['x-axis'] = df['x-axis'].astype('float32')
    df['y-axis'] = df['y-axis'].astype('float32')
    df['z-axis'] = df['z-axis'].astype('float32')

    return df

# %%
class WISDMDataset(Dataset):
    def __init__(self, data, window_size=128, scaler=None):
        self.window_size = window_size
        self.data = []
        self.labels = []

        self.activity_encoder = LabelEncoder()

        # sliding window
        for user in data['user'].unique():
            user_data = data[data['user'] == user]
            sensor_data = user_data[['x-axis', 'y-axis', 'z-axis']].values
            activity_labels = user_data['activity'].values

            for i in range(0, len(sensor_data) - window_size + 1, window_size // 2):
                window = sensor_data[i:i + window_size]
                labels_in_window = activity_labels[i:i + window_size]

                if len(window) == window_size:
                    # 최빈값을 label로
                    # Counter(labels_in_window).most_common(1) -> [('Walking', 120)]과 같은 형태
                    most_common_label = Counter(labels_in_window).most_common(1)[0][0]

                    self.data.append(window)
                    self.labels.append(most_common_label)

        # label encoding
        self.encoded_labels = self.activity_encoder.fit_transform(self.labels)

        # scaling
        self.data = np.array(self.data)
        original_shape = self.data.shape
        if scaler is None:
            self.scaler = StandardScaler()
            self.data = self.scaler.fit_transform(self.data.reshape(-1, 3)).reshape(original_shape) # StandardSclaer는 2차원 입력을 받음
        else:
            self.scaler = scaler
            self.data = self.scaler.transform(self.data.reshape(-1, 3)).reshape(original_shape)

        print(f"Dataset created with {len(self.data)} samples.")
        print(f"... Activity distribution: {Counter(self.labels)}\n") # Counter: 각 항목이 몇 개씩 들어 있는지 세서 딕셔너리 형태로 알려줌

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # [길이 128, 채널 3] 형태의 데이터를 [채널 3, 길이 128]로 변환
        data_tensor = torch.FloatTensor(self.data[idx]).transpose(0, 1)
        label_tensor = torch.LongTensor([self.encoded_labels[idx]])[0]
        return data_tensor, label_tensor

# %%
class CnnHarModel(nn.Module):
    def __init__(self, num_classes, input_channels=3):
        super(CnnHarModel, self).__init__()

        # 컨볼루션 레이어 블록
        self.conv_layers = nn.Sequential(
            # Block 1
            nn.Conv1d(in_channels=input_channels, out_channels=64, kernel_size=7, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),

            # Block 2
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),

            # Block 3
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )

        self.flattened_size = 256 * 16

        # 분류를 위한 완전 연결 레이어
        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(start_dim=1),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        # 입력 shape: (Batch, 3, 128)
        x = self.conv_layers(x)    # 출력 shape: (Batch, 256, 16)
        output = self.classifier(x) # 출력 shape: (Batch, num_classes)
        return output

# %%
def train_model(model, train_loader, val_loader, num_epochs, model_save_path, class_weights=None, patience=10):
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5) # 손실이 개선되지 않으면 학습률을 낮춤

    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    best_val_loss = float('inf') # 가장 좋았던 검증 손실을 저장하는 변수
    early_stop_counter = 0

    for epoch in range(num_epochs):
        # 훈련 단계
        model.train()
        train_loss = 0.0
        correct_train, total_train = 0, 0
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optimizer.zero_grad() # 이전 그래디언트 초기화
            outputs = model(data) # 순전파
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) # 그래디언트 폭주 방지를 위한 gradient clipping
            optimizer.step() # 가중치 업데이트
            train_loss += loss.item()

            # 훈련 정확도 계산
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        # 검증 단계
        model.eval()
        val_loss, correct_val, total_val = 0.0, 0, 0
        with torch.no_grad():
            for data, labels in val_loader:
                data, labels = data.to(device), labels.to(device)
                outputs = model(data)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        avg_train_loss = train_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        avg_val_loss = val_loss / len(val_loader)
        val_accuracy = correct_val / total_val

        history['train_loss'].append(avg_train_loss)
        history['train_acc'].append(train_accuracy)
        history['val_loss'].append(avg_val_loss)
        history['val_acc'].append(val_accuracy)
        scheduler.step(avg_val_loss)

        # 최고 성능 모델 저장 (Early Stopping 기준)
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), model_save_path) # 지정된 경로에 모델 저장
            early_stop_counter = 0  # 카운터 초기화
        else:
            early_stop_counter += 1 # 성능이 개선되지 않으면 카운터 증가

        if early_stop_counter >= patience:
            print(f"Early stopping triggered after {epoch + 1} epochs.")
            break # 훈련 중단

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}, Train Accuracy: {train_accuracy:.4f},  Val Accuracy: {val_accuracy:.4f}')

    return history

# %%
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
# 모델 평가
def evaluate_model(model, test_loader, dataset):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for data, labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            all_preds.extend(torch.argmax(outputs, 1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    print(f"\nAccuracy: {accuracy_score(all_labels, all_preds):.4f}")
    print(classification_report(all_labels, all_preds, target_names=dataset.activity_encoder.classes_, digits=4))
    plot_confusion_matrix(all_labels, all_preds, dataset.activity_encoder.classes_)

# %%
def plot_training_history(history, title):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    fig.suptitle(title, fontsize=16)

    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['val_loss'], label='Validation Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epoch'); ax1.legend(); ax1.grid(True)

    ax2.plot(history['train_acc'], label='Training Accuracy', color='blue')
    ax2.plot(history['val_acc'], label='Validation Accuracy', color='green')
    ax2.set_title('Training and Validation Accuracy')
    ax2.set_xlabel('Epoch'); ax2.legend(); ax2.grid(True)

    plt.show()

# %% [markdown]
# ### `run_experiment` 함수의 역할
# parameter
# - `activity_type`: "Dynamic" 또는 "Static"
# - `activities`: 해당 실험에 사용할 활동 목록
# - `full_df`: 전체 데이터프레임
# - `num_epochs`: 훈련 에포크 수
#
# 함수 동작 과정
# 1.  주어진 활동 목록으로 원본 데이터를 필터링
# 2.  피험자 ID를 기준으로 훈련/검증/테스트 데이터프레임으로 나눔
# 3.  데이터셋, 데이터로더 생성(스케일러 데이터 유출 방지 로직 포함)
# 4.  분류할 클래스 수에 맞춰 모델을 생성
# 5.  모델을 훈련하고, 최고 성능 모델을 저장
# 6.  저장된 최고 모델로 최종 평가를 수행하고, 훈련 과정을 시각화

# %%
def run_experiment(activity_type, activities, full_df, num_epochs=30):
    print("="*60)
    print(f"### STARTING EXPERIMENT FOR: {activity_type.upper()} ACTIVITIES ###")
    print("="*60)

    # 1. 실험에 맞는 데이터만 필터링
    df = full_df[full_df['activity'].isin(activities)].copy()
    print(f"Filtered data for {activity_type} activities. Total rows: {len(df)}")

    # 2. 피험자 ID 기준으로 데이터프레임 분할
    train_df = df[df['user'] <= 28]
    val_df = df[(df['user'] > 28) & (df['user'] <= 32)]
    test_df = df[(df['user'] > 32) & (df['user'] <= 36)]

    # 3. 데이터셋 및 데이터로더 생성
    print("\nCreating datasets...")
    train_dataset = WISDMDataset(train_df, window_size=128)
    fitted_scaler = train_dataset.scaler
    val_dataset = WISDMDataset(val_df, window_size=128, scaler=fitted_scaler)
    test_dataset = WISDMDataset(test_df, window_size=128, scaler=fitted_scaler)

    class_weights = compute_class_weight(
        'balanced',
        classes=np.unique(train_dataset.encoded_labels),
        y=train_dataset.encoded_labels
    )
    class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

    print(f"Class Weights for {activity_type}: {train_dataset.activity_encoder.classes_}")
    print(f"Calculated weights: {class_weights.cpu().numpy()}")
    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    # 4. 모델 생성
    num_classes = len(activities)
    model = CnnHarModel(
        num_classes=num_classes,
        input_channels=3
    ).to(device)

    print(f"Model for {activity_type} created with {num_classes} output classes.")

    print("\n--- Model Summary ---")
    print(summary(model, input_size=(64, 3, 128))) # (batch_size, channels, sequence_length)
    print("---------------------\n")

    # 5. 모델 훈련
    print(f"--- Training {activity_type} Model ---")
    model_save_path = f'best_model_{activity_type.lower()}.pth'
    history = train_model(model, train_loader, val_loader, num_epochs, model_save_path, class_weights, patience=20)

    # 6. 최종 평가 및 시각화
    print(f"\n--- Final Evaluation for {activity_type} Model ---")
    model.load_state_dict(torch.load(model_save_path))
    evaluate_model(model, test_loader, test_dataset)
    plot_training_history(history, f'Training History for {activity_type} Activities')
    print("\n")

if __name__ == '__main__':
    file_path = '/content/drive/MyDrive/AI_data/WISDM_HAR.csv'
    full_data = load_and_preprocess_data(file_path)

    # dynamic activities
    dynamic_activities = ['Walking', 'Jogging', 'Upstairs', 'Downstairs']
    run_experiment('Dynamic', dynamic_activities, full_data, num_epochs=100)

    # static activities
    static_activities = ['Sitting', 'Standing']
    run_experiment('Static', static_activities, full_data, num_epochs=100)
# Out:
# ============================================================
# ### STARTING EXPERIMENT FOR: DYNAMIC ACTIVITIES ###
# ============================================================
# Filtered data for Dynamic activities. Total rows: 978132
#
# Creating datasets...
# Dataset created with 11642 samples.
# ... Activity distribution: Counter({'Walking': 5026, 'Jogging': 4007, 'Upstairs': 1464, 'Downstairs': 1145})
#
# Dataset created with 1952 samples.
# ... Activity distribution: Counter({'Walking': 846, 'Jogging': 610, 'Upstairs': 276, 'Downstairs': 220})
#
# Dataset created with 1637 samples.
# ... Activity distribution: Counter({'Walking': 648, 'Jogging': 631, 'Upstairs': 179, 'Downstairs': 179})
#
# Class Weights for Dynamic: ['Downstairs' 'Jogging' 'Upstairs' 'Walking']
# Calculated weights: [2.5419214  0.7263539  1.9880464  0.57908875]
# Model for Dynamic created with 4 output classes.
#
# --- Model Summary ---
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CnnHarModel                              [64, 4]                   --
# ├─Sequential: 1-1                        [64, 256, 16]             --
# │    └─Conv1d: 2-1                       [64, 64, 128]             1,408
# │    └─BatchNorm1d: 2-2                  [64, 64, 128]             128
# │    └─ReLU: 2-3                         [64, 64, 128]             --
# │    └─MaxPool1d: 2-4                    [64, 64, 64]              --
# │    └─Conv1d: 2-5                       [64, 128, 64]             24,704
# │    └─BatchNorm1d: 2-6                  [64, 128, 64]             256
# │    └─ReLU: 2-7                         [64, 128, 64]             --
# │    └─MaxPool1d: 2-8                    [64, 128, 32]             --
# │    └─Conv1d: 2-9                       [64, 256, 32]             98,560
# │    └─BatchNorm1d: 2-10                 [64, 256, 32]             512
# │    └─ReLU: 2-11                        [64, 256, 32]             --
# │    └─MaxPool1d: 2-12                   [64, 256, 16]             --
# ├─Sequential: 1-2                        [64, 4]                   --
# │    └─AdaptiveAvgPool1d: 2-13           [64, 256, 1]              --
# │    └─Flatten: 2-14                     [64, 256]                 --
# │    └─Dropout: 2-15                     [64, 256]                 --
# │    └─Linear: 2-16                      [64, 4]                   1,028
# ==========================================================================================
# Total params: 126,596
# Trainable params: 126,596
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 314.70
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 25.17
# Params size (MB): 0.51
# Estimated Total Size (MB): 25.77
# ==========================================================================================
# ---------------------
#
# --- Training Dynamic Model ---
# Epoch [1/100], Train Loss: 0.4712, Val Loss: 0.6550, Train Accuracy: 0.8681,  Val Accuracy: 0.7736
# Epoch [2/100], Train Loss: 0.2257, Val Loss: 1.1812, Train Accuracy: 0.9454,  Val Accuracy: 0.7551
# Epoch [3/100], Train Loss: 0.1540, Val Loss: 0.7365, Train Accuracy: 0.9611,  Val Accuracy: 0.8135
# Epoch [4/100], Train Loss: 0.1178, Val Loss: 0.8688, Train Accuracy: 0.9731,  Val Accuracy: 0.8099
# Epoch [5/100], Train Loss: 0.0990, Val Loss: 0.7675, Train Accuracy: 0.9766,  Val Accuracy: 0.7987
# Epoch [6/100], Train Loss: 0.0836, Val Loss: 0.6064, Train Accuracy: 0.9808,  Val Accuracy: 0.8192
# Epoch [7/100], Train Loss: 0.0711, Val Loss: 0.8705, Train Accuracy: 0.9826,  Val Accuracy: 0.7905
# Epoch [8/100], Train Loss: 0.0671, Val Loss: 1.1123, Train Accuracy: 0.9851,  Val Accuracy: 0.7951
# Epoch [9/100], Train Loss: 0.0576, Val Loss: 0.4794, Train Accuracy: 0.9865,  Val Accuracy: 0.9114
# Epoch [10/100], Train Loss: 0.0570, Val Loss: 0.6837, Train Accuracy: 0.9880,  Val Accuracy: 0.8279
# Epoch [11/100], Train Loss: 0.0452, Val Loss: 1.4889, Train Accuracy: 0.9881,  Val Accuracy: 0.8192
# Epoch [12/100], Train Loss: 0.0456, Val Loss: 0.9930, Train Accuracy: 0.9900,  Val Accuracy: 0.8330
# Epoch [13/100], Train Loss: 0.0390, Val Loss: 1.0013, Train Accuracy: 0.9910,  Val Accuracy: 0.8002
# Epoch [14/100], Train Loss: 0.0336, Val Loss: 0.7977, Train Accuracy: 0.9924,  Val Accuracy: 0.8489
# Epoch [15/100], Train Loss: 0.0317, Val Loss: 0.9666, Train Accuracy: 0.9917,  Val Accuracy: 0.8356
# Epoch [16/100], Train Loss: 0.0194, Val Loss: 0.8843, Train Accuracy: 0.9960,  Val Accuracy: 0.8407
# Epoch [17/100], Train Loss: 0.0130, Val Loss: 1.1566, Train Accuracy: 0.9963,  Val Accuracy: 0.7838
# Epoch [18/100], Train Loss: 0.0145, Val Loss: 0.7733, Train Accuracy: 0.9964,  Val Accuracy: 0.8422
# Epoch [19/100], Train Loss: 0.0123, Val Loss: 0.9097, Train Accuracy: 0.9974,  Val Accuracy: 0.8197
# Epoch [20/100], Train Loss: 0.0123, Val Loss: 0.8722, Train Accuracy: 0.9964,  Val Accuracy: 0.8417
# Epoch [21/100], Train Loss: 0.0097, Val Loss: 0.8818, Train Accuracy: 0.9974,  Val Accuracy: 0.8499
# Epoch [22/100], Train Loss: 0.0089, Val Loss: 0.8429, Train Accuracy: 0.9978,  Val Accuracy: 0.8571
# Epoch [23/100], Train Loss: 0.0056, Val Loss: 0.7274, Train Accuracy: 0.9989,  Val Accuracy: 0.8535
# Epoch [24/100], Train Loss: 0.0076, Val Loss: 0.8172, Train Accuracy: 0.9982,  Val Accuracy: 0.8427
# Epoch [25/100], Train Loss: 0.0046, Val Loss: 0.6167, Train Accuracy: 0.9990,  Val Accuracy: 0.9093
# Epoch [26/100], Train Loss: 0.0052, Val Loss: 0.8261, Train Accuracy: 0.9986,  Val Accuracy: 0.8530
# Epoch [27/100], Train Loss: 0.0054, Val Loss: 0.8262, Train Accuracy: 0.9983,  Val Accuracy: 0.8504
# Epoch [28/100], Train Loss: 0.0045, Val Loss: 0.7289, Train Accuracy: 0.9987,  Val Accuracy: 0.8576
# Early stopping triggered after 29 epochs.
#
# --- Final Evaluation for Dynamic Model ---
#
# Accuracy: 0.9102
#               precision    recall  f1-score   support
#
#   Downstairs     0.6972    0.9777    0.8140       179
#      Jogging     0.9817    0.9334    0.9569       631
#     Upstairs     0.7527    0.7821    0.7671       179
#      Walking     0.9767    0.9043    0.9391       648
#
#     accuracy                         0.9102      1637
#    macro avg     0.8521    0.8994    0.8693      1637
# weighted avg     0.9235    0.9102    0.9135      1637
# ============================================================
# ### STARTING EXPERIMENT FOR: STATIC ACTIVITIES ###
# ============================================================
# Filtered data for Static activities. Total rows: 108333
#
# Creating datasets...
# Dataset created with 1152 samples.
# ... Activity distribution: Counter({'Sitting': 646, 'Standing': 506})
#
# Dataset created with 276 samples.
# ... Activity distribution: Counter({'Sitting': 140, 'Standing': 136})
#
# Dataset created with 226 samples.
# ... Activity distribution: Counter({'Sitting': 135, 'Standing': 91})
#
# Class Weights for Static: ['Sitting' 'Standing']
# Calculated weights: [0.89164084 1.1383399 ]
# Model for Static created with 2 output classes.
#
# --- Model Summary ---
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CnnHarModel                              [64, 2]                   --
# ├─Sequential: 1-1                        [64, 256, 16]             --
# │    └─Conv1d: 2-1                       [64, 64, 128]             1,408
# │    └─BatchNorm1d: 2-2                  [64, 64, 128]             128
# │    └─ReLU: 2-3                         [64, 64, 128]             --
# │    └─MaxPool1d: 2-4                    [64, 64, 64]              --
# │    └─Conv1d: 2-5                       [64, 128, 64]             24,704
# │    └─BatchNorm1d: 2-6                  [64, 128, 64]             256
# │    └─ReLU: 2-7                         [64, 128, 64]             --
# │    └─MaxPool1d: 2-8                    [64, 128, 32]             --
# │    └─Conv1d: 2-9                       [64, 256, 32]             98,560
# │    └─BatchNorm1d: 2-10                 [64, 256, 32]             512
# │    └─ReLU: 2-11                        [64, 256, 32]             --
# │    └─MaxPool1d: 2-12                   [64, 256, 16]             --
# ├─Sequential: 1-2                        [64, 2]                   --
# │    └─AdaptiveAvgPool1d: 2-13           [64, 256, 1]              --
# │    └─Flatten: 2-14                     [64, 256]                 --
# │    └─Dropout: 2-15                     [64, 256]                 --
# │    └─Linear: 2-16                      [64, 2]                   514
# ==========================================================================================
# Total params: 126,082
# Trainable params: 126,082
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 314.66
# ==========================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 25.17
# Params size (MB): 0.50
# Estimated Total Size (MB): 25.77
# ==========================================================================================
# ---------------------
#
# --- Training Static Model ---
# Epoch [1/100], Train Loss: 0.1135, Val Loss: 0.6399, Train Accuracy: 0.9566,  Val Accuracy: 0.8152
# Epoch [2/100], Train Loss: 0.0726, Val Loss: 1.2553, Train Accuracy: 0.9766,  Val Accuracy: 0.7935
# Epoch [3/100], Train Loss: 0.0574, Val Loss: 1.0796, Train Accuracy: 0.9783,  Val Accuracy: 0.7391
# Epoch [4/100], Train Loss: 0.0650, Val Loss: 1.1839, Train Accuracy: 0.9731,  Val Accuracy: 0.7319
# Epoch [5/100], Train Loss: 0.0533, Val Loss: 1.2870, Train Accuracy: 0.9774,  Val Accuracy: 0.6486
# Epoch [6/100], Train Loss: 0.0524, Val Loss: 0.9836, Train Accuracy: 0.9809,  Val Accuracy: 0.7319
# Epoch [7/100], Train Loss: 0.0555, Val Loss: 0.7166, Train Accuracy: 0.9809,  Val Accuracy: 0.8261
# Epoch [8/100], Train Loss: 0.0456, Val Loss: 0.9931, Train Accuracy: 0.9818,  Val Accuracy: 0.7355
# Epoch [9/100], Train Loss: 0.0521, Val Loss: 0.7419, Train Accuracy: 0.9826,  Val Accuracy: 0.8514
# Epoch [10/100], Train Loss: 0.0409, Val Loss: 0.6520, Train Accuracy: 0.9844,  Val Accuracy: 0.8659
# Epoch [11/100], Train Loss: 0.0369, Val Loss: 0.7604, Train Accuracy: 0.9887,  Val Accuracy: 0.8188
# Epoch [12/100], Train Loss: 0.0328, Val Loss: 0.8096, Train Accuracy: 0.9896,  Val Accuracy: 0.8261
# Epoch [13/100], Train Loss: 0.0287, Val Loss: 0.9079, Train Accuracy: 0.9913,  Val Accuracy: 0.7609
# Epoch [14/100], Train Loss: 0.0392, Val Loss: 0.8435, Train Accuracy: 0.9844,  Val Accuracy: 0.8225
# Epoch [15/100], Train Loss: 0.0307, Val Loss: 0.9711, Train Accuracy: 0.9905,  Val Accuracy: 0.8007
# Epoch [16/100], Train Loss: 0.0202, Val Loss: 0.7983, Train Accuracy: 0.9948,  Val Accuracy: 0.8551
# Epoch [17/100], Train Loss: 0.0233, Val Loss: 0.9018, Train Accuracy: 0.9931,  Val Accuracy: 0.8478
# Epoch [18/100], Train Loss: 0.0274, Val Loss: 0.9028, Train Accuracy: 0.9896,  Val Accuracy: 0.8587
# Epoch [19/100], Train Loss: 0.0301, Val Loss: 0.8762, Train Accuracy: 0.9922,  Val Accuracy: 0.8442
# Epoch [20/100], Train Loss: 0.0241, Val Loss: 0.9205, Train Accuracy: 0.9948,  Val Accuracy: 0.8442
# Early stopping triggered after 21 epochs.
#
# --- Final Evaluation for Static Model ---
#
# Accuracy: 0.9912
#               precision    recall  f1-score   support
#
#      Sitting     0.9854    1.0000    0.9926       135
#     Standing     1.0000    0.9780    0.9889        91
#
#     accuracy                         0.9912       226
#    macro avg     0.9927    0.9890    0.9908       226
# weighted avg     0.9913    0.9912    0.9911       226
