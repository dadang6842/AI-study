# %% [markdown]
# # WISDM HAR
#
# Class
# - Walking, Jogging, Upstairs, Downstairs, Sitting, Standing
#
# Sampling rate
# - 20Hz
#
# Fields
# - user, activity, timestamp, x-acceleration, y-acceleration, z-acceleration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (Conv1D, MaxPool1D, BatchNormalization, Dense,
                                     Input, ReLU, Dropout, LayerNormalization,
                                     MultiHeadAttention, GlobalAveragePooling1D, GRU)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
LABELS = ["Walking", "Jogging", "Upstairs", "Downstairs", "Sitting", "Standing"]

# %%
names = ["user_id", "activity", "timestamp", "x_axis", "y_axis", "z_axis", "NaN"]
data = pd.read_csv("/content/drive/MyDrive/AI_data/WISDM_ar_v1.1_raw.txt", header=None, names=names, comment=";") # comment: ';'로 시작하는 줄 무시(주석)

# %%
data.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis  NaN
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953  NaN
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424  NaN
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722  NaN
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717  NaN
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164  NaN

# %%
def convert_to_float(x):
    try:
        return np.float32(x)
    except:
        return np.nan

# %%
df = data.drop('NaN', axis=1)
df.isna().sum()
# Out:
# user_id      0
# activity     0
# timestamp    0
# x_axis       0
# y_axis       0
# z_axis       1
# dtype: int64

# %%
df = df.dropna()
df.isna().sum()
# Out:
# user_id      0
# activity     0
# timestamp    0
# x_axis       0
# y_axis       0
# z_axis       0
# dtype: int64

# %%
df["z_axis"] = df["z_axis"].replace(regex=True, to_replace=r';', value=r'')

df["x_axis"] = df["x_axis"].apply(convert_to_float)
df["y_axis"] = df["y_axis"].apply(convert_to_float)
df["z_axis"] = df["z_axis"].apply(convert_to_float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1098203 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1098203 non-null  int64
#  1   activity   1098203 non-null  object
#  2   timestamp  1098203 non-null  int64
#  3   x_axis     1098203 non-null  float32
#  4   y_axis     1098203 non-null  float32
#  5   z_axis     1098203 non-null  float32
# dtypes: float32(3), int64(2), object(1)
# memory usage: 46.1+ MB

# %%
df['activity'].value_counts()
# Out:
# activity
# Walking       424397
# Jogging       342176
# Upstairs      122869
# Downstairs    100427
# Sitting        59939
# Standing       48395
# Name: count, dtype: int64

# %%
df['user_id'].value_counts()
# Out:
# user_id
# 20    56632
# 19    45383
# 31    44282
# 8     41188
# 29    38245
# 14    38192
# 13    37093
# 34    35947
# 32    35506
# 21    35436
# 3     35161
# 27    34958
# 10    34883
# 18    32811
# 12    32641
# 26    32578
# 36    32261
# 11    31658
# 7     30967
# 1     29978
# 6     29704
# 33    29453
# 5     28509
# 15    28154
# 24    25736
# 23    25673
# 30    25335
# 2     23525
# 35    22394
# 22    22310
# 17    22020
# 28    21358
# 16    20470
# 25    13468
# 9     12923
# 4     11371
# Name: count, dtype: int64

# %%
# Label Encoding
label_encoder = LabelEncoder()
df['activity_encoded'] = label_encoder.fit_transform(df['activity'])
num_classes = len(label_encoder.classes_)

df.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis  \
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164
#
#    activity_encoded
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
# label_encoder 매핑 결과 보기
dict(enumerate(label_encoder.classes_))
# Out:
# {0: 'Downstairs',
#  1: 'Jogging',
#  2: 'Sitting',
#  3: 'Standing',
#  4: 'Upstairs',
#  5: 'Walking'}

# %%
# Data Split
df_train = df[df['user_id'] <= 28]
df_val   = df[(df['user_id'] > 28) & (df['user_id'] <= 32)]
df_test = df[df['user_id'] > 32]

# %%
# 정규화
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_train.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.fit_transform(df_train.loc[:, ['x_axis', 'y_axis', 'z_axis']])
# test 셋에서 train에서 학습한 scaler 사용
df_val.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.transform(df_val.loc[:, ['x_axis', 'y_axis', 'z_axis']])
df_test.loc[:, ['x_axis', 'y_axis', 'z_axis']] = scaler.transform(df_test.loc[:, ['x_axis', 'y_axis', 'z_axis']])

# %% [markdown]
# Segmentation
# - 슬라이딩 윈도우 방식
# - 데이터를 time_steps만큼 자르고 step 간격으로 이동
# - 해당 구간에서 가장 많이 나타난 label을 출력값으로 저장
# - 결과적으로 딥러닝 모델에 넣을 수 있는 3차원 입력 데이터와 라벨 벡터를 생성
# - 3차원 입력 데이터: (샘플 수, 한 샘플이 가지는 시간 길이, feature 개수)

# %%
def create_dataset(x, y, time_steps=200, step=40):
    xs, ys = [], []
    for i in range(0, len(x) - time_steps, step):
        v = x.iloc[i:i + time_steps].values
        labels = y.iloc[i:i + time_steps]
        values, counts = np.unique(labels, return_counts=True)
        mode_label = values[np.argmax(counts)]
        xs.append(v)
        ys.append(mode_label)
    return np.array(xs), np.array(ys)

TIME_STEPS = 200
STEP = 40
x_train, y_train = create_dataset(df_train[['x_axis', 'y_axis', 'z_axis']], df_train['activity_encoded'], TIME_STEPS, STEP)
x_val, y_val = create_dataset(df_val[['x_axis', 'y_axis', 'z_axis']], df_val['activity_encoded'], TIME_STEPS, STEP)
x_test, y_test = create_dataset(df_test[['x_axis', 'y_axis', 'z_axis']], df_test['activity_encoded'], TIME_STEPS, STEP)

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((20865, 200, 3), (20865,), (3580, 200, 3), (3580,), (2997, 200, 3), (2997,))

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, Transformer 1

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x = x + pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 200, 128)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 662,918 (2.53 MB)
#  Trainable params: 662,150 (2.53 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WIDSM_HAR_CNN_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.6276 - sparse_categorical_accuracy: 0.7696
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.67095, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - loss: 0.6269 - sparse_categorical_accuracy: 0.7699 - val_loss: 1.0800 - val_sparse_categorical_accuracy: 0.6709
# Epoch 2/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2182 - sparse_categorical_accuracy: 0.9224
# Epoch 2: val_sparse_categorical_accuracy improved from 0.67095 to 0.77765, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2180 - sparse_categorical_accuracy: 0.9225 - val_loss: 1.6900 - val_sparse_categorical_accuracy: 0.7777
# Epoch 3/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4260 - sparse_categorical_accuracy: 0.8512
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.77765
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - loss: 0.4246 - sparse_categorical_accuracy: 0.8517 - val_loss: 2.2858 - val_sparse_categorical_accuracy: 0.7709
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2982 - sparse_categorical_accuracy: 0.9184
# Epoch 4: val_sparse_categorical_accuracy improved from 0.77765 to 0.80196, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.2971 - sparse_categorical_accuracy: 0.9186 - val_loss: 1.8315 - val_sparse_categorical_accuracy: 0.8020
# Epoch 5/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2539 - sparse_categorical_accuracy: 0.9311
# Epoch 5: val_sparse_categorical_accuracy improved from 0.80196 to 0.80670, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2530 - sparse_categorical_accuracy: 0.9313 - val_loss: 1.4045 - val_sparse_categorical_accuracy: 0.8067
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0829 - sparse_categorical_accuracy: 0.9734
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.80670
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0829 - sparse_categorical_accuracy: 0.9734 - val_loss: 1.9384 - val_sparse_categorical_accuracy: 0.8000
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1430 - sparse_categorical_accuracy: 0.9586
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.80670
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9586 - val_loss: 1.4639 - val_sparse_categorical_accuracy: 0.7832
# Epoch 8/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9788
# Epoch 8: val_sparse_categorical_accuracy improved from 0.80670 to 0.82123, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0675 - sparse_categorical_accuracy: 0.9788 - val_loss: 1.6490 - val_sparse_categorical_accuracy: 0.8212
# Epoch 9/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0729 - sparse_categorical_accuracy: 0.9768
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.82123
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9768 - val_loss: 1.9384 - val_sparse_categorical_accuracy: 0.8036
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9839
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.82123
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9839 - val_loss: 1.9923 - val_sparse_categorical_accuracy: 0.8198
# Epoch 11/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9822
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.82123
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9822 - val_loss: 1.5574 - val_sparse_categorical_accuracy: 0.8095
# Epoch 12/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9867
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.82123
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9867 - val_loss: 1.5561 - val_sparse_categorical_accuracy: 0.7966
# Epoch 13/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9845
# Epoch 13: val_sparse_categorical_accuracy improved from 0.82123 to 0.83073, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9845 - val_loss: 1.6062 - val_sparse_categorical_accuracy: 0.8307
# Epoch 14/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9876
# Epoch 14: val_sparse_categorical_accuracy improved from 0.83073 to 0.83715, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9876 - val_loss: 2.0033 - val_sparse_categorical_accuracy: 0.8372
# Epoch 15/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9870
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.83715
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0368 - sparse_categorical_accuracy: 0.9870 - val_loss: 1.6720 - val_sparse_categorical_accuracy: 0.8061
# Epoch 16/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9860
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.83715
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0449 - sparse_categorical_accuracy: 0.9860 - val_loss: 1.9474 - val_sparse_categorical_accuracy: 0.8176
# Epoch 17/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9882
# Epoch 17: val_sparse_categorical_accuracy improved from 0.83715 to 0.87039, saving model to WIDSM_HAR_CNN_Transformer_best.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.6458 - val_sparse_categorical_accuracy: 0.8704
# Epoch 18/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9894
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9894 - val_loss: 1.0073 - val_sparse_categorical_accuracy: 0.8229
# Epoch 19/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9886
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9886 - val_loss: 1.4640 - val_sparse_categorical_accuracy: 0.8073
# Epoch 20/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1039 - sparse_categorical_accuracy: 0.9688
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9689 - val_loss: 2.0896 - val_sparse_categorical_accuracy: 0.8324
# Epoch 21/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0311 - sparse_categorical_accuracy: 0.9890
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0312 - sparse_categorical_accuracy: 0.9890 - val_loss: 1.6231 - val_sparse_categorical_accuracy: 0.7897
# Epoch 22/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1877 - sparse_categorical_accuracy: 0.9375
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1868 - sparse_categorical_accuracy: 0.9378 - val_loss: 1.1250 - val_sparse_categorical_accuracy: 0.8184
# Epoch 23/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0425 - sparse_categorical_accuracy: 0.9875
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0426 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.7354 - val_sparse_categorical_accuracy: 0.8282
# Epoch 24/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9904
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9904 - val_loss: 1.1177 - val_sparse_categorical_accuracy: 0.8045
# Epoch 25/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9885
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9885 - val_loss: 1.7506 - val_sparse_categorical_accuracy: 0.8123
# Epoch 26/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9928
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9928 - val_loss: 1.8081 - val_sparse_categorical_accuracy: 0.8179
# Epoch 27/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0158 - sparse_categorical_accuracy: 0.9952
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0160 - sparse_categorical_accuracy: 0.9951 - val_loss: 1.6388 - val_sparse_categorical_accuracy: 0.8011
# Epoch 28/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3117 - sparse_categorical_accuracy: 0.9013
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.3097 - sparse_categorical_accuracy: 0.9018 - val_loss: 1.1029 - val_sparse_categorical_accuracy: 0.8034
# Epoch 29/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1099 - sparse_categorical_accuracy: 0.9676
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9677 - val_loss: 1.7077 - val_sparse_categorical_accuracy: 0.7888
# Epoch 30/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9867
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9867 - val_loss: 1.9792 - val_sparse_categorical_accuracy: 0.7763
# Epoch 31/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9327
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.2426 - sparse_categorical_accuracy: 0.9329 - val_loss: 1.2157 - val_sparse_categorical_accuracy: 0.8154
# Epoch 32/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1197 - sparse_categorical_accuracy: 0.9677
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.1191 - sparse_categorical_accuracy: 0.9679 - val_loss: 1.7607 - val_sparse_categorical_accuracy: 0.8128
# Epoch 33/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9905
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9905 - val_loss: 1.8808 - val_sparse_categorical_accuracy: 0.8131
# Epoch 34/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0220 - sparse_categorical_accuracy: 0.9920
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9920 - val_loss: 2.4859 - val_sparse_categorical_accuracy: 0.8140
# Epoch 35/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9921
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9921 - val_loss: 2.0041 - val_sparse_categorical_accuracy: 0.8168
# Epoch 36/100
# 323/327 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9929
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9929 - val_loss: 2.7764 - val_sparse_categorical_accuracy: 0.7858
# Epoch 37/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3340 - sparse_categorical_accuracy: 0.9035
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.87039
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.3326 - sparse_categorical_accuracy: 0.9038 - val_loss: 1.7140 - val_sparse_categorical_accuracy: 0.7659
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 17.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WIDSM_HAR_CNN_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 58 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.22%
# Training loss: 0.0235
# Test accuracy: 91.36%
# Test loss: 0.5099

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8269    0.8153    0.8211       287
#            1     0.9989    0.9068    0.9506      1009
#            2     0.8952    0.9955    0.9427       223
#            3     1.0000    0.5878    0.7404       148
#            4     0.7143    0.8304    0.7680       289
#            5     0.9228    0.9990    0.9594      1041
#
#     accuracy                         0.9136      2997
#    macro avg     0.8930    0.8558    0.8637      2997
# weighted avg     0.9209    0.9136    0.9127      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 3, Transformer 1

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(64, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x = x + pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 200, 64)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 200, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 200, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_6 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_2 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_2             │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 686,854 (2.62 MB)
#  Trainable params: 685,958 (2.62 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.6079 - sparse_categorical_accuracy: 0.7898
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.78771, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 26s 40ms/step - loss: 0.6072 - sparse_categorical_accuracy: 0.7900 - val_loss: 0.6541 - val_sparse_categorical_accuracy: 0.7877
# Epoch 2/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3070 - sparse_categorical_accuracy: 0.9026
# Epoch 2: val_sparse_categorical_accuracy improved from 0.78771 to 0.81760, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 25s 17ms/step - loss: 0.3062 - sparse_categorical_accuracy: 0.9028 - val_loss: 1.3402 - val_sparse_categorical_accuracy: 0.8176
# Epoch 3/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1320 - sparse_categorical_accuracy: 0.9598
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.81760
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.1318 - sparse_categorical_accuracy: 0.9599 - val_loss: 1.3432 - val_sparse_categorical_accuracy: 0.7472
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1686 - sparse_categorical_accuracy: 0.9511
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.81760
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1680 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.9812 - val_sparse_categorical_accuracy: 0.7966
# Epoch 5/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2193 - sparse_categorical_accuracy: 0.9337
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.81760
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.2182 - sparse_categorical_accuracy: 0.9340 - val_loss: 1.1221 - val_sparse_categorical_accuracy: 0.7257
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2303 - sparse_categorical_accuracy: 0.9211
# Epoch 6: val_sparse_categorical_accuracy improved from 0.81760 to 0.82011, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.2295 - sparse_categorical_accuracy: 0.9214 - val_loss: 1.7119 - val_sparse_categorical_accuracy: 0.8201
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9796
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.82011
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9796 - val_loss: 1.8571 - val_sparse_categorical_accuracy: 0.8034
# Epoch 8/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9850
# Epoch 8: val_sparse_categorical_accuracy improved from 0.82011 to 0.82095, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9850 - val_loss: 1.6635 - val_sparse_categorical_accuracy: 0.8209
# Epoch 9/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9577
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.82095
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.1475 - sparse_categorical_accuracy: 0.9579 - val_loss: 1.7894 - val_sparse_categorical_accuracy: 0.8011
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3510 - sparse_categorical_accuracy: 0.8962
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.82095
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3493 - sparse_categorical_accuracy: 0.8967 - val_loss: 2.1510 - val_sparse_categorical_accuracy: 0.8201
# Epoch 11/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9777
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.82095
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0693 - sparse_categorical_accuracy: 0.9777 - val_loss: 1.6088 - val_sparse_categorical_accuracy: 0.8123
# Epoch 12/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0852 - sparse_categorical_accuracy: 0.9768
# Epoch 12: val_sparse_categorical_accuracy improved from 0.82095 to 0.83184, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0850 - sparse_categorical_accuracy: 0.9769 - val_loss: 1.8792 - val_sparse_categorical_accuracy: 0.8318
# Epoch 13/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9881
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.83184
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9881 - val_loss: 1.8204 - val_sparse_categorical_accuracy: 0.8271
# Epoch 14/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2108 - sparse_categorical_accuracy: 0.9425
# Epoch 14: val_sparse_categorical_accuracy improved from 0.83184 to 0.90447, saving model to WISDM_HAR_CNN_Transformer_best2.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.2096 - sparse_categorical_accuracy: 0.9428 - val_loss: 0.5526 - val_sparse_categorical_accuracy: 0.9045
# Epoch 15/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9858
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.8061 - val_sparse_categorical_accuracy: 0.8453
# Epoch 16/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9888
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9888 - val_loss: 1.9635 - val_sparse_categorical_accuracy: 0.8321
# Epoch 17/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9899
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9899 - val_loss: 1.8460 - val_sparse_categorical_accuracy: 0.8433
# Epoch 18/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9867
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9868 - val_loss: 1.7599 - val_sparse_categorical_accuracy: 0.8374
# Epoch 19/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9906
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9906 - val_loss: 2.0003 - val_sparse_categorical_accuracy: 0.8581
# Epoch 20/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3530 - sparse_categorical_accuracy: 0.8878
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.8779 - val_sparse_categorical_accuracy: 0.8601
# Epoch 21/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1420 - sparse_categorical_accuracy: 0.9585
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9586 - val_loss: 1.3268 - val_sparse_categorical_accuracy: 0.8517
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9864
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0423 - sparse_categorical_accuracy: 0.9864 - val_loss: 1.3481 - val_sparse_categorical_accuracy: 0.8464
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2436 - sparse_categorical_accuracy: 0.9173
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.2425 - sparse_categorical_accuracy: 0.9177 - val_loss: 1.1076 - val_sparse_categorical_accuracy: 0.8260
# Epoch 24/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9871
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9871 - val_loss: 1.3944 - val_sparse_categorical_accuracy: 0.8369
# Epoch 25/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0250 - sparse_categorical_accuracy: 0.9919
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9918 - val_loss: 1.6585 - val_sparse_categorical_accuracy: 0.8198
# Epoch 26/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0617 - sparse_categorical_accuracy: 0.9838
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9839 - val_loss: 1.7032 - val_sparse_categorical_accuracy: 0.8299
# Epoch 27/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9906
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9906 - val_loss: 1.9361 - val_sparse_categorical_accuracy: 0.8366
# Epoch 28/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1809 - sparse_categorical_accuracy: 0.9541
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9543 - val_loss: 1.8901 - val_sparse_categorical_accuracy: 0.7858
# Epoch 29/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3447 - sparse_categorical_accuracy: 0.8975
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.3442 - sparse_categorical_accuracy: 0.8976 - val_loss: 1.9992 - val_sparse_categorical_accuracy: 0.8212
# Epoch 30/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9793
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0696 - sparse_categorical_accuracy: 0.9794 - val_loss: 2.3405 - val_sparse_categorical_accuracy: 0.8162
# Epoch 31/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9879
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9879 - val_loss: 1.9485 - val_sparse_categorical_accuracy: 0.8215
# Epoch 32/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9910
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9910 - val_loss: 1.6624 - val_sparse_categorical_accuracy: 0.8137
# Epoch 33/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0379 - sparse_categorical_accuracy: 0.9879
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0378 - sparse_categorical_accuracy: 0.9879 - val_loss: 1.8766 - val_sparse_categorical_accuracy: 0.8209
# Epoch 34/100
# 324/327 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9936
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.90447
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9936 - val_loss: 2.2286 - val_sparse_categorical_accuracy: 0.8346
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 66 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 98.86%
# Training loss: 0.0322
# Test accuracy: 91.83%
# Test loss: 0.3912

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8054    0.8362    0.8205       287
#            1     0.9979    0.9316    0.9636      1009
#            2     0.8775    0.9955    0.9328       223
#            3     0.7169    0.8041    0.7580       148
#            4     0.7701    0.6955    0.7309       289
#            5     0.9564    0.9894    0.9726      1041
#
#     accuracy                         0.9183      2997
#    macro avg     0.8540    0.8754    0.8631      2997
# weighted avg     0.9202    0.9183    0.9181      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 2, Transformer 2

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x = x + pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 200, 128)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_11 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_11 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_4 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_4             │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_5             │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,190,022 (4.54 MB)
#  Trainable params: 1,189,254 (4.54 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7124 - sparse_categorical_accuracy: 0.7494
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.78017, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 33s 57ms/step - loss: 0.7117 - sparse_categorical_accuracy: 0.7496 - val_loss: 0.9847 - val_sparse_categorical_accuracy: 0.7802
# Epoch 2/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2751 - sparse_categorical_accuracy: 0.9071
# Epoch 2: val_sparse_categorical_accuracy improved from 0.78017 to 0.81872, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.2749 - sparse_categorical_accuracy: 0.9072 - val_loss: 1.5644 - val_sparse_categorical_accuracy: 0.8187
# Epoch 3/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1606 - sparse_categorical_accuracy: 0.9459
# Epoch 3: val_sparse_categorical_accuracy improved from 0.81872 to 0.82793, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9459 - val_loss: 1.0044 - val_sparse_categorical_accuracy: 0.8279
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1596 - sparse_categorical_accuracy: 0.9522
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.82793
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1594 - sparse_categorical_accuracy: 0.9522 - val_loss: 1.8777 - val_sparse_categorical_accuracy: 0.8196
# Epoch 5/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1426 - sparse_categorical_accuracy: 0.9573
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.82793
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.1425 - sparse_categorical_accuracy: 0.9573 - val_loss: 1.6329 - val_sparse_categorical_accuracy: 0.7749
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2288 - sparse_categorical_accuracy: 0.9323
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.82793
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.2283 - sparse_categorical_accuracy: 0.9324 - val_loss: 1.7497 - val_sparse_categorical_accuracy: 0.8131
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0999 - sparse_categorical_accuracy: 0.9697
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.82793
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9697 - val_loss: 1.8517 - val_sparse_categorical_accuracy: 0.8115
# Epoch 8/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2204 - sparse_categorical_accuracy: 0.9343
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.82793
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.2201 - sparse_categorical_accuracy: 0.9344 - val_loss: 1.3332 - val_sparse_categorical_accuracy: 0.7994
# Epoch 9/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1880 - sparse_categorical_accuracy: 0.9465
# Epoch 9: val_sparse_categorical_accuracy improved from 0.82793 to 0.83156, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1877 - sparse_categorical_accuracy: 0.9465 - val_loss: 1.0806 - val_sparse_categorical_accuracy: 0.8316
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9673
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.83156
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.7044 - val_sparse_categorical_accuracy: 0.8165
# Epoch 11/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9595
# Epoch 11: val_sparse_categorical_accuracy improved from 0.83156 to 0.84777, saving model to WISDM_HAR_CNN_Transformer_best3.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1300 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.6765 - val_sparse_categorical_accuracy: 0.8478
# Epoch 12/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0698 - sparse_categorical_accuracy: 0.9767
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9767 - val_loss: 1.8239 - val_sparse_categorical_accuracy: 0.8299
# Epoch 13/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0888 - sparse_categorical_accuracy: 0.9721
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.0888 - sparse_categorical_accuracy: 0.9721 - val_loss: 1.9256 - val_sparse_categorical_accuracy: 0.8036
# Epoch 14/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9789
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9789 - val_loss: 1.6452 - val_sparse_categorical_accuracy: 0.8193
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1304 - sparse_categorical_accuracy: 0.9598
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9599 - val_loss: 1.9419 - val_sparse_categorical_accuracy: 0.8223
# Epoch 16/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9758
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9758 - val_loss: 1.3479 - val_sparse_categorical_accuracy: 0.8140
# Epoch 17/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1524 - sparse_categorical_accuracy: 0.9544
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1520 - sparse_categorical_accuracy: 0.9545 - val_loss: 1.8126 - val_sparse_categorical_accuracy: 0.8196
# Epoch 18/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1124 - sparse_categorical_accuracy: 0.9700
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.1123 - sparse_categorical_accuracy: 0.9701 - val_loss: 1.7038 - val_sparse_categorical_accuracy: 0.8321
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9762
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9762 - val_loss: 2.2007 - val_sparse_categorical_accuracy: 0.7461
# Epoch 20/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3785 - sparse_categorical_accuracy: 0.8728
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8730 - val_loss: 2.0045 - val_sparse_categorical_accuracy: 0.8140
# Epoch 21/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0995 - sparse_categorical_accuracy: 0.9702
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.0996 - sparse_categorical_accuracy: 0.9702 - val_loss: 1.2044 - val_sparse_categorical_accuracy: 0.7964
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1300 - sparse_categorical_accuracy: 0.9598
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9599 - val_loss: 2.2180 - val_sparse_categorical_accuracy: 0.8321
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1153 - sparse_categorical_accuracy: 0.9672
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.1152 - sparse_categorical_accuracy: 0.9672 - val_loss: 2.2260 - val_sparse_categorical_accuracy: 0.8098
# Epoch 24/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1665 - sparse_categorical_accuracy: 0.9462
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.1661 - sparse_categorical_accuracy: 0.9464 - val_loss: 1.8086 - val_sparse_categorical_accuracy: 0.8271
# Epoch 25/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9801
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9801 - val_loss: 1.2022 - val_sparse_categorical_accuracy: 0.8193
# Epoch 26/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9763
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9762 - val_loss: 1.9959 - val_sparse_categorical_accuracy: 0.7978
# Epoch 27/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0770 - sparse_categorical_accuracy: 0.9738
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0769 - sparse_categorical_accuracy: 0.9738 - val_loss: 2.1855 - val_sparse_categorical_accuracy: 0.8123
# Epoch 28/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9802
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0627 - sparse_categorical_accuracy: 0.9802 - val_loss: 2.0642 - val_sparse_categorical_accuracy: 0.8263
# Epoch 29/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0679 - sparse_categorical_accuracy: 0.9782
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - loss: 0.0679 - sparse_categorical_accuracy: 0.9782 - val_loss: 2.1043 - val_sparse_categorical_accuracy: 0.8279
# Epoch 30/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0737 - sparse_categorical_accuracy: 0.9787
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9787 - val_loss: 1.9603 - val_sparse_categorical_accuracy: 0.7978
# Epoch 31/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9787
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.84777
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9787 - val_loss: 1.8007 - val_sparse_categorical_accuracy: 0.8036
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 90 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 97.92%
# Training loss: 0.0625
# Test accuracy: 92.06%
# Test loss: 0.4378

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8362    0.8537    0.8448       287
#            1     1.0000    0.9376    0.9678      1009
#            2     0.9954    0.9731    0.9841       223
#            3     0.6682    0.9797    0.7945       148
#            4     0.7636    0.5813    0.6601       289
#            5     0.9411    0.9971    0.9683      1041
#
#     accuracy                         0.9206      2997
#    macro avg     0.8674    0.8871    0.8699      2997
# weighted avg     0.9243    0.9206    0.9192      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 4
# - CNN 3, Transformer 2

# %%
input_shape = (x_train.shape[1], x_train.shape[2])  # (time_steps, features)
num_classes = 6

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(64, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x = x + pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=512)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 200, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 200, 64)        │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 200, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_14 (ReLU)                 │ (None, 200, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 200, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_15 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_6 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_8             │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_9             │ (None, 100, 256)       │       527,104 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_6      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,213,958 (4.63 MB)
#  Trainable params: 1,213,062 (4.63 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "WISDM_HAR_CNN_Transformer_best4.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            x_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(x_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6687 - sparse_categorical_accuracy: 0.7671
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.75112, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - loss: 0.6679 - sparse_categorical_accuracy: 0.7674 - val_loss: 1.6695 - val_sparse_categorical_accuracy: 0.7511
# Epoch 2/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.8955
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.75112
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.2884 - sparse_categorical_accuracy: 0.8957 - val_loss: 2.5933 - val_sparse_categorical_accuracy: 0.6807
# Epoch 3/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2208 - sparse_categorical_accuracy: 0.9359
# Epoch 3: val_sparse_categorical_accuracy improved from 0.75112 to 0.82821, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.2203 - sparse_categorical_accuracy: 0.9360 - val_loss: 2.0074 - val_sparse_categorical_accuracy: 0.8282
# Epoch 4/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9631
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.82821
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1205 - sparse_categorical_accuracy: 0.9631 - val_loss: 1.9490 - val_sparse_categorical_accuracy: 0.8075
# Epoch 5/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9540
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.82821
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9540 - val_loss: 2.4030 - val_sparse_categorical_accuracy: 0.7679
# Epoch 6/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1814 - sparse_categorical_accuracy: 0.9432
# Epoch 6: val_sparse_categorical_accuracy improved from 0.82821 to 0.82933, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1809 - sparse_categorical_accuracy: 0.9434 - val_loss: 1.7025 - val_sparse_categorical_accuracy: 0.8293
# Epoch 7/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1008 - sparse_categorical_accuracy: 0.9696
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1009 - sparse_categorical_accuracy: 0.9695 - val_loss: 1.8303 - val_sparse_categorical_accuracy: 0.7626
# Epoch 8/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4041 - sparse_categorical_accuracy: 0.8435
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.4033 - sparse_categorical_accuracy: 0.8438 - val_loss: 1.8568 - val_sparse_categorical_accuracy: 0.7615
# Epoch 9/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4769 - sparse_categorical_accuracy: 0.8339
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.4758 - sparse_categorical_accuracy: 0.8342 - val_loss: 1.7858 - val_sparse_categorical_accuracy: 0.7609
# Epoch 10/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2977 - sparse_categorical_accuracy: 0.8860
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.2976 - sparse_categorical_accuracy: 0.8861 - val_loss: 1.7192 - val_sparse_categorical_accuracy: 0.7508
# Epoch 11/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2789 - sparse_categorical_accuracy: 0.8976
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.2784 - sparse_categorical_accuracy: 0.8978 - val_loss: 1.8989 - val_sparse_categorical_accuracy: 0.7897
# Epoch 12/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2951 - sparse_categorical_accuracy: 0.8888
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.2947 - sparse_categorical_accuracy: 0.8889 - val_loss: 1.6186 - val_sparse_categorical_accuracy: 0.8112
# Epoch 13/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1992 - sparse_categorical_accuracy: 0.9305
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1991 - sparse_categorical_accuracy: 0.9306 - val_loss: 1.0262 - val_sparse_categorical_accuracy: 0.7620
# Epoch 14/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3425 - sparse_categorical_accuracy: 0.8911
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.3415 - sparse_categorical_accuracy: 0.8914 - val_loss: 1.5302 - val_sparse_categorical_accuracy: 0.7536
# Epoch 15/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1934 - sparse_categorical_accuracy: 0.9415
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.82933
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1932 - sparse_categorical_accuracy: 0.9415 - val_loss: 1.5897 - val_sparse_categorical_accuracy: 0.7908
# Epoch 16/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9594
# Epoch 16: val_sparse_categorical_accuracy improved from 0.82933 to 0.84050, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.5935 - val_sparse_categorical_accuracy: 0.8405
# Epoch 17/100
# 326/327 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9571
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.84050
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9571 - val_loss: 1.6027 - val_sparse_categorical_accuracy: 0.7791
# Epoch 18/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9620
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.84050
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.1208 - sparse_categorical_accuracy: 0.9620 - val_loss: 1.4143 - val_sparse_categorical_accuracy: 0.7846
# Epoch 19/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1464 - sparse_categorical_accuracy: 0.9579
# Epoch 19: val_sparse_categorical_accuracy improved from 0.84050 to 0.86760, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - loss: 0.1463 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.5399 - val_sparse_categorical_accuracy: 0.8676
# Epoch 20/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1290 - sparse_categorical_accuracy: 0.9592
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.86760
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1289 - sparse_categorical_accuracy: 0.9592 - val_loss: 1.2443 - val_sparse_categorical_accuracy: 0.7925
# Epoch 21/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1497 - sparse_categorical_accuracy: 0.9534
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.86760
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.9343 - val_sparse_categorical_accuracy: 0.7980
# Epoch 22/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.9433
# Epoch 22: val_sparse_categorical_accuracy improved from 0.86760 to 0.89916, saving model to WISDM_HAR_CNN_Transformer_best4.weights.h5
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1789 - sparse_categorical_accuracy: 0.9434 - val_loss: 0.4537 - val_sparse_categorical_accuracy: 0.8992
# Epoch 23/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1442 - sparse_categorical_accuracy: 0.9524
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1441 - sparse_categorical_accuracy: 0.9524 - val_loss: 0.8338 - val_sparse_categorical_accuracy: 0.8142
# Epoch 24/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1192 - sparse_categorical_accuracy: 0.9614
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1192 - sparse_categorical_accuracy: 0.9614 - val_loss: 0.6537 - val_sparse_categorical_accuracy: 0.8581
# Epoch 25/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0871 - sparse_categorical_accuracy: 0.9727
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9726 - val_loss: 1.0484 - val_sparse_categorical_accuracy: 0.8229
# Epoch 26/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1730 - sparse_categorical_accuracy: 0.9421
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1726 - sparse_categorical_accuracy: 0.9422 - val_loss: 1.8502 - val_sparse_categorical_accuracy: 0.8045
# Epoch 27/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9555
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9555 - val_loss: 1.8775 - val_sparse_categorical_accuracy: 0.8067
# Epoch 28/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1021 - sparse_categorical_accuracy: 0.9669
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1021 - sparse_categorical_accuracy: 0.9669 - val_loss: 1.9102 - val_sparse_categorical_accuracy: 0.8089
# Epoch 29/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0786 - sparse_categorical_accuracy: 0.9738
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.0786 - sparse_categorical_accuracy: 0.9739 - val_loss: 1.8602 - val_sparse_categorical_accuracy: 0.7662
# Epoch 30/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9608
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.1178 - sparse_categorical_accuracy: 0.9608 - val_loss: 1.8515 - val_sparse_categorical_accuracy: 0.7919
# Epoch 31/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1287 - sparse_categorical_accuracy: 0.9595
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1286 - sparse_categorical_accuracy: 0.9595 - val_loss: 1.4860 - val_sparse_categorical_accuracy: 0.8140
# Epoch 32/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9707
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9707 - val_loss: 1.2334 - val_sparse_categorical_accuracy: 0.8106
# Epoch 33/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9751
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9751 - val_loss: 2.0188 - val_sparse_categorical_accuracy: 0.7997
# Epoch 34/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1056 - sparse_categorical_accuracy: 0.9646
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9646 - val_loss: 1.9892 - val_sparse_categorical_accuracy: 0.7841
# Epoch 35/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9606
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1304 - sparse_categorical_accuracy: 0.9607 - val_loss: 1.1636 - val_sparse_categorical_accuracy: 0.8173
# Epoch 36/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1395 - sparse_categorical_accuracy: 0.9571
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1392 - sparse_categorical_accuracy: 0.9572 - val_loss: 1.8352 - val_sparse_categorical_accuracy: 0.7916
# Epoch 37/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0811 - sparse_categorical_accuracy: 0.9767
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.7276 - val_sparse_categorical_accuracy: 0.8268
# Epoch 38/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9708
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9708 - val_loss: 1.3355 - val_sparse_categorical_accuracy: 0.8187
# Epoch 39/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1216 - sparse_categorical_accuracy: 0.9613
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1214 - sparse_categorical_accuracy: 0.9613 - val_loss: 1.5964 - val_sparse_categorical_accuracy: 0.7687
# Epoch 40/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0819 - sparse_categorical_accuracy: 0.9727
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0819 - sparse_categorical_accuracy: 0.9727 - val_loss: 2.3199 - val_sparse_categorical_accuracy: 0.8031
# Epoch 41/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9772
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9772 - val_loss: 1.7104 - val_sparse_categorical_accuracy: 0.7944
# Epoch 42/100
# 325/327 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9608
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.89916
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9609 - val_loss: 1.1052 - val_sparse_categorical_accuracy: 0.8109
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("WISDM_HAR_CNN_Transformer_best4.weights.h5")

train_loss, train_acc = model.evaluate(x_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 98 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 96.42%
# Training loss: 0.1067
# Test accuracy: 92.43%
# Test loss: 0.4165

# %%
y_pred_proba = model.predict(x_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8012    0.9408    0.8654       287
#            1     0.9796    0.9495    0.9643      1009
#            2     0.9024    0.9955    0.9467       223
#            3     0.7267    0.8446    0.7812       148
#            4     0.9198    0.5952    0.7227       289
#            5     0.9499    0.9827    0.9660      1041
#
#     accuracy                         0.9243      2997
#    macro avg     0.8799    0.8847    0.8744      2997
# weighted avg     0.9282    0.9243    0.9218      2997

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
