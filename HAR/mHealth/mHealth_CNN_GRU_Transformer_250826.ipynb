# %% [markdown]
# # UCI mHealth - CNN-GRU-Transformer
# - https://archive.ics.uci.edu/dataset/319/mhealth+dataset
#
# #### 데이터 구조
# - 10명의 참가자별로 mHealth_subject<SUBJECT_ID>.log 파일 존재
# - 가속도, 자이로, 자기장, 심전도 -> 총 23개의 feature
#
# #### 라벨
# 0. Other
# 1. Standing still
# 2. Sitting and relaxing
# 3. Lying down
# 4. Walking
# 5. Climbing stairs
# 6. Waist bends forward
# 7. Frontal elevation of arms
# 8. Knees bending (crouching)
# 9. Cycling
# 10. Jogging
# 11. Running
# 12. Jump front & back

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Conv1D, BatchNormalization, ReLU, MaxPool1D, GlobalAveragePooling1D, MultiHeadAttention, LayerNormalization, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.utils import resample
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
LABELS = [
    'Other', 'Standing', 'Sitting', 'Lying', 'Walking',
    'Climbing stairs', 'Waist bends', 'Frontal elevation',
    'Knees bending', 'Cycling', 'Jogging', 'Running', 'Jumping'
]

# %%
base_dir = "/content/drive/MyDrive/AI_data/MHEALTHDATASET"
dfs = []
col_names = [
    'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
    'ecg1', 'ecg2',
    'acc_left_ankle_x', 'acc_left_ankle_y', 'acc_left_ankle_z',
    'gyro_left_ankle_x', 'gyro_left_ankle_y', 'gyro_left_ankle_z',
    'magnet_left_ankle_x', 'magnet_left_ankl6e_y', 'magnet_left_ankle_z',
    'acc_right_arm_x', 'acc_right_arm_y', 'acc_right_arm_z',
    'gyro_right_arm_x', 'gyro_right_arm_y', 'gyro_right_arm_z',
    'magnet_right_arm_x', 'magnet_right_arm_y', 'magnet_right_arm_z',
    'label', 'subject'
]

for i in range(1, 11):
    path = os.path.join(base_dir, f"mHealth_subject{i}.log")
    df_i = pd.read_csv(path, sep='\t', header=None)
    df_i['subject'] = i
    dfs.append(df_i)

df = pd.concat(dfs, ignore_index=True)
df = df.dropna(how='any', axis=0)
df.columns = col_names
df
# Out:
#          acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0            -9.8184     0.009971      0.29563  0.004186  0.004186
# 1            -9.8489     0.524040      0.37348  0.004186  0.016745
# 2            -9.6602     0.181850      0.43742  0.016745  0.037677
# 3            -9.6507     0.214220      0.24033  0.079540  0.117220
# 4            -9.7030     0.303890      0.31156  0.221870  0.205130
# ...              ...          ...          ...       ...       ...
# 1215740      -9.2476    -0.248070     -2.62230  0.230250  0.234430
# 1215741      -9.4632    -0.073513     -2.11190  0.276300  0.284670
# 1215742      -9.4011    -0.144580     -3.02350  0.288850  0.301410
# 1215743      -9.3732    -0.026252     -2.70760  0.351650  0.347460
# 1215744      -9.3518    -0.592450     -2.63230  0.280480  0.272110
#
#          acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0                  2.1849           -9.6967           0.63077
# 1                  2.3876           -9.5080           0.68389
# 2                  2.4086           -9.5674           0.68113
# 3                  2.1814           -9.4301           0.55031
# 4                  2.4173           -9.3889           0.71098
# ...                   ...               ...               ...
# 1215740            1.7849           -9.8287           0.29725
# 1215741            1.8687           -9.8766           0.46236
# 1215742            1.6928           -9.9290           0.16631
# 1215743            1.5279           -9.6306           0.30458
# 1215744            1.6614           -9.8398           0.18088
#
#          gyro_left_ankle_x  gyro_left_ankle_y  ...  acc_right_arm_y  \
# 0                 0.103900           -0.84053  ...          -4.5781
# 1                 0.085343           -0.83865  ...          -4.3198
# 2                 0.085343           -0.83865  ...          -4.2772
# 3                 0.085343           -0.83865  ...          -4.3163
# 4                 0.085343           -0.83865  ...          -4.1459
# ...                    ...                ...  ...              ...
# 1215740          -0.341370           -0.90056  ...          -8.9071
# 1215741          -0.341370           -0.90056  ...          -8.7455
# 1215742          -0.341370           -0.90056  ...          -9.1155
# 1215743          -0.341370           -0.90056  ...          -9.1441
# 1215744          -0.332100           -0.90432  ...          -8.9324
#
#          acc_right_arm_z  gyro_right_arm_x  gyro_right_arm_y  \
# 0               0.187760         -0.449020          -1.01030
# 1               0.023595         -0.449020          -1.01030
# 2               0.275720         -0.449020          -1.01030
# 3               0.367520         -0.456860          -1.00820
# 4               0.407290         -0.456860          -1.00820
# ...                  ...               ...               ...
# 1215740         0.294230          0.041176          -0.99384
# 1215741         0.448140          0.041176          -0.99384
# 1215742         0.450480          0.041176          -0.99384
# 1215743         0.594880          0.041176          -0.99384
# 1215744         0.761710          0.035294          -1.02050
#
#          gyro_right_arm_z  magnet_right_arm_x  magnet_right_arm_y  \
# 0                0.034483            -2.35000           -1.610200
# 1                0.034483            -2.16320           -0.882540
# 2                0.034483            -1.61750           -0.165620
# 3                0.025862            -1.07710            0.006945
# 4                0.025862            -0.53684            0.175900
# ...                   ...                 ...                 ...
# 1215740         -0.480600             2.40890            7.496100
# 1215741         -0.480600             1.69450            7.866000
# 1215742         -0.480600             1.15770            8.052800
# 1215743         -0.480600             0.27441            9.487900
# 1215744         -0.471980            -0.98056            9.663600
#
#          magnet_right_arm_z  label  subject
# 0                 -0.030899      0        1
# 1                  0.326570      0        1
# 2                 -0.030693      0        1
# 3                 -0.382620      0        1
# 4                 -1.095500      0        1
# ...                     ...    ...      ...
# 1215740            7.915500      0       10
# 1215741            7.897500      0       10
# 1215742            7.884900      0       10
# 1215743            5.325800      0       10
# 1215744            3.493900      0       10
#
# [1215745 rows x 25 columns]

# %%
df.label.value_counts()
# Out:
# label
# 0     872550
# 1      30720
# 2      30720
# 3      30720
# 4      30720
# 9      30720
# 5      30720
# 11     30720
# 10     30720
# 7      29441
# 8      29337
# 6      28315
# 12     10342
# Name: count, dtype: int64

# %%
# downsampling
from sklearn.utils import resample

df_majority = df[df.label==0]
df_minorities = df[df.label!=0]

df_majority_downsampled = resample(df_majority, n_samples=30000, random_state=42)
df = pd.concat([df_majority_downsampled, df_minorities])
df.label.value_counts()
# Out:
# label
# 1     30720
# 3     30720
# 2     30720
# 4     30720
# 9     30720
# 11    30720
# 5     30720
# 10    30720
# 0     30000
# 7     29441
# 8     29337
# 6     28315
# 12    10342
# Name: count, dtype: int64

# %%
# df.to_csv('/content/drive/MyDrive/AI_data/MHEALTHDATASET/mhealth_resampled_data.csv',index = False)

# %%
df.isnull().sum()
# Out:
# acc_chest_x             0
# acc_chest_y             0
# acc_chest_z             0
# ecg1                    0
# ecg2                    0
# acc_left_ankle_x        0
# acc_left_ankle_y        0
# acc_left_ankle_z        0
# gyro_left_ankle_x       0
# gyro_left_ankle_y       0
# gyro_left_ankle_z       0
# magnet_left_ankle_x     0
# magnet_left_ankl6e_y    0
# magnet_left_ankle_z     0
# acc_right_arm_x         0
# acc_right_arm_y         0
# acc_right_arm_z         0
# gyro_right_arm_x        0
# gyro_right_arm_y        0
# gyro_right_arm_z        0
# magnet_right_arm_x      0
# magnet_right_arm_y      0
# magnet_right_arm_z      0
# label                   0
# subject                 0
# dtype: int64

# %%
# 피험자 1-6: 훈련, 피험자 7-8: 검증, 피험자 8-9: 테스트
train = df[~df['subject'].isin([7, 8, 9, 10])]
val = df[df['subject'].isin([7, 8])]
test = df[df['subject'].isin([9, 10])]

train.shape, val.shape, test.shape
# Out:
# ((226128, 25), (73326, 25), (73741, 25))

# %%
X_train = train.drop(['label','subject'], axis=1)
y_train = train['label']

X_val = val.drop(['label','subject'], axis=1)
y_val = val['label']

X_test = test.drop(['label','subject'], axis=1)
y_test = test['label']

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((226128, 23), (226128,), (73326, 23), (73326,), (73741, 23), (73741,))

# %%
sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=X_train.columns)
X_val = pd.DataFrame(sc.transform(X_val), columns=X_val.columns)
X_test = pd.DataFrame(sc.transform(X_test), columns=X_train.columns)

X_train
# Out:
#         acc_chest_x  acc_chest_y  acc_chest_z      ecg1      ecg2  \
# 0         -0.087384    -0.180627    -0.786215  0.007915 -0.011472
# 1         -0.328788    -0.300078     0.605666 -0.081073 -0.087624
# 2          0.241808     0.040644    -0.641235  0.070732 -0.107931
# 3         -0.354832    -0.009466     0.177121 -0.447507 -1.224823
# 4          0.244441     0.152781    -0.843392 -0.332342 -0.184085
# ...             ...          ...          ...       ...       ...
# 226123    -0.998367     0.135213    -0.547845 -0.248588 -0.544528
# 226124    -1.148293     0.104779    -0.661009 -0.180527 -0.544528
# 226125    -1.076286     0.134339    -1.033485 -0.107247 -0.534377
# 226126    -0.955557     0.620911    -1.302284  0.002681 -0.427768
# 226127    -1.031326     1.212066    -1.397428  0.028855 -0.493764
#
#         acc_left_ankle_x  acc_left_ankle_y  acc_left_ankle_z  \
# 0              -0.577582          0.733111          0.855263
# 1              -0.048897         -0.100417          0.083515
# 2               0.010368          0.093603         -0.501927
# 3              -0.497284         -0.085610          0.353416
# 4              -1.151754         -0.146134         -0.361905
# ...                  ...               ...               ...
# 226123         -0.299251         -0.707677          0.882140
# 226124          0.232369         -0.590383          0.757580
# 226125          1.156834         -0.723743          0.356439
# 226126          0.927660         -0.718710         -0.643712
# 226127          0.327690         -1.632098         -1.826351
#
#         gyro_left_ankle_x  gyro_left_ankle_y  ...  magnet_left_ankle_z  \
# 0                0.283638          -0.578020  ...            -0.402525
# 1               -0.577486          -0.415903  ...             0.011245
# 2               -0.867129           0.049140  ...             0.540380
# 3               -1.442512          -0.458564  ...            -0.030661
# 4                1.782740           0.484325  ...             2.124397
# ...                   ...                ...  ...                  ...
# 226123          -0.432654          -0.603626  ...             0.449349
# 226124          -0.432654          -0.603626  ...             0.287044
# 226125          -0.432654          -0.603626  ...             0.031366
# 226126          -0.354383          -0.629232  ...             0.009413
# 226127          -0.354383          -0.629232  ...            -0.011482
#
#         acc_right_arm_x  acc_right_arm_y  acc_right_arm_z  gyro_right_arm_x  \
# 0             -0.878509        -0.115785         0.092842         -1.287582
# 1              0.142070        -0.403044         0.292032         -1.181228
# 2              0.419364        -0.149160        -0.108985         -0.159630
# 3              0.347123        -0.554803        -0.268771          0.292298
# 4             -0.463871        -0.334905        -0.028403         -0.584985
# ...                 ...              ...              ...               ...
# 226123        -0.424959        -0.777297         0.256151         -0.190019
# 226124        -0.667105        -1.022036         0.412414         -0.190019
# 226125        -0.789524        -1.428916         0.539305         -0.190019
# 226126        -0.565365        -1.578079         0.372380         -0.190019
# 226127        -0.266865        -1.285248         0.331576         -0.045704
#
#         gyro_right_arm_y  gyro_right_arm_z  magnet_right_arm_x  \
# 0               0.881529         -0.227001            0.355856
# 1              -0.788334         -0.017597           -0.007098
# 2              -0.799296         -1.414959           -0.118250
# 3              -1.000270         -1.567971            0.008544
# 4              -0.481392          0.522008            0.201140
# ...                  ...               ...                 ...
# 226123         -1.164606         -0.086059           -0.832750
# 226124         -1.164606         -0.086059           -0.891081
# 226125         -1.164606         -0.086059           -0.798699
# 226126         -1.164606         -0.086059           -0.468607
# 226127         -1.259630         -0.118272           -0.137930
#
#         magnet_right_arm_y  magnet_right_arm_z
# 0                -0.757309            0.065910
# 1                -0.073927           -0.046895
# 2                -0.093139           -0.227639
# 3                -0.094608           -0.020982
# 4                 0.141492           -0.024674
# ...                    ...                 ...
# 226123           -0.733695           -0.744858
# 226124           -1.279427           -0.798790
# 226125           -2.073697           -0.786247
# 226126           -2.871990           -0.626123
# 226127           -3.089391           -0.301282
#
# [226128 rows x 23 columns]

# %% [markdown]
# ### create_dataset
# - X에 dataframe을 입력 -> 여러 개의 columns
# - x.shape이 (time_steps, n_features)이기 때문에 Xs.shape은 (n_samples, time_steps, n_features). 따라서 reshape이 필요 없음
# - ys: 윈도우 내 최빈값을 라벨로 설정, 1D 리스트
# - sklearn, keras에서 y를 (n_samples, 1) 형태로 사용하기 때문에 reshape

# %%
def create_dataset(X, y, time_steps, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        x = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(x)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

# %%
TIME_STEPS = 200
STEPS = 40

X_train, y_train = create_dataset(X_train, y_train, TIME_STEPS, STEPS)
X_val, y_val = create_dataset(X_val, y_val, TIME_STEPS, STEPS)
X_test, y_test = create_dataset(X_test, y_test, TIME_STEPS, STEPS)

print(f"Training sequences: {X_train.shape}")
print(f"Validation sequences: {X_val.shape}")
print(f"Test sequences: {X_test.shape}")
# Out:
# Training sequences: (5649, 200, 23)
# Validation sequences: (1829, 200, 23)
# Test sequences: (1839, 200, 23)

# %%
def positional_encoding(length, depth):
    depth = depth/2
    positions = np.arange(length)[:, np.newaxis] # 각 시퀀스 위치 pos 벡터
    depths = np.arange(depth)[np.newaxis, :]/depth # /depth로 정규화,
    angle_rates = 1 / (10000**depths)
    angle_rads = positions * angle_rates # broadcasting
    pos_encoding = np.concatenate(
        [np.sin(angle_rads), np.cos(angle_rads)], axis=-1)
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = int(embed_dim)
        self.num_heads = int(num_heads)
        self.ff_dim = int(ff_dim)
        self.rate = float(rate)

        self.att = MultiHeadAttention(
            num_heads=self.num_heads,
            key_dim=self.embed_dim // self.num_heads
        )
        self.ffn = Sequential([
            Dense(self.ff_dim, activation="relu"),
            Dense(self.embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(self.rate)
        self.dropout2 = Dropout(self.rate)

    def call(self, inputs, training=None):
        attn = self.att(inputs, inputs, training=training)
        x1 = self.layernorm1(inputs + self.dropout1(attn, training=training))
        ffn = self.ffn(x1, training=training)
        return self.layernorm2(x1 + self.dropout2(ffn, training=training))

# %% [markdown]
# ## Model 1
# - CNN 2, GRU 1, Transformer 1
# - Conv1D 출력과 TransformerBlock의 embed_dim 수가 일치해야함
# - residual addition 할 때 shape이 맞아야 하기 때문

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x += pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block               │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 874,381 (3.34 MB)
#  Trainable params: 873,613 (3.33 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.0315 - sparse_categorical_accuracy: 0.6709
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.89995, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - loss: 1.0252 - sparse_categorical_accuracy: 0.6729 - val_loss: 0.3139 - val_sparse_categorical_accuracy: 0.8999
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9838
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.89995
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0554 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.4180 - val_sparse_categorical_accuracy: 0.8338
# Epoch 3/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9823
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.89995
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.6735 - val_sparse_categorical_accuracy: 0.8201
# Epoch 4/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9909
# Epoch 4: val_sparse_categorical_accuracy improved from 0.89995 to 0.94314, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.4889 - val_sparse_categorical_accuracy: 0.9431
# Epoch 5/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9899
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.94314
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.3797 - val_sparse_categorical_accuracy: 0.9049
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9977
# Epoch 6: val_sparse_categorical_accuracy improved from 0.94314 to 0.97704, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.0903 - val_sparse_categorical_accuracy: 0.9770
# Epoch 7/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9946
# Epoch 7: val_sparse_categorical_accuracy improved from 0.97704 to 0.98907, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0357 - val_sparse_categorical_accuracy: 0.9891
# Epoch 8/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0571 - sparse_categorical_accuracy: 0.9867
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0566 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.2137 - val_sparse_categorical_accuracy: 0.9666
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9980
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.3820 - val_sparse_categorical_accuracy: 0.9278
# Epoch 10/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0099 - sparse_categorical_accuracy: 0.9964
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0105 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.4141 - val_sparse_categorical_accuracy: 0.9251
# Epoch 11/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0706 - sparse_categorical_accuracy: 0.9835
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0694 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0829 - val_sparse_categorical_accuracy: 0.9781
# Epoch 12/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9974
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0671 - val_sparse_categorical_accuracy: 0.9858
# Epoch 13/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9977
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.5694 - val_sparse_categorical_accuracy: 0.8934
# Epoch 14/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0318 - sparse_categorical_accuracy: 0.9914
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0328 - sparse_categorical_accuracy: 0.9911 - val_loss: 1.9525 - val_sparse_categorical_accuracy: 0.7452
# Epoch 15/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9877
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0969 - val_sparse_categorical_accuracy: 0.9688
# Epoch 16/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9927
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1447 - val_sparse_categorical_accuracy: 0.9240
# Epoch 17/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9983
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.98907
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9858
# Epoch 18/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9986
# Epoch 18: val_sparse_categorical_accuracy improved from 0.98907 to 0.99180, saving model to UCI_mHealth_CNN_GRU_Transformer_best.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0049 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0301 - val_sparse_categorical_accuracy: 0.9918
# Epoch 19/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9997
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0016 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.1419 - val_sparse_categorical_accuracy: 0.9759
# Epoch 20/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9989
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0495 - val_sparse_categorical_accuracy: 0.9902
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9981
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0613 - val_sparse_categorical_accuracy: 0.9869
# Epoch 22/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9997
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.0673 - val_sparse_categorical_accuracy: 0.9869
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9988
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0922 - val_sparse_categorical_accuracy: 0.9486
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 6.8061e-04 - sparse_categorical_accuracy: 0.9997
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 6.8293e-04 - sparse_categorical_accuracy: 0.9997 - val_loss: 0.2273 - val_sparse_categorical_accuracy: 0.9481
# Epoch 25/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0034 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9825
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9988
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0755 - val_sparse_categorical_accuracy: 0.9874
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.8318e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 7.7954e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0775 - val_sparse_categorical_accuracy: 0.9874
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.0166e-04 - sparse_categorical_accuracy: 0.9998
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 3.0562e-04 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9863
# Epoch 29/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2313 - sparse_categorical_accuracy: 0.9597
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.2289 - sparse_categorical_accuracy: 0.9600 - val_loss: 1.8958 - val_sparse_categorical_accuracy: 0.7824
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9891
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0528 - sparse_categorical_accuracy: 0.9891 - val_loss: 1.1150 - val_sparse_categorical_accuracy: 0.8294
# Epoch 31/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9862
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9864 - val_loss: 1.1674 - val_sparse_categorical_accuracy: 0.8671
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9977
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9977 - val_loss: 1.2718 - val_sparse_categorical_accuracy: 0.8617
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9968
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0064 - sparse_categorical_accuracy: 0.9968 - val_loss: 1.2422 - val_sparse_categorical_accuracy: 0.8934
# Epoch 34/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9983
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0115 - sparse_categorical_accuracy: 0.9982 - val_loss: 1.8977 - val_sparse_categorical_accuracy: 0.7687
# Epoch 35/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9924
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.9064 - val_sparse_categorical_accuracy: 0.8677
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9876
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0456 - sparse_categorical_accuracy: 0.9877 - val_loss: 1.3436 - val_sparse_categorical_accuracy: 0.8300
# Epoch 37/100
# 87/89 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9992
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9992 - val_loss: 1.2453 - val_sparse_categorical_accuracy: 0.8797
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9991
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0030 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.7269 - val_sparse_categorical_accuracy: 0.9131
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 64 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.88%
# Training loss: 0.0026
# Test accuracy: 99.08%
# Test loss: 0.0300

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9871    0.9935    0.9903       154
#            2     1.0000    0.9935    0.9967       154
#            3     1.0000    1.0000    1.0000       153
#            4     1.0000    0.9286    0.9630       154
#            5     0.9329    0.9935    0.9623       154
#            6     0.9925    1.0000    0.9963       133
#            7     1.0000    0.9929    0.9964       141
#            8     1.0000    0.9932    0.9966       146
#            9     0.9935    1.0000    0.9967       153
#           10     1.0000    0.9935    0.9967       154
#           11     1.0000    1.0000    1.0000       154
#           12     0.9608    1.0000    0.9800        49
#
#     accuracy                         0.9908      1839
#    macro avg     0.9898    0.9914    0.9904      1839
# weighted avg     0.9912    0.9908    0.9908      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 2
# - CNN 2, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x += pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_2 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_2             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,269,133 (4.84 MB)
#  Trainable params: 1,268,365 (4.84 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.1751 - sparse_categorical_accuracy: 0.6345
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.71241, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 1.1680 - sparse_categorical_accuracy: 0.6367 - val_loss: 1.5771 - val_sparse_categorical_accuracy: 0.7124
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9768
# Epoch 2: val_sparse_categorical_accuracy improved from 0.71241 to 0.86605, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0900 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.3621 - val_sparse_categorical_accuracy: 0.8660
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9791
# Epoch 3: val_sparse_categorical_accuracy improved from 0.86605 to 0.89229, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.7075 - val_sparse_categorical_accuracy: 0.8923
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9866
# Epoch 4: val_sparse_categorical_accuracy improved from 0.89229 to 0.92400, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.4165 - val_sparse_categorical_accuracy: 0.9240
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9958
# Epoch 5: val_sparse_categorical_accuracy improved from 0.92400 to 0.94642, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.9464
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9919
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.94642
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9919 - val_loss: 1.8200 - val_sparse_categorical_accuracy: 0.8168
# Epoch 7/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0740 - sparse_categorical_accuracy: 0.9820
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.94642
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0735 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.8050 - val_sparse_categorical_accuracy: 0.9426
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9894
# Epoch 8: val_sparse_categorical_accuracy improved from 0.94642 to 0.97212, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0390 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.1122 - val_sparse_categorical_accuracy: 0.9721
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9966
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.1753 - val_sparse_categorical_accuracy: 0.9459
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9978
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0078 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.2072 - val_sparse_categorical_accuracy: 0.9464
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9721
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.1338 - sparse_categorical_accuracy: 0.9722 - val_loss: 1.3916 - val_sparse_categorical_accuracy: 0.8737
# Epoch 12/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9939
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.7478 - val_sparse_categorical_accuracy: 0.8994
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0097 - sparse_categorical_accuracy: 0.9973
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.7665 - val_sparse_categorical_accuracy: 0.9300
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9880
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0690 - sparse_categorical_accuracy: 0.9880 - val_loss: 1.5231 - val_sparse_categorical_accuracy: 0.8923
# Epoch 15/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9972
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0112 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.3713 - val_sparse_categorical_accuracy: 0.9524
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9962
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0128 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.5015 - val_sparse_categorical_accuracy: 0.8699
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9984
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.2751 - val_sparse_categorical_accuracy: 0.9497
# Epoch 18/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9988
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0025 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.3204 - val_sparse_categorical_accuracy: 0.9071
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9887
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0730 - sparse_categorical_accuracy: 0.9888 - val_loss: 1.0930 - val_sparse_categorical_accuracy: 0.8617
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9968
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.2038 - val_sparse_categorical_accuracy: 0.9721
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9893
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0523 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.7099 - val_sparse_categorical_accuracy: 0.9196
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0599 - sparse_categorical_accuracy: 0.9869
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.4682 - val_sparse_categorical_accuracy: 0.9535
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9927
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0341 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.4897 - val_sparse_categorical_accuracy: 0.9535
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9930
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.97212
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0243 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.3852 - val_sparse_categorical_accuracy: 0.9574
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9986
# Epoch 25: val_sparse_categorical_accuracy improved from 0.97212 to 0.97266, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1673 - val_sparse_categorical_accuracy: 0.9727
# Epoch 26/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0126 - sparse_categorical_accuracy: 0.9978
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.97266
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.4399 - val_sparse_categorical_accuracy: 0.9541
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9993
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.97266
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9634
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9993
# Epoch 28: val_sparse_categorical_accuracy improved from 0.97266 to 0.98086, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.1158 - val_sparse_categorical_accuracy: 0.9809
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 9.9349e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 29: val_sparse_categorical_accuracy improved from 0.98086 to 0.98141, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 9.9274e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.1123 - val_sparse_categorical_accuracy: 0.9814
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9978
# Epoch 30: val_sparse_categorical_accuracy improved from 0.98141 to 0.98633, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0784 - val_sparse_categorical_accuracy: 0.9863
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0735 - sparse_categorical_accuracy: 0.9851
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.98633
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.1630 - val_sparse_categorical_accuracy: 0.9748
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9982
# Epoch 32: val_sparse_categorical_accuracy improved from 0.98633 to 0.98797, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0129 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9880
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9988
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.98797
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.1007 - val_sparse_categorical_accuracy: 0.9841
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 9.7728e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.98797
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 9.8560e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9874
# Epoch 35/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9993
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.98797
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0013 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9863
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.2920e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.98797
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 3.2971e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0901 - val_sparse_categorical_accuracy: 0.9880
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9991
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.98797
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0014 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9863
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9993
# Epoch 38: val_sparse_categorical_accuracy improved from 0.98797 to 0.99071, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9993 - val_loss: 0.0622 - val_sparse_categorical_accuracy: 0.9907
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9992
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.99071
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0021 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0670 - val_sparse_categorical_accuracy: 0.9891
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9995
# Epoch 40: val_sparse_categorical_accuracy improved from 0.99071 to 0.99180, saving model to UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0529 - val_sparse_categorical_accuracy: 0.9918
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9979
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0731 - val_sparse_categorical_accuracy: 0.9874
# Epoch 42/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9964
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0614 - val_sparse_categorical_accuracy: 0.9885
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9861
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 0.9508
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9951
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.1140 - val_sparse_categorical_accuracy: 0.9814
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9986
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0069 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1423 - val_sparse_categorical_accuracy: 0.9759
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9983
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9907
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9972
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0488 - val_sparse_categorical_accuracy: 0.9913
# Epoch 48/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0082 - sparse_categorical_accuracy: 0.9983
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9983 - val_loss: 2.0131 - val_sparse_categorical_accuracy: 0.8382
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9962
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.3130 - val_sparse_categorical_accuracy: 0.8797
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9982
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0045 - sparse_categorical_accuracy: 0.9982 - val_loss: 1.3176 - val_sparse_categorical_accuracy: 0.8824
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 1.5513 - val_sparse_categorical_accuracy: 0.8917
# Epoch 52/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9994
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.9194 - val_sparse_categorical_accuracy: 0.8650
# Epoch 53/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9991
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0032 - sparse_categorical_accuracy: 0.9991 - val_loss: 1.7215 - val_sparse_categorical_accuracy: 0.8704
# Epoch 54/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9991
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9990 - val_loss: 2.2334 - val_sparse_categorical_accuracy: 0.8163
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9786
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9786 - val_loss: 1.6960 - val_sparse_categorical_accuracy: 0.7693
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9920
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0314 - sparse_categorical_accuracy: 0.9920 - val_loss: 1.7583 - val_sparse_categorical_accuracy: 0.8660
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9955
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9955 - val_loss: 0.6350 - val_sparse_categorical_accuracy: 0.9136
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9994
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9994 - val_loss: 1.0358 - val_sparse_categorical_accuracy: 0.8978
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9967
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.6365 - val_sparse_categorical_accuracy: 0.9103
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9991
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.99180
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.5809 - val_sparse_categorical_accuracy: 0.9289
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 40.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best2.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 70 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.91%
# Training loss: 0.0038
# Test accuracy: 99.40%
# Test loss: 0.0324

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9870    0.9870    0.9870       154
#            2     1.0000    1.0000    1.0000       154
#            3     1.0000    1.0000    1.0000       153
#            4     1.0000    0.9935    0.9967       154
#            5     1.0000    0.9675    0.9835       154
#            6     0.9852    1.0000    0.9925       133
#            7     1.0000    0.9858    0.9929       141
#            8     0.9667    0.9932    0.9797       146
#            9     0.9935    1.0000    0.9967       153
#           10     1.0000    1.0000    1.0000       154
#           11     1.0000    1.0000    1.0000       154
#           12     0.9800    1.0000    0.9899        49
#
#     accuracy                         0.9940      1839
#    macro avg     0.9933    0.9944    0.9938      1839
# weighted avg     0.9941    0.9940    0.9940      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 3
# - CNN 3, GRU 2, Transformer 1

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x += pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_8 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_9 (ReLU)                  │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_10 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_10 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_4 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_4             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_4      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,318,925 (5.03 MB)
#  Trainable params: 1,317,901 (5.03 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.0394 - sparse_categorical_accuracy: 0.6750
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.78568, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - loss: 1.0330 - sparse_categorical_accuracy: 0.6770 - val_loss: 0.6471 - val_sparse_categorical_accuracy: 0.7857
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0644 - sparse_categorical_accuracy: 0.9827
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.78568
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - loss: 0.0646 - sparse_categorical_accuracy: 0.9827 - val_loss: 1.2912 - val_sparse_categorical_accuracy: 0.7146
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0595 - sparse_categorical_accuracy: 0.9847
# Epoch 3: val_sparse_categorical_accuracy improved from 0.78568 to 0.82504, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.8152 - val_sparse_categorical_accuracy: 0.8250
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0232 - sparse_categorical_accuracy: 0.9935
# Epoch 4: val_sparse_categorical_accuracy improved from 0.82504 to 0.86714, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.8040 - val_sparse_categorical_accuracy: 0.8671
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9861
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.86714
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9862 - val_loss: 2.2621 - val_sparse_categorical_accuracy: 0.8332
# Epoch 6/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9861
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.86714
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9862 - val_loss: 1.7886 - val_sparse_categorical_accuracy: 0.8321
# Epoch 7/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9930
# Epoch 7: val_sparse_categorical_accuracy improved from 0.86714 to 0.90049, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.2986 - val_sparse_categorical_accuracy: 0.9005
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9914
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9914 - val_loss: 3.3465 - val_sparse_categorical_accuracy: 0.6736
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9896
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9896 - val_loss: 1.2774 - val_sparse_categorical_accuracy: 0.8518
# Epoch 10/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9937
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0212 - sparse_categorical_accuracy: 0.9937 - val_loss: 1.7849 - val_sparse_categorical_accuracy: 0.8425
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1662 - sparse_categorical_accuracy: 0.9676
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.1652 - sparse_categorical_accuracy: 0.9678 - val_loss: 1.7211 - val_sparse_categorical_accuracy: 0.8168
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9914
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0388 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.9743 - val_sparse_categorical_accuracy: 0.8781
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9815
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.90049
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.1007 - sparse_categorical_accuracy: 0.9816 - val_loss: 1.4900 - val_sparse_categorical_accuracy: 0.8420
# Epoch 14/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9861
# Epoch 14: val_sparse_categorical_accuracy improved from 0.90049 to 0.90541, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9863 - val_loss: 1.2157 - val_sparse_categorical_accuracy: 0.9054
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0266 - sparse_categorical_accuracy: 0.9941
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.90541
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9941 - val_loss: 1.6212 - val_sparse_categorical_accuracy: 0.8639
# Epoch 16/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0121 - sparse_categorical_accuracy: 0.9965
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.90541
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0122 - sparse_categorical_accuracy: 0.9964 - val_loss: 1.6105 - val_sparse_categorical_accuracy: 0.8830
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9976
# Epoch 17: val_sparse_categorical_accuracy improved from 0.90541 to 0.90760, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.9316 - val_sparse_categorical_accuracy: 0.9076
# Epoch 18/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9975
# Epoch 18: val_sparse_categorical_accuracy improved from 0.90760 to 0.90815, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9976 - val_loss: 1.2108 - val_sparse_categorical_accuracy: 0.9081
# Epoch 19/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9987
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.90815
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9987 - val_loss: 1.4452 - val_sparse_categorical_accuracy: 0.9060
# Epoch 20/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9971
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.90815
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9971 - val_loss: 1.5105 - val_sparse_categorical_accuracy: 0.8841
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9956
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.90815
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9956 - val_loss: 1.6835 - val_sparse_categorical_accuracy: 0.8491
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984
# Epoch 22: val_sparse_categorical_accuracy improved from 0.90815 to 0.90869, saving model to UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984 - val_loss: 1.0780 - val_sparse_categorical_accuracy: 0.9087
# Epoch 23/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9980
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0063 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.8766 - val_sparse_categorical_accuracy: 0.9021
# Epoch 24/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9992
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9992 - val_loss: 1.1448 - val_sparse_categorical_accuracy: 0.9054
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7.2101e-04 - sparse_categorical_accuracy: 0.9999
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 7.2260e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.2759 - val_sparse_categorical_accuracy: 0.9087
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9999
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.0012 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.3617 - val_sparse_categorical_accuracy: 0.9081
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.5820e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 4.5755e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.4683 - val_sparse_categorical_accuracy: 0.9076
# Epoch 28/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.1794e-04 - sparse_categorical_accuracy: 0.9995
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 8.1194e-04 - sparse_categorical_accuracy: 0.9995 - val_loss: 1.5145 - val_sparse_categorical_accuracy: 0.9076
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 6.0349e-04 - sparse_categorical_accuracy: 0.9999
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 6.0483e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 1.4510 - val_sparse_categorical_accuracy: 0.9054
# Epoch 30/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.7959e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 3.7881e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.6088 - val_sparse_categorical_accuracy: 0.9071
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.1672e-04 - sparse_categorical_accuracy: 0.9997
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 4.1831e-04 - sparse_categorical_accuracy: 0.9997 - val_loss: 1.7127 - val_sparse_categorical_accuracy: 0.9060
# Epoch 32/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3.3724e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 3.4125e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.8918 - val_sparse_categorical_accuracy: 0.9054
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.2469e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 6.2211e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9337 - val_sparse_categorical_accuracy: 0.9060
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 9.4066e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 9.4183e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9377 - val_sparse_categorical_accuracy: 0.9060
# Epoch 35/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.1515e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 1.1507e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9696 - val_sparse_categorical_accuracy: 0.9054
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 8.4707e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 8.5273e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9652 - val_sparse_categorical_accuracy: 0.9054
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0496e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 2.0420e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9633 - val_sparse_categorical_accuracy: 0.9049
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.1527e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 1.1516e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9584 - val_sparse_categorical_accuracy: 0.9049
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7.3655e-05 - sparse_categorical_accuracy: 1.0000
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 7.3901e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9517 - val_sparse_categorical_accuracy: 0.9049
# Epoch 40/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3068e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 1.3010e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9642 - val_sparse_categorical_accuracy: 0.9049
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.0424e-04 - sparse_categorical_accuracy: 1.0000
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 1.0411e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 1.9761 - val_sparse_categorical_accuracy: 0.9049
# Epoch 42/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9985
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.90869
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0108 - sparse_categorical_accuracy: 0.9982 - val_loss: 4.2639 - val_sparse_categorical_accuracy: 0.4204
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best3.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 78 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 99.96%
# Training loss: 0.0007
# Test accuracy: 92.06%
# Test loss: 0.6594

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000       140
#            1     0.9935    1.0000    0.9968       154
#            2     1.0000    0.5000    0.6667       154
#            3     1.0000    1.0000    1.0000       153
#            4     1.0000    1.0000    1.0000       154
#            5     1.0000    0.9935    0.9967       154
#            6     0.7074    1.0000    0.8287       133
#            7     1.0000    0.9078    0.9517       141
#            8     1.0000    0.6233    0.7679       146
#            9     0.6296    1.0000    0.7727       153
#           10     1.0000    1.0000    1.0000       154
#           11     1.0000    1.0000    1.0000       154
#           12     1.0000    1.0000    1.0000        49
#
#     accuracy                         0.9206      1839
#    macro avg     0.9485    0.9250    0.9216      1839
# weighted avg     0.9475    0.9206    0.9181      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model 4
# - CNN 3, GRU 2, Transformer 2

# %%
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, features)
num_classes = 13

def build_model(input_shape, num_classes=6):
    inputs = Input(shape=input_shape)

    # CNN 특징 추출 레이어
    x = Conv1D(128, 5, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(128, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPool1D(2)(x)

    x = Conv1D(256, 3, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = GRU(256, return_sequences=True)(x)
    x = GRU(256, return_sequences=True)(x)

    pos_enc = positional_encoding(x.shape[1], x.shape[2])
    x += pos_enc

    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)
    x = TransformerBlock(embed_dim=256, num_heads=8, ff_dim=128)(x)

    x = GlobalAveragePooling1D()(x)

    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy']
    )
    return model

model = build_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 200, 23)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 200, 128)       │        14,848 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_14 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 200, 128)       │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 200, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_15 (ReLU)                 │ (None, 200, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 100, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_16 (Conv1D)              │ (None, 100, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 100, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_16 (ReLU)                 │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_10 (GRU)                    │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 100, 256)       │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add_6 (Add)                     │ (None, 100, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_6             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transformer_block_7             │ (None, 100, 256)       │       330,112 │
# │ (TransformerBlock)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_6      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,649,037 (6.29 MB)
#  Trainable params: 1,648,013 (6.29 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5",
                save_best_only=True,
                save_weights_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=20,
                verbose=1,
                mode='max',
                restore_best_weights=True
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_data=(X_val, y_val),
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.1645 - sparse_categorical_accuracy: 0.6223
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.77966, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - loss: 1.1512 - sparse_categorical_accuracy: 0.6266 - val_loss: 1.2050 - val_sparse_categorical_accuracy: 0.7797
# Epoch 2/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1022 - sparse_categorical_accuracy: 0.9722
# Epoch 2: val_sparse_categorical_accuracy improved from 0.77966 to 0.78568, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 0.1022 - sparse_categorical_accuracy: 0.9722 - val_loss: 1.1558 - val_sparse_categorical_accuracy: 0.7857
# Epoch 3/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0886 - sparse_categorical_accuracy: 0.9802
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.78568
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9803 - val_loss: 1.2457 - val_sparse_categorical_accuracy: 0.7780
# Epoch 4/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9945
# Epoch 4: val_sparse_categorical_accuracy improved from 0.78568 to 0.79005, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9945 - val_loss: 1.8603 - val_sparse_categorical_accuracy: 0.7900
# Epoch 5/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9820
# Epoch 5: val_sparse_categorical_accuracy improved from 0.79005 to 0.82176, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9821 - val_loss: 1.6000 - val_sparse_categorical_accuracy: 0.8218
# Epoch 6/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0193 - sparse_categorical_accuracy: 0.9957
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.82176
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9957 - val_loss: 1.6686 - val_sparse_categorical_accuracy: 0.7829
# Epoch 7/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9944
# Epoch 7: val_sparse_categorical_accuracy improved from 0.82176 to 0.92291, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.5798 - val_sparse_categorical_accuracy: 0.9229
# Epoch 8/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9934
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.8679 - val_sparse_categorical_accuracy: 0.8622
# Epoch 9/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9915
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.4423 - val_sparse_categorical_accuracy: 0.8896
# Epoch 10/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9940
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9940 - val_loss: 1.5568 - val_sparse_categorical_accuracy: 0.7977
# Epoch 11/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9793
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9792 - val_loss: 3.0507 - val_sparse_categorical_accuracy: 0.6736
# Epoch 12/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1842 - sparse_categorical_accuracy: 0.9540
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.1830 - sparse_categorical_accuracy: 0.9543 - val_loss: 1.0506 - val_sparse_categorical_accuracy: 0.8387
# Epoch 13/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9940
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.6910 - val_sparse_categorical_accuracy: 0.9005
# Epoch 14/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1103 - sparse_categorical_accuracy: 0.9668
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.1109 - sparse_categorical_accuracy: 0.9665 - val_loss: 2.1208 - val_sparse_categorical_accuracy: 0.8256
# Epoch 15/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9918
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9918 - val_loss: 2.6313 - val_sparse_categorical_accuracy: 0.7715
# Epoch 16/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0636 - sparse_categorical_accuracy: 0.9855
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9856 - val_loss: 1.8615 - val_sparse_categorical_accuracy: 0.8212
# Epoch 17/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0177 - sparse_categorical_accuracy: 0.9951
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9951 - val_loss: 1.9816 - val_sparse_categorical_accuracy: 0.8693
# Epoch 18/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0398 - sparse_categorical_accuracy: 0.9878
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.2897 - val_sparse_categorical_accuracy: 0.9191
# Epoch 19/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0665 - sparse_categorical_accuracy: 0.9908
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.92291
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.7172 - val_sparse_categorical_accuracy: 0.8945
# Epoch 20/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9968
# Epoch 20: val_sparse_categorical_accuracy improved from 0.92291 to 0.93767, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - loss: 0.0135 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.2761 - val_sparse_categorical_accuracy: 0.9377
# Epoch 21/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9991
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.93767
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9991 - val_loss: 1.6321 - val_sparse_categorical_accuracy: 0.8360
# Epoch 22/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0178 - sparse_categorical_accuracy: 0.9945
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.93767
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0177 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.8534 - val_sparse_categorical_accuracy: 0.9060
# Epoch 23/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0103 - sparse_categorical_accuracy: 0.9970
# Epoch 23: val_sparse_categorical_accuracy improved from 0.93767 to 0.94587, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0106 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.4293 - val_sparse_categorical_accuracy: 0.9459
# Epoch 24/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9946
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9946 - val_loss: 1.2755 - val_sparse_categorical_accuracy: 0.8907
# Epoch 25/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9963
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0144 - sparse_categorical_accuracy: 0.9963 - val_loss: 1.1288 - val_sparse_categorical_accuracy: 0.8939
# Epoch 26/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0091 - sparse_categorical_accuracy: 0.9969
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9969 - val_loss: 1.7829 - val_sparse_categorical_accuracy: 0.8568
# Epoch 27/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0142 - sparse_categorical_accuracy: 0.9966
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9967 - val_loss: 1.2235 - val_sparse_categorical_accuracy: 0.8939
# Epoch 28/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9980
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9980 - val_loss: 1.5788 - val_sparse_categorical_accuracy: 0.8907
# Epoch 29/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9994
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0023 - sparse_categorical_accuracy: 0.9993 - val_loss: 2.1954 - val_sparse_categorical_accuracy: 0.8513
# Epoch 30/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9994
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.0024 - sparse_categorical_accuracy: 0.9994 - val_loss: 2.5639 - val_sparse_categorical_accuracy: 0.8480
# Epoch 31/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0157 - sparse_categorical_accuracy: 0.9972
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9970 - val_loss: 1.8482 - val_sparse_categorical_accuracy: 0.8393
# Epoch 32/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3112 - sparse_categorical_accuracy: 0.9391
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.9395 - val_loss: 0.4295 - val_sparse_categorical_accuracy: 0.9049
# Epoch 33/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0762 - sparse_categorical_accuracy: 0.9842
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.94587
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.5965 - val_sparse_categorical_accuracy: 0.7900
# Epoch 34/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0720 - sparse_categorical_accuracy: 0.9878
# Epoch 34: val_sparse_categorical_accuracy improved from 0.94587 to 0.94915, saving model to UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.3385 - val_sparse_categorical_accuracy: 0.9492
# Epoch 35/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0396 - sparse_categorical_accuracy: 0.9934
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9934 - val_loss: 0.8588 - val_sparse_categorical_accuracy: 0.9218
# Epoch 36/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9947
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0205 - sparse_categorical_accuracy: 0.9947 - val_loss: 1.1390 - val_sparse_categorical_accuracy: 0.9027
# Epoch 37/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1363 - sparse_categorical_accuracy: 0.9553
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1365 - sparse_categorical_accuracy: 0.9552 - val_loss: 2.2770 - val_sparse_categorical_accuracy: 0.7840
# Epoch 38/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.2037 - sparse_categorical_accuracy: 0.9068
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.2032 - sparse_categorical_accuracy: 0.9072 - val_loss: 1.5018 - val_sparse_categorical_accuracy: 0.8726
# Epoch 39/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1128 - sparse_categorical_accuracy: 0.9597
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9598 - val_loss: 1.1438 - val_sparse_categorical_accuracy: 0.9016
# Epoch 40/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0750 - sparse_categorical_accuracy: 0.9730
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9729 - val_loss: 1.2053 - val_sparse_categorical_accuracy: 0.9076
# Epoch 41/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0836 - sparse_categorical_accuracy: 0.9651
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0839 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.8951 - val_sparse_categorical_accuracy: 0.9191
# Epoch 42/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.1256 - sparse_categorical_accuracy: 0.9625
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.1251 - sparse_categorical_accuracy: 0.9626 - val_loss: 1.4140 - val_sparse_categorical_accuracy: 0.8759
# Epoch 43/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9699
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.4781 - val_sparse_categorical_accuracy: 0.9360
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9669
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 0.0845 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.7921 - val_sparse_categorical_accuracy: 0.9202
# Epoch 45/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9715
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3479 - val_sparse_categorical_accuracy: 0.9360
# Epoch 46/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0585 - sparse_categorical_accuracy: 0.9753
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.2359 - val_sparse_categorical_accuracy: 0.9388
# Epoch 47/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0263 - sparse_categorical_accuracy: 0.9902
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0261 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.7723 - val_sparse_categorical_accuracy: 0.8978
# Epoch 48/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0810 - sparse_categorical_accuracy: 0.9824
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9826 - val_loss: 1.2567 - val_sparse_categorical_accuracy: 0.9016
# Epoch 49/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9972
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.9668 - val_sparse_categorical_accuracy: 0.8999
# Epoch 50/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9966
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.5217 - val_sparse_categorical_accuracy: 0.8814
# Epoch 51/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9917
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 0.0309 - sparse_categorical_accuracy: 0.9917 - val_loss: 1.7210 - val_sparse_categorical_accuracy: 0.8469
# Epoch 52/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0207 - sparse_categorical_accuracy: 0.9957
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9957 - val_loss: 1.1880 - val_sparse_categorical_accuracy: 0.8704
# Epoch 53/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9952
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9952 - val_loss: 1.0272 - val_sparse_categorical_accuracy: 0.9021
# Epoch 54/100
# 88/89 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9890
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.94915
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0719 - sparse_categorical_accuracy: 0.9887 - val_loss: 1.7959 - val_sparse_categorical_accuracy: 0.7534
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 34.

# %%
# 모델 평가
model = build_model(input_shape, num_classes)
model.load_weights("UCI_mHealth_CNN_GRU_Transformer_best4.weights.h5")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 110 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training accuracy: 98.92%
# Training loss: 0.0327
# Test accuracy: 97.39%
# Test loss: 0.1322

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.8429    0.9147       140
#            1     0.8844    0.9935    0.9358       154
#            2     1.0000    0.9610    0.9801       154
#            3     0.9935    1.0000    0.9967       153
#            4     1.0000    0.9610    0.9801       154
#            5     0.9563    0.9935    0.9745       154
#            6     0.9500    1.0000    0.9744       133
#            7     0.9586    0.9858    0.9720       141
#            8     0.9726    0.9726    0.9726       146
#            9     0.9935    1.0000    0.9967       153
#           10     0.9935    0.9935    0.9935       154
#           11     1.0000    0.9935    0.9967       154
#           12     0.9783    0.9184    0.9474        49
#
#     accuracy                         0.9739      1839
#    macro avg     0.9754    0.9704    0.9720      1839
# weighted avg     0.9755    0.9739    0.9737      1839

# %%
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
